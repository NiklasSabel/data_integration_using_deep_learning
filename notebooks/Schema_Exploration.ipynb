# %%
import pandas as pd
import numpy as np
import json

# %%
properties = pd.read_csv('schemaorg-current-https-properties.csv')
types = pd.read_csv('schemaorg-current-https-types.csv')

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1442 entries, 0 to 1441
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  1442 non-null   object
#  1   label               1442 non-null   object
#  2   comment             1442 non-null   object
#  3   subPropertyOf       146 non-null    object
#  4   equivalentProperty  26 non-null     object
#  5   subproperties       46 non-null     object
#  6   domainIncludes      1441 non-null   object
#  7   rangeIncludes       1441 non-null   object
#  8   inverseOf           50 non-null     object
#  9   supersedes          66 non-null     object
#  10  supersededBy        67 non-null     object
#  11  isPartOf            0 non-null      float64
# dtypes: float64(1), object(11)
# memory usage: 135.3+ KB

# %%
types.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1329 entries, 0 to 1328
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1329 non-null   object
#  1   label            1329 non-null   object
#  2   comment          1329 non-null   object
#  3   subTypeOf        1320 non-null   object
#  4   enumerationtype  441 non-null    object
#  5   equivalentClass  18 non-null     object
#  6   properties       801 non-null    object
#  7   subTypes         176 non-null    object
#  8   supersedes       12 non-null     object
#  9   supersededBy     15 non-null     object
#  10  isPartOf         0 non-null      float64
# dtypes: float64(1), object(10)
# memory usage: 114.3+ KB

# %%
display(properties)
# Out:
#                                        id             label  \
# 0                https://schema.org/about             about
# 1             https://schema.org/abridged          abridged
# 2             https://schema.org/abstract          abstract
# 3     https://schema.org/accelerationTime  accelerationTime
# 4       https://schema.org/acceptedAnswer    acceptedAnswer
# ...                                   ...               ...
# 1437             https://schema.org/xpath             xpath
# 1438         https://schema.org/yearBuilt         yearBuilt
# 1439     https://schema.org/yearlyRevenue     yearlyRevenue
# 1440  https://schema.org/yearsInOperation  yearsInOperation
# 1441             https://schema.org/yield             yield
#
#                                                 comment  \
# 0                    The subject matter of the content.
# 1     Indicates whether the book is an abridged edit...
# 2     An abstract is a short description that summar...
# 3     The time needed to accelerate the vehicle from...
# 4     The answer(s) that has been accepted as best, ...
# ...                                                 ...
# 1437  An XPath, e.g. of a <a class="localLink" href=...
# 1438  The year an <a class="localLink" href="/Accomm...
# 1439        The size of the business in annual revenue.
# 1440                           The age of the business.
# 1441  The quantity that results by performing instru...
#
#                            subPropertyOf equivalentProperty  \
# 0                                    NaN                NaN
# 1                                    NaN                NaN
# 2                                    NaN                NaN
# 3                                    NaN                NaN
# 4     https://schema.org/suggestedAnswer                NaN
# ...                                  ...                ...
# 1437                                 NaN                NaN
# 1438                                 NaN                NaN
# 1439                                 NaN                NaN
# 1440                                 NaN                NaN
# 1441                                 NaN                NaN
#
#                        subproperties  \
# 0      https://schema.org/mainEntity
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 1437                             NaN
# 1438                             NaN
# 1439                             NaN
# 1440                             NaN
# 1441  https://schema.org/recipeYield
#
#                                          domainIncludes  \
# 0     https://schema.org/CommunicateAction, https://...
# 1                               https://schema.org/Book
# 2                       https://schema.org/CreativeWork
# 3                            https://schema.org/Vehicle
# 4                           https://schema.org/Question
# ...                                                 ...
# 1437  https://schema.org/SpeakableSpecification, htt...
# 1438                   https://schema.org/Accommodation
# 1439                https://schema.org/BusinessAudience
# 1440                https://schema.org/BusinessAudience
# 1441                           https://schema.org/HowTo
#
#                                           rangeIncludes  \
# 0                              https://schema.org/Thing
# 1                            https://schema.org/Boolean
# 2                               https://schema.org/Text
# 3                  https://schema.org/QuantitativeValue
# 4     https://schema.org/Answer, https://schema.org/...
# ...                                                 ...
# 1437                       https://schema.org/XPathType
# 1438                          https://schema.org/Number
# 1439               https://schema.org/QuantitativeValue
# 1440               https://schema.org/QuantitativeValue
# 1441  https://schema.org/QuantitativeValue, https://...
#
#                          inverseOf supersedes supersededBy  isPartOf
# 0     https://schema.org/subjectOf        NaN          NaN       NaN
# 1                              NaN        NaN          NaN       NaN
# 2                              NaN        NaN          NaN       NaN
# 3                              NaN        NaN          NaN       NaN
# 4                              NaN        NaN          NaN       NaN
# ...                            ...        ...          ...       ...
# 1437                           NaN        NaN          NaN       NaN
# 1438                           NaN        NaN          NaN       NaN
# 1439                           NaN        NaN          NaN       NaN
# 1440                           NaN        NaN          NaN       NaN
# 1441                           NaN        NaN          NaN       NaN
#
# [1442 rows x 12 columns]

# %%
display(properties[properties["equivalentProperty"].notnull()])
# Out:
#                                               id                    label  \
# 372               https://schema.org/description              description
# 634                https://schema.org/identifier               identifier
# 706                      https://schema.org/isbn                     isbn
# 709                      https://schema.org/issn                     issn
# 710               https://schema.org/issueNumber              issueNumber
# 749        https://schema.org/legislationApplies       legislationApplies
# 750        https://schema.org/legislationChanges       legislationChanges
# 751   https://schema.org/legislationConsolidates  legislationConsolidates
# 752           https://schema.org/legislationDate          legislationDate
# 753    https://schema.org/legislationDateVersion   legislationDateVersion
# 755   https://schema.org/legislationJurisdiction  legislationJurisdiction
# 756     https://schema.org/legislationLegalForce    legislationLegalForce
# 757     https://schema.org/legislationLegalValue    legislationLegalValue
# 758       https://schema.org/legislationPassedBy      legislationPassedBy
# 759    https://schema.org/legislationResponsible   legislationResponsible
# 760     https://schema.org/legislationTransposes    legislationTransposes
# 761           https://schema.org/legislationType          legislationType
# 856                      https://schema.org/name                     name
# 934                   https://schema.org/pageEnd                  pageEnd
# 935                 https://schema.org/pageStart                pageStart
# 936                https://schema.org/pagination               pagination
# 1086              https://schema.org/recordLabel              recordLabel
# 1236                  https://schema.org/spatial                  spatial
# 1237          https://schema.org/spatialCoverage          spatialCoverage
# 1310         https://schema.org/temporalCoverage         temporalCoverage
# 1414             https://schema.org/volumeNumber             volumeNumber
#
#                                                 comment  \
# 372                          A description of the item.
# 634   The identifier property represents any kind of...
# 706                               The ISBN of the book.
# 709   The International Standard Serial Number (ISSN...
# 710   Identifies the issue of publication; for examp...
# 749   Indicates that this legislation (or part of a ...
# 750   Another legislation that this legislation chan...
# 751   Indicates another legislation taken into accou...
# 752   The date of adoption or signature of the legis...
# 753   The point-in-time at which the provided descri...
# 755   The jurisdiction from which the legislation or...
# 756   Whether the legislation is currently in force,...
# 757   The legal value of this legislation file. The ...
# 758   The person or organization that originally pas...
# 759   An individual or organization that has some ki...
# 760   Indicates that this legislation (or part of le...
# 761   The type of the legislation. Examples of value...
# 856                               The name of the item.
# 934   The page on which the work ends; for example "...
# 935   The page on which the work starts; for example...
# 936   Any description of pages that is not separated...
# 1086                 The label that issued the release.
# 1236  The "spatial" property can be used in cases wh...
# 1237  The spatialCoverage of a CreativeWork indicate...
# 1310  The temporalCoverage of a CreativeWork indicat...
# 1414  Identifies the volume of publication or multi-...
#
#                                           subPropertyOf  \
# 372                                                 NaN
# 634                                                 NaN
# 706                       https://schema.org/identifier
# 709                       https://schema.org/identifier
# 710                         https://schema.org/position
# 749                                                 NaN
# 750                                                 NaN
# 751                                                 NaN
# 752                      https://schema.org/dateCreated
# 753                                                 NaN
# 755   https://schema.org/jurisdiction, https://schem...
# 756                                                 NaN
# 757                                                 NaN
# 758                          https://schema.org/creator
# 759                                                 NaN
# 760               https://schema.org/legislationApplies
# 761                            https://schema.org/genre
# 856   https://schema.org/http://www.w3.org/2000/01/r...
# 934                                                 NaN
# 935                                                 NaN
# 936                                                 NaN
# 1086                                                NaN
# 1236                                                NaN
# 1237                 https://schema.org/contentLocation
# 1310                                                NaN
# 1414                        https://schema.org/position
#
#                                      equivalentProperty  \
# 372                http://purl.org/dc/terms/description
# 634                 http://purl.org/dc/terms/identifier
# 706                  http://purl.org/ontology/bibo/isbn
# 709                  http://purl.org/ontology/bibo/issn
# 710                 http://purl.org/ontology/bibo/issue
# 749       http://data.europa.eu/eli/ontology#implements
# 750          http://data.europa.eu/eli/ontology#changes
# 751     http://data.europa.eu/eli/ontology#consolidates
# 752    http://data.europa.eu/eli/ontology#date_document
# 753     http://data.europa.eu/eli/ontology#version_date
# 755     http://data.europa.eu/eli/ontology#jurisdiction
# 756         http://data.europa.eu/eli/ontology#in_force
# 757      http://data.europa.eu/eli/ontology#legal_value
# 758        http://data.europa.eu/eli/ontology#passed_by
# 759   http://data.europa.eu/eli/ontology#responsibil...
# 760       http://data.europa.eu/eli/ontology#transposes
# 761    http://data.europa.eu/eli/ontology#type_document
# 856                      http://purl.org/dc/terms/title
# 934               http://purl.org/ontology/bibo/pageEnd
# 935             http://purl.org/ontology/bibo/pageStart
# 936                 http://purl.org/ontology/bibo/pages
# 1086                  http://purl.org/ontology/mo/label
# 1236                   http://purl.org/dc/terms/spatial
# 1237                   http://purl.org/dc/terms/spatial
# 1310                  http://purl.org/dc/terms/temporal
# 1414               http://purl.org/ontology/bibo/volume
#
#                                           subproperties  \
# 372   https://schema.org/disambiguatingDescription, ...
# 634   https://schema.org/accountId, https://schema.o...
# 706                                                 NaN
# 709                                                 NaN
# 710                                                 NaN
# 749            https://schema.org/legislationTransposes
# 750                                                 NaN
# 751                                                 NaN
# 752                                                 NaN
# 753                                                 NaN
# 755                                                 NaN
# 756                                                 NaN
# 757                                                 NaN
# 758                                                 NaN
# 759                                                 NaN
# 760                                                 NaN
# 761                                                 NaN
# 856                                                 NaN
# 934                                                 NaN
# 935                                                 NaN
# 936                                                 NaN
# 1086                                                NaN
# 1236                                                NaN
# 1237  https://schema.org/announcementLocation, https...
# 1310                                                NaN
# 1414                                                NaN
#
#                                          domainIncludes  \
# 372                            https://schema.org/Thing
# 634                            https://schema.org/Thing
# 706                             https://schema.org/Book
# 709   https://schema.org/Blog, https://schema.org/Cr...
# 710                 https://schema.org/PublicationIssue
# 749                      https://schema.org/Legislation
# 750                      https://schema.org/Legislation
# 751                      https://schema.org/Legislation
# 752                      https://schema.org/Legislation
# 753                      https://schema.org/Legislation
# 755                      https://schema.org/Legislation
# 756                      https://schema.org/Legislation
# 757                https://schema.org/LegislationObject
# 758                      https://schema.org/Legislation
# 759                      https://schema.org/Legislation
# 760                      https://schema.org/Legislation
# 761                      https://schema.org/Legislation
# 856                            https://schema.org/Thing
# 934   https://schema.org/Article, https://schema.org...
# 935   https://schema.org/Article, https://schema.org...
# 936   https://schema.org/Article, https://schema.org...
# 1086                    https://schema.org/MusicRelease
# 1236                    https://schema.org/CreativeWork
# 1237                    https://schema.org/CreativeWork
# 1310                    https://schema.org/CreativeWork
# 1414               https://schema.org/PublicationVolume
#
#                                           rangeIncludes inverseOf  \
# 372                             https://schema.org/Text       NaN
# 634   https://schema.org/PropertyValue, https://sche...       NaN
# 706                             https://schema.org/Text       NaN
# 709                             https://schema.org/Text       NaN
# 710   https://schema.org/Integer, https://schema.org...       NaN
# 749                      https://schema.org/Legislation       NaN
# 750                      https://schema.org/Legislation       NaN
# 751                      https://schema.org/Legislation       NaN
# 752                             https://schema.org/Date       NaN
# 753                             https://schema.org/Date       NaN
# 755   https://schema.org/AdministrativeArea, https:/...       NaN
# 756                 https://schema.org/LegalForceStatus       NaN
# 757                  https://schema.org/LegalValueLevel       NaN
# 758   https://schema.org/Organization, https://schem...       NaN
# 759   https://schema.org/Organization, https://schem...       NaN
# 760                      https://schema.org/Legislation       NaN
# 761   https://schema.org/CategoryCode, https://schem...       NaN
# 856                             https://schema.org/Text       NaN
# 934   https://schema.org/Integer, https://schema.org...       NaN
# 935   https://schema.org/Integer, https://schema.org...       NaN
# 936                             https://schema.org/Text       NaN
# 1086                    https://schema.org/Organization       NaN
# 1236                           https://schema.org/Place       NaN
# 1237                           https://schema.org/Place       NaN
# 1310  https://schema.org/DateTime, https://schema.or...       NaN
# 1414  https://schema.org/Integer, https://schema.org...       NaN
#
#                                   supersedes supersededBy  isPartOf
# 372                                      NaN          NaN       NaN
# 634                                      NaN          NaN       NaN
# 706                                      NaN          NaN       NaN
# 709                                      NaN          NaN       NaN
# 710                                      NaN          NaN       NaN
# 749                                      NaN          NaN       NaN
# 750                                      NaN          NaN       NaN
# 751                                      NaN          NaN       NaN
# 752                                      NaN          NaN       NaN
# 753                                      NaN          NaN       NaN
# 755                                      NaN          NaN       NaN
# 756                                      NaN          NaN       NaN
# 757                                      NaN          NaN       NaN
# 758                                      NaN          NaN       NaN
# 759                                      NaN          NaN       NaN
# 760                                      NaN          NaN       NaN
# 761                                      NaN          NaN       NaN
# 856                                      NaN          NaN       NaN
# 934                                      NaN          NaN       NaN
# 935                                      NaN          NaN       NaN
# 936                                      NaN          NaN       NaN
# 1086                                     NaN          NaN       NaN
# 1236                                     NaN          NaN       NaN
# 1237                                     NaN          NaN       NaN
# 1310  https://schema.org/datasetTimeInterval          NaN       NaN
# 1414                                     NaN          NaN       NaN

# %%
display(properties[properties["subPropertyOf"].notnull()])
# Out:
#                                             id                  label  \
# 4            https://schema.org/acceptedAnswer         acceptedAnswer
# 16    https://schema.org/accommodationCategory  accommodationCategory
# 18                https://schema.org/accountId              accountId
# 22       https://schema.org/acquireLicensePage     acquireLicensePage
# 27             https://schema.org/actionOption           actionOption
# ...                                        ...                    ...
# 1414           https://schema.org/volumeNumber           volumeNumber
# 1425                 https://schema.org/winner                 winner
# 1430           https://schema.org/workLocation           workLocation
# 1431          https://schema.org/workPerformed          workPerformed
# 1432          https://schema.org/workPresented          workPresented
#
#                                                 comment  \
# 4     The answer(s) that has been accepted as best, ...
# 16    Category of an <a class="localLink" href="/Acc...
# 18    The identifier for the account the payment wil...
# 22    Indicates a page documenting how licenses can ...
# 27    A sub property of object. The options subject ...
# ...                                                 ...
# 1414  Identifies the volume of publication or multi-...
# 1425  A sub property of participant. The winner of t...
# 1430   A contact location for a person's place of work.
# 1431  A work performed in some event, for example a ...
# 1432             The movie presented during this event.
#
#                            subPropertyOf  \
# 4     https://schema.org/suggestedAnswer
# 16           https://schema.org/category
# 18         https://schema.org/identifier
# 22          https://schema.org/usageInfo
# 27             https://schema.org/object
# ...                                  ...
# 1414         https://schema.org/position
# 1425      https://schema.org/participant
# 1430         https://schema.org/location
# 1431     https://schema.org/workFeatured
# 1432     https://schema.org/workFeatured
#
#                         equivalentProperty subproperties  \
# 4                                      NaN           NaN
# 16                                     NaN           NaN
# 18                                     NaN           NaN
# 22                                     NaN           NaN
# 27                                     NaN           NaN
# ...                                    ...           ...
# 1414  http://purl.org/ontology/bibo/volume           NaN
# 1425                                   NaN           NaN
# 1430                                   NaN           NaN
# 1431                                   NaN           NaN
# 1432                                   NaN           NaN
#
#                             domainIncludes  \
# 4              https://schema.org/Question
# 16        https://schema.org/Accommodation
# 18              https://schema.org/Invoice
# 22         https://schema.org/CreativeWork
# 27         https://schema.org/ChooseAction
# ...                                    ...
# 1414  https://schema.org/PublicationVolume
# 1425         https://schema.org/LoseAction
# 1430             https://schema.org/Person
# 1431              https://schema.org/Event
# 1432     https://schema.org/ScreeningEvent
#
#                                           rangeIncludes inverseOf  \
# 4     https://schema.org/Answer, https://schema.org/...       NaN
# 16                              https://schema.org/Text       NaN
# 18                              https://schema.org/Text       NaN
# 22    https://schema.org/CreativeWork, https://schem...       NaN
# 27    https://schema.org/Text, https://schema.org/Thing       NaN
# ...                                                 ...       ...
# 1414  https://schema.org/Integer, https://schema.org...       NaN
# 1425                          https://schema.org/Person       NaN
# 1430  https://schema.org/ContactPoint, https://schem...       NaN
# 1431                    https://schema.org/CreativeWork       NaN
# 1432                           https://schema.org/Movie       NaN
#
#                      supersedes supersededBy  isPartOf
# 4                           NaN          NaN       NaN
# 16                          NaN          NaN       NaN
# 18                          NaN          NaN       NaN
# 22                          NaN          NaN       NaN
# 27    https://schema.org/option          NaN       NaN
# ...                         ...          ...       ...
# 1414                        NaN          NaN       NaN
# 1425                        NaN          NaN       NaN
# 1430                        NaN          NaN       NaN
# 1431                        NaN          NaN       NaN
# 1432                        NaN          NaN       NaN
#
# [146 rows x 12 columns]

# %%
display(properties[properties["supersedes"].notnull()])
# Out:
#                                         id              label  \
# 26    https://schema.org/actionApplication  actionApplication
# 27         https://schema.org/actionOption       actionOption
# 34                https://schema.org/actor              actor
# 55                https://schema.org/album              album
# 91           https://schema.org/areaServed         areaServed
# ...                                    ...                ...
# 1271           https://schema.org/subEvent           subEvent
# 1297   https://schema.org/targetCollection   targetCollection
# 1310   https://schema.org/temporalCoverage   temporalCoverage
# 1342              https://schema.org/track              track
# 1416           https://schema.org/warranty           warranty
#
#                                                 comment  \
# 26        An application that can complete the request.
# 27    A sub property of object. The options subject ...
# 34    An actor, e.g. in tv, radio, movie, video game...
# 55                                       A music album.
# 91    The geographic area where a service or offered...
# ...                                                 ...
# 1271  An Event that is part of this event. For examp...
# 1297  A sub property of object. The collection targe...
# 1310  The temporalCoverage of a CreativeWork indicat...
# 1342  A music recording (track)&#x2014;usually a sin...
# 1416     The warranty promise(s) included in the offer.
#
#                   subPropertyOf                 equivalentProperty  \
# 26                          NaN                                NaN
# 27    https://schema.org/object                                NaN
# 34                          NaN                                NaN
# 55                          NaN                                NaN
# 91                          NaN                                NaN
# ...                         ...                                ...
# 1271                        NaN                                NaN
# 1297  https://schema.org/object                                NaN
# 1310                        NaN  http://purl.org/dc/terms/temporal
# 1342                        NaN                                NaN
# 1416                        NaN                                NaN
#
#                                           subproperties  \
# 26                                                  NaN
# 27                                                  NaN
# 34                            https://schema.org/readBy
# 55                                                  NaN
# 91    https://schema.org/availableAtOrFrom, https://...
# ...                                                 ...
# 1271                                                NaN
# 1297                                                NaN
# 1310                                                NaN
# 1342                                                NaN
# 1416                                                NaN
#
#                                          domainIncludes  \
# 26                        https://schema.org/EntryPoint
# 27                      https://schema.org/ChooseAction
# 34    https://schema.org/Clip, https://schema.org/Cr...
# 55                        https://schema.org/MusicGroup
# 91    https://schema.org/ContactPoint, https://schem...
# ...                                                 ...
# 1271                           https://schema.org/Event
# 1297                    https://schema.org/UpdateAction
# 1310                    https://schema.org/CreativeWork
# 1342  https://schema.org/MusicGroup, https://schema....
# 1416  https://schema.org/Demand, https://schema.org/...
#
#                                           rangeIncludes  \
# 26               https://schema.org/SoftwareApplication
# 27    https://schema.org/Text, https://schema.org/Thing
# 34                            https://schema.org/Person
# 55                        https://schema.org/MusicAlbum
# 91    https://schema.org/AdministrativeArea, https:/...
# ...                                                 ...
# 1271                           https://schema.org/Event
# 1297                           https://schema.org/Thing
# 1310  https://schema.org/DateTime, https://schema.or...
# 1342  https://schema.org/ItemList, https://schema.or...
# 1416                 https://schema.org/WarrantyPromise
#
#                           inverseOf                              supersedes  \
# 26                              NaN          https://schema.org/application
# 27                              NaN               https://schema.org/option
# 34                              NaN               https://schema.org/actors
# 55                              NaN               https://schema.org/albums
# 91                              NaN          https://schema.org/serviceArea
# ...                             ...                                     ...
# 1271  https://schema.org/superEvent            https://schema.org/subEvents
# 1297                            NaN           https://schema.org/collection
# 1310                            NaN  https://schema.org/datasetTimeInterval
# 1342                            NaN               https://schema.org/tracks
# 1416                            NaN      https://schema.org/warrantyPromise
#
#      supersededBy  isPartOf
# 26            NaN       NaN
# 27            NaN       NaN
# 34            NaN       NaN
# 55            NaN       NaN
# 91            NaN       NaN
# ...           ...       ...
# 1271          NaN       NaN
# 1297          NaN       NaN
# 1310          NaN       NaN
# 1342          NaN       NaN
# 1416          NaN       NaN
#
# [66 rows x 12 columns]

# %%
person_example = pd.read_json('Person_123movies.pics_September2020.json.gz', compression='gzip', lines=True)

# %%
person_example.head()
# Out:
#    row_id             name                                        description  \
# 0       0       Anna Faris  Anna Faris was born in Baltimore, Maryland, on...
# 1       1  Elisa Gabrielli  Actress and Improvisor Elisa Gabrielli began h...
# 2       2     Tania Gunadi  Tania Gunadi was born in Bandung, Java, Indone...
# 3       3     Walter Jones  Walter is an actor, dancer and singer. Walter ...
# 4       4       James Caan  A masculine and enigmatic actor whose life and...
#
#                                               sameas  \
# 0  https://ww1.123movies.pics/celebrity/anna-fari...
# 1  https://ww1.123movies.pics/celebrity/elisa-gab...
# 2  https://ww1.123movies.pics/celebrity/tania-gun...
# 3  https://ww1.123movies.pics/celebrity/walter-jo...
# 4  https://ww1.123movies.pics/celebrity/james-caa...
#
#                                             page_url
# 0  https://ww1.123movies.pics/movie/cloudy-with-a...
# 1  https://ww1.123movies.pics/movie/cloudy-with-a...
# 2  https://ww1.123movies.pics/movie/cloudy-with-a...
# 3  https://ww1.123movies.pics/movie/cloudy-with-a...
# 4  https://ww1.123movies.pics/movie/cloudy-with-a...

# %%
path = '..Person_statistics/column_statistics/'

# %%
person_columns = pd.read_csv('Person_statistics/column_statistics/top100_Person_column_statistics.txt')

# %%
person_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   column                         66 non-null     object
#  1   occurs_in_percentage_of_hosts  66 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.2+ KB

# %%
display(person_columns[person_columns['occurs_in_percentage_of_hosts'] >= 10.00])
# Out:
#          column  occurs_in_percentage_of_hosts
# 0          name                           98.0
# 1   description                           40.0
# 2      jobtitle                           35.0
# 3     birthdate                           29.0
# 4       address                           26.0
# 5           url                           23.0
# 6     givenname                           20.0
# 7    familyname                           19.0
# 8     telephone                           18.0
# 9         image                           14.0
# 10     worksfor                           14.0
# 11    deathdate                           14.0
# 12        email                           13.0
# 13   birthplace                           12.0
# 14       gender                           12.0
# 15  affiliation                           12.0

# %%
place_statistics = pd.read_csv('Place_statistics/column_statistics/Place_column_statistics.txt')
display(place_statistics)
# Out:
#                    column  occurs_in_percentage_of_hosts
# 0                 address                          93.05
# 1                    name                          90.04
# 2               telephone                          62.39
# 3                     geo                          40.18
# 4             description                          18.22
# ..                    ...                            ...
# 249                 quote                           0.00
# 250  interactionstatistic                           0.00
# 251             videocode                           0.00
# 252              fonction                           0.00
# 253               trading                           0.00
#
# [254 rows x 2 columns]

# %%
display(place_statistics[place_statistics['occurs_in_percentage_of_hosts']>= 10])
# Out:
#         column  occurs_in_percentage_of_hosts
# 0      address                          93.05
# 1         name                          90.04
# 2    telephone                          62.39
# 3          geo                          40.18
# 4  description                          18.22

# %%
airport_columns = pd.read_csv('Airport_statistics/column_statistics/Airport_column_statistics.txt')
display(airport_columns)
# Out:
#                        column  occurs_in_percentage_of_hosts
# 0                        name                          97.05
# 1                         geo                          71.85
# 2                     address                          69.44
# 3                   telephone                          52.28
# 4                 description                          44.77
# 5                    iatacode                          42.90
# 6                    icaocode                          28.42
# 7                       image                          19.57
# 8                       email                          14.75
# 9                openinghours                          11.26
# 10                  faxnumber                           9.12
# 11                     sameas                           6.43
# 12                        url                           4.56
# 13              alternatename                           4.29
# 14           containedinplace                           2.68
# 15                      photo                           2.41
# 16               publicaccess                           1.88
# 17             amenityfeature                           1.61
# 18               itemreviewed                           1.34
# 19                       logo                           1.34
# 20        isaccessibleforfree                           1.34
# 21            aggregaterating                           1.07
# 22                   latitude                           1.07
# 23                  longitude                           1.07
# 24                      naics                           0.80
# 25                     slogan                           0.80
# 26                     review                           0.80
# 27             smokingallowed                           0.80
# 28                   headline                           0.54
# 29  openinghoursspecification                           0.54
# 30           mainentityofpage                           0.54
# 31                 identifier                           0.54
# 32                 pricerange                           0.54
# 33                touristtype                           0.27
# 34                  subjectof                           0.27
# 35                  itinerary                           0.27
# 36                     hasmap                           0.27
# 37                  legalname                           0.27
# 38           interactioncount                           0.27
# 39             additionaltype                           0.27
# 40         additionalproperty                           0.27
# 41                 postalcode                           0.27
# 42            addresslocality                           0.27
# 43              addressregion                           0.27
# 44                 areaserved                           0.27
# 45         currenciesaccepted                           0.27
# 46            paymentaccepted                           0.27
# 47                     isicv4                           0.27

# %%
display(airport_columns[airport_columns['occurs_in_percentage_of_hosts']>=10])
# Out:
#          column  occurs_in_percentage_of_hosts
# 0          name                          97.05
# 1           geo                          71.85
# 2       address                          69.44
# 3     telephone                          52.28
# 4   description                          44.77
# 5      iatacode                          42.90
# 6      icaocode                          28.42
# 7         image                          19.57
# 8         email                          14.75
# 9  openinghours                          11.26

# %%
hotel_sample = pd.read_json('Hotel_jsonsample.json', lines=True)
display(hotel_sample)
# Out:
#     row_id                                               name  \
# 0        0                                       Hotel Nautic
# 1        1                                      Hotel Ginepro
# 2        2  Best Western Plus Casino Royale - Center Strip...
# 3        3                Hotel Reinholdi Guest Accommodation
# 4        4                           Hotel Parkway Guesthouse
# 5        5  Hôtel Dream Inn Dubai Apartments Duplex Ctrl P...
# 6        6  The Edwardian Manchester, A Radisson Collectio...
# 7        7                              Hotel Bologna Airport
# 8        8                                     Vysotsky Hotel
# 9        9                             Residence Sodexo Hotel
# 10      10                                    Narkissos Hotel
# 11      11                         Turangi Holiday Park Hotel
# 12      12                   Sinerama Hotel Apartamento Hotel
# 13      13                              Hotel Splendid Palace
# 14      14             Hotel The Esplanade Holiday Apartments
# 15      15  Hôtel Le Saint-Antoine Hotel &amp; Spa, BW Pre...
# 16      16                              Sunshine Resort Hotel
# 17      17                                   Philoxenia Hotel
# 18      18                                     Club 777 Hotel
# 19      19                    Hotel NH Sevilla Plaza de Armas
# 20      20                        Hotel Appartement Le Kleber
# 21      21        Appart''hôtel Adonis Hotel &amp; Apartments
# 22      22       Hôtel Sotetsu Fresa Inn Nihombashi-Ningyocho
# 23      23                    Hôtel CVK Taksim Hotel Istanbul
# 24      24                             H Hotel Zephyros Hotel
#
#                                               address  \
# 0   {'streetaddress': 'Virgilio 24 Ca´n Pastilla, ...
# 1   {'streetaddress': 'VIA ADAMELLO 27, Aprica, It...
# 2   {'streetaddress': '3411 Las Vegas Blvd S, Las ...
# 3   {'addressregion': 'Haapsalu linn', 'streetaddr...
# 4   {'addressregion': 'Dublin City', 'streetaddres...
# 5   {'streetaddress': 'One by Omniyat Business Bay...
# 6   {'addressregion': 'Greater Manchester', 'stree...
# 7   {'streetaddress': 'Via M.E Lepido 203/14, Bolo...
# 8   {'addressregion': 'Russian Federation', 'stree...
# 9   {'addresscountry': 'Algeria', 'streetaddress':...
# 10  {'streetaddress': 'Kamari, Kamari, Greece', 'a...
# 11  {'addresscountry': 'New Zealand', 'streetaddre...
# 12  {'addresscountry': 'Portugal', 'streetaddress'...
# 13  {'addresscountry': 'Italy', 'addressregion': '...
# 14  {'addresscountry': 'Australia', 'streetaddress...
# 15  {'addresscountry': 'France', 'streetaddress': ...
# 16  {'addressregion': 'Nomós Kefallinías', 'addres...
# 17  {'addressregion': 'Dodecanese Islands', 'stree...
# 18  {'addressregion': 'Uzbekistan', 'streetaddress...
# 19  {'streetaddress': 'Marques de Paradas, s/n, Se...
# 20  {'streetaddress': '1 place Kléber, Estrasburgo...
# 21  {'streetaddress': 'Naoussa, Paros, Grèce', 'ad...
# 22  {'addressregion': 'Tokyo', 'streetaddress': '1...
# 23  {'addressregion': 'Istanbul', 'addresscountry'...
# 24  {'streetaddress': 'Myrties, Kalymnos, Greece',...
#
#                                           description  \
# 0   Este hotel moderno y minimalista ubicado en la...
# 1                                Near Aprica Ski Area
# 2                            Near The Venetian Casino
# 3   El Reinholdi Guest Accommodation está situado ...
# 4   Este agradable hotel está ubicado en O'Connell...
# 5                       Cet hôtel raffiné est à Dubai
# 6   Situé au coeur de Manchester, près de GMEX, ce...
# 7                                  Near Ducati Museum
# 8   Vysotsky Hotel is located on the 39th floor of...
# 9   This hotel enjoys a great location in Hassi Me...
# 10  Hotel Narkissos is located in the island of Sa...
# 11  Take in the views from a garden and make use o...
# 12                           Near Vasco de Gama Beach
# 13                      Near Limone Sul Garda Harbour
# 14  The Esplanade Holiday Apartments, situado a so...
# 15                               Rennes (zone Centre)
# 16                             Near Port of Argostoli
# 17                                 Near Grande Grotta
# 18               This lovely hotel is in Fergana City
# 19               A poca distancia de Metropol Parasol
# 20                                               None
# 21                     À proximité de Plage de Piperi
# 22                                  Tokyo (zone Chūō)
# 23    À proximité de Musée Madame Tussauds d'Istanbul
# 24      Near Kalymnos Climbing Guide - Simon Montmory
#
#                                            pricerange  \
# 0           desde 78€ por noche (igualamos el precio)
# 1   £80 per night - Save up to 25% - Price Match G...
# 2   £215 per night - Save up to 25% - Price Match ...
# 3           desde 35€ por noche (igualamos el precio)
# 4          desde 130€ por noche (igualamos el precio)
# 5   à partir de 18,507€ par nuit avec garantie du ...
# 6   à partir de 103€ par nuit avec garantie du mei...
# 7   £60 per night - Save up to 25% - Price Match G...
# 8   £77 per night - Save up to 25% - Price Match G...
# 9   £54 per night - Save up to 25% - Price Match G...
# 10  £26 per night - Save up to 25% - Price Match G...
# 11  £34 per night - Save up to 25% - Price Match G...
# 12  £81 per night - Save up to 25% - Price Match G...
# 13  £209 per night - Save up to 25% - Price Match ...
# 14          desde 94€ por noche (igualamos el precio)
# 15  à partir de 129€ par nuit avec garantie du mei...
# 16  £25 per night - Save up to 25% - Price Match G...
# 17  £39 per night - Save up to 25% - Price Match G...
# 18  £62 per night - Save up to 25% - Price Match G...
# 19          desde 78€ por noche (igualamos el precio)
# 20         desde 480€ por noche (igualamos el precio)
# 21  à partir de 49€ par nuit avec garantie du meil...
# 22  à partir de 52€ par nuit avec garantie du meil...
# 23  à partir de 129€ par nuit avec garantie du mei...
# 24  £61 per night - Save up to 25% - Price Match G...
#
#                                              page_url
# 0   https://www.es.lastminute.com/hoteles/espana/c...
# 1   https://www.lastminute.com/hotels/italy/aprica...
# 2   https://www.lastminute.com/hotels/united-state...
# 3   https://www.es.lastminute.com/hoteles/estonia/...
# 4   https://www.es.lastminute.com/hoteles/irlanda/...
# 5   https://www.fr.lastminute.com/hotel/emirats-ar...
# 6   https://www.fr.lastminute.com/hotel/royaume-un...
# 7   https://www.lastminute.com/hotels/italy/bologn...
# 8   https://www.lastminute.com/hotels/russian-fede...
# 9   https://www.lastminute.com/hotels/algeria/hass...
# 10  https://www.lastminute.com/hotels/greece/kamar...
# 11  https://www.lastminute.com/hotels/new-zealand/...
# 12  https://www.lastminute.com/hotels/portugal/sin...
# 13  https://www.lastminute.com/hotels/italy/limone...
# 14  https://www.es.lastminute.com/hoteles/australi...
# 15  https://www.fr.lastminute.com/hotel/france/ren...
# 16  https://www.lastminute.com/hotels/greece/argos...
# 17  https://www.lastminute.com/hotels/greece/kalym...
# 18  https://www.lastminute.com/hotels/uzbekistan/f...
# 19  https://www.es.lastminute.com/hoteles/espana/s...
# 20  https://www.es.lastminute.com/hoteles/francia/...
# 21  https://www.fr.lastminute.com/hotel/grece/paro...
# 22  https://www.fr.lastminute.com/hotel/japon/toky...
# 23  https://www.fr.lastminute.com/hotel/turquie/is...
# 24  https://www.lastminute.com/hotels/greece/kalym...
