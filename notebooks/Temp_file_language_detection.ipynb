# %%
import pandas as pd
import re
import os
import fasttext
import progressbar
import json
import gzip
import shutil
from nltk.tokenize import word_tokenize
fasttext.FastText.eprint = lambda x: None # avoid Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
path_parent = os.path.dirname(os.getcwd())
pretrained_fasttext_path = os.path.join(path_parent, 'src/models/lid.176.bin')
model = fasttext.load_model(pretrained_fasttext_path)

# %%
text = "Das$ ist ein de2utscher 2text wt fe2lern"

# %%
text
# Out:
# 'This$ is a may2be an english 2text'

# %%
model.predict(text)
# Out:
# (('__label__de',), array([0.99296874]))

# %%
cleaned_data_path
# Out:
# '/work-ceph/bizer-tp2021/data_integration_using_deep_learning/src/data/product/LocalBusiness_top100/cleaned_new_threshold'

# %%
def remove_punctuation(token_vector):
    return token_vector.apply(lambda token_list: [word for word in token_list if word not in string.punctuation])

# %%
def remove_with_fasttext():
    """
    reads all files from cleaned data path and removes non-english products from the data tables
    :return:
    """
    pretrained_fasttext_path = os.path.join(path_parent, 'src/models/lid.176.bin')
    model = fasttext.load_model(pretrained_fasttext_path)

    # list all top 100 product files
    files = [file for file in os.listdir(data_path) if file.endswith('.json.gz')]

    removed_rows_dict = {}

    count_files = 0

    for file in files:
        print(file)
        df = pd.read_json(os.path.join(data_path, '{}'.format(file)), compression='gzip', lines=True)
        if df.shape[0] > 20: # for top100 & min3
        #if df.shape[0] > 0: # for rest only
            df['concat'] = ''

            for j in range(df.shape[1]):  # iterate over columns
                df['concat'] = df['concat'] + df.iloc[:,j].astype('str')
                

            # iterrate over rows and save row_ids of english products
            english_products = []
            non_english_products = []
            count = 0
            with progressbar.ProgressBar(max_value=df.shape[0]) as bar:
                for i in range(df.shape[0]):  # iterate over rows
                    row_id = int(df['row_id'][i])
                    cell = df['concat'][i]
                    cell_new = re.sub('[^A-Za-z_\s]', ' ', cell)
                    cell_pred = model.predict([cell])
                    cell_new_pred = model.predict([cell_new])
                    print(cell_new)
                    print("no_cleaning", cell_pred)
                    print("cleaning", cell_new_pred)
                    if cell_pred == [['__label__en']]:
                        english_products.append(row_id)
                    else:
                        non_english_products.append(row_id)
                    count += 1
                    bar.update(count)

# %%
data_path = os.path.join(path_parent, 'src/data/LocalBusiness/LocalBusiness_top100')

# %%
remove_with_fasttext()
# Out:
# LocalBusiness_sparkasse.de_September2020.json.gz
#   0% (40 of 12312) |                     | Elapsed Time: 0:00:00 ETA:   0:00:30
#  Kreissparkasse Bautzen   Geldautomat Weigsdorf K blitz  postalcode             addresslocality    Weigsdorf K blitz    streetaddress    Kaufhallenweg  a               kundenservice ksk bautzen de  latitude                longitude               Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten w kreissparkasse bautzen geldautomat weigsdorf koeblitz        html Kreissparkasse Bautzen   Geldautomat Weigsdorf K blitz  postalcode             addresslocality    Weigsdorf K blitz    streetaddress    Kaufhallenweg  a               kundenservice ksk bautzen de  latitude                longitude               Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten w kreissparkasse bautzen geldautomat weigsdorf koeblitz        html
# no_cleaning ([['__label__de']], [array([0.29312006], dtype=float32)])
# cleaning ([['__label__de']], [array([0.48432803], dtype=float32)])
#  Sparkasse Passau   Gesch ftsstelle Neustift  streetaddress    Alte Poststr   b    addresslocality    Passau    postalcode                       info sparkasse passau de  longitude                  latitude                  Fr                We                Th                Mo                Tu                                 https   www sparkasse de filialen p sparkasse passau geschaeftsstelle neustift       html Sparkasse Passau   Gesch ftsstelle Neustift  streetaddress    Alte Poststr   b    addresslocality    Passau    postalcode                       info sparkasse passau de  longitude                  latitude                  Fr                We                Th                Mo                Tu                                 https   www sparkasse de filialen p sparkasse passau geschaeftsstelle neustift       html
# no_cleaning ([['__label__en']], [array([0.19499932], dtype=float32)])
# cleaning ([['__label__de']], [array([0.3101789], dtype=float32)])
#  Sparkasse Bamberg   Gesch ftsstelle Viereth Trunstadt  addresslocality    Viereth Trunstadt    streetaddress    Hauptstra e       postalcode                           info sparkasse bamberg de  longitude                  latitude                  Fr                Mo                Tu                Th                               https   www sparkasse de filialen v sparkasse bamberg geschaeftsstelle viereth trunstadt       html Sparkasse Bamberg   Gesch ftsstelle Viereth Trunstadt  addresslocality    Viereth Trunstadt    streetaddress    Hauptstra e       postalcode                           info sparkasse bamberg de  longitude                  latitude                  Fr                Mo                Tu                Th                               https   www sparkasse de filialen v sparkasse bamberg geschaeftsstelle viereth trunstadt       html
# no_cleaning ([['__label__de']], [array([0.2575064], dtype=float32)])
# cleaning ([['__label__de']], [array([0.39315245], dtype=float32)])
#  Sparkasse Saarbr cken   FirmenkundenCenter West  addresslocality    V lklingen    postalcode             streetaddress    Bismarckstra e                     service sk sb de  latitude                  longitude                  Fr                Th                Mo                Tu                Th                Tu                Mo                Fr                We                We                               https   www sparkasse de filialen v sparkasse saarbruecken firmenkundencenter west        html Sparkasse Saarbr cken   FirmenkundenCenter West  addresslocality    V lklingen    postalcode             streetaddress    Bismarckstra e                     service sk sb de  latitude                  longitude                  Fr                Th                Mo                Tu                Th                Tu                Mo                Fr                We                We                               https   www sparkasse de filialen v sparkasse saarbruecken firmenkundencenter west        html
# no_cleaning ([['__label__en']], [array([0.3453075], dtype=float32)])
# cleaning ([['__label__de']], [array([0.1852134], dtype=float32)])
#  Kreissparkasse Anhalt Bitterfeld   Geldautomat Aken  streetaddress    K thener Str        addresslocality    Aken  Elbe     postalcode                      info ksk anhalt bitterfeld de  longitude                  latitude                  Mo                Fr                Su                Su                Fr                We                Th                Mo                Sa                Tu                Th                We                Sa                Tu              Nonehttps   www sparkasse de geldautomaten a kreissparkasse anhalt bitterfeld geldautomat aken       html Kreissparkasse Anhalt Bitterfeld   Geldautomat Aken  streetaddress    K thener Str        addresslocality    Aken  Elbe     postalcode                      info ksk anhalt bitterfeld de  longitude                  latitude                  Mo                Fr                Su                Su                Fr                We                Th                Mo                Sa                Tu                Th                We                Sa                Tu              Nonehttps   www sparkasse de geldautomaten a kreissparkasse anhalt bitterfeld geldautomat aken       html
# no_cleaning ([['__label__en']], [array([0.23165856], dtype=float32)])
# cleaning ([['__label__de']], [array([0.33830243], dtype=float32)])
#  Sparkasse Niederbayern Mitte   Geldautomat Wallersdorf  streetaddress    Marktplatz      postalcode             addresslocality    Wallersdorf                  wallersdorf sparkasse niederbayern mitte de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr                              https   www sparkasse de geldautomaten w sparkasse niederbayern mitte geldautomat wallersdorf        html Sparkasse Niederbayern Mitte   Geldautomat Wallersdorf  streetaddress    Marktplatz      postalcode             addresslocality    Wallersdorf                  wallersdorf sparkasse niederbayern mitte de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr                              https   www sparkasse de geldautomaten w sparkasse niederbayern mitte geldautomat wallersdorf        html
# no_cleaning ([['__label__de']], [array([0.29700428], dtype=float32)])
# cleaning ([['__label__de']], [array([0.46564126], dtype=float32)])
#  Sparkasse im Landkreis Cham   Geldautomat Michelsneukirchen  streetaddress    Hauptstra e       postalcode             addresslocality    Michelsneukirchen               service spk cham de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten m sparkasse im landkreis cham geldautomat michelsneukirchen        html Sparkasse im Landkreis Cham   Geldautomat Michelsneukirchen  streetaddress    Hauptstra e       postalcode             addresslocality    Michelsneukirchen               service spk cham de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten m sparkasse im landkreis cham geldautomat michelsneukirchen        html
# no_cleaning ([['__label__de']], [array([0.3177663], dtype=float32)])
# cleaning ([['__label__de']], [array([0.5087734], dtype=float32)])
#  Sparkasse Dortmund   Geldautomat Westerfilde  postalcode             streetaddress    Westerfilder Stra e       addresslocality    Dortmund              info sparkasse dortmund de  latitude                  longitude               NoneNonehttps   www sparkasse de geldautomaten d sparkasse dortmund geldautomat westerfilde       html Sparkasse Dortmund   Geldautomat Westerfilde  postalcode             streetaddress    Westerfilder Stra e       addresslocality    Dortmund              info sparkasse dortmund de  latitude                  longitude               NoneNonehttps   www sparkasse de geldautomaten d sparkasse dortmund geldautomat westerfilde       html
# no_cleaning ([['__label__de']], [array([0.32588416], dtype=float32)])
# cleaning ([['__label__de']], [array([0.35521382], dtype=float32)])
#  Sparkasse Hohenlohekreis   Geldautomat D rzbach  postalcode             streetaddress    Hauptstr        addresslocality    D rzbach                 info spk hohenlohekreis de  latitude                 longitude                 Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten d sparkasse hohenlohekreis geldautomat doerzbach        html Sparkasse Hohenlohekreis   Geldautomat D rzbach  postalcode             streetaddress    Hauptstr        addresslocality    D rzbach                 info spk hohenlohekreis de  latitude                 longitude                 Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten d sparkasse hohenlohekreis geldautomat doerzbach        html
# no_cleaning ([['__label__de']], [array([0.23680423], dtype=float32)])
# cleaning ([['__label__de']], [array([0.3220761], dtype=float32)])
#  Sparkasse Mainfranken W rzburg   Geldautomat Lohr  streetaddress    Marktplatz      postalcode             addresslocality    Lohr               internetfiliale sparkasse mainfranken de  latitude                  longitude               Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten l sparkasse mainfranken wuerzburg geldautomat lohr       html Sparkasse Mainfranken W rzburg   Geldautomat Lohr  streetaddress    Marktplatz      postalcode             addresslocality    Lohr               internetfiliale sparkasse mainfranken de  latitude                  longitude               Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten l sparkasse mainfranken wuerzburg geldautomat lohr       html
# no_cleaning ([['__label__en']], [array([0.20854692], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.28708237], dtype=float32)])
#   Kreissparkasse Verden   Geldautomat SB Center Verden Walle  postalcode             addresslocality    Verden    streetaddress    Waller Heerstra e                 service ksk verden de  longitude                  latitude                 Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten v kreissparkasse verden geldautomat sb center verden walle        html  Kreissparkasse Verden   Geldautomat SB Center Verden Walle  postalcode             addresslocality    Verden    streetaddress    Waller Heerstra e                 service ksk verden de  longitude                  latitude                 Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten v kreissparkasse verden geldautomat sb center verden walle        html
# no_cleaning ([['__label__en']], [array([0.19489436], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.2062389], dtype=float32)])
#   Sparkasse M nsterland Ost   BeratungsCenter Sendenhorst  addresslocality    Sendenhorst    postalcode             streetaddress    Kirchstra e                        info sparkasse mslo de  latitude                longitude               Tu                Th                We                Tu                Mo                Fr                Th                                 https   www sparkasse de filialen s sparkasse muensterland ost beratungscenter sendenhorst       html  Sparkasse M nsterland Ost   BeratungsCenter Sendenhorst  addresslocality    Sendenhorst    postalcode             streetaddress    Kirchstra e                        info sparkasse mslo de  latitude                longitude               Tu                Th                We                Tu                Mo                Fr                Th                                 https   www sparkasse de filialen s sparkasse muensterland ost beratungscenter sendenhorst       html
# no_cleaning ([['__label__en']], [array([0.19001402], dtype=float32)])
# cleaning ([['__label__de']], [array([0.28217465], dtype=float32)])
#   Vereinigte Sparkassen Eschenbach i d OPf  Neustadt a d Waldnaab Vohenstrau    Geldautomat Neuhaus a d  Pegnitz  streetaddress    Bahnhofstra e      postalcode             addresslocality    Neuhaus an der Pegnitz                  info vspk neustadt de  longitude                  latitude                 Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten n vereinigte sparkassen eschenbach i d opf neustadt a d waldnaab vohenstrauss geldautomat neuhaus a d pegnitz       html  Vereinigte Sparkassen Eschenbach i d OPf  Neustadt a d Waldnaab Vohenstrau    Geldautomat Neuhaus a d  Pegnitz  streetaddress    Bahnhofstra e      postalcode             addresslocality    Neuhaus an der Pegnitz                  info vspk neustadt de  longitude                  latitude                 Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten n vereinigte sparkassen eschenbach i d opf neustadt a d waldnaab vohenstrauss geldautomat neuhaus a d pegnitz       html
# no_cleaning ([['__label__de']], [array([0.3979453], dtype=float32)])
# cleaning ([['__label__de']], [array([0.53899974], dtype=float32)])
#   Sparkasse Pforzheim Calw   Geldautomat Nagold  streetaddress    Marktstr        addresslocality    Nagold    postalcode                       info sparkasse pforzheim calw de  longitude               latitude                Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten n sparkasse pforzheim calw geldautomat nagold       html  Sparkasse Pforzheim Calw   Geldautomat Nagold  streetaddress    Marktstr        addresslocality    Nagold    postalcode                       info sparkasse pforzheim calw de  longitude               latitude                Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten n sparkasse pforzheim calw geldautomat nagold       html
# no_cleaning ([['__label__en']], [array([0.25541648], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.25087684], dtype=float32)])
#   Kreissparkasse Reutlingen   Geldautomat Reutlingen  E Center   Am Heilbrunnen  streetaddress    Am Heilbrunnen       addresslocality    Reutlingen    postalcode                        info ksk reutlingen de  latitude                longitude              Th                Mo                Sa                Su                Tu                We                Fr                              https   www sparkasse de geldautomaten r kreissparkasse reutlingen geldautomat reutlingen e center am heilbrunnen       html  Kreissparkasse Reutlingen   Geldautomat Reutlingen  E Center   Am Heilbrunnen  streetaddress    Am Heilbrunnen       addresslocality    Reutlingen    postalcode                        info ksk reutlingen de  latitude                longitude              Th                Mo                Sa                Su                Tu                We                Fr                              https   www sparkasse de geldautomaten r kreissparkasse reutlingen geldautomat reutlingen e center am heilbrunnen       html
# no_cleaning ([['__label__de']], [array([0.22800907], dtype=float32)])
# cleaning ([['__label__de']], [array([0.42525366], dtype=float32)])
#   Die Sparkasse Bremen   SB Filiale Kattenesch  postalcode             addresslocality    Bremen    streetaddress    Dreyer Stra e                filiale   sparkasse bremen de  longitude                  latitude                None              https   www sparkasse de filialen b die sparkasse bremen sb filiale kattenesch        html  Die Sparkasse Bremen   SB Filiale Kattenesch  postalcode             addresslocality    Bremen    streetaddress    Dreyer Stra e                filiale   sparkasse bremen de  longitude                  latitude                None              https   www sparkasse de filialen b die sparkasse bremen sb filiale kattenesch        html
# no_cleaning ([['__label__de']], [array([0.14779013], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.2766062], dtype=float32)])
#   Sparkasse Zollernalb   Gesch ftsstelle Stettiner Stra e  addresslocality    Balingen    postalcode             streetaddress    Stettiner Stra e                info spkza de  latitude                longitude               Tu                We                Tu                Mo                Th                Fr                Mo                Th                Fr                             https   www sparkasse de filialen b sparkasse zollernalb geschaeftsstelle stettiner strasse        html  Sparkasse Zollernalb   Gesch ftsstelle Stettiner Stra e  addresslocality    Balingen    postalcode             streetaddress    Stettiner Stra e                info spkza de  latitude                longitude               Tu                We                Tu                Mo                Th                Fr                Mo                Th                Fr                             https   www sparkasse de filialen b sparkasse zollernalb geschaeftsstelle stettiner strasse        html
# no_cleaning ([['__label__en']], [array([0.20607382], dtype=float32)])
# cleaning ([['__label__de']], [array([0.3489055], dtype=float32)])
#   Sparkasse Pfullendorf Me kirch   Filiale Schwenningen  addresslocality    Schwenningen    streetaddress    Hauptstra e   a    postalcode                          info sparkasse pm de  latitude                  longitude                 Mo                Tu                Fr                Th              Nonehttps   www sparkasse de filialen s sparkasse pfullendorf messkirch filiale schwenningen       html  Sparkasse Pfullendorf Me kirch   Filiale Schwenningen  addresslocality    Schwenningen    streetaddress    Hauptstra e   a    postalcode                          info sparkasse pm de  latitude                  longitude                 Mo                Tu                Fr                Th              Nonehttps   www sparkasse de filialen s sparkasse pfullendorf messkirch filiale schwenningen       html
# no_cleaning ([['__label__en']], [array([0.23250364], dtype=float32)])
# cleaning ([['__label__de']], [array([0.2697722], dtype=float32)])
#   Kreissparkasse K ln   Geldautomat Waldorf  REWE Markt  postalcode             streetaddress    Donnerbachweg      addresslocality    Bornheim              info ksk koeln de  latitude                  longitude             None               https   www sparkasse de geldautomaten b kreissparkasse koeln geldautomat waldorf rewe markt        html  Kreissparkasse K ln   Geldautomat Waldorf  REWE Markt  postalcode             streetaddress    Donnerbachweg      addresslocality    Bornheim              info ksk koeln de  latitude                  longitude             None               https   www sparkasse de geldautomaten b kreissparkasse koeln geldautomat waldorf rewe markt        html
# no_cleaning ([['__label__de']], [array([0.30715758], dtype=float32)])
# cleaning ([['__label__de']], [array([0.41865408], dtype=float32)])
#   Sparkasse G ttingen   Geldautomat Gro  Ellershausen  streetaddress    Dransfelder Stra e       addresslocality    G ttingen    postalcode                       info spk goettingen de  latitude                longitude               We                Su                Sa                Fr                Mo                Th                Tu              Nonehttps   www sparkasse de geldautomaten g sparkasse goettingen geldautomat gross ellershausen        html  Sparkasse G ttingen   Geldautomat Gro  Ellershausen  streetaddress    Dransfelder Stra e       addresslocality    G ttingen    postalcode                       info spk goettingen de  latitude                longitude               We                Su                Sa                Fr                Mo                Th                Tu              Nonehttps   www sparkasse de geldautomaten g sparkasse goettingen geldautomat gross ellershausen        html
# no_cleaning ([['__label__en']], [array([0.24651608], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.2709704], dtype=float32)])
#   Sparkasse Landshut   Gesch ftsstelle Neufahrn  addresslocality    Neufahrn    postalcode             streetaddress    Hauptstr                   info sparkasse landshut de  longitude                latitude                  Th                Th                Mo                Fr                Fr                Mo                             https   www sparkasse de filialen n sparkasse landshut geschaeftsstelle neufahrn       html  Sparkasse Landshut   Gesch ftsstelle Neufahrn  addresslocality    Neufahrn    postalcode             streetaddress    Hauptstr                   info sparkasse landshut de  longitude                latitude                  Th                Th                Mo                Fr                Fr                Mo                             https   www sparkasse de filialen n sparkasse landshut geschaeftsstelle neufahrn       html
# no_cleaning ([['__label__de']], [array([0.2159384], dtype=float32)])
# cleaning ([['__label__de']], [array([0.47360915], dtype=float32)])
#   Kreissparkasse Limburg   Geldautomat Bad Camberg  postalcode             addresslocality    Bad Camberg    streetaddress    Limburger Str                   info ksk limburg de  longitude               latitude                Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten b kreissparkasse limburg geldautomat bad camberg        html  Kreissparkasse Limburg   Geldautomat Bad Camberg  postalcode             addresslocality    Bad Camberg    streetaddress    Limburger Str                   info ksk limburg de  longitude               latitude                Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten b kreissparkasse limburg geldautomat bad camberg        html
# no_cleaning ([['__label__en']], [array([0.23346917], dtype=float32)])
# cleaning ([['__label__de']], [array([0.23782583], dtype=float32)])
#   Sparkasse Hildesheim Goslar Peine   Geldautomat Drispenstedt  streetaddress    Ehrlicherstra e       addresslocality    Hildesheim    postalcode                        info sparkasse hgp de  latitude                longitude               Fr                Su                We                Th                Mo                Tu                Sa              Nonehttps   www sparkasse de geldautomaten h sparkasse hildesheim goslar peine geldautomat drispenstedt        html  Sparkasse Hildesheim Goslar Peine   Geldautomat Drispenstedt  streetaddress    Ehrlicherstra e       addresslocality    Hildesheim    postalcode                        info sparkasse hgp de  latitude                longitude               Fr                Su                We                Th                Mo                Tu                Sa              Nonehttps   www sparkasse de geldautomaten h sparkasse hildesheim goslar peine geldautomat drispenstedt        html
# no_cleaning ([['__label__en']], [array([0.25860208], dtype=float32)])
# cleaning ([['__label__de']], [array([0.28710902], dtype=float32)])
#   Nord Ostsee Sparkasse   Regionaldirektion Nieb ll  streetaddress    Hauptstr        addresslocality    Nieb ll    postalcode                           info nospa de  longitude                  latitude                Fr                We                Tu                Th                Mo                Th                Tu                Fr                Mo                              https   www sparkasse de filialen n nord ostsee sparkasse regionaldirektion niebuell       html  Nord Ostsee Sparkasse   Regionaldirektion Nieb ll  streetaddress    Hauptstr        addresslocality    Nieb ll    postalcode                           info nospa de  longitude                  latitude                Fr                We                Tu                Th                Mo                Th                Tu                Fr                Mo                              https   www sparkasse de filialen n nord ostsee sparkasse regionaldirektion niebuell       html
# no_cleaning ([['__label__en']], [array([0.14362608], dtype=float32)])
# cleaning ([['__label__de']], [array([0.3989159], dtype=float32)])
#   Sparkasse Pfaffenhofen   S Immobiliencenter S Immobilien   Sparkasse Pfaffenhofen  addresslocality    Pfaffenhofen    postalcode             streetaddress    Sparkassenplatz                       immobiliencenter spk paf de  latitude                  longitude                  Fr                We                Tu                Mo                Fr                Tu                Mo                Th                Th                            https   www sparkasse de filialen p sparkasse pfaffenhofen s immobiliencenter s immobilien sparkasse pfaffenhofen        html  Sparkasse Pfaffenhofen   S Immobiliencenter S Immobilien   Sparkasse Pfaffenhofen  addresslocality    Pfaffenhofen    postalcode             streetaddress    Sparkassenplatz                       immobiliencenter spk paf de  latitude                  longitude                  Fr                We                Tu                Mo                Fr                Tu                Mo                Th                Th                            https   www sparkasse de filialen p sparkasse pfaffenhofen s immobiliencenter s immobilien sparkasse pfaffenhofen        html
# no_cleaning ([['__label__en']], [array([0.19844529], dtype=float32)])
# cleaning ([['__label__de']], [array([0.40049174], dtype=float32)])
#   Sparkasse Dachau   Geldautomat Altom nster  addresslocality    Altom nster    streetaddress    Herzog Georg Stra e      postalcode                       gebietsdirektion altomuenster sparkasse dachau de  longitude                 latitude                NoneNonehttps   www sparkasse de geldautomaten a sparkasse dachau geldautomat altomuenster        html  Sparkasse Dachau   Geldautomat Altom nster  addresslocality    Altom nster    streetaddress    Herzog Georg Stra e      postalcode                       gebietsdirektion altomuenster sparkasse dachau de  longitude                 latitude                NoneNonehttps   www sparkasse de geldautomaten a sparkasse dachau geldautomat altomuenster        html
# no_cleaning ([['__label__de']], [array([0.32207486], dtype=float32)])
# cleaning ([['__label__de']], [array([0.38139498], dtype=float32)])
#   Berliner Sparkasse   Beratungscenter M rkisches Viertel  postalcode             addresslocality    Berlin    streetaddress    Senftenberger Ring                  info berliner sparkasse de  longitude                  latitude                  Mo                Tu                We                Fr                Th              Nonehttps   www sparkasse de filialen b berliner sparkasse beratungscenter maerkisches viertel        html  Berliner Sparkasse   Beratungscenter M rkisches Viertel  postalcode             addresslocality    Berlin    streetaddress    Senftenberger Ring                  info berliner sparkasse de  longitude                  latitude                  Mo                Tu                We                Fr                Th              Nonehttps   www sparkasse de filialen b berliner sparkasse beratungscenter maerkisches viertel        html
# no_cleaning ([['__label__de']], [array([0.2794231], dtype=float32)])
# cleaning ([['__label__de']], [array([0.4959676], dtype=float32)])
#   Kreissparkasse Ostalb   Filiale Sebaldstra e   Vor bergehend geschlossen   postalcode             addresslocality    Schw bisch Gm nd    streetaddress    Sebaldstra e                  info ksk ostalb de  latitude                longitude             NoneNonehttps   www sparkasse de filialen s kreissparkasse ostalb filiale sebaldstrasse voruebergehend geschlossen        html  Kreissparkasse Ostalb   Filiale Sebaldstra e   Vor bergehend geschlossen   postalcode             addresslocality    Schw bisch Gm nd    streetaddress    Sebaldstra e                  info ksk ostalb de  latitude                longitude             NoneNonehttps   www sparkasse de filialen s kreissparkasse ostalb filiale sebaldstrasse voruebergehend geschlossen        html
# no_cleaning ([['__label__de']], [array([0.48759195], dtype=float32)])
# cleaning ([['__label__de']], [array([0.52760506], dtype=float32)])
#   Kreissparkasse Rottweil   Gesch ftsstelle Seedorf  streetaddress    Freudenst dter Str        addresslocality    Seedorf    postalcode                           info ksk rw de  latitude                  longitude                  Fr                Mo                Fr                Mo              Nonehttps   www sparkasse de filialen s kreissparkasse rottweil geschaeftsstelle seedorf        html  Kreissparkasse Rottweil   Gesch ftsstelle Seedorf  streetaddress    Freudenst dter Str        addresslocality    Seedorf    postalcode                           info ksk rw de  latitude                  longitude                  Fr                Mo                Fr                Mo              Nonehttps   www sparkasse de filialen s kreissparkasse rottweil geschaeftsstelle seedorf        html
# no_cleaning ([['__label__de']], [array([0.2270694], dtype=float32)])
# cleaning ([['__label__de']], [array([0.4218329], dtype=float32)])
#   Berliner Sparkasse   Geldautomat U Bhf  Alexanderplatz  streetaddress    Alexanderplatz      addresslocality    Berlin    postalcode                         info berliner sparkasse de  longitude                  latitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten b berliner sparkasse geldautomat u bhf alexanderplatz        html  Berliner Sparkasse   Geldautomat U Bhf  Alexanderplatz  streetaddress    Alexanderplatz      addresslocality    Berlin    postalcode                         info berliner sparkasse de  longitude                  latitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten b berliner sparkasse geldautomat u bhf alexanderplatz        html
# no_cleaning ([['__label__de']], [array([0.21704397], dtype=float32)])
# cleaning ([['__label__de']], [array([0.31745332], dtype=float32)])
#   Sparkasse Schweinfurt Ha berge   Geldautomat Hofheim  addresslocality    Hofheim in Unterfranken    streetaddress    Marktplatz      postalcode                         hofheim sparkasse sw has de  latitude                longitude                Fr                Su                We                Th                Mo                Tu                Sa              Nonehttps   www sparkasse de geldautomaten h sparkasse schweinfurt hassberge geldautomat hofheim        html  Sparkasse Schweinfurt Ha berge   Geldautomat Hofheim  addresslocality    Hofheim in Unterfranken    streetaddress    Marktplatz      postalcode                         hofheim sparkasse sw has de  latitude                longitude                Fr                Su                We                Th                Mo                Tu                Sa              Nonehttps   www sparkasse de geldautomaten h sparkasse schweinfurt hassberge geldautomat hofheim        html
# no_cleaning ([['__label__en']], [array([0.27302396], dtype=float32)])
# cleaning ([['__label__de']], [array([0.3443026], dtype=float32)])
#   Kreissparkasse Kusel   Geldautomat Wolfstein  addresslocality    Wolfstein    streetaddress    Hauptstr        postalcode                       info ksk kusel de  latitude                  longitude               NoneNonehttps   www sparkasse de geldautomaten w kreissparkasse kusel geldautomat wolfstein        html  Kreissparkasse Kusel   Geldautomat Wolfstein  addresslocality    Wolfstein    streetaddress    Hauptstr        postalcode                       info ksk kusel de  latitude                  longitude               NoneNonehttps   www sparkasse de geldautomaten w kreissparkasse kusel geldautomat wolfstein        html
# no_cleaning ([['__label__de']], [array([0.2681411], dtype=float32)])
# cleaning ([['__label__de']], [array([0.35841882], dtype=float32)])
#   Sparkasse Hilden Ratingen Velbert   SB Center Rathausarkaden  streetaddress    Thomasstra e  a    addresslocality    Velbert    postalcode                        info sparkasse hrv de  latitude                  longitude                 Sa                Fr                Tu                Mo                We                Su                Th              Nonehttps   www sparkasse de filialen v sparkasse hilden ratingen velbert sb center rathausarkaden      html  Sparkasse Hilden Ratingen Velbert   SB Center Rathausarkaden  streetaddress    Thomasstra e  a    addresslocality    Velbert    postalcode                        info sparkasse hrv de  latitude                  longitude                 Sa                Fr                Tu                Mo                We                Su                Th              Nonehttps   www sparkasse de filialen v sparkasse hilden ratingen velbert sb center rathausarkaden      html
# no_cleaning ([['__label__en']], [array([0.2624536], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.21033306], dtype=float32)])
#   Kreissparkasse Soltau   Geldautomat Bispingen  postalcode             addresslocality    Bispingen    streetaddress    Hauptstra e                service ksk soltau de  longitude                  latitude                NoneNonehttps   www sparkasse de geldautomaten b kreissparkasse soltau geldautomat bispingen       html  Kreissparkasse Soltau   Geldautomat Bispingen  postalcode             addresslocality    Bispingen    streetaddress    Hauptstra e                service ksk soltau de  longitude                  latitude                NoneNonehttps   www sparkasse de geldautomaten b kreissparkasse soltau geldautomat bispingen       html
# no_cleaning ([['__label__de']], [array([0.30466315], dtype=float32)])
# cleaning ([['__label__de']], [array([0.28854227], dtype=float32)])
#   Kreissparkasse G ppingen   Geldautomat Ebersbach  postalcode             streetaddress    Ludwigstra e      addresslocality    Ebersbach              info ksk gp de  latitude                  longitude                 Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten e kreissparkasse goeppingen geldautomat ebersbach        html  Kreissparkasse G ppingen   Geldautomat Ebersbach  postalcode             streetaddress    Ludwigstra e      addresslocality    Ebersbach              info ksk gp de  latitude                  longitude                 Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten e kreissparkasse goeppingen geldautomat ebersbach        html
# no_cleaning ([['__label__de']], [array([0.22422671], dtype=float32)])
# cleaning ([['__label__de']], [array([0.28511766], dtype=float32)])
#   Sparkasse zu L beck AG   Geldautomat M nkhofer Weg  streetaddress    M nkhofer Weg       addresslocality    L beck    postalcode                         info sparkasse luebeck de  longitude                  latitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten l sparkasse zu luebeck ag geldautomat moenkhofer weg       html  Sparkasse zu L beck AG   Geldautomat M nkhofer Weg  streetaddress    M nkhofer Weg       addresslocality    L beck    postalcode                         info sparkasse luebeck de  longitude                  latitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten l sparkasse zu luebeck ag geldautomat moenkhofer weg       html
# no_cleaning ([['__label__de']], [array([0.19208941], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.25307855], dtype=float32)])
#   Frankfurter Sparkasse   Geldautomat Sachsenhausen  postalcode             addresslocality    Frankfurt    streetaddress    Darmst dter Landstr                    affentorplatz frankfurter sparkasse de  latitude                longitude               Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten f frankfurter sparkasse geldautomat sachsenhausen       html  Frankfurter Sparkasse   Geldautomat Sachsenhausen  postalcode             addresslocality    Frankfurt    streetaddress    Darmst dter Landstr                    affentorplatz frankfurter sparkasse de  latitude                longitude               Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten f frankfurter sparkasse geldautomat sachsenhausen       html
# no_cleaning ([['__label__de']], [array([0.2582755], dtype=float32)])
# cleaning ([['__label__de']], [array([0.37326398], dtype=float32)])
#   Kreissparkasse Rottweil   Geldautomat Lindenhof  addresslocality    Oberndorf    streetaddress    Lindenhofplatz       postalcode                            info ksk rw de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten o kreissparkasse rottweil geldautomat lindenhof        html  Kreissparkasse Rottweil   Geldautomat Lindenhof  addresslocality    Oberndorf    streetaddress    Lindenhofplatz       postalcode                            info ksk rw de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten o kreissparkasse rottweil geldautomat lindenhof        html
# no_cleaning ([['__label__de']], [array([0.242579], dtype=float32)])
# cleaning ([['__label__de']], [array([0.3860668], dtype=float32)])
#   Sparkasse Unstrut Hainich   Geldautomat Oberdorla  streetaddress    Am Anger       postalcode             addresslocality    Oberdorla              info spk uh de  latitude                  longitude                Th                Mo                Sa                Su                Tu                We                Fr                             https   www sparkasse de geldautomaten o sparkasse unstrut hainich geldautomat oberdorla        html  Sparkasse Unstrut Hainich   Geldautomat Oberdorla  streetaddress    Am Anger       postalcode             addresslocality    Oberdorla              info spk uh de  latitude                  longitude                Th                Mo                Sa                Su                Tu                We                Fr                             https   www sparkasse de geldautomaten o sparkasse unstrut hainich geldautomat oberdorla        html
# no_cleaning ([['__label__en']], [array([0.25205636], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.24811457], dtype=float32)])
#   OstseeSparkasse Rostock   SB Gesch ftsstelle Hanse Outlet  addresslocality    Broderstorf    postalcode             streetaddress    Am Handelspark                ospa ospa de  longitude                  latitude               Th                Tu                Mo                Sa                Fr                We                               https   www sparkasse de filialen b ostseesparkasse rostock sb geschaeftsstelle hanse outlet        html  OstseeSparkasse Rostock   SB Gesch ftsstelle Hanse Outlet  addresslocality    Broderstorf    postalcode             streetaddress    Am Handelspark                ospa ospa de  longitude                  latitude               Th                Tu                Mo                Sa                Fr                We                               https   www sparkasse de filialen b ostseesparkasse rostock sb geschaeftsstelle hanse outlet        html
# no_cleaning ([['__label__de']], [array([0.16791122], dtype=float32)])
# cleaning ([['__label__de']], [array([0.33664387], dtype=float32)])
#   Sparkasse Neuwied   Geldautomat Rheinbreitbach  addresslocality    Rheinbreitbach    streetaddress    Hauptstr        postalcode                           service sparkasse neuwied de  longitude                 latitude                  Fr                Su                We                Th                Mo                Tu                Sa                              https   www sparkasse de geldautomaten r sparkasse neuwied geldautomat rheinbreitbach       html  Sparkasse Neuwied   Geldautomat Rheinbreitbach  addresslocality    Rheinbreitbach    streetaddress    Hauptstr        postalcode                           service sparkasse neuwied de  longitude                 latitude                  Fr                Su                We                Th                Mo                Tu                Sa                              https   www sparkasse de geldautomaten r sparkasse neuwied geldautomat rheinbreitbach       html
# no_cleaning ([['__label__de']], [array([0.2489807], dtype=float32)])
# cleaning ([['__label__de']], [array([0.4080413], dtype=float32)])
#   Sparkasse Neunkirchen   KompetenzCenter SmartLAB  addresslocality    Neunkirchen    postalcode             streetaddress    Stummplatz                 service spk neunkirchen de  latitude                 longitude                 Th                Sa                Tu                Mo                We                Fr              Nonehttps   www sparkasse de filialen n sparkasse neunkirchen kompetenzcenter smartlab        html  Sparkasse Neunkirchen   KompetenzCenter SmartLAB  addresslocality    Neunkirchen    postalcode             streetaddress    Stummplatz                 service spk neunkirchen de  latitude                 longitude                 Th                Sa                Tu                Mo                We                Fr              Nonehttps   www sparkasse de filialen n sparkasse neunkirchen kompetenzcenter smartlab        html
# no_cleaning ([['__label__en']], [array([0.17632411], dtype=float32)])
# cleaning ([['__label__de']], [array([0.30384028], dtype=float32)])
#   Sparkasse Langen Seligenstadt   Geldautomat Dreieich   G tzenhain  streetaddress    Rheinstra e       addresslocality    Dreieich    postalcode                        Privatkunden  sls direkt de  longitude                  latitude                 Th                Mo                Sa                Su                Tu                We                Fr                                https   www sparkasse de geldautomaten d sparkasse langen seligenstadt geldautomat dreieich goetzenhain      html  Sparkasse Langen Seligenstadt   Geldautomat Dreieich   G tzenhain  streetaddress    Rheinstra e       addresslocality    Dreieich    postalcode                        Privatkunden  sls direkt de  longitude                  latitude                 Th                Mo                Sa                Su                Tu                We                Fr                                https   www sparkasse de geldautomaten d sparkasse langen seligenstadt geldautomat dreieich goetzenhain      html
# no_cleaning ([['__label__de']], [array([0.28173232], dtype=float32)])
# cleaning ([['__label__de']], [array([0.4454291], dtype=float32)])
#   Sparkasse Celle Gifhorn Wolfsburg   Geldautomat Fa berg  streetaddress    Lange Reihe      postalcode             addresslocality    Fa berg              info sparkasse cgw de  longitude                  latitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten f sparkasse celle gifhorn wolfsburg geldautomat fassberg        html  Sparkasse Celle Gifhorn Wolfsburg   Geldautomat Fa berg  streetaddress    Lange Reihe      postalcode             addresslocality    Fa berg              info sparkasse cgw de  longitude                  latitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten f sparkasse celle gifhorn wolfsburg geldautomat fassberg        html
# no_cleaning ([['__label__de']], [array([0.2424096], dtype=float32)])
# cleaning ([['__label__de']], [array([0.24463162], dtype=float32)])
#   Sparkasse Wittgenstein   Gesch ftsstelle Feudingen  addresslocality    Bad Laasphe    streetaddress    Sieg Lahn Str        postalcode                           internet sparkasse wittgenstein de  latitude                  longitude                 Fr                Tu                Th                Th                We                Mo                Fr                Tu                Mo                              https   www sparkasse de filialen b sparkasse wittgenstein geschaeftsstelle feudingen        html  Sparkasse Wittgenstein   Gesch ftsstelle Feudingen  addresslocality    Bad Laasphe    streetaddress    Sieg Lahn Str        postalcode                           internet sparkasse wittgenstein de  latitude                  longitude                 Fr                Tu                Th                Th                We                Mo                Fr                Tu                Mo                              https   www sparkasse de filialen b sparkasse wittgenstein geschaeftsstelle feudingen        html
# no_cleaning ([['__label__en']], [array([0.20654541], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.29248282], dtype=float32)])
# ...
# no_cleaning ([['__label__en']], [array([0.26498732], dtype=float32)])
# cleaning ([['__label__de']], [array([0.3750726], dtype=float32)])
#    Kreissparkasse Tuttlingen   Gesch ftsstelle Schura  postalcode             addresslocality    Schura    streetaddress    Lange Stra e                 info ksk tut de  latitude                longitude               We                Th                Fr                Th                Tu                Mo                Fr                            https   www sparkasse de filialen s kreissparkasse tuttlingen geschaeftsstelle schura       html   Kreissparkasse Tuttlingen   Gesch ftsstelle Schura  postalcode             addresslocality    Schura    streetaddress    Lange Stra e                 info ksk tut de  latitude                longitude               We                Th                Fr                Th                Tu                Mo                Fr                            https   www sparkasse de filialen s kreissparkasse tuttlingen geschaeftsstelle schura       html
# no_cleaning ([['__label__de']], [array([0.16353776], dtype=float32)])
# cleaning ([['__label__de']], [array([0.35427225], dtype=float32)])
#    Landessparkasse zu Oldenburg   Geldautomat Wildeshausen  postalcode             streetaddress    Gildeplatz      addresslocality    Wildeshausen  NoneNone  longitude               latitude                Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten w landessparkasse zu oldenburg geldautomat wildeshausen       html   Landessparkasse zu Oldenburg   Geldautomat Wildeshausen  postalcode             streetaddress    Gildeplatz      addresslocality    Wildeshausen  NoneNone  longitude               latitude                Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten w landessparkasse zu oldenburg geldautomat wildeshausen       html
# no_cleaning ([['__label__de']], [array([0.23783237], dtype=float32)])
# cleaning ([['__label__de']], [array([0.32503077], dtype=float32)])
#    Hamburger Sparkasse   Geldautomat Barmbek  postalcode             streetaddress    Osterbekstr     a c    addresslocality    Hamburg  NoneNone  longitude                   latitude                   Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten h hamburger sparkasse geldautomat barmbek       html   Hamburger Sparkasse   Geldautomat Barmbek  postalcode             streetaddress    Osterbekstr     a c    addresslocality    Hamburg  NoneNone  longitude                   latitude                   Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten h hamburger sparkasse geldautomat barmbek       html
# no_cleaning ([['__label__en']], [array([0.20449652], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.26437947], dtype=float32)])
#    Sparkasse Arnsberg Sundern   Geldautomat Bruchhausen  postalcode             streetaddress    Lindenstra e       addresslocality    Arnsberg               info spk as de  longitude               latitude                Th                Mo                Sa                Su                Tu                We                Fr                              https   www sparkasse de geldautomaten a sparkasse arnsberg sundern geldautomat bruchhausen        html   Sparkasse Arnsberg Sundern   Geldautomat Bruchhausen  postalcode             streetaddress    Lindenstra e       addresslocality    Arnsberg               info spk as de  longitude               latitude                Th                Mo                Sa                Su                Tu                We                Fr                              https   www sparkasse de geldautomaten a sparkasse arnsberg sundern geldautomat bruchhausen        html
# no_cleaning ([['__label__de']], [array([0.22399059], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.2674674], dtype=float32)])
#    Hamburger Sparkasse   Geldautomat Bramfeld  addresslocality    Hamburg    postalcode             streetaddress    Bramfelder Chaussee                  haspa haspa de  longitude                  latitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten h hamburger sparkasse geldautomat bramfeld       html   Hamburger Sparkasse   Geldautomat Bramfeld  addresslocality    Hamburg    postalcode             streetaddress    Bramfelder Chaussee                  haspa haspa de  longitude                  latitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten h hamburger sparkasse geldautomat bramfeld       html
# no_cleaning ([['__label__en']], [array([0.19976985], dtype=float32)])
# cleaning ([['__label__de']], [array([0.270111], dtype=float32)])
#    Saalesparkasse   Geldautomat Heide Nord  postalcode             streetaddress    Heidering      addresslocality    Halle  Saale                info saalesparkasse de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr                             https   www sparkasse de geldautomaten h saalesparkasse geldautomat heide nord       html   Saalesparkasse   Geldautomat Heide Nord  postalcode             streetaddress    Heidering      addresslocality    Halle  Saale                info saalesparkasse de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr                             https   www sparkasse de geldautomaten h saalesparkasse geldautomat heide nord       html
# no_cleaning ([['__label__en']], [array([0.21452984], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.28881824], dtype=float32)])
#    Sparkasse Alt tting M hldorf   Geldautomat Teising  streetaddress    Hauptstra e      addresslocality    Teising    postalcode                        info spkam de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten t sparkasse altoetting muehldorf geldautomat teising        html   Sparkasse Alt tting M hldorf   Geldautomat Teising  streetaddress    Hauptstra e      addresslocality    Teising    postalcode                        info spkam de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten t sparkasse altoetting muehldorf geldautomat teising        html
# no_cleaning ([['__label__de']], [array([0.1920054], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.19106345], dtype=float32)])
#    Salzlandsparkasse   Gesch ftsstelle Barby  postalcode             addresslocality    Barby    streetaddress    Magdeburger Stra e                      info salzlandsparkasse de  longitude                  latitude                  Th                Fr                Tu                Tu                               https   www sparkasse de filialen b salzlandsparkasse geschaeftsstelle barby       html   Salzlandsparkasse   Gesch ftsstelle Barby  postalcode             addresslocality    Barby    streetaddress    Magdeburger Stra e                      info salzlandsparkasse de  longitude                  latitude                  Th                Fr                Tu                Tu                               https   www sparkasse de filialen b salzlandsparkasse geschaeftsstelle barby       html
# no_cleaning ([['__label__de']], [array([0.20787434], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.40131697], dtype=float32)])
#    Stadtsparkasse Bocholt   SB Center Stenern  postalcode             addresslocality    Bocholt    streetaddress    Robert Koch Ring                stenern ssk bocholt de  latitude                  longitude                Mo                Fr                Su                Su                Fr                We                Th                Mo                Sa                Tu                Th                We                Sa                Tu              Nonehttps   www sparkasse de filialen b stadtsparkasse bocholt sb center stenern        html   Stadtsparkasse Bocholt   SB Center Stenern  postalcode             addresslocality    Bocholt    streetaddress    Robert Koch Ring                stenern ssk bocholt de  latitude                  longitude                Mo                Fr                Su                Su                Fr                We                Th                Mo                Sa                Tu                Th                We                Sa                Tu              Nonehttps   www sparkasse de filialen b stadtsparkasse bocholt sb center stenern        html
# no_cleaning ([['__label__en']], [array([0.21095866], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.26619032], dtype=float32)])
#    Sparkasse F rth   Geldautomat Soldnerstra e  postalcode             addresslocality    F rth    streetaddress    Soldnerstra e                 info sparkasse fuerth de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten f sparkasse fuerth geldautomat soldnerstrasse       html   Sparkasse F rth   Geldautomat Soldnerstra e  postalcode             addresslocality    F rth    streetaddress    Soldnerstra e                 info sparkasse fuerth de  latitude                  longitude                  Th                Mo                Sa                Su                Tu                We                Fr              Nonehttps   www sparkasse de geldautomaten f sparkasse fuerth geldautomat soldnerstrasse       html
# no_cleaning ([['__label__de']], [array([0.23586039], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.21735023], dtype=float32)])
#    Sparkasse Hameln Weserbergland   Geldautomat Hessisch Oldendorf  Westertor  addresslocality    Hessisch Oldendorf    streetaddress    Westertor       postalcode                        info spkhw de  latitude                  longitude                 We                Su                Sa                Fr                Mo                Th                Tu                              https   www sparkasse de geldautomaten h sparkasse hameln weserbergland geldautomat hessisch oldendorf westertor       html   Sparkasse Hameln Weserbergland   Geldautomat Hessisch Oldendorf  Westertor  addresslocality    Hessisch Oldendorf    streetaddress    Westertor       postalcode                        info spkhw de  latitude                  longitude                 We                Su                Sa                Fr                Mo                Th                Tu                              https   www sparkasse de geldautomaten h sparkasse hameln weserbergland geldautomat hessisch oldendorf westertor       html
# no_cleaning ([['__label__de']], [array([0.26461458], dtype=float32)])
# cleaning ([['__label__de']], [array([0.43912414], dtype=float32)])
#    Sparkasse Emsland   Geldautomat Meppen Kaufland  addresslocality    Meppen    postalcode             streetaddress    Am Neuen Markt               info sparkasse emsland de  longitude                latitude                  Sa                Tu                Fr                Su                We                Mo                Th              Nonehttps   www sparkasse de geldautomaten m sparkasse emsland geldautomat meppen kaufland       html   Sparkasse Emsland   Geldautomat Meppen Kaufland  addresslocality    Meppen    postalcode             streetaddress    Am Neuen Markt               info sparkasse emsland de  longitude                latitude                  Sa                Tu                Fr                Su                We                Mo                Th              Nonehttps   www sparkasse de geldautomaten m sparkasse emsland geldautomat meppen kaufland       html
# no_cleaning ([['__label__de']], [array([0.23200427], dtype=float32)])
# cleaning ([['__label__de']], [array([0.39835486], dtype=float32)])
#    Sparkasse N rnberg   Gesch ftsstelle Zabo  addresslocality    N rnberg    postalcode             streetaddress    Zerzabelshofer Hauptstr                     info sparkasse nuernberg de  longitude                  latitude                  We                Tu                Th                Th                Mo                Fr                             https   www sparkasse de filialen n sparkasse nuernberg geschaeftsstelle zabo       html   Sparkasse N rnberg   Gesch ftsstelle Zabo  addresslocality    N rnberg    postalcode             streetaddress    Zerzabelshofer Hauptstr                     info sparkasse nuernberg de  longitude                  latitude                  We                Tu                Th                Th                Mo                Fr                             https   www sparkasse de filialen n sparkasse nuernberg geschaeftsstelle zabo       html
# no_cleaning ([['__label__de']], [array([0.19054666], dtype=float32)])
# cleaning ([['__label__de']], [array([0.28832838], dtype=float32)])
#    Kreissparkasse Bersenbr ck   Geldautomat Berge  streetaddress    Bippener Str       addresslocality    Berge    postalcode                       berge ksk bersenbrueck de  longitude               latitude                Tu                Su                Th                We                Fr                Mo                Sa              Nonehttps   www sparkasse de geldautomaten b kreissparkasse bersenbrueck geldautomat berge        html   Kreissparkasse Bersenbr ck   Geldautomat Berge  streetaddress    Bippener Str       addresslocality    Berge    postalcode                       berge ksk bersenbrueck de  longitude               latitude                Tu                Su                Th                We                Fr                Mo                Sa              Nonehttps   www sparkasse de geldautomaten b kreissparkasse bersenbrueck geldautomat berge        html
# no_cleaning ([['__label__en']], [array([0.22742476], dtype=float32)])
# cleaning ([['__label__fr']], [array([0.22585757], dtype=float32)])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1685116/4122155188.py in <module>
# ----> 1 remove_with_fasttext()
#
# /tmp/ipykernel_1685116/3660071322.py in remove_with_fasttext()
#      35                     cell_new = re.sub('[^A-Za-z_\s]', ' ', cell)
#      36                     cell_pred = model.predict([cell])
# ---> 37                     cell_new_pred = model.predict([cell_new])
#      38                     print(cell_new)
#      39                     print("no_cleaning", cell_pred)
#
# ~/anaconda3/lib/python3.8/site-packages/fasttext/FastText.py in predict(self, text, k, threshold, on_unicode_error)
#     218         if type(text) == list:
#     219             text = [check(entry) for entry in text]
# --> 220             all_labels, all_probs = self.f.multilinePredict(
#     221                 text, k, threshold, on_unicode_error)
#     222
#
# KeyboardInterrupt:
