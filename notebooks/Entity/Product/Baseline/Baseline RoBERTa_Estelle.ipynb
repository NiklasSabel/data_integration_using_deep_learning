# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import re
import numpy as np
import sklearn
import os

# %%
file_path = '/content/drive/MyDrive/Colab/'

# %%
df_train = pd.read_csv(os.path.join(file_path,'df_train'))
df_test = pd.read_csv(os.path.join(file_path,'df_test'))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3186: DtypeWarning: Columns (17,26,27,30,32,34,43,50,51,52,54,58,60,63,64,65,71,72,78,79,80,83,84,85,86,87,88,89) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3186: DtypeWarning: Columns (32,43,44,49,50,54,55,56,60,61,63,64,65,67,69) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_train
# Out:
#        Unnamed: 0  ...  cluster_id_mapped
# 0               0  ...                891
# 1               1  ...                779
# 2               2  ...                575
# 3               3  ...               1308
# 4               4  ...               1408
# ...           ...  ...                ...
# 19461       19461  ...                549
# 19462       19462  ...                 82
# 19463       19463  ...                265
# 19464       19464  ...               1044
# 19465       19465  ...                919
#
# [19466 rows x 92 columns]

# %%
train = df_train.rename(columns={"concat": "text","cluster_id_mapped":"label"})[['text','label']]
test = df_test.rename(columns={"concat": "text","cluster_id_mapped":"label"})[['text','label']]

# %%
train
# Out:
#                                                     text  label
# 0      mason pearson brush. A handcrafted hairbrush f...    891
# 1      rum body lotion. a lightweight rum-scented bod...    779
# 2      Cisco Catalyst WS-C2960X-24TD-L Stackable Rack...    575
# 3      Silk Strands Shantung SS05 Kitchen Bath Floors...   1308
# 4      Laurel Heights Elevated Beige LH96 Kitchen Bat...   1408
# ...                                                  ...    ...
# 19461  Anthelios Xl Leche Spf50+ 250ml ANTHELIOS XL S...    549
# 19462  Autohelios gel autobronceador 100ml AUTOHELIOS...     82
# 19463  Avene Cleanance Solar Spf50+ 50 ml Avene Clean...    265
# 19464                         Essência White Beer 500g ,   1044
# 19465             Envelope Aromático Baby - 5 unidades ,    919
#
# [19466 rows x 2 columns]

# %%
num_columns = len(set.union(set(test.label.unique()), set(train.label.unique())))

# %%
# arguments
train_args = {
    'num_train_epochs': 25,
    'overwrite_output_dir': True
}

# %%
from simpletransformers.classification import ClassificationModel

# Create a ClassificationModel
model = ClassificationModel('roberta', 'roberta-base', num_labels=num_columns, args=train_args)
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'roberta.pooler.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
model.train_model(train)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/19466 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/25 [00:00<?, ?it/s]
# Running Epoch 0 of 25:   0%|          | 0/2434 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_408/4159083419.py in <module>
# ----> 1 model.train_model(train)
#
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py in train_model(self, train_df, multi_label, output_dir, show_running_loss, args, eval_df, verbose, **kwargs)
#     610             eval_df=eval_df,
#     611             verbose=verbose,
# --> 612             **kwargs,
#     613         )
#     614
#
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py in train(self, train_dataloader, output_dir, multi_label, show_running_loss, eval_df, test_df, verbose, **kwargs)
#     914                     loss.backward()
#     915
# --> 916                 tr_loss += loss.item()
#     917                 if (step + 1) % args.gradient_accumulation_steps == 0:
#     918                     if self.args.fp16:
#
# KeyboardInterrupt:

# %%
result, model_outputs, wrong_predictions = model.eval_model(test)
