# %% [markdown]
# # This notebook will give a first baseline estimation for the matching of entities via a random forest algorithm as multi-class classification

# %%
import os
import pandas as pd
import plotly.express as px
import progressbar
import json
import numpy as np
import nltk
from nltk.corpus import stopwords
import string
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
def remove_stopwords(token_vector, stopwords_list):
    return token_vector.apply(lambda token_list: [word for word in token_list if word not in stopwords_list])

# %%
def remove_punctuation(token_vector):
    return token_vector.apply(lambda token_list: [word for word in token_list if word not in string.punctuation])

# %%
#get path informationb
product_path = '../../../../src/data/product'
train_test_all_filtered_path = os.path.join(product_path, 'train_test_split/output_unfiltered_tables/large/after_manual_checking')

# %%
#fet whole data for baseline
all_filtered_tables_df = pd.read_json(os.path.join(train_test_all_filtered_path,'train/concatenated_data/train_all_filtered_tables.json.gz'), compression='gzip', lines=True)

# %%
all_filtered_tables_df
# Out:
#        row_id                                               name  \
# 0           0                               mason pearson brush.
# 1          35                                   rum body lotion.
# 2         323  Cisco Catalyst WS-C2960X-24TD-L Stackable Rack...
# 3          25                 Laurel Heights Charcoal Crest LH99
# 4          58                    Laurel Heights Gray Summit LH98
# ...       ...                                                ...
# 11605     724  Anthelios Xl Spf50 Gel-crema Toque Seco Color ...
# 11606     755               Vichy neovadiol crema piel seca 50ml
# 11607     779                    Anthelios Xl Leche Spf50+ 250ml
# 11608     827                Autohelios gel autobronceador 100ml
# 11609     832                 Avene Cleanance Solar Spf50+ 50 ml
#
#                                                   offers  \
# 0      {'pricecurrency': 'USD', 'price': '175.00', 'i...
# 1      {'price': '38.00', 'availability': 'http://sch...
# 2      {'price': '0.00', 'pricecurrency': 'GBP', 'ite...
# 3      {'pricecurrency': 'USD', 'price': '0', 'availa...
# 4      {'pricecurrency': 'USD', 'price': '0', 'availa...
# ...                                                  ...
# 11605  {'offercount': '20', 'pricecurrency': 'EUR', '...
# 11606  {'offercount': '3', 'price': '23.99', 'availab...
# 11607  {'pricecurrency': 'EUR', 'price': '16.99', 'hi...
# 11608  {'highprice': '11.95', 'offercount': '2', 'pri...
# 11609  {'lowprice': '13.35', 'price': '13.35', 'price...
#
#                                              description               sku  \
# 0      A handcrafted hairbrush from Mason Pearson wit...      210000000083
# 1      a lightweight rum-scented body lotion that abs...      210000000448
# 2                                                   None  WS-C2960X-24TD-L
# 3      Marchand's Interior & Hardware in Gonzales has...              None
# 4      Marchand's Interior & Hardware in Gonzales has...              None
# ...                                                  ...               ...
# 11605  Anthelios xl spf50 gelcrema toque seco color 5...            1047.0
# 11606  Vichy neovadiol crema piel seca 50 ml NEOVADIO...            2931.0
# 11607  ANTHELIOS XL SPF 50 LECHE ATERCIOPELADA 250ml ...            1032.0
# 11608  AUTOHELIOS GELLECHE Autobronceador hidratante ...            1039.0
# 11609  Avene Cleanance Solar Spf50 50 ml Matificante ...            4341.0
#
#                                                 page_url  cluster_id  \
# 0      https://www.malinandgoetz.com/mason-pearson-brush     1617106
# 1      https://eu.malinandgoetz.com/rum-body-lotion-8...     1257145
# 2            https://www.odsi.co.uk/ws-c2960x-24td-l.php      758825
# 3      https://www.marchands.net/american-olean-laure...    18329550
# 4      https://www.marchands.net/american-olean-laure...    52605388
# ...                                                  ...         ...
# 11605  https://www.boticas23.com/anthelios-xl-spf50-g...     1937007
# 11606  https://www.boticas23.com/vichy-neovadiol-crem...       33370
# 11607  https://www.boticas23.com/anthelios-xl-leche-s...      708960
# 11608  https://www.boticas23.com/autohelios-gel-autob...       62047
# 11609  https://www.boticas23.com/avene-cleanance-sola...      256149
#
#                                               table_id         brand_x  \
# 0      Product_malinandgoetz.com_September2020.json.gz            None
# 1      Product_malinandgoetz.com_September2020.json.gz            None
# 2             Product_odsi.co.uk_September2020.json.gz           Cisco
# 3          Product_marchands.net_September2020.json.gz  American Olean
# 4          Product_marchands.net_September2020.json.gz  American Olean
# ...                                                ...             ...
# 11605      Product_boticas23.com_September2020.json.gz  La Roche-Posay
# 11606      Product_boticas23.com_September2020.json.gz           Vichy
# 11607      Product_boticas23.com_September2020.json.gz  La Roche-Posay
# 11608      Product_boticas23.com_September2020.json.gz  La Roche-Posay
# 11609      Product_boticas23.com_September2020.json.gz           Avene
#
#               brand_y  ... position product-sku product-name  ratingcount  \
# 0                None  ...      NaN        None         None          NaN
# 1                None  ...      NaN        None         None          NaN
# 2               cisco  ...      NaN        None         None          NaN
# 3      american olean  ...      NaN        None         None          NaN
# 4      american olean  ...      NaN        None         None          NaN
# ...               ...  ...      ...         ...          ...          ...
# 11605            None  ...      NaN        None         None          NaN
# 11606            None  ...      NaN        None         None          NaN
# 11607            None  ...      NaN        None         None          NaN
# 11608            None  ...      NaN        None         None          NaN
# 11609            None  ...      NaN        None         None          NaN
#
#       breadcrumb inlanguage ispartof speakable availability pricevaliduntil
# 0           None       None     None      None         None            None
# 1           None       None     None      None         None            None
# 2           None       None     None      None         None            None
# 3           None       None     None      None         None            None
# 4           None       None     None      None         None            None
# ...          ...        ...      ...       ...          ...             ...
# 11605       None       None     None      None         None            None
# 11606       None       None     None      None         None            None
# 11607       None       None     None      None         None            None
# 11608       None       None     None      None         None            None
# 11609       None       None     None      None         None            None
#
# [11610 rows x 67 columns]

# %%
# get information about train and test table split
product_path = '../../../../src/data/product'
zip_files_train = [file for file in os.listdir(os.path.join(train_test_all_filtered_path, 'train')) if file.endswith('.json.gz')]
zip_files_val = [file for file in os.listdir(os.path.join(train_test_all_filtered_path, 'val')) if file.endswith('.json.gz')]
zip_files_test = [file for file in os.listdir(os.path.join(train_test_all_filtered_path, 'test')) if file.endswith('.json.gz')]

# %%
all_filtered_tables_df
# Out:
#        row_id                                               name  \
# 0         399  WD 2TB Elements Portable External Hard Drive -...
# 1          18                         Three Gifts Goat Milk Soap
# 2         601                      GoPro Head Strap + Quick Clip
# 3         722                         GoPro 3 way grip Arm GoPro
# 4           0                               mason pearson brush.
# ...       ...                                                ...
# 31287     834              Gibson Les Paul Joe Bonamassa Goldtop
# 31288     854               Gibson Birdseye Les Paul 1959 Cherry
# 31289     442                     Epiphone Masterbilt AJ 500 RCE
# 31290    1074                           Essência White Beer 500g
# 31291    1099               Envelope Aromático Baby - 5 unidades
#
#                                                   offers  \
# 0      {'pricecurrency': 'USD', 'price': '74.99', 'sk...
# 1      {'price': '8.5', 'availability': 'https://sche...
# 2      {'pricecurrency': 'CAD', 'availability': 'http...
# 3      {'price': '102.99', 'pricecurrency': 'CAD', 'a...
# 4      {'pricecurrency': 'USD', 'price': '175.00', 'i...
# ...                                                  ...
# 31287  {'price': '2599.00', 'pricevaliduntil': '2021-...
# 31288  {'price': '0.00', 'pricevaliduntil': '2021-12-...
# 31289  {'pricevaliduntil': '2021-12-31', 'price': '44...
# 31290                              {'price': 'R$ 92,00'}
# 31291                              {'price': 'R$ 12,30'}
#
#                                              description             sku  \
# 0      Brand: Western Digital Color: black Features: ...      B06W55K9N6
# 1      Gold, frankincense and myrrh - three gifts giv...            None
# 2                                                   None            None
# 3                                                   None            None
# 4      A handcrafted hairbrush from Mason Pearson wit...    210000000083
# ...                                                  ...             ...
# 31287                                               None  210000000448.0
# 31288                                               None  210000000722.0
# 31289                                               None  210000000077.0
# 31290                                               None            None
# 31291                                               None            None
#
#                              brand  \
# 0      {'name': 'Western Digital'}
# 1                             None
# 2                            GoPro
# 3                            GoPro
# 4                             None
# ...                            ...
# 31287                         None
# 31288                         None
# 31289                         None
# 31290                         None
# 31291                         None
#
#                                                 page_url  cluster_id  \
# 0      https://area399.com/products/wd-2tb-elements-p...      541658
# 1      https://www.thecraftist.com/product-page/three...    65383188
# 2      https://www.specialisteduski.com/gopro-head-st...      863679
# 3      https://www.specialisteduski.com/gopro-3-way-g...      251884
# 4      https://www.malinandgoetz.com/mason-pearson-brush     1617106
# ...                                                  ...         ...
# 31287  https://sixtysixtysounds.com/product/gibson-le...     1257145
# 31288  https://sixtysixtysounds.com/product/gibson-bi...     1524820
# 31289  https://sixtysixtysounds.com/product/epiphone-...     1702641
# 31290  https://www.lojapeterpaiva.com.br/produto/esse...     2434654
# 31291  https://www.lojapeterpaiva.com.br/produto/enve...     1738768
#
#                                                 table_id brand_x  ... video  \
# 0              Product_area399.com_September2020.json.gz    None  ...  None
# 1          Product_thecraftist.com_September2020.json.gz    None  ...  None
# 2      Product_specialisteduski.com_September2020.jso...   GoPro  ...  None
# 3      Product_specialisteduski.com_September2020.jso...   GoPro  ...  None
# 4        Product_malinandgoetz.com_September2020.json.gz    None  ...  None
# ...                                                  ...     ...  ...   ...
# 31287  Product_sixtysixtysounds.com_September2020.jso...    None  ...  None
# 31288  Product_sixtysixtysounds.com_September2020.jso...    None  ...  None
# 31289  Product_sixtysixtysounds.com_September2020.jso...    None  ...  None
# 31290  Product_lojapeterpaiva.com.br_September2020.js...    None  ...  None
# 31291  Product_lojapeterpaiva.com.br_September2020.js...    None  ...  None
#
#       position ratingcount target breadcrumb ispartof  speakable title  \
# 0          NaN         NaN   None       None     None       None  None
# 1          NaN         NaN   None       None     None       None  None
# 2          NaN         NaN   None       None     None       None  None
# 3          NaN         NaN   None       None     None       None  None
# 4          NaN         NaN   None       None     None       None  None
# ...        ...         ...    ...        ...      ...        ...   ...
# 31287      NaN         NaN   None       None     None       None  None
# 31288      NaN         NaN   None       None     None       None  None
# 31289      NaN         NaN   None       None     None       None  None
# 31290      NaN         NaN   None       None     None       None  None
# 31291      NaN         NaN   None       None     None       None  None
#
#       isconsumablefor productbrand
# 0                None         None
# 1                None         None
# 2                None         None
# 3                None         None
# 4                None         None
# ...               ...          ...
# 31287            None         None
# 31288            None         None
# 31289            None         None
# 31290            None  Peter Paiva
# 31291            None  Peter Paiva
#
# [31292 rows x 88 columns]

# %%
all_filtered_tables_df['dataset']=''

# %%
all_filtered_tables_df.loc[all_filtered_tables_df['table_id'].isin(zip_files_train),'dataset']='train'

# %%
all_filtered_tables_df.loc[all_filtered_tables_df['table_id'].isin(zip_files_val),'dataset']='val'

# %%
all_filtered_tables_df.loc[all_filtered_tables_df['table_id'].isin(zip_files_test),'dataset']='test'

# %%
all_filtered_tables_df
# Out:
#        row_id                                               name  \
# 0         399  WD 2TB Elements Portable External Hard Drive -...
# 1          18                         Three Gifts Goat Milk Soap
# 2         601                      GoPro Head Strap + Quick Clip
# 3         722                         GoPro 3 way grip Arm GoPro
# 4           0                               mason pearson brush.
# ...       ...                                                ...
# 31287     834              Gibson Les Paul Joe Bonamassa Goldtop
# 31288     854               Gibson Birdseye Les Paul 1959 Cherry
# 31289     442                     Epiphone Masterbilt AJ 500 RCE
# 31290    1074                           Essência White Beer 500g
# 31291    1099               Envelope Aromático Baby - 5 unidades
#
#                                                   offers  \
# 0      {'pricecurrency': 'USD', 'price': '74.99', 'sk...
# 1      {'price': '8.5', 'availability': 'https://sche...
# 2      {'pricecurrency': 'CAD', 'availability': 'http...
# 3      {'price': '102.99', 'pricecurrency': 'CAD', 'a...
# 4      {'pricecurrency': 'USD', 'price': '175.00', 'i...
# ...                                                  ...
# 31287  {'price': '2599.00', 'pricevaliduntil': '2021-...
# 31288  {'price': '0.00', 'pricevaliduntil': '2021-12-...
# 31289  {'pricevaliduntil': '2021-12-31', 'price': '44...
# 31290                              {'price': 'R$ 92,00'}
# 31291                              {'price': 'R$ 12,30'}
#
#                                              description             sku  \
# 0      Brand: Western Digital Color: black Features: ...      B06W55K9N6
# 1      Gold, frankincense and myrrh - three gifts giv...            None
# 2                                                   None            None
# 3                                                   None            None
# 4      A handcrafted hairbrush from Mason Pearson wit...    210000000083
# ...                                                  ...             ...
# 31287                                               None  210000000448.0
# 31288                                               None  210000000722.0
# 31289                                               None  210000000077.0
# 31290                                               None            None
# 31291                                               None            None
#
#                              brand  \
# 0      {'name': 'Western Digital'}
# 1                             None
# 2                            GoPro
# 3                            GoPro
# 4                             None
# ...                            ...
# 31287                         None
# 31288                         None
# 31289                         None
# 31290                         None
# 31291                         None
#
#                                                 page_url  cluster_id  \
# 0      https://area399.com/products/wd-2tb-elements-p...      541658
# 1      https://www.thecraftist.com/product-page/three...    65383188
# 2      https://www.specialisteduski.com/gopro-head-st...      863679
# 3      https://www.specialisteduski.com/gopro-3-way-g...      251884
# 4      https://www.malinandgoetz.com/mason-pearson-brush     1617106
# ...                                                  ...         ...
# 31287  https://sixtysixtysounds.com/product/gibson-le...     1257145
# 31288  https://sixtysixtysounds.com/product/gibson-bi...     1524820
# 31289  https://sixtysixtysounds.com/product/epiphone-...     1702641
# 31290  https://www.lojapeterpaiva.com.br/produto/esse...     2434654
# 31291  https://www.lojapeterpaiva.com.br/produto/enve...     1738768
#
#                                                 table_id brand_x  ...  \
# 0              Product_area399.com_September2020.json.gz    None  ...
# 1          Product_thecraftist.com_September2020.json.gz    None  ...
# 2      Product_specialisteduski.com_September2020.jso...   GoPro  ...
# 3      Product_specialisteduski.com_September2020.jso...   GoPro  ...
# 4        Product_malinandgoetz.com_September2020.json.gz    None  ...
# ...                                                  ...     ...  ...
# 31287  Product_sixtysixtysounds.com_September2020.jso...    None  ...
# 31288  Product_sixtysixtysounds.com_September2020.jso...    None  ...
# 31289  Product_sixtysixtysounds.com_September2020.jso...    None  ...
# 31290  Product_lojapeterpaiva.com.br_September2020.js...    None  ...
# 31291  Product_lojapeterpaiva.com.br_September2020.js...    None  ...
#
#       position ratingcount target breadcrumb ispartof speakable  title  \
# 0          NaN         NaN   None       None     None      None   None
# 1          NaN         NaN   None       None     None      None   None
# 2          NaN         NaN   None       None     None      None   None
# 3          NaN         NaN   None       None     None      None   None
# 4          NaN         NaN   None       None     None      None   None
# ...        ...         ...    ...        ...      ...       ...    ...
# 31287      NaN         NaN   None       None     None      None   None
# 31288      NaN         NaN   None       None     None      None   None
# 31289      NaN         NaN   None       None     None      None   None
# 31290      NaN         NaN   None       None     None      None   None
# 31291      NaN         NaN   None       None     None      None   None
#
#       isconsumablefor productbrand dataset
# 0                None         None    test
# 1                None         None    test
# 2                None         None    test
# 3                None         None    test
# 4                None         None   train
# ...               ...          ...     ...
# 31287            None         None    test
# 31288            None         None    test
# 31289            None         None    test
# 31290            None  Peter Paiva     val
# 31291            None  Peter Paiva     val
#
# [31292 rows x 89 columns]

# %%
#filter down the dataframe
df_whole = all_filtered_tables_df[['row_id','name','description','cluster_id','table_id','dataset']]

# %%
df_whole.sort_values(by=['cluster_id','dataset'])
# Out:
#        row_id                                               name  \
# 189       236              Begg x Co Kishorn Scarf: Flannel Grey
# 1237      731                           Canon EOS REBEL T7i Body
# 6360      592                                Canon EOS Rebel T7i
# 7708      142                  Cakebread Reserve Chardonnay 2017
# 5671      342               Canon EOS Rebel T7i DSLR Camera Body
# ...       ...                                                ...
# 13379      14  Xiaomi Redmi Note 7 Pro 6.3 inch 6GB RAM 128GB...
# 15654       6  Xiaomi Redmi Note 7 Pro 6.3 inch 6GB RAM 128GB...
# 20242      25  Xiaomi Redmi Note 7 Pro 6.3 inch 6GB RAM 128GB...
# 7488     1111  Xiaomi Redmi Note 7 Pro 6.3 inch 6GB RAM 128GB...
# 11026      43  Xiaomi Redmi Note 7 Pro 6.3 inch 6GB RAM 128GB...
#
#                                              description  cluster_id  \
# 189    Woven in Begg x Co's historic Ayrshire mill on...         985
# 1237   EOS Rebel T7i The EOS Rebel T7i camera has pro...         985
# 6360   <p>Packing a versatile feature-set in a sleek ...         985
# 7708   Seductive, slightly floral aromas of creamy go...         985
# 5671   Packing a versatile feature-set in a sleek and...         985
# ...                                                  ...         ...
# 13379  Xiaomi Redmi Note 7 Pro CPU: Snapdragon 675 Oc...    80168995
# 15654  Xiaomi Redmi Note 7 Pro CPU: Snapdragon 675 Oc...    80168995
# 20242  Xiaomi Redmi Note 7 Pro CPU: Snapdragon 675 Oc...    80168995
# 7488   Xiaomi Redmi Note 7 Pro CPU: Snapdragon 675 Oc...    80168995
# 11026  Xiaomi Redmi Note 7 Pro CPU: Snapdragon 675 Oc...    80168995
#
#                                                 table_id dataset
# 189     Product_trunkclothiers.com_September2020.json.gz    test
# 1237      Product_discountshop.com_September2020.json.gz    test
# 6360    Product_prophotosupply.com_September2020.json.gz    test
# 7708        Product_ocwinemart.com_September2020.json.gz    test
# 5671        Product_cameramall.com_September2020.json.gz   train
# ...                                                  ...     ...
# 13379  Product_store-singapore.com_September2020.json.gz   train
# 15654     Product_store-belgie.com_September2020.json.gz   train
# 20242     Product_storegermany.com_September2020.json.gz   train
# 7488          Product_iwebshop.com_September2020.json.gz     val
# 11026     Product_store-italia.com_September2020.json.gz     val
#
# [31292 rows x 6 columns]

# %%
df_whole.sort_values(by=['cluster_id','dataset']).to_excel('Test_Data_Check_1.xlsx')

# %% [markdown]
# ### Only use idf-tf vector based features

# %%
# fill emtpy values for description and the concat name and description
df_whole.description.fillna(value=',', inplace=True)
df_whole['concat_information']=df_whole['name'].astype(str)+df_whole['description'].astype(str)
df_whole.drop(columns=['name','description'],inplace= True)
# Out:
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# /tmp/ipykernel_436305/4099819629.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['concat_information']=df_whole['name'].astype(str)+df_whole['description'].astype(str)
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#clean concated description column to use tf-idf 
df_whole['concat_information'] = df_whole['concat_information'].apply(lambda row: row.lower())
df_whole['tokens'] = df_whole['concat_information'].apply(lambda row: word_tokenize(row))
df_whole['tokens'] = remove_stopwords(df_whole['tokens'],stopwords.words())
df_whole['tokens'] = remove_punctuation (df_whole['tokens'])
df_whole.drop(columns=['concat_information'],inplace=True)
# Out:
# /tmp/ipykernel_436305/256944513.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['concat_information'] = df_whole['concat_information'].apply(lambda row: row.lower())
# /tmp/ipykernel_436305/256944513.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['tokens'] = df_whole['concat_information'].apply(lambda row: word_tokenize(row))
# /tmp/ipykernel_436305/256944513.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['tokens'] = remove_stopwords(df_whole['tokens'],stopwords.words())
# /tmp/ipykernel_436305/256944513.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['tokens'] = remove_punctuation (df_whole['tokens'])

# %%
#define vectorizer to match preprocessed tokes
def dummy_fun(doc):
    return doc

tfidf = TfidfVectorizer(
    analyzer='word',
    tokenizer=dummy_fun,
    preprocessor=dummy_fun,
    token_pattern=None, 
    max_features=15000)  
tfidf_value = tfidf.fit_transform(df_whole['tokens'])

# %%
df_tfidf = pd.DataFrame(tfidf_value.toarray(), columns=tfidf.get_feature_names())
df_prepared = pd.concat([df_whole, df_tfidf], axis=1)

# %%
df_train = df_prepared[df_prepared['table_id'].isin(zip_files_train)].reset_index()
df_target_train = df_train['cluster_id']
df_train.drop(columns=['cluster_id','table_id','tokens'],inplace= True)

# %%
df_test = df_prepared[df_prepared['table_id'].isin(zip_files_test)].reset_index()
df_target_test = df_test['cluster_id']
df_test.drop(columns=['cluster_id','table_id','tokens'],inplace= True)

# %%
# Baseline random forest
rf = RandomForestClassifier()
rf.fit(df_train,df_target_train)
prediction = rf.predict(df_test) 
f1_mic = f1_score(df_target_test,prediction,average='micro')
f1_mac = f1_score(df_target_test,prediction,average='macro')
accuracy = accuracy_score(df_target_test,prediction) 
precision = precision_score(df_target_test,prediction,average='micro') 
recall = recall_score(df_target_test,prediction,average='micro') 
precision_mac = precision_score(df_target_test,prediction,average='macro') 
recall_mac = recall_score(df_target_test,prediction,average='macro') 
print("The F1-Score micro on test set: {:.4f}".format(f1_mic))
print("The F1-Score on test set: {:.4f}".format(f1_mac))
print("The Precision on test set: {:.4f}".format(precision))
print("The Recall on test set: {:.4f}".format(recall))
print("The Precision macro on test set: {:.4f}".format(precision_mac))
print("The Recall macro on test set: {:.4f}".format(recall_mac))
print("The Accuracy-Score on test set: {:.4f}".format(accuracy))
# Out:
# The F1-Score micro on test set: 0.7717
# The F1-Score on test set: 0.6596
# The Precision on test set: 0.7717
# The Recall on test set: 0.7717
# The Precision macro on test set: 0.7026
# The Recall macro on test set: 0.6725
# The Accuracy-Score on test set: 0.7717
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Only use tf vector based features

# %%
#filter down the dataframe
df_whole = all_filtered_tables_df[['name','description','cluster_id','table_id']]

# %%
# fill emtpy values for description and the concat name and description
df_whole.description.fillna(value=',', inplace=True)
df_whole['concat_information']=df_whole['name'].astype(str)#+df_whole['description'].astype(str)
df_whole.drop(columns=['name','description'],inplace= True)
# Out:
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# /tmp/ipykernel_436305/3294319364.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['concat_information']=df_whole['name'].astype(str)#+df_whole['description'].astype(str)
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#clean concated description column to use tf-idf 
df_whole['concat_information'] = df_whole['concat_information'].apply(lambda row: row.lower())
df_whole['tokens'] = df_whole['concat_information'].apply(lambda row: word_tokenize(row))
df_whole['tokens'] = remove_stopwords(df_whole['tokens'],stopwords.words())
df_whole['tokens'] = remove_punctuation (df_whole['tokens'])
df_whole.drop(columns=['concat_information'],inplace=True)
# Out:
# /tmp/ipykernel_436305/256944513.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['concat_information'] = df_whole['concat_information'].apply(lambda row: row.lower())
# /tmp/ipykernel_436305/256944513.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['tokens'] = df_whole['concat_information'].apply(lambda row: word_tokenize(row))
# /tmp/ipykernel_436305/256944513.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['tokens'] = remove_stopwords(df_whole['tokens'],stopwords.words())
# /tmp/ipykernel_436305/256944513.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['tokens'] = remove_punctuation (df_whole['tokens'])

# %%
#define vectorizer to match preprocessed tokes for term frequency
def dummy(doc):
    return doc

vectorizer  = CountVectorizer(
        tokenizer=dummy,
        preprocessor=dummy,
        max_features=15000)  
tf_value = vectorizer.fit_transform(df_whole['tokens'])

# %%
df_tf = pd.DataFrame(tf_value.toarray(), columns=vectorizer.get_feature_names())
df_prepared = pd.concat([df_whole, df_tf], axis=1)

# %%
df_train = df_prepared[df_prepared['table_id'].isin(zip_files_train)].reset_index()
df_target_train = df_train['cluster_id']
df_train.drop(columns=['cluster_id','table_id','tokens'],inplace= True)

# %%
df_test = df_prepared[df_prepared['table_id'].isin(zip_files_test)].reset_index()
df_target_test = df_test['cluster_id']
df_test.drop(columns=['cluster_id','table_id','tokens'],inplace= True)

# %%
# Baseline random forest
rf = RandomForestClassifier()
rf.fit(df_train,df_target_train)
prediction = rf.predict(df_test) 
f1_mic = f1_score(df_target_test,prediction,average='micro')
f1_mac = f1_score(df_target_test,prediction,average='macro')
accuracy = accuracy_score(df_target_test,prediction) 
precision = precision_score(df_target_test,prediction,average='micro') 
recall = recall_score(df_target_test,prediction,average='micro') 
precision_mac = precision_score(df_target_test,prediction,average='macro') 
recall_mac = recall_score(df_target_test,prediction,average='macro') 
print("The F1-Score micro on test set: {:.4f}".format(f1_mic))
print("The F1-Score macro on test set: {:.4f}".format(f1_mac))
print("The Precision on test set: {:.4f}".format(precision))
print("The Recall on test set: {:.4f}".format(recall))
print("The Precision macro on test set: {:.4f}".format(precision_mac))
print("The Recall macro on test set: {:.4f}".format(recall_mac))
print("The Accuracy-Score on test set: {:.4f}".format(accuracy))
# Out:
# The F1-Score micro on test set: 0.8122
# The F1-Score macro on test set: 0.7295
# The Precision on test set: 0.8122
# The Recall on test set: 0.8122
# The Precision macro on test set: 0.7751
# The Recall macro on test set: 0.7365
# The Accuracy-Score on test set: 0.8122
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Combine tf-idf and tf vector based features

# %%
#filter down the dataframe
df_whole = all_filtered_tables_df[['name','description','cluster_id','table_id']]

# %%
# fill emtpy values for description and the concat name and description
df_whole.description.fillna(value=',', inplace=True)
df_whole['concat_information']=df_whole['name'].astype(str)#+df_whole['description'].astype(str)
df_whole.drop(columns=['name','description'],inplace= True)
# Out:
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# /tmp/ipykernel_436305/3294319364.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['concat_information']=df_whole['name'].astype(str)#+df_whole['description'].astype(str)
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#clean concated description column to use tf-idf 
df_whole['concat_information'] = df_whole['concat_information'].apply(lambda row: row.lower())
df_whole['tokens'] = df_whole['concat_information'].apply(lambda row: word_tokenize(row))
df_whole['tokens'] = remove_stopwords(df_whole['tokens'],stopwords.words())
df_whole['tokens'] = remove_punctuation (df_whole['tokens'])
df_whole.drop(columns=['concat_information'],inplace=True)
# Out:
# /tmp/ipykernel_436305/256944513.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['concat_information'] = df_whole['concat_information'].apply(lambda row: row.lower())
# /tmp/ipykernel_436305/256944513.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['tokens'] = df_whole['concat_information'].apply(lambda row: word_tokenize(row))
# /tmp/ipykernel_436305/256944513.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['tokens'] = remove_stopwords(df_whole['tokens'],stopwords.words())
# /tmp/ipykernel_436305/256944513.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_whole['tokens'] = remove_punctuation (df_whole['tokens'])

# %%
#define vectorizer to match preprocessed tokes for term frequency
def dummy(doc):
    return doc

vectorizer  = CountVectorizer(
        tokenizer=dummy,
        preprocessor=dummy,
        max_features=15000)  
tf_value = vectorizer.fit_transform(df_whole['tokens'])

# %%
#define vectorizer to match preprocessed tokes
def dummy_fun(doc):
    return doc

tfidf = TfidfVectorizer(
    analyzer='word',
    tokenizer=dummy_fun,
    preprocessor=dummy_fun,
    token_pattern=None,
    max_features=15000)  
tfidf_value = tfidf.fit_transform(df_whole['tokens'])

# %%
df_tf = pd.DataFrame(tf_value.toarray(), columns=vectorizer.get_feature_names())
df_tfidf = pd.DataFrame(tfidf_value.toarray(), columns=tfidf.get_feature_names())
df_prepared = pd.concat([df_whole, df_tfidf, df_tf], axis=1)

# %%
df_train = df_prepared[df_prepared['table_id'].isin(zip_files_train)].reset_index()
df_target_train = df_train['cluster_id']
df_train.drop(columns=['cluster_id','table_id','tokens'],inplace= True)

# %%
df_test = df_prepared[df_prepared['table_id'].isin(zip_files_test)].reset_index()
df_target_test = df_test['cluster_id']
df_test.drop(columns=['cluster_id','table_id','tokens'],inplace= True)

# %%
# Baseline random forest
rf = RandomForestClassifier()
rf.fit(df_train,df_target_train)
prediction = rf.predict(df_test) 
f1_mic = f1_score(df_target_test,prediction,average='micro')
f1_mac = f1_score(df_target_test,prediction,average='macro')
accuracy = accuracy_score(df_target_test,prediction) 
precision = precision_score(df_target_test,prediction,average='micro') 
recall = recall_score(df_target_test,prediction,average='micro') 
precision_mac = precision_score(df_target_test,prediction,average='macro') 
recall_mac = recall_score(df_target_test,prediction,average='macro') 
print("The F1-Score micro on test set: {:.4f}".format(f1_mic))
print("The F1-Score macro on test set: {:.4f}".format(f1_mac))
print("The Precision on test set: {:.4f}".format(precision))
print("The Recall on test set: {:.4f}".format(recall))
print("The Precision macro on test set: {:.4f}".format(precision_mac))
print("The Recall macro on test set: {:.4f}".format(recall_mac))
print("The Accuracy-Score on test set: {:.4f}".format(accuracy))
# Out:
# The F1-Score micro on test set: 0.8163
# The F1-Score macro on test set: 0.7417
# The Precision on test set: 0.8163
# The Recall on test set: 0.8163
# The Precision macro on test set: 0.7873
# The Recall macro on test set: 0.7462
# The Accuracy-Score on test set: 0.8163
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
