# %%
import os
import pandas as pd
import plotly.express as px
import progressbar
import json
import numpy as np
import nltk
from nltk.corpus import stopwords
import string
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize
pd.set_option('display.max_colwidth', None)

# %%
def remove_stopwords(token_vector, stopwords_list):
    return token_vector.apply(lambda token_list: [word for word in token_list if word not in stopwords_list])

# %%
def remove_punctuation(token_vector):
    return token_vector.apply(lambda token_list: [word for word in token_list if word not in string.punctuation])

# %%
def jaccard_similarity_score(original, translation):
    intersect = set(original).intersection(set(translation))
    union = set(original).union(set(translation))
    try:
        return len(intersect) / len(union)
    except ZeroDivisionError:
        return 0

# %% [markdown]
# ## Get the paths and build table names for iteration

# %%
data_path = '../src/data'
mapping_corpus_path = data_path + r'/product/lspc2020_to_tablecorpus'
mapping_corpus_path_2 = data_path + r'/product/lspc2020_to_tablecorpus/Cleaned'
table_corpus_path = data_path + r'/product/product_top100/cleaned'
table_corpus_path_with_id = data_path + r'/product/product_top100/cleaned/with_id'
table_corpus_path2 = data_path + r'/product/product_minimum3/cleaned/with_id'

# %%
zip_files_mapping = [file for file in os.listdir(mapping_corpus_path_2) if file.endswith('.json.gz')]
zip_files_tables = [file for file in os.listdir(table_corpus_path) if file.endswith('.json.gz')]

# %% [markdown]
# ## Match the number dictionaries with the information about the brand

# %%
df_large = pd.read_json(os.path.join(mapping_corpus_path_2, 'df_large_matched.json'), compression='gzip', orient='records', lines=True)

# %%
df_large
# Out:
#           cluster_id  \
# 0           59178314
# 1           70692685
# 2             395606
# 3            3361797
# 4             235755
# ...              ...
# 24688354     8653717
# 24688355    22258637
# 24688356    41434658
# 24688357    62702145
# 24688358    60936713
#
#                                                                                                                 url  \
# 0                 https://www.cultureindoor.com/796-irrigation-arrosage-tuyau-pe-20mm-semi-rigide-rouleau-100m.html
# 1         https://www.culturekings.com/products/new-era-new-era-new-orleans-pelicans-nba-940-a-frame-snapback-black
# 2                            https://www.culturekings.com/products/new-era-x-nrl-west-tigers-aframe-charcoal-orange
# 3                                              https://www.customizedgirl.com/design/2605608/The+Real+Baseball+Moms
# 4                                             https://www.customizedgirl.com/design/2613423/Mentally+Dating+Ronaldo
# ...                                                                                                             ...
# 24688354                                                         https://shop-list.com/women/utuwa-tatara/sg3232-03
# 24688355                                                           https://shop-list.com/women/youmotto/famille-ltm
# 24688356                        https://shop.agwaycapecod.com/products/019014710959/adult-small-breed-dog-food-5-lb
# 24688357                                  https://shop.agwaycapecod.com/products/037321455042/ant-killer-dust-3-lbs
# 24688358                                                        https://shop.areefcreation.com/products/ls-apr-344b
#
#           row_id                                          table_id  Valid  \
# 0           1561   Product_cultureindoor.com_September2020.json.gz      1
# 1           3893    Product_culturekings.com_September2020.json.gz      1
# 2           3894    Product_culturekings.com_September2020.json.gz      1
# 3           9318  Product_customizedgirl.com_September2020.json.gz      1
# 4           9319  Product_customizedgirl.com_September2020.json.gz      1
# ...          ...                                               ...    ...
# 24688354    1620       Product_shop-list.com_September2020.json.gz      1
# 24688355    1621       Product_shop-list.com_September2020.json.gz      1
# 24688356     126    Product_agwaycapecod.com_September2020.json.gz      1
# 24688357     127    Product_agwaycapecod.com_September2020.json.gz      1
# 24688358     120   Product_areefcreation.com_September2020.json.gz      1
#
#                                                                                name  \
# 0                       irrigation ,arrosage Tuyau PE 20mm semi rigide rouleau 100m
# 1                    New Era New Orleans Pelicans NBA 9FORTY A-Frame Snapback Black
# 2                                  New Era X NRL West Tigers Aframe Charcoal/orange
# 3                                                      The Real Baseball Moms (2XL)
# 4                                                     Mentally Dating Ronaldo (2XL)
# ...                                                                             ...
# 24688354                                            vZXEC h[ yAv[gZbg(Vf) v[g Mtg 
# 24688355  t@~[ OgC}bg80~60cm[gC }bg gC^[ Jg[ _ i` IV AC{[uE n O CeA 􂦂ېOK tH ~ `RȊO]
# 24688356                                          Adult Small Breed Dog Food, 5-Lb.
# 24688357                                                    Ant Killer Dust, 3-Lbs.
# 24688358                                                            ARC Prince Acro
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                             Tuyau PE 20mm semi rigide rouleau 100m, idéal pour les irrigations de jardins et arrosage automatique, retrouvez toute l'irrigation chez culture indoor le leader du jardinage et de l'hydroponie en france et en europe
# 1         New Era is back at it again this season with another unique instalment of the 940 silhouette. This time around Culture Kings has the Worldwide Exclusive on these so you can be assured that you won't find them anywhere else. Culture Kings have worked closely with New Era to design a hat that features a slightly higher crown for increased comfort and added style points. The highest quality cotton twill fabric has been used for extreme comfort and durability and the shape is so unique that you just won't find this on any other hat. - Curved Brim - Extra room at the crown- Embroidered team logo- Rear snapback closure
# 2                                                                                                                                                                                                                                                                                                                                                                                                                          The Iconic New Era is the premium siloute of headwear worldwide. The official Major league baseball on field hat, as well as now NRL. It's fit is can be worn with flat visor or curved, The best quality hat in the world.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Are you a real baseball mom fan? Customize a cute design spoof on the \"real housewives\" show. Add your team's name and your athlete's name.
# 4                                                                                                                                                                                                                                                                                                                                                                                   Mentally dating Christiano Ronaldo. Yeah girl, me too. He literally has changed the game of soccer into something women watch just to see him. That hair, those abs, the smile. It's too much to handle. If I was the goalie, I'd let him score every single time.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 24688354                                                                                                                                                                                                                                                                                               yPrincessRoyalDreams-vZXCh[-zyAv[gZbg(Vf)(v[g2_̃ZbgłB)fBYj[EvZX݂hCEFfBOhC[WBFȂXg[[ƋɁAK𑡂܂B܂AϔȂ̂ŁAMtgƂĂ߂łBFB₲Ƒւ̃v[gMtgɂł傤B+++V[Y֘Ai+++EyAOXZbg(Vf)EyAXeOXZbg(Vf)EXeOX&amp;v[gZbg(AG)EXeOX&amp;v[gZbg(vcF)TCY21~H2.3cmeʁ[ގ({)@v[g͉_gpĂ܂BӂƓdqWOKHNGNG̑t̎戵mFB݌ɂ̏i͓XʓX܂ł̔Ă܂B݌ɐ̍XV͐sĂ܂A󋵂ɂĂ͏ii؂ƂȂ邱Ƃ܂B܂i񂹂ɂ肨͂܂łɂԂꍇ܂Bqlɂ͕KA܂Aꃁ[J[ŕi؂ꓙ̗Rɂח肪ȂAׂ͓xꍇ̓LZĂꍇ܂Ƃ炩߂B
# 24688355                                                                                                                                                                                                                                                                                                                                                                                                                                                                  yiڍׁzyގzpC/|GXe100yTCYz80~60cmyYzyɂĂ̂ӁzEŏ̐͗VітAڐ肷邱Ƃ܂̂ŁAK̕ƕĐĂB͎኱kނƂ܂Agpɂ͂܂BEh@iȂȂ߃h܂ށj͐΂ɂgpɂȂȂłBpCiёj̔`̘č݂ƂȂ܂̂Ŏ􂢂ߒv܂ByӁzE܂肽ŕۊǂĂׁAiɐ܂ȂtĂ邱Ƃ܂Bx󂵂Ă܂ƁA܂ȂڗȂȂ܂BEg̃j^[̐ݒɂAF̌قȂ邱Ƃ܂BB
# 24688356                                                                                                                                                                                                                                                                      Eukanuba, 5 LB, Adult Small Breed Dry Dog Food, Has A Higher Amount Of Fat To Meet The Unique Energy Levels, Kibble Size Suits Their Metabolisms & Stomach Size, Promotes Active, Daily Living With Antioxidants For Immune Health, Fiber For Healthy Digestion, Fatty Acids For Coat & Skin Health & Other Natural Nutrients, Natural Flavor Of Chicken & Whole Grains.
# 24688357                                                                                                                                                                                                                                                                              3 LB, Water-Proof Ant Killer Dust, Use Indoors & Outdoors, Kills Ants, Spiders, Wasps, Bees, Scorpions, Fleas, Roaches & Other Insects That Invade Your Home, A Light Dusting Around The Outside Of Your Home Provides A Bug Busting Barrier For Up To 8 Months. Active Ingredient: Deltamethrin In A Waterproof Dust Formulation That Is Unaffected By Weather.
# 24688358                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
#
#                        brand
# 0            FRANCE ARROSAGE
# 1                       None
# 2                       None
# 3         CustomizedGirl.com
# 4         CustomizedGirl.com
# ...                      ...
# 24688354                None
# 24688355                None
# 24688356                None
# 24688357                None
# 24688358                None
#
# [24688359 rows x 8 columns]

# %%
df_joined_clothes = df_large.merge(df_clothes_cleaned, left_on=['table_id','row_id'], right_on = ['table_id','row_id'], how='left')

# %%
df_joined_electronics.to_json(mapping_corpus_path_2 + '/joined_electronics_v2.json', compression='gzip', orient='records', lines=True)

# %%
df_joined_clothes.to_json(mapping_corpus_path_2 + '/joined_clothes_v2.json', compression='gzip', orient='records', lines=True)

# %%
df_joined_electronics = pd.read_json(os.path.join(mapping_corpus_path_2, 'joined_electronics_v2.json'), compression='gzip', orient='records', lines=True)

# %%
df_joined_clothes = pd.read_json(os.path.join(mapping_corpus_path_2, 'joined_clothes_v2.json'), compression='gzip', orient='records', lines=True)

# %%
df_joined_clothes = pd.read_csv(os.path.join(mapping_corpus_path_2, 'clothes_clusters_all_8_tables_post_processed.csv'))

# %%
df_joined_electronics = pd.read_csv(os.path.join(mapping_corpus_path_2, 'electronics_clusters_all_10_tables_post_processed.csv'))

# %%
df_joined_clothes
# Out:
#       Unnamed: 0  Unnamed: 0.1  cluster_id  \
# 0              4         15925    78110534
# 1              5         18456       79412
# 2              6         19121      587935
# 3              7         19932      391605
# 4              8         27046     2434654
# ...          ...           ...         ...
# 6028        9729      24666813      434734
# 6029        9730      24668368     5121322
# 6030        9731      24671086     5121322
# 6031        9732      24671279     1512681
# 6032        9734      24688025     5121322
#
#                                                                                                                url  \
# 0                      https://www.cn.forzieri.com/chn/product_view.asp?l=chn&c=chn&dept_id=18&sku=dg130320-027-00
# 1                            https://www.lookingglassphoto.com/peak-design-the-everyday-messenger-charcoal-15.html
# 2                                         https://soloptical.net/es/rayban-reg-justin-color-mix-rb4165-622-55.html
# 3                                                     https://www.whisknyc.com/cake-stand-w-glass-dome-anchor.html
# 4                             https://avcstore.com/products/saramonic-sr-tm1-cardioid-condenser-shotgun-microphone
# ...                                                                                                            ...
# 6028                 https://www.scottscycle.com/product/chamois-buttr-original-formula-chamois-cream-184928-1.htm
# 6029                                     https://urbanpalms.com/product/lg-bottle-palm-tree-hyophorbe-lagenicaulis
# 6030                                              https://spectrumtelescope.com/product/glass-solar-filter-st1150g
# 6031  https://www.abiza.co.uk/product/raw-garnet-necklace-january-birthday-gifts-raw-stone-necklace-garnet-jewelry
# 6032                                     https://kensphilodendrons.com/product/anthurium-clavigerum-plant-on-totem
#
#       row_id                                             table_id  Valid  \
# 0       3400           Product_forzieri.com_September2020.json.gz      1
# 1       2600  Product_lookingglassphoto.com_September2020.json.gz      1
# 2        558         Product_soloptical.net_September2020.json.gz      1
# 3       3052           Product_whisknyc.com_September2020.json.gz      1
# 4        803           Product_avcstore.com_September2020.json.gz      1
# ...      ...                                                  ...    ...
# 6028      69        Product_scottscycle.com_September2020.json.gz      1
# 6029       5         Product_urbanpalms.com_September2020.json.gz      1
# 6030      30  Product_spectrumtelescope.com_September2020.json.gz      1
# 6031      32            Product_abiza.co.uk_September2020.json.gz      1
# 6032      27  Product_kensphilodendrons.com_September2020.json.gz      1
#
#                                                               name  \
# 0                                           small \"devotion\" bag
# 1     peak design peak design the everyday messenger- charcoal 15”
# 2                          rayban ® justin color mix rb4165 622/55
# 3                                  13\" glass cake stand with dome
# 4           saramonic sr-tm1 cardioid condenser shotgun microphone
# ...                                                            ...
# 6028                                original formula chamois cream
# 6029                 lg. bottle palm tree (hyophorbe lagenicaulis)
# 6030                                    glass solar filter st1150g
# 6031                                           raw garnet necklace
# 6032                     anthurium clavigerum plant in 2x2x7\" pot
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Leather handle, detachable shoulder strap, front plate with logo jewel heart, magnetic closure, inner flat pocket, leather inner, gold finish metal accessories, made in italy.Sensorial gift wrap available
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Gafas de sol de última colección y diseños novedosos que representan uno de los principales accesorios de la moda actual
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# 4     For TV, Broadcast & Video ProductionCardioid Polar PatternEnhanced Rear Signal Rejection40 Hz to 20 kHz Frequency ResponseInternal 150-Hour Lithium-Ion BatterySupports 48V Phantom PowerSelectable Pad, Roll-Off & High BoostXLR 3-Pin OutputIncludes Windscreen & Mic ClipIncludes XLR Cable & USB Charging CableThe Saramonic SR-TM1 is a medium-length cardioid condenser shotgun microphone offering high SPL handling and full-bandwidth frequency reproduction for sound recordists, boom operators, and videographers in broadcast, video, and television production. The cardioid polar pattern ensures reliable directivity with enhanced rejection of signal at the rear of capsule. Operate the SR-TM1 via 48 VDC phantom power or the internal lithium-ion battery, which delivers up to 150 hours of use and recharges through the supplied micro-USB cable.Selection of the -10 dB pad allows the SR-TM1 to capture loud sound sources without inducing distortion while the 40 Hz to 20 kHz frequency response accurately conveys your source's tone. Customize the SR-TM1's sonic performance with the switchable 150 Hz high-pass filter for minimized low-frequency rumble, and the 6 dB high-frequency boost for improved vocal clarity.Connect the SR-TM1 to your mixer or microphone preamp via the XLR 3-pin output. It includes a foam windscreen, short XLR cable, and mic clip with a camera shoe mount.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 6028                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Chamois Butt’r Original is a non-greasy skin lubricant developed by cyclists for use with all chamois. Chamois Butt’r isn’t just for cyclists! It lubricates, soothes, and softens the skin of all...
# 6029                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Unique and unlike any other palm Bottle Palm is a distinctive addition to any plant collection. Contained in a planter the Bottle Palm is a shapely centerpiece to any porch patio or well lit indoor area. Native to the Mascarene Islands mature trunks have sometimes attained heights of 20 feet.
# 6030                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Your O.D. Measurement:11 1/8” (283mm)to11 3/8” (289mm) Fits:Celestron 10\" Newt;Orion SkyWatcher 10\"
# 6031                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Gorgeous deep red Raw Garnet stones in their most natural state have been hand crafted into pendants and suspending from beautiful shimmering chains. Available in 14K Gold Fill or 925 Sterling Silver. Great for layering but just as good as a single and a very versatile piece. Comes with a crystal information card in a beautiful Abiza gift box. Perfect for January Birthdays or healing purposes! Over 700 Sold with lots of 5⭐️ Reviews!
# 6032                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                One of the largest climbing and most unusual Leaf varieties of Anthurium This plant grows rapidly on moist totems and even faster when allowed to climb outdoors in zone 10 and above. This beautiful rare plant is a great addition to any conservatory collection.
#
#                  brand_x brand_y  \
# 0     Dolce & Gabbana żΰ     NaN
# 1            PEAK DESIGN     NaN
# 2                    NaN     NaN
# 3                    NaN     NaN
# 4              SARAMONIC     NaN
# ...                  ...     ...
# 6028                 NaN     NaN
# 6029         Urban Palms     NaN
# 6030  Spectrum Telescope     NaN
# 6031     Abiza Jewellery     NaN
# 6032               Ken's     NaN
#
#                                                                                      tokens
# 0                                                ['small', "''", 'devotion\\', "''", 'bag']
# 1     ['peak', 'design', 'peak', 'design', 'everyday', 'messenger-', 'charcoal', '15', '”']
# 2                             ['rayban', '®', 'justin', 'color', 'mix', 'rb4165', '622/55']
# 3                                          ['13\\', "''", 'glass', 'cake', 'stand', 'dome']
# 4                 ['saramonic', 'sr-tm1', 'cardioid', 'condenser', 'shotgun', 'microphone']
# ...                                                                                     ...
# 6028                                            ['original', 'formula', 'chamois', 'cream']
# 6029                          ['lg', 'bottle', 'palm', 'tree', 'hyophorbe', 'lagenicaulis']
# 6030                                                ['glass', 'solar', 'filter', 'st1150g']
# 6031                                                          ['raw', 'garnet', 'necklace']
# 6032                                  ['anthurium', 'clavigerum', 'plant', '2x2x7\\', "''"]
#
# [6033 rows x 12 columns]

# %% [markdown]
# ## Get information about electronic clusters and train model

# %%
df_grouped_electronics = df_joined_electronics.groupby('cluster_id').count()
# only look at clusters that have at least one brand associated
df_set_electronics = df_grouped_electronics.reset_index()[['cluster_id','table_id']].rename(columns={'table_id':'Amount'})

# %%
df_10_electronics=df_set_electronics[df_set_electronics['Amount']>10]

# %%
df_10_electronics
# Out:
#      cluster_id  Amount
# 2          3668      11
# 3          6076      14
# 4          6443      13
# 5          6505      13
# 6          6690      17
# ..          ...     ...
# 615    52362093      20
# 616    53457772      61
# 617    64651308      11
# 618    66614988      12
# 621    80097153      59
#
# [307 rows x 2 columns]

# %%
#df_10_electronics.to_csv('electronics10.csv')

# %%
# We discard all clusters with less than 2 entries, cause we cannot match anything there, so 1,6 million clusters remain
df_set_electronics=df_set_electronics[df_set_electronics['Amount']>1]
df_15_electronics=df_set_electronics[df_set_electronics['Amount']>12]
df_15_electronics
# Out:
#      cluster_id  Amount
# 3          6076      14
# 4          6443      13
# 5          6505      13
# 6          6690      17
# 8          7366      13
# ..          ...     ...
# 611    48051979      13
# 613    48051984      13
# 615    52362093      20
# 616    53457772      61
# 621    80097153      59
#
# [190 rows x 2 columns]

# %%
#merge brand name to cluster amount
df_cluster_brand = df_15_electronics[df_15_electronics['Amount']<200].merge(df_joined_electronics.dropna()[['cluster_id','brand_y']].drop_duplicates('cluster_id', keep='last'), left_on=['cluster_id'], right_on = ['cluster_id'], how='left')
df_cluster_brand

# %%
#clean product column and lowercase
df_joined_electronics=df_joined_electronics.dropna(subset = ['name'])
df_joined_electronics['name'] = df_joined_electronics['name'].apply(lambda row: row.lower())
df_joined_electronics
#get only cluster ids with at least one brand electronics
df_compare_electronics = df_joined_electronics[df_joined_electronics['cluster_id'].isin(df_set_electronics['cluster_id'].tolist())]
#merge with set to get amount of tables per cluster in overview
df_compare_electronics = df_compare_electronics.merge(df_set_electronics, left_on=['cluster_id'], right_on = ['cluster_id'], how='left')

# %%
#use tokenizer for product names to get tokes for training the model
df_compare_electronics['product_tokes'] = df_compare_electronics['name'].apply(lambda row: word_tokenize(row))
df_compare_electronics['product_tokes'] = remove_stopwords(df_compare_electronics['product_tokes'],stopwords.words())
df_compare_electronics['product_tokes'] = remove_punctuation (df_compare_electronics['product_tokes'])
#get tagged words
tagged_data = [TaggedDocument(words=_d, tags=[str(i)]) for i, _d in enumerate(df_compare_electronics['product_tokes'])]
# build model and vocabulary
model = Doc2Vec(vector_size=50, min_count = 5, epochs = 25, dm = 0)
model.build_vocab(tagged_data)
# Train model
model.train(tagged_data, total_examples=model.corpus_count, epochs=25)

# %%
#get cluster ids for basline products and with that indices of top products to use model
#1524820,47566,6076,14418,28307,33570,39040,51314,99153,215254,685416, 984421 , 1808651,2887810,34506065,47841827,620473,56116,94055, 150211,182246, 516888, 562955 
top_clusters_list = df_15_electronics['cluster_id'].tolist()
index_top_clusters_list=[]
for id in top_clusters_list:
    index_top_clusters_list.append(df_compare_electronics[df_compare_electronics['cluster_id']==id].index[0])

# %%
# get most similar products for each of the base clusters and save them if they have more than 5 tables
electronics_clusters_search=[]
for i in index_top_clusters_list:
    similar_doc = model.docvecs.most_similar(f'{i}', topn = 20)
    electronics_clusters_search.append(int(i))
    for index, similarity in similar_doc:
        if df_compare_electronics.iloc[int(index)]['Amount']>8:
            electronics_clusters_search.append(int(index))
    jaccard_score = df_compare_electronics['product_tokes'].apply(lambda row: jaccard_similarity_score(row,df_compare_electronics.iloc[int(i)]['product_tokes']) )
    indizes=sorted(range(len(jaccard_score)), key=lambda i: jaccard_score[i])[-20:]
    for index in indizes:
         if df_compare_electronics.iloc[int(index)]['Amount']>8:
            electronics_clusters_search.append(int(index))    
df_electroncis_final = df_compare_electronics.iloc[electronics_clusters_search]

# %%
df_electroncis_final.drop_duplicates('cluster_id', keep='first').to_excel("Final_Electronics_v4.xlsx")

# %%
df_electroncis_final = df_electroncis_final.drop_duplicates('cluster_id', keep='first')

# %%
df_joined_electronics.loc[df_joined_electronics['cluster_id'].isin(df_electroncis_final['cluster_id'].tolist())]

# %% [markdown]
# ## Cluster statistics for product category clothes

# %%
df_grouped_clothes = df_joined_clothes.groupby('cluster_id').count()

# %%
# only look at clusters that have at least one brand associated
df_set_clothes = df_grouped_clothes[df_grouped_clothes['brand_y']>0].reset_index()[['cluster_id','table_id']].rename(columns={'table_id':'Amount'})

# %%
# We discard all clusters with less than 2 entries, cause we cannot match anything there, so 1,6 million clusters remain
df_set_clothes=df_set_clothes[df_set_clothes['Amount']>1]
df_set_clothes
# Out:
#      cluster_id  Amount
# 0         16573       6
# 1         18496       8
# 2         37366       3
# 3         37525       9
# 4         42322       8
# ..          ...     ...
# 282    77602818      15
# 283    78110534      12
# 284    78499693      15
# 285    78736275       8
# 286    80330359      13
#
# [279 rows x 2 columns]

# %%
df_8_clothes=df_set_clothes[df_set_clothes['Amount']>8]
df_8_clothes
# Out:
#      cluster_id  Amount
# 3         37525       9
# 5         58043       9
# 6         70109      10
# 12       127282       9
# 15       142594       9
# ..          ...     ...
# 281    77104640       9
# 282    77602818      15
# 283    78110534      12
# 284    78499693      15
# 286    80330359      13
#
# [104 rows x 2 columns]

# %%
df_10_clothes=df_set_clothes[df_set_clothes['Amount']>10]
df_10_clothes
# Out:
#      cluster_id  Amount
# 16       148199      20
# 17       150322      11
# 20       186753      12
# 24       200956      15
# 34       308891      13
# 38       363117      13
# 39       371522      11
# 40       390077      13
# 58       570162      11
# 66       668889      12
# 71       800686      11
# 73       878031      14
# 81       944406      16
# 83       950691      14
# 89       998602      15
# 96      1067266      11
# 101     1143749      11
# 102     1151318      11
# 105     1187638      15
# 110     1249086      12
# 120     1467318      21
# 132     1601750      14
# 143     1776451      11
# 147     1812180      11
# 167     2385296      11
# 173     2628369      15
# 177     2732926      11
# 181     2929687      11
# 187     2951290      12
# 201     3826688      11
# 209     4676796      13
# 213     5121322    1814
# 215     5313953      30
# 224     8280952      16
# 226    12651417      12
# 229    17020190      11
# 232    22374911      15
# 233    22374917      16
# 234    22374918      14
# 236    23221103      24
# 249    44159446      13
# 252    50849594      13
# 255    57829305      14
# 256    57968795      12
# 257    58083280      19
# 261    58592784      17
# 270    68554513      12
# 282    77602818      15
# 283    78110534      12
# 284    78499693      15
# 286    80330359      13

# %%
#merge brand name to cluster amount
df_cluster_brand_clothes = df_10_clothes[df_10_clothes['Amount']<400].merge(df_joined_clothes.dropna()[['cluster_id','brand_y']].drop_duplicates('cluster_id', keep='last'), left_on=['cluster_id'], right_on = ['cluster_id'], how='left')
df_cluster_brand_clothes
# Out:
#      cluster_id  Amount          brand_y
# 0          5310      11           armani
# 1         37366      14        tag heuer
# 2         37525      12            coach
# 3         42322      14        tag heuer
# 4         58043      12              NaN
# ..          ...     ...              ...
# 262    68554513      13              NaN
# 263    77602818      16        valentino
# 264    78110534      13  dolce & gabbana
# 265    78499693      16  dolce & gabbana
# 266    80330359      14        valentino
#
# [267 rows x 3 columns]

# %%
df_joined_clothes=df_joined_clothes.dropna(subset = ['name'])
#clean product column and lowercase
df_joined_clothes['name'] = df_joined_clothes['name'].apply(lambda row: row.lower())
df_joined_clothes
#get only cluster ids with at least one brand electronics
df_compare_clothes = df_joined_clothes[df_joined_clothes['cluster_id'].isin(df_set_clothes['cluster_id'].tolist())]
#merge with set to get amount of tables per cluster in overview
df_compare_clothes = df_compare_clothes.merge(df_set_clothes, left_on=['cluster_id'], right_on = ['cluster_id'], how='left')

# %%
#use tokenizer for product names to get tokes for training the model
df_compare_clothes['product_tokes'] = df_compare_clothes['name'].apply(lambda row: word_tokenize(row))
df_compare_clothes['product_tokes'] = remove_stopwords(df_compare_clothes['product_tokes'],stopwords.words())
df_compare_clothes['product_tokes'] = remove_punctuation (df_compare_clothes['product_tokes'])
#get tagged words
tagged_data = [TaggedDocument(words=_d, tags=[str(i)]) for i, _d in enumerate(df_compare_clothes['product_tokes'])]
# build model and vocabulary
model = Doc2Vec(vector_size=50, min_count = 5, epochs = 25, dm = 0)
model.build_vocab(tagged_data)
# Train model
model.train(tagged_data, total_examples=model.corpus_count, epochs=25)

# %%
#get cluster ids and with that indices of top products to use model
#5310, 58043,104343,142594,174327, 186753,421372,677207,834201, 881202,  895708,939889, 1249086,1290229, 1852022,2459966, 2732926 , 22374915, 22374918, 26097914,44159446, 58592784, 78110534,135583,148199, 200956, 950691, 1592417,2464591
top_clusters_list = df_10_clothes['cluster_id'].tolist()
index_top_clusters_list=[]
for id in top_clusters_list:
    index_top_clusters_list.append(df_compare_clothes[df_compare_clothes['cluster_id']==id].index[0])

# %%
# get most similar products for each of the base clusters and save them if they have more than 5 tables
clothes_clusters_search=[]
for i in index_top_clusters_list:
    similar_doc = model.docvecs.most_similar(f'{i}', topn = 20)
    clothes_clusters_search.append(int(i))
    for index, similarity in similar_doc:
        if df_compare_clothes.iloc[int(index)]['Amount']>8:
            clothes_clusters_search.append(int(index))
    jaccard_score = df_compare_clothes['product_tokes'].apply(lambda row: jaccard_similarity_score(row,df_compare_clothes.iloc[int(i)]['product_tokes']) )
    indizes=sorted(range(len(jaccard_score)), key=lambda i: jaccard_score[i])[-20:]
    for index in indizes:
         if df_compare_clothes.iloc[int(index)]['Amount']>8:
            clothes_clusters_search.append(int(index))    
df_clothes_final = df_compare_clothes.iloc[clothes_clusters_search]

# %%
df_clothes_final.drop_duplicates('cluster_id', keep='first').to_excel("Final_Clothes_v4.xlsx")

# %%
df_joined_clothes = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Clothes_clusters_all_8_tables_post_processed_lower_threshold.csv'))
df_joined_clothes['category']='clothes'

# %%
df_joined_electronics = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Electronics_clusters_all_8_tables_post_processed_lower_threshold.csv'))
df_joined_electronics['category']='electronics'

# %%
df_joined_bikes = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Bikes_clusters_all_8_tables_post_processed_lower_threshold.csv'))
df_joined_bikes['category']='bikes'

# %%
df_joined_cars = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Cars_clusters_all_8_tables_post_processed_lower_threshold.csv'))
df_joined_cars['category']='cars'

# %%
df_joined_technology = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Technology_clusters_all_8_tables_post_processed_lower_threshold.csv'))
df_joined_technology['category']='technology'

# %%
df_joined_drugstore = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Drugstore_clusters_all_8_tables_post_processed_lower_threshold.csv'))
df_joined_drugstore['category']='drugstore'

# %%
df_joined_tools = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Tools_clusters_all_8_tables_post_processed_lower_threshold.csv'))
df_joined_tools['category']='tools'

# %%
df_joined_random = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Random_clusters_all_8_tables_post_processed_lower_threshold.csv'))
df_joined_random['category']='random'

# %%
frames = [df_joined_electronics, df_joined_clothes,df_joined_bikes,df_joined_cars,df_joined_technology,df_joined_drugstore,df_joined_tools,df_joined_random]
df_concat = pd.concat(frames).drop(columns = ['Unnamed: 0','Unnamed: 0.1','Valid'])
df_concat
# Out:
#        cluster_id  \
# 0         2456244
# 1            9885
# 2           16617
# 3          323989
# 4          210849
# ...           ...
# 21663    35840949
# 21664    36306411
# 21665    62520180
# 21666    56187443
# 21667     5121322
#
#                                                                                                                                   url  \
# 0                                                      https://shop-stjohns.simplyforlife.com/quest-chips-cheddar-sour-cream-32g.html
# 1                                     https://www.tecnoprecios.net/t%C3%B3ner-original/497-toner-canon-723-amarillo-8500-paginas.html
# 2                                                      https://simplifinetworks.com/v2/point-to-multi-point/266-nanobeam-ac-gen2.html
# 3                                                                           https://store.macs-4-u.com.au/usb-c-charge-cable-1-m.html
# 4                                                        https://www.cingolanibikeshop.com/specialized-sella-power-comp-nero-143.html
# ...                                                                                                                               ...
# 21663                    https://www.taffscarpets.com/american-olean-quarry-tile-reds--oranges-canyon-red-2-tile-flooring-0q0122chipa
# 21664  https://www.mainstreetfloorcoveringvermont.com/american-olean-mirasol-whites--creams-silver-marble-12-tile-flooring-ml7212121p
# 21665                   https://www.thefloordrs.com/american-olean-quarry-naturals-beiges--browns-desert--2-tile-flooring-0n0322chipa
# 21666                                                https://www.amitybicycles.com/product/garmin-edge-510-silicone-case-198697-1.htm
# 21667                                                       https://kensphilodendrons.com/product/anthurium-clavigerum-plant-on-totem
#
#        row_id  \
# 0        1958
# 1         607
# 2         167
# 3         192
# 4         447
# ...       ...
# 21663      47
# 21664      35
# 21665      59
# 21666     353
# 21667      27
#
#                                                                table_id  \
# 0                       Product_simplyforlife.com_September2020.json.gz
# 1                        Product_tecnoprecios.net_September2020.json.gz
# 2                    Product_simplifinetworks.com_September2020.json.gz
# 3                         Product_macs-4-u.com.au_September2020.json.gz
# 4                   Product_cingolanibikeshop.com_September2020.json.gz
# ...                                                                 ...
# 21663                    Product_taffscarpets.com_September2020.json.gz
# 21664  Product_mainstreetfloorcoveringvermont.com_September2020.json.gz
# 21665                     Product_thefloordrs.com_September2020.json.gz
# 21666                   Product_amitybicycles.com_September2020.json.gz
# 21667               Product_kensphilodendrons.com_September2020.json.gz
#
#                                                             name  \
# 0      quest nutrition quest - chips, cheddar & sour cream (32g)
# 1                          toner canon 723 amarillo 8500 páginas
# 2                                               nanobeam-ac-gen2
# 3                                       usb-c charge cable (1 m)
# 4                          specialized sella power comp nero 143
# ...                                                          ...
# 21663                               quarry tile canyon red q01 1
# 21664                                 mirasol silver marble ml72
# 21665                                quarry naturals desertn03 1
# 21666                                     edge 510 silicone case
# 21667                  anthurium clavigerum plant in 2x2x7\" pot
#
#                                                                                                                                                                                                                                                                 description  \
# 0                                                                                                                                                                                                                                                                       NaN
# 1                                                                                                                                                                                                                          TONER CANON 723 AMARILLO 8500 PáGINAS LBP7750CDN
# 2                         NBE-5AC-Gen2The sleek NanoBeam design with proprietary airMAX ac chipset and dedicated management Wi-Fi for easy U Mobile app support and fast setup. This airMAX ac CPE pivots on a ball joint for mounting and alignment flexibility.DATA SHEET
# 3                                                                                                                                                                                                                                                  USB-C Charge Cable (1 m)
# 4                                                                                                                                                                                                                                                 SELLA POWER COMP NERO 143
# ...                                                                                                                                                                                                                                                                     ...
# 21663                                                                                                                      Taff's Carpets in Kearney has a top selection of American Olean Ceramic & Porcelain Tile Flooring, including Quarry Tile Canyon Red in 2\" x 2\"
# 21664                                                                                                 Main Street Floor Covering in Essex Junction has a top selection of American Olean Ceramic & Porcelain Tile Flooring, including Mirasol™ Silver Marble in 12\" x 12\"
# 21665                                                                                                             The Floor Doctors in Des Moines has a top selection of American Olean Ceramic & Porcelain Tile Flooring, including Quarry Naturals® Desert * in 2\" x 2\"
# 21666                                                                                                        Protect your Garmin Edge 510 with a form-fitting, silicone case and keep your mind at ease. Choose from a variety of cool colors to match your personal style.
# 21667  One of the largest climbing and most unusual Leaf varieties of Anthurium This plant grows rapidly on moist totems and even faster when allowed to climb outdoors in zone 10 and above. This beautiful rare plant is a great addition to any conservatory collection.
#
#                brand_x         brand_y  \
# 0      Quest Nutrition             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4          Specialized             NaN
# ...                ...             ...
# 21663   American Olean  american olean
# 21664   American Olean  american olean
# 21665   American Olean  american olean
# 21666              NaN             NaN
# 21667            Ken's             NaN
#
#                                                                             tokens  \
# 0      ['quest', 'nutrition', 'quest', 'chips', 'cheddar', 'sour', 'cream', '32g']
# 1                         ['toner', 'canon', '723', 'amarillo', '8500', 'páginas']
# 2                                                             ['nanobeam-ac-gen2']
# 3                                                ['usb-c', 'charge', 'cable', '1']
# 4                         ['specialized', 'sella', 'power', 'comp', 'nero', '143']
# ...                                                                            ...
# 21663                                      ['quarry', 'canyon', 'red', 'q01', '1']
# 21664                                      ['mirasol', 'silver', 'marble', 'ml72']
# 21665                                     ['quarry', 'naturals', 'desertn03', '1']
# 21666                                          ['edge', '510', 'silicone', 'case']
# 21667                        ['anthurium', 'clavigerum', 'plant', '2x2x7\\', "''"]
#
#           category
# 0      electronics
# 1      electronics
# 2      electronics
# 3      electronics
# 4      electronics
# ...            ...
# 21663       random
# 21664       random
# 21665       random
# 21666       random
# 21667       random
#
# [64935 rows x 10 columns]

# %%
df_grouped= df_concat.groupby('cluster_id').count()
# only look at clusters that have at least one brand associated
df_set = df_grouped.reset_index()[['cluster_id','table_id']].rename(columns={'table_id':'Amount'})

# %%
df_set=df_set[df_set['Amount']>7]

# %%
df_10=df_set[df_set['Amount']>15]

# %%
df_10
# Out:
#       cluster_id  Amount
# 11          6076      18
# 12          6443      21
# 15          6690      19
# 25          9046      19
# 32         12841      23
# ...          ...     ...
# 3120    77483648     500
# 3126    78260404      78
# 3135    79641193      17
# 3136    79862908      22
# 3138    80097153      59
#
# [626 rows x 2 columns]

# %%
#clean product column and lowercase
df_concat=df_concat.dropna(subset = ['name'])
df_concat['name'] = df_concat['name'].apply(lambda row: row.lower())
df_concat
#get only cluster ids with at least one brand electronics
df_compare = df_concat[df_concat['cluster_id'].isin(df_set['cluster_id'].tolist())]
#merge with set to get amount of tables per cluster in overview
df_compare = df_compare.merge(df_set, left_on=['cluster_id'], right_on = ['cluster_id'], how='left')
# Out:
# <ipython-input-67-83c1e9bd45a7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_concat['name'] = df_concat['name'].apply(lambda row: row.lower())

# %%
df_compare
# Out:
#        cluster_id  \
# 0         2456244
# 1           16617
# 2          323989
# 3          345616
# 4          213496
# ...           ...
# 57772      617074
# 57773    35840949
# 57774    36306411
# 57775    56187443
# 57776     5121322
#
#                                                                                                                                   url  \
# 0                                                      https://shop-stjohns.simplyforlife.com/quest-chips-cheddar-sour-cream-32g.html
# 1                                                      https://simplifinetworks.com/v2/point-to-multi-point/266-nanobeam-ac-gen2.html
# 2                                                                           https://store.macs-4-u.com.au/usb-c-charge-cable-1-m.html
# 3        https://www.scan.co.uk/products/6tb-wd-red-pro-wd6003ffbx-35-nas-hdd-sata-iii-6gb-s-7200rpm-256mb-cache-shock-sensor-ncq-oem
# 4                                                                                   https://de.camerok.com/Sony_SEL30M35_camera_lense
# ...                                                                                                                               ...
# 57772                                                      https://www.giantrenosparks.com/product/garmin-forerunner-245-365508-1.htm
# 57773                    https://www.taffscarpets.com/american-olean-quarry-tile-reds--oranges-canyon-red-2-tile-flooring-0q0122chipa
# 57774  https://www.mainstreetfloorcoveringvermont.com/american-olean-mirasol-whites--creams-silver-marble-12-tile-flooring-ml7212121p
# 57775                                                https://www.amitybicycles.com/product/garmin-edge-510-silicone-case-198697-1.htm
# 57776                                                       https://kensphilodendrons.com/product/anthurium-clavigerum-plant-on-totem
#
#        row_id  \
# 0        1958
# 1         167
# 2         192
# 3        4945
# 4         644
# ...       ...
# 57772     128
# 57773      47
# 57774      35
# 57775     353
# 57776      27
#
#                                                                table_id  \
# 0                       Product_simplyforlife.com_September2020.json.gz
# 1                    Product_simplifinetworks.com_September2020.json.gz
# 2                         Product_macs-4-u.com.au_September2020.json.gz
# 3                              Product_scan.co.uk_September2020.json.gz
# 4                             Product_camerok.com_September2020.json.gz
# ...                                                                 ...
# 57772                 Product_giantrenosparks.com_September2020.json.gz
# 57773                    Product_taffscarpets.com_September2020.json.gz
# 57774  Product_mainstreetfloorcoveringvermont.com_September2020.json.gz
# 57775                   Product_amitybicycles.com_September2020.json.gz
# 57776               Product_kensphilodendrons.com_September2020.json.gz
#
#                                                             name  \
# 0      quest nutrition quest - chips, cheddar & sour cream (32g)
# 1                                               nanobeam-ac-gen2
# 2                                       usb-c charge cable (1 m)
# 3                   wd red pro 6tb 3.5\" sata nas hdd/hard drive
# 4                                     sony sel30m35 camera lense
# ...                                                          ...
# 57772                                             forerunner 245
# 57773                               quarry tile canyon red q01 1
# 57774                                 mirasol silver marble ml72
# 57775                                     edge 510 silicone case
# 57776                  anthurium clavigerum plant in 2x2x7\" pot
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           NaN
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NBE-5AC-Gen2The sleek NanoBeam design with proprietary airMAX ac chipset and dedicated management Wi-Fi for easy U Mobile app support and fast setup. This airMAX ac CPE pivots on a ball joint for mounting and alignment flexibility.DATA SHEET
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      USB-C Charge Cable (1 m)
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        6TB WD Red Pro WD6003FFBX, 3.5\" NAS HDD, SATA III 6Gb/s, 7200rpm, 256MB Cache, Shock Sensor, NCQ, OEM
# 4      Dieses Objektiv wurde entwickelt, um bieten vielseitige Hochleistungs-makro-Funktionen in einem kompakten, leichten Körper. Es ist eine echte 1:1 makro-Objektiv mit einer erstaunlichen Naheinstellgrenze von nur knapp 1 Zoll.Die SEL30M35 wurde entwickelt, um bieten vielseitige Hochleistungs-makro-Funktionen in einem Objektiv ist kompakt, leicht und einfach zu bedienen. Es ist eine echte 1:1 makro-Objektiv mit 2,4 Zentimeter minimale Arbeitsabstand ermöglicht winzigen Themen und details zu erbringenden mit hervorragender Auflösung und Kontrast.1:1 AbbildungsmaßstabDie SEL30M35 hat eine 1:1-Abbildungsmaßstab so, dass die Probanden erfasst werden können, werden in voller Größe auf dem Bildsensor der Kamera. Dies macht es einfach, um zu Schießen Qualität makro-Nahaufnahmen von Blumen, Insekten und kleine Objekte.Asphärische/ED-Glas-ElementeDie SEL30M35 bietet eine hervorragende Bildqualität über den gesamten Bildbereich, mit hohem Kontrast und minimale chromatische aberration von unendlich bis 1:1 Vergrößerung bei allen Blendeneinstellungen. ED-Glas verwendet wird, für die G4-element, minimieren die chromatische aberration und die Farbe Blutungen sowie multi-Beschichtung während für besonders saubere, klare rendering.Gemacht für FilmeDie SEL30M35 ebenso führt auch bei Videoaufnahmen. Dank eines internen Schrittmotor und hinten-mit Schwerpunkt design ist optimiert für video-performance für Laufruhe Grundvoraussetzung für hochwertige Film zu erfassen. Darüber hinaus werden die filter Halterung nicht drehen, während der Schwerpunkt für die problemlose polarisierten filter verwenden.Glatte Manuelle FokussierungEin easy-grip-Fokus-ring auf dem Objektivtubus gibt Ihnen eine Feste \"hands-on\" fühlen sich in der manuellen Fokussierung. Zusätzlich, Direct Manual Focus (DMF) können Sie den Fokus manuell nach AF lock-on, ohne die Notwendigkeit für einen Wechsel. Dies kann sehr nützlich in Situationen, in denen der AF nicht sperren auf das Thema genau, oder wenn AF Schlösser auf einen Punkt, der nicht mit Ihrer Absicht. Elektronische manueller Fokus-Technologie wurde ursprünglich entwickelt für den professionellen Sony Camcorder, um glatte, präzise Fokussierung.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 57772                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              You do the running. Forerunner 245 does the thinking. This GPS smartwatch doesn’t just tell you where you ran. It tracks your stats, crunches the numbers and gets to know all about your...
# 57773                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Taff's Carpets in Kearney has a top selection of American Olean Ceramic & Porcelain Tile Flooring, including Quarry Tile Canyon Red in 2\" x 2\"
# 57774                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Main Street Floor Covering in Essex Junction has a top selection of American Olean Ceramic & Porcelain Tile Flooring, including Mirasol™ Silver Marble in 12\" x 12\"
# 57775                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Protect your Garmin Edge 510 with a form-fitting, silicone case and keep your mind at ease. Choose from a variety of cool colors to match your personal style.
# 57776                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      One of the largest climbing and most unusual Leaf varieties of Anthurium This plant grows rapidly on moist totems and even faster when allowed to climb outdoors in zone 10 and above. This beautiful rare plant is a great addition to any conservatory collection.
#
#                brand_x         brand_y  \
# 0      Quest Nutrition             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                   WD             NaN
# 4                 Sony             NaN
# ...                ...             ...
# 57772              NaN             NaN
# 57773   American Olean  american olean
# 57774   American Olean  american olean
# 57775              NaN             NaN
# 57776            Ken's             NaN
#
#                                                                             tokens  \
# 0      ['quest', 'nutrition', 'quest', 'chips', 'cheddar', 'sour', 'cream', '32g']
# 1                                                             ['nanobeam-ac-gen2']
# 2                                                ['usb-c', 'charge', 'cable', '1']
# 3          ['wd', 'red', 'pro', '6tb', '3.5\\', "''", 'sata', 'hdd/hard', 'drive']
# 4                                          ['sony', 'sel30m35', 'camera', 'lense']
# ...                                                                            ...
# 57772                                                        ['forerunner', '245']
# 57773                                      ['quarry', 'canyon', 'red', 'q01', '1']
# 57774                                      ['mirasol', 'silver', 'marble', 'ml72']
# 57775                                          ['edge', '510', 'silicone', 'case']
# 57776                        ['anthurium', 'clavigerum', 'plant', '2x2x7\\', "''"]
#
#           category  Amount
# 0      electronics      23
# 1      electronics      18
# 2      electronics      12
# 3      electronics      13
# 4      electronics      11
# ...            ...     ...
# 57772       random     110
# 57773       random      10
# 57774       random      22
# 57775       random      28
# 57776       random    9920
#
# [57777 rows x 11 columns]

# %%
#use tokenizer for product names to get tokes for training the model
df_compare['product_tokes'] = df_compare['name'].apply(lambda row: word_tokenize(row))
df_compare['product_tokes'] = remove_stopwords(df_compare['product_tokes'],stopwords.words())
df_compare['product_tokes'] = remove_punctuation (df_compare['product_tokes'])
#get tagged words
tagged_data = [TaggedDocument(words=_d, tags=[str(i)]) for i, _d in enumerate(df_compare['product_tokes'])]
# build model and vocabulary
model = Doc2Vec(vector_size=50, min_count = 5, epochs = 25, dm = 0)
model.build_vocab(tagged_data)
# Train model
model.train(tagged_data, total_examples=model.corpus_count, epochs=25)

# %%
#get cluster ids for basline products and with that indices of top products to use model
#1524820,47566,6076,14418,28307,33570,39040,51314,99153,215254,685416, 984421 , 1808651,2887810,34506065,47841827,620473,56116,94055, 150211,182246, 516888, 562955 
top_clusters_list = df_10['cluster_id'].tolist()
index_top_clusters_list=[]
for id in top_clusters_list:
    index_top_clusters_list.append(df_compare[df_compare['cluster_id']==id].index[0])

# %%
# get most similar products for each of the base clusters and save them if they have more than 5 tables
count = 0
clusters_search=[]
with progressbar.ProgressBar(max_value=len(index_top_clusters_list)) as bar:
    for i in index_top_clusters_list:
        similar_doc = model.docvecs.most_similar(f'{i}', topn = 20)
        clusters_search.append(int(i))
        for index, similarity in similar_doc:
            if df_compare.iloc[int(index)]['Amount']>7:
                if df_compare.iloc[int(index)]['category']==df_compare.iloc[int(i)]['category']:
                    clusters_search.append(int(index))
        jaccard_score = df_compare['product_tokes'].apply(lambda row: jaccard_similarity_score(row,df_compare.iloc[int(i)]['product_tokes']) )
        indizes=sorted(range(len(jaccard_score)), key=lambda i: jaccard_score[i])[-20:]
        for index in indizes:
            if df_compare.iloc[int(index)]['Amount']>:
                if df_compare.iloc[int(index)]['category']==df_compare.iloc[int(i)]['category']:
                    clusters_search.append(int(index)) 
        count=count+1
        bar.update(count)
df_final = df_compare.iloc[clusters_search]
# Out:
#  29% (184 of 626) |######                | Elapsed Time: 0:30:32 ETA:   1:13:26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-fc4382dc4dd9> in <module>
#       9             if df_compare.iloc[int(index)]['Amount']>8:
#      10                 clusters_search.append(int(index))
# ---> 11         jaccard_score = df_compare['product_tokes'].apply(lambda row: jaccard_similarity_score(row,df_compare.iloc[int(i)]['product_tokes']) )
#      12         indizes=sorted(range(len(jaccard_score)), key=lambda i: jaccard_score[i])[-20:]
#      13         for index in indizes:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-71-fc4382dc4dd9> in <lambda>(row)
#       9             if df_compare.iloc[int(index)]['Amount']>8:
#      10                 clusters_search.append(int(index))
# ---> 11         jaccard_score = df_compare['product_tokes'].apply(lambda row: jaccard_similarity_score(row,df_compare.iloc[int(i)]['product_tokes']) )
#      12         indizes=sorted(range(len(jaccard_score)), key=lambda i: jaccard_score[i])[-20:]
#      13         for index in indizes:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1501             self._validate_integer(key, axis)
#    1502
# -> 1503             return self.obj._ixs(key, axis=axis)
#    1504
#    1505     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    2949             # if we are a copy, mark as such
#    2950             copy = isinstance(new_values, np.ndarray) and new_values.base is None
# -> 2951             result = self._constructor_sliced(
#    2952                 new_values,
#    2953                 index=self.columns,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     266             name = ibase.maybe_extract_name(name, data, type(self))
#     267
# --> 268             if is_empty_data(data) and dtype is None:
#     269                 # gh-17261
#     270                 warnings.warn(
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/construction.py in is_empty_data(data)
#     625     """
#     626     is_none = data is None
# --> 627     is_list_like_without_dtype = is_list_like(data) and not hasattr(data, "dtype")
#     628     is_simple_empty = is_list_like_without_dtype and not data
#     629     return is_none or is_simple_empty
#
# pandas/_libs/lib.pyx in pandas._libs.lib.is_list_like()
#
# pandas/_libs/lib.pyx in pandas._libs.lib.c_is_list_like()
#
# ~/anaconda3/lib/python3.8/abc.py in __instancecheck__(cls, instance)
#      96         def __instancecheck__(cls, instance):
#      97             """Override for isinstance(instance, cls)."""
# ---> 98             return _abc_instancecheck(cls, instance)
#      99
#     100         def __subclasscheck__(cls, subclass):
#
# KeyboardInterrupt:

# %%
df_final.drop_duplicates('cluster_id', keep='first').to_excel("Final_lower threshold.xlsx")

# %%
df_joined_clothes = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Clothes_clusters_all_8_tables_post_processed.csv'))
df_joined_clothes['category']='clothes'

# %%
df_joined_electronics = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Electronics_clusters_all_8_tables_post_processed.csv'))
df_joined_electronics['category']='electronics'

# %%
df_joined_bikes = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Bikes_clusters_all_8_tables_post_processed.csv'))
df_joined_bikes['category']='bikes'

# %%
df_joined_cars = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Cars_clusters_all_8_tables_post_processed.csv'))
df_joined_cars['category']='cars'

# %%
df_joined_technology = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Technology_clusters_all_8_tables_post_processed.csv'))
df_joined_technology['category']='technology'

# %%
df_joined_drugstore = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Drugstore_clusters_all_8_tables_post_processed.csv'))
df_joined_drugstore['category']='drugstore'

# %%
df_joined_tools = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Tools_clusters_all_8_tables_post_processed.csv'))
df_joined_tools['category']='tools'

# %%
df_joined_random = pd.read_csv(os.path.join(mapping_corpus_path_2, 'Random_clusters_all_8_tables_post_processed.csv'))
df_joined_random['category']='random'

# %%
frames = [df_joined_electronics, df_joined_clothes,df_joined_bikes,df_joined_cars,df_joined_technology,df_joined_drugstore,df_joined_tools,df_joined_random]
df_concat = pd.concat(frames).drop(columns = ['Unnamed: 0','Unnamed: 0.1','Valid'])
df_concat
# Out:
#        cluster_id  \
# 0            9885
# 1          323989
# 2          210849
# 3          345616
# 4          213496
# ...           ...
# 19673    35840949
# 19674    36306411
# 19675    62520180
# 19676    56187443
# 19677     5121322
#
#                                                                                                                                   url  \
# 0                                     https://www.tecnoprecios.net/t%C3%B3ner-original/497-toner-canon-723-amarillo-8500-paginas.html
# 1                                                                           https://store.macs-4-u.com.au/usb-c-charge-cable-1-m.html
# 2                                                        https://www.cingolanibikeshop.com/specialized-sella-power-comp-nero-143.html
# 3        https://www.scan.co.uk/products/6tb-wd-red-pro-wd6003ffbx-35-nas-hdd-sata-iii-6gb-s-7200rpm-256mb-cache-shock-sensor-ncq-oem
# 4                                                                                   https://de.camerok.com/Sony_SEL30M35_camera_lense
# ...                                                                                                                               ...
# 19673                    https://www.taffscarpets.com/american-olean-quarry-tile-reds--oranges-canyon-red-2-tile-flooring-0q0122chipa
# 19674  https://www.mainstreetfloorcoveringvermont.com/american-olean-mirasol-whites--creams-silver-marble-12-tile-flooring-ml7212121p
# 19675                   https://www.thefloordrs.com/american-olean-quarry-naturals-beiges--browns-desert--2-tile-flooring-0n0322chipa
# 19676                                                https://www.amitybicycles.com/product/garmin-edge-510-silicone-case-198697-1.htm
# 19677                                                       https://kensphilodendrons.com/product/anthurium-clavigerum-plant-on-totem
#
#        row_id  \
# 0         607
# 1         192
# 2         447
# 3        4945
# 4         644
# ...       ...
# 19673      47
# 19674      35
# 19675      59
# 19676     353
# 19677      27
#
#                                                                table_id  \
# 0                        Product_tecnoprecios.net_September2020.json.gz
# 1                         Product_macs-4-u.com.au_September2020.json.gz
# 2                   Product_cingolanibikeshop.com_September2020.json.gz
# 3                              Product_scan.co.uk_September2020.json.gz
# 4                             Product_camerok.com_September2020.json.gz
# ...                                                                 ...
# 19673                    Product_taffscarpets.com_September2020.json.gz
# 19674  Product_mainstreetfloorcoveringvermont.com_September2020.json.gz
# 19675                     Product_thefloordrs.com_September2020.json.gz
# 19676                   Product_amitybicycles.com_September2020.json.gz
# 19677               Product_kensphilodendrons.com_September2020.json.gz
#
#                                                name  \
# 0             toner canon 723 amarillo 8500 páginas
# 1                          usb-c charge cable (1 m)
# 2             specialized sella power comp nero 143
# 3      wd red pro 6tb 3.5\" sata nas hdd/hard drive
# 4                        sony sel30m35 camera lense
# ...                                             ...
# 19673                  quarry tile canyon red q01 1
# 19674                    mirasol silver marble ml72
# 19675                   quarry naturals desertn03 1
# 19676                        edge 510 silicone case
# 19677     anthurium clavigerum plant in 2x2x7\" pot
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              TONER CANON 723 AMARILLO 8500 PáGINAS LBP7750CDN
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      USB-C Charge Cable (1 m)
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     SELLA POWER COMP NERO 143
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        6TB WD Red Pro WD6003FFBX, 3.5\" NAS HDD, SATA III 6Gb/s, 7200rpm, 256MB Cache, Shock Sensor, NCQ, OEM
# 4      Dieses Objektiv wurde entwickelt, um bieten vielseitige Hochleistungs-makro-Funktionen in einem kompakten, leichten Körper. Es ist eine echte 1:1 makro-Objektiv mit einer erstaunlichen Naheinstellgrenze von nur knapp 1 Zoll.Die SEL30M35 wurde entwickelt, um bieten vielseitige Hochleistungs-makro-Funktionen in einem Objektiv ist kompakt, leicht und einfach zu bedienen. Es ist eine echte 1:1 makro-Objektiv mit 2,4 Zentimeter minimale Arbeitsabstand ermöglicht winzigen Themen und details zu erbringenden mit hervorragender Auflösung und Kontrast.1:1 AbbildungsmaßstabDie SEL30M35 hat eine 1:1-Abbildungsmaßstab so, dass die Probanden erfasst werden können, werden in voller Größe auf dem Bildsensor der Kamera. Dies macht es einfach, um zu Schießen Qualität makro-Nahaufnahmen von Blumen, Insekten und kleine Objekte.Asphärische/ED-Glas-ElementeDie SEL30M35 bietet eine hervorragende Bildqualität über den gesamten Bildbereich, mit hohem Kontrast und minimale chromatische aberration von unendlich bis 1:1 Vergrößerung bei allen Blendeneinstellungen. ED-Glas verwendet wird, für die G4-element, minimieren die chromatische aberration und die Farbe Blutungen sowie multi-Beschichtung während für besonders saubere, klare rendering.Gemacht für FilmeDie SEL30M35 ebenso führt auch bei Videoaufnahmen. Dank eines internen Schrittmotor und hinten-mit Schwerpunkt design ist optimiert für video-performance für Laufruhe Grundvoraussetzung für hochwertige Film zu erfassen. Darüber hinaus werden die filter Halterung nicht drehen, während der Schwerpunkt für die problemlose polarisierten filter verwenden.Glatte Manuelle FokussierungEin easy-grip-Fokus-ring auf dem Objektivtubus gibt Ihnen eine Feste \"hands-on\" fühlen sich in der manuellen Fokussierung. Zusätzlich, Direct Manual Focus (DMF) können Sie den Fokus manuell nach AF lock-on, ohne die Notwendigkeit für einen Wechsel. Dies kann sehr nützlich in Situationen, in denen der AF nicht sperren auf das Thema genau, oder wenn AF Schlösser auf einen Punkt, der nicht mit Ihrer Absicht. Elektronische manueller Fokus-Technologie wurde ursprünglich entwickelt für den professionellen Sony Camcorder, um glatte, präzise Fokussierung.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 19673                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Taff's Carpets in Kearney has a top selection of American Olean Ceramic & Porcelain Tile Flooring, including Quarry Tile Canyon Red in 2\" x 2\"
# 19674                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Main Street Floor Covering in Essex Junction has a top selection of American Olean Ceramic & Porcelain Tile Flooring, including Mirasol™ Silver Marble in 12\" x 12\"
# 19675                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 The Floor Doctors in Des Moines has a top selection of American Olean Ceramic & Porcelain Tile Flooring, including Quarry Naturals® Desert * in 2\" x 2\"
# 19676                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Protect your Garmin Edge 510 with a form-fitting, silicone case and keep your mind at ease. Choose from a variety of cool colors to match your personal style.
# 19677                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      One of the largest climbing and most unusual Leaf varieties of Anthurium This plant grows rapidly on moist totems and even faster when allowed to climb outdoors in zone 10 and above. This beautiful rare plant is a great addition to any conservatory collection.
#
#               brand_x         brand_y  \
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2         Specialized             NaN
# 3                  WD             NaN
# 4                Sony             NaN
# ...               ...             ...
# 19673  American Olean  american olean
# 19674  American Olean  american olean
# 19675  American Olean  american olean
# 19676             NaN             NaN
# 19677           Ken's             NaN
#
#                                                                         tokens  \
# 0                     ['toner', 'canon', '723', 'amarillo', '8500', 'páginas']
# 1                                            ['usb-c', 'charge', 'cable', '1']
# 2                     ['specialized', 'sella', 'power', 'comp', 'nero', '143']
# 3      ['wd', 'red', 'pro', '6tb', '3.5\\', "''", 'sata', 'hdd/hard', 'drive']
# 4                                      ['sony', 'sel30m35', 'camera', 'lense']
# ...                                                                        ...
# 19673                                  ['quarry', 'canyon', 'red', 'q01', '1']
# 19674                                  ['mirasol', 'silver', 'marble', 'ml72']
# 19675                                 ['quarry', 'naturals', 'desertn03', '1']
# 19676                                      ['edge', '510', 'silicone', 'case']
# 19677                    ['anthurium', 'clavigerum', 'plant', '2x2x7\\', "''"]
#
#           category
# 0      electronics
# 1      electronics
# 2      electronics
# 3      electronics
# 4      electronics
# ...            ...
# 19673       random
# 19674       random
# 19675       random
# 19676       random
# 19677       random
#
# [51631 rows x 10 columns]

# %%
df_grouped= df_concat.groupby('cluster_id').count()
# only look at clusters that have at least one brand associated
df_set = df_grouped.reset_index()[['cluster_id','table_id']].rename(columns={'table_id':'Amount'})

# %%
df_set=df_set[df_set['Amount']>7]

# %%
df_10=df_set[df_set['Amount']>15]

# %%
df_10
# Out:
#       cluster_id  Amount
# 15          6690      17
# 25          9046      19
# 32         12841      23
# 36         14418      24
# 42         16440      21
# ...          ...     ...
# 3052    76869317      59
# 3055    77483648     174
# 3061    78260404      78
# 3069    79641193      17
# 3070    79862908      22
#
# [504 rows x 2 columns]

# %%
#clean product column and lowercase
df_concat=df_concat.dropna(subset = ['name'])
df_concat['name'] = df_concat['name'].apply(lambda row: row.lower())
df_concat
#get only cluster ids with at least one brand electronics
df_compare = df_concat[df_concat['cluster_id'].isin(df_set['cluster_id'].tolist())]
#merge with set to get amount of tables per cluster in overview
df_compare = df_compare.merge(df_set, left_on=['cluster_id'], right_on = ['cluster_id'], how='left')

# %%
df_compare
# Out:
#        cluster_id  \
# 0          323989
# 1          345616
# 2          213496
# 3          167469
# 4         2374515
# ...           ...
# 43490      617074
# 43491    35840949
# 43492    36306411
# 43493    56187443
# 43494     5121322
#
#                                                                                                                                                                                   url  \
# 0                                                                                                                           https://store.macs-4-u.com.au/usb-c-charge-cable-1-m.html
# 1                                                        https://www.scan.co.uk/products/6tb-wd-red-pro-wd6003ffbx-35-nas-hdd-sata-iii-6gb-s-7200rpm-256mb-cache-shock-sensor-ncq-oem
# 2                                                                                                                                   https://de.camerok.com/Sony_SEL30M35_camera_lense
# 3      https://www.boulanger.com/ref/9000224731?xtor=AL-6875-%5B7%5D-%5B1395090794%5D-%5Bdeeplink%5D&utm_medium=affiliation&utm_source=effinity&utm_campaign=7&utm_content=1395090794
# 4                                                                            https://www.tecnoprecios.net/tinta-original/860-multipack-canon-pg-545-cl-546-blister-mg2450-mg2550.html
# ...                                                                                                                                                                               ...
# 43490                                                                                                      https://www.giantrenosparks.com/product/garmin-forerunner-245-365508-1.htm
# 43491                                                                    https://www.taffscarpets.com/american-olean-quarry-tile-reds--oranges-canyon-red-2-tile-flooring-0q0122chipa
# 43492                                                  https://www.mainstreetfloorcoveringvermont.com/american-olean-mirasol-whites--creams-silver-marble-12-tile-flooring-ml7212121p
# 43493                                                                                                https://www.amitybicycles.com/product/garmin-edge-510-silicone-case-198697-1.htm
# 43494                                                                                                       https://kensphilodendrons.com/product/anthurium-clavigerum-plant-on-totem
#
#        row_id  \
# 0         192
# 1        4945
# 2         644
# 3        6052
# 4         611
# ...       ...
# 43490     128
# 43491      47
# 43492      35
# 43493     353
# 43494      27
#
#                                                                table_id  \
# 0                         Product_macs-4-u.com.au_September2020.json.gz
# 1                              Product_scan.co.uk_September2020.json.gz
# 2                             Product_camerok.com_September2020.json.gz
# 3                           Product_boulanger.com_September2020.json.gz
# 4                        Product_tecnoprecios.net_September2020.json.gz
# ...                                                                 ...
# 43490                 Product_giantrenosparks.com_September2020.json.gz
# 43491                    Product_taffscarpets.com_September2020.json.gz
# 43492  Product_mainstreetfloorcoveringvermont.com_September2020.json.gz
# 43493                   Product_amitybicycles.com_September2020.json.gz
# 43494               Product_kensphilodendrons.com_September2020.json.gz
#
#                                                                    name  \
# 0                                              usb-c charge cable (1 m)
# 1                          wd red pro 6tb 3.5\" sata nas hdd/hard drive
# 2                                            sony sel30m35 camera lense
# 3      caméra de sécurité xiaomi mi home security camera 360degrés 1080
# 4                        cartucho tinta canon pg545 negro + cl546 color
# ...                                                                 ...
# 43490                                                    forerunner 245
# 43491                                      quarry tile canyon red q01 1
# 43492                                        mirasol silver marble ml72
# 43493                                            edge 510 silicone case
# 43494                         anthurium clavigerum plant in 2x2x7\" pot
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      USB-C Charge Cable (1 m)
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        6TB WD Red Pro WD6003FFBX, 3.5\" NAS HDD, SATA III 6Gb/s, 7200rpm, 256MB Cache, Shock Sensor, NCQ, OEM
# 2      Dieses Objektiv wurde entwickelt, um bieten vielseitige Hochleistungs-makro-Funktionen in einem kompakten, leichten Körper. Es ist eine echte 1:1 makro-Objektiv mit einer erstaunlichen Naheinstellgrenze von nur knapp 1 Zoll.Die SEL30M35 wurde entwickelt, um bieten vielseitige Hochleistungs-makro-Funktionen in einem Objektiv ist kompakt, leicht und einfach zu bedienen. Es ist eine echte 1:1 makro-Objektiv mit 2,4 Zentimeter minimale Arbeitsabstand ermöglicht winzigen Themen und details zu erbringenden mit hervorragender Auflösung und Kontrast.1:1 AbbildungsmaßstabDie SEL30M35 hat eine 1:1-Abbildungsmaßstab so, dass die Probanden erfasst werden können, werden in voller Größe auf dem Bildsensor der Kamera. Dies macht es einfach, um zu Schießen Qualität makro-Nahaufnahmen von Blumen, Insekten und kleine Objekte.Asphärische/ED-Glas-ElementeDie SEL30M35 bietet eine hervorragende Bildqualität über den gesamten Bildbereich, mit hohem Kontrast und minimale chromatische aberration von unendlich bis 1:1 Vergrößerung bei allen Blendeneinstellungen. ED-Glas verwendet wird, für die G4-element, minimieren die chromatische aberration und die Farbe Blutungen sowie multi-Beschichtung während für besonders saubere, klare rendering.Gemacht für FilmeDie SEL30M35 ebenso führt auch bei Videoaufnahmen. Dank eines internen Schrittmotor und hinten-mit Schwerpunkt design ist optimiert für video-performance für Laufruhe Grundvoraussetzung für hochwertige Film zu erfassen. Darüber hinaus werden die filter Halterung nicht drehen, während der Schwerpunkt für die problemlose polarisierten filter verwenden.Glatte Manuelle FokussierungEin easy-grip-Fokus-ring auf dem Objektivtubus gibt Ihnen eine Feste \"hands-on\" fühlen sich in der manuellen Fokussierung. Zusätzlich, Direct Manual Focus (DMF) können Sie den Fokus manuell nach AF lock-on, ohne die Notwendigkeit für einen Wechsel. Dies kann sehr nützlich in Situationen, in denen der AF nicht sperren auf das Thema genau, oder wenn AF Schlösser auf einen Punkt, der nicht mit Ihrer Absicht. Elektronische manueller Fokus-Technologie wurde ursprünglich entwickelt für den professionellen Sony Camcorder, um glatte, präzise Fokussierung.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Xiaomi -Caméra de sécurité Domestique 360° 1080P- Blanc
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           MULTIPACK CANON PG-545/CL-546 BLISTER MG2450-MG2550
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 43490                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              You do the running. Forerunner 245 does the thinking. This GPS smartwatch doesn’t just tell you where you ran. It tracks your stats, crunches the numbers and gets to know all about your...
# 43491                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Taff's Carpets in Kearney has a top selection of American Olean Ceramic & Porcelain Tile Flooring, including Quarry Tile Canyon Red in 2\" x 2\"
# 43492                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Main Street Floor Covering in Essex Junction has a top selection of American Olean Ceramic & Porcelain Tile Flooring, including Mirasol™ Silver Marble in 12\" x 12\"
# 43493                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Protect your Garmin Edge 510 with a form-fitting, silicone case and keep your mind at ease. Choose from a variety of cool colors to match your personal style.
# 43494                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      One of the largest climbing and most unusual Leaf varieties of Anthurium This plant grows rapidly on moist totems and even faster when allowed to climb outdoors in zone 10 and above. This beautiful rare plant is a great addition to any conservatory collection.
#
#               brand_x         brand_y  \
# 0                 NaN             NaN
# 1                  WD             NaN
# 2                Sony             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
# 43490             NaN             NaN
# 43491  American Olean  american olean
# 43492  American Olean  american olean
# 43493             NaN             NaN
# 43494           Ken's             NaN
#
#                                                                                     tokens  \
# 0                                                        ['usb-c', 'charge', 'cable', '1']
# 1                  ['wd', 'red', 'pro', '6tb', '3.5\\', "''", 'sata', 'hdd/hard', 'drive']
# 2                                                  ['sony', 'sel30m35', 'camera', 'lense']
# 3      ['caméra', 'sécurité', 'xiaomi', 'home', 'security', 'camera', '360degrés', '1080']
# 4                       ['cartucho', 'tinta', 'canon', 'pg545', 'negro', 'cl546', 'color']
# ...                                                                                    ...
# 43490                                                                ['forerunner', '245']
# 43491                                              ['quarry', 'canyon', 'red', 'q01', '1']
# 43492                                              ['mirasol', 'silver', 'marble', 'ml72']
# 43493                                                  ['edge', '510', 'silicone', 'case']
# 43494                                ['anthurium', 'clavigerum', 'plant', '2x2x7\\', "''"]
#
#           category  Amount
# 0      electronics      11
# 1      electronics       9
# 2      electronics      11
# 3      electronics       9
# 4      electronics      16
# ...            ...     ...
# 43490       random     109
# 43491       random      10
# 43492       random      22
# 43493       random      28
# 43494       random    6649
#
# [43495 rows x 11 columns]

# %%
#use tokenizer for product names to get tokes for training the model
df_compare['product_tokes'] = df_compare['name'].apply(lambda row: word_tokenize(row))
df_compare['product_tokes'] = remove_stopwords(df_compare['product_tokes'],stopwords.words())
df_compare['product_tokes'] = remove_punctuation (df_compare['product_tokes'])
#get tagged words
tagged_data = [TaggedDocument(words=_d, tags=[str(i)]) for i, _d in enumerate(df_compare['product_tokes'])]
# build model and vocabulary
model = Doc2Vec(vector_size=50, min_count = 5, epochs = 25, dm = 0)
model.build_vocab(tagged_data)
# Train model
model.train(tagged_data, total_examples=model.corpus_count, epochs=25)

# %%
#get cluster ids for basline products and with that indices of top products to use model
#1524820,47566,6076,14418,28307,33570,39040,51314,99153,215254,685416, 984421 , 1808651,2887810,34506065,47841827,620473,56116,94055, 150211,182246, 516888, 562955 
top_clusters_list = df_10['cluster_id'].tolist()
index_top_clusters_list=[]
for id in top_clusters_list:
    index_top_clusters_list.append(df_compare[df_compare['cluster_id']==id].index[0])

# %%
# get most similar products for each of the base clusters and save them if they have more than 5 tables
count = 0
clusters_search=[]
with progressbar.ProgressBar(max_value=len(index_top_clusters_list)) as bar:
    for i in index_top_clusters_list:
        similar_doc = model.docvecs.most_similar(f'{i}', topn = 20)
        clusters_search.append(int(i))
        for index, similarity in similar_doc:
            if df_compare.iloc[int(index)]['Amount']>7:
                if df_compare.iloc[int(index)]['category']==df_compare.iloc[int(i)]['category']:
                        clusters_search.append(int(index)) 
        jaccard_score = df_compare['product_tokes'].apply(lambda row: jaccard_similarity_score(row,df_compare.iloc[int(i)]['product_tokes']) )
        indizes=sorted(range(len(jaccard_score)), key=lambda i: jaccard_score[i])[-20:]
        for index in indizes:
             if df_compare.iloc[int(index)]['Amount']>7:
                    if df_compare.iloc[int(index)]['category']==df_compare.iloc[int(i)]['category']:
                        clusters_search.append(int(index)) 
        count=count+1
        bar.update(count)
df_final = df_compare.iloc[clusters_search]
# Out:
#   0% (3 of 626) |                        | Elapsed Time: 0:00:20 ETA:   1:45:37
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-8b7bdb66e6b2> in <module>
#      10                 if df_compare.iloc[int(index)]['category']==df_compare.iloc[int(i)]['category']:
#      11                         clusters_search.append(int(index))
# ---> 12         jaccard_score = df_compare['product_tokes'].apply(lambda row: jaccard_similarity_score(row,df_compare.iloc[int(i)]['product_tokes']) )
#      13         indizes=sorted(range(len(jaccard_score)), key=lambda i: jaccard_score[i])[-20:]
#      14         for index in indizes:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-74-8b7bdb66e6b2> in <lambda>(row)
#      10                 if df_compare.iloc[int(index)]['category']==df_compare.iloc[int(i)]['category']:
#      11                         clusters_search.append(int(index))
# ---> 12         jaccard_score = df_compare['product_tokes'].apply(lambda row: jaccard_similarity_score(row,df_compare.iloc[int(i)]['product_tokes']) )
#      13         indizes=sorted(range(len(jaccard_score)), key=lambda i: jaccard_score[i])[-20:]
#      14         for index in indizes:
#
# <ipython-input-4-4510237b5013> in jaccard_similarity_score(original, translation)
#       1 def jaccard_similarity_score(original, translation):
#       2     intersect = set(original).intersection(set(translation))
# ----> 3     union = set(original).union(set(translation))
#       4     try:
#       5         return len(intersect) / len(union)
#
# KeyboardInterrupt:

# %%
df_final.drop_duplicates('cluster_id', keep='first').to_excel("Final_v3.xlsx")
