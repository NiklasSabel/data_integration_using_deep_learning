# %%
#!pip install rank-bm25
# from rank_bm25 import BM25Okapi
import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
import os
from os import listdir
from os.path import isfile, join
import re
import numpy as np
from math import floor, ceil

import json
import gzip

from os import walk
from scipy.spatial import KDTree

# !pip install geopy
# !pip install phonenumbers
# !pip install pycountry

import geopy.distance
import phonenumbers
import pycountry

# %%
path = r"../../../../src/data"
lb_path_min3 = path + r"/LocalBusiness/LocalBusiness_minimum3/geo_preprocessed_v3"
lb_path_top100 = path + r"/LocalBusiness/LocalBusiness_top100/geo_preprocessed_v3"
rest_path_min3 = path + r"/Restaurant/Restaurant_minimum3/geo_preprocessed_v3"
rest_path_top100 = path + r"/Restaurant/Restaurant_top100/geo_preprocessed_v3"
hotel_path_min3 = path + r"/Hotel/Hotel_minimum3/geo_preprocessed_v3"
hotel_path_top100 = path + r"/Hotel/Hotel_top100/geo_preprocessed_v3"

# %%
file_path_list = [lb_path_min3, lb_path_top100, rest_path_min3, rest_path_top100, hotel_path_min3, hotel_path_top100]

for path in file_path_list:
    current = len(os.listdir(path))
    print(current)
# Out:
# 35417
# 100
# 5037
# 100
# 7788
# 98

# %%
file_path_list = [lb_path_min3, lb_path_top100, rest_path_min3, rest_path_top100, hotel_path_min3, hotel_path_top100]


def create_df(file_path):
    files = os.listdir(file_path)
    df_as_list = []
    for lb in files:
        with gzip.open(file_path + '/' + lb, 'r') as dataFile:
            for line in dataFile:
                lineData = json.loads(line.decode('utf-8'))
                lineData["origin"] = lb
                df_as_list.append(lineData)
    df = pd.DataFrame(df_as_list)
    return df


print("creating df")
df_list = []
for file_path in file_path_list:
    df = create_df(file_path)
    df_list.append(df)

df_all = pd.concat(df_list, axis=0, ignore_index=True)

print("concatenation done")
print("Number of unique tables:", df_all['origin'].nunique())
# Out:
# creating df
# concatenation done
# Number of unique tables: 48540

# %%
# First Subset is to get only entries where a telephone nuumber is available
df_clean_phone = df_all[df_all["telephone"].notna()]
# Check number of tables left
print("Number of unique tables with telephone_number:", df_clean_phone["origin"].nunique())

df_clean_phone = df_clean_phone[
    ["row_id", "origin", "name", "address", "page_url", "telephone", "addressregion", "streetaddress",
     "addresslocality", "addresscountry", "longitude", "latitude"]]
# Out:
# Number of unique tables with telephone_number: 36067

# %%
df_clean_phone.head()
# Out:
#     row_id                                           origin  \
# 52       1  LocalBusiness_litmind.com_September2020.json.gz
# 53       2  LocalBusiness_litmind.com_September2020.json.gz
# 56       5  LocalBusiness_litmind.com_September2020.json.gz
# 58       7  LocalBusiness_litmind.com_September2020.json.gz
# 59       8  LocalBusiness_litmind.com_September2020.json.gz
#
#                                                 name  \
# 52                                      Galga Studio
# 53                             Salvador Model Agency
# 56  EFTI - Centro Internacional de Fotografía y Cine
# 58                            Black&amp;berry Models
# 59                                         Yatepeino
#
#                                               address  \
# 52  {'addresslocality': 'Madrid', 'addresscountry'...
# 53  {'postalcode': '28001', 'addresslocality': 'Ma...
# 56                                               None
# 58                                               None
# 59                                               None
#
#                                              page_url      telephone  \
# 52                https://es.litmind.com/galga_studio            +34
# 53         https://es.litmind.com/salvadormodelagency  +34 914310707
# 56  https://www.litmind.com/eftimasterfotografiamo...  +34 915529999
# 58        https://www.litmind.com/blackandberrymodels  +34 666819078
# 59             https://www.litmind.com/yatepeino/info            +93
#
#    addressregion               streetaddress addresslocality addresscountry  \
# 52        Madrid    calle Lorenzo Gonzalez 4          Madrid             ES
# 53        Madrid  General Pardiñas, 34. 1º7ª          Madrid             ES
# 56          None                        None            None           None
# 58          None                        None            None           None
# 59          None                        None            None           None
#
#            longitude         latitude
# 52        -3.6495914       40.4315119
# 53  -3.6835849285126  40.423894105042
# 56              None             None
# 58              None             None
# 59              None             None

# %%
# First round of parsing with raw data
# try parsing only from telephone_numbers

df_clean_phone_parse = df_clean_phone.copy()

def normalizer_2(entity):
    number = entity["telephone"]
    phone_number = phonenumbers.parse(number)
    return phone_number

df_clean_phone_parse.reset_index(inplace=True)
phone_objects = []
for row_index in df_clean_phone_parse.index:
    try:
        phone_object = normalizer_2(df_clean_phone_parse.iloc[row_index])
        phone_objects.append(phone_object)
    except:
        phone_objects.append("unknown")

# %%
# append to df_clean
df_clean_phone_parse["phone_object"] = pd.Series(phone_objects)

# save unkown rows where parser failed
unknown_rows = df_clean_phone_parse[df_clean_phone_parse["phone_object"] == "unknown"]
df_clean_phone_parse = df_clean_phone_parse.drop(unknown_rows.index)

# use phone package to isolate valid phone numbers
df_clean_phone_parse = df_clean_phone_parse[df_clean_phone_parse["phone_object"].apply(phonenumbers.is_valid_number)]
df_clean_phone_parse["E.164 format"] = df_clean_phone_parse["phone_object"].apply(
    lambda objects: phonenumbers.format_number(objects, phonenumbers.PhoneNumberFormat.E164))

# %%
# Have a look at parsed numbers
df_clean_phone_parse['telephoneNorm'] = df_clean_phone_parse['E.164 format'].str.replace('+', '').astype(np.int64)
df_clean_phone_parse["E.164 format"].value_counts().sort_values().tail(20)
# Out:
# /tmp/ipykernel_148074/1964253420.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_clean_phone_parse['telephoneNorm'] = df_clean_phone_parse['E.164 format'].str.replace('+', '').astype(np.int64)
# +918004561000     2383
# +85267718566      2393
# +622139730888     2806
# +74951334958      2853
# +420222518768     2943
# +421915427748     2967
# +420606556615     3035
# +40364431800      3268
# +74956468503      3538
# +919319111766     3709
# +914440114081     3785
# +421905383904     3863
# +420725535406     3892
# +18883836917      4371
# +18885385188      4916
# +14072333331      4918
# +919313931393     6937
# +18884082399      7363
# +918076909847    13811
# +78007750219     23168
# Name: E.164 format, dtype: int64

# %%
df_clean_phone_parse.head()
# Out:
#    index  row_id                                           origin  \
# 1     53       2  LocalBusiness_litmind.com_September2020.json.gz
# 2     56       5  LocalBusiness_litmind.com_September2020.json.gz
# 3     58       7  LocalBusiness_litmind.com_September2020.json.gz
# 5     60       9  LocalBusiness_litmind.com_September2020.json.gz
# 6     61      10  LocalBusiness_litmind.com_September2020.json.gz
#
#                                                name  \
# 1                             Salvador Model Agency
# 2  EFTI - Centro Internacional de Fotografía y Cine
# 3                            Black&amp;berry Models
# 5                                       Nomade MNGT
# 6                                 UNIC AZAFATAS S.L
#
#                                              address  \
# 1  {'postalcode': '28001', 'addresslocality': 'Ma...
# 2                                               None
# 3                                               None
# 5                                               None
# 6  {'postalcode': '28250', 'addresscountry': 'ES'...
#
#                                             page_url       telephone  \
# 1         https://es.litmind.com/salvadormodelagency   +34 914310707
# 2  https://www.litmind.com/eftimasterfotografiamo...   +34 915529999
# 3        https://www.litmind.com/blackandberrymodels   +34 666819078
# 5                 https://es.litmind.com/nomade.mngt  +54 1143611490
# 6                      https://es.litmind.com/456459   +34 918599376
#
#   addressregion               streetaddress addresslocality addresscountry  \
# 1        Madrid  General Pardiñas, 34. 1º7ª          Madrid             ES
# 2          None                        None            None           None
# 3          None                        None            None           None
# 5          None                        None            None           None
# 6        Madrid            C/ TORRENCINA 18    TORRELODONES             ES
#
#           longitude         latitude  \
# 1  -3.6835849285126  40.423894105042
# 2              None             None
# 3              None             None
# 5              None             None
# 6        -3.8939949       40.5808292
#
#                                    phone_object   E.164 format  telephoneNorm
# 1   Country Code: 34 National Number: 914310707   +34914310707    34914310707
# 2   Country Code: 34 National Number: 915529999   +34915529999    34915529999
# 3   Country Code: 34 National Number: 666819078   +34666819078    34666819078
# 5  Country Code: 54 National Number: 1143611490  +541143611490   541143611490
# 6   Country Code: 34 National Number: 918599376   +34918599376    34918599376

# %%
df_clean_phone.head()
# Out:
#     row_id                                           origin  \
# 52       1  LocalBusiness_litmind.com_September2020.json.gz
# 53       2  LocalBusiness_litmind.com_September2020.json.gz
# 56       5  LocalBusiness_litmind.com_September2020.json.gz
# 58       7  LocalBusiness_litmind.com_September2020.json.gz
# 59       8  LocalBusiness_litmind.com_September2020.json.gz
#
#                                                 name  \
# 52                                      Galga Studio
# 53                             Salvador Model Agency
# 56  EFTI - Centro Internacional de Fotografía y Cine
# 58                            Black&amp;berry Models
# 59                                         Yatepeino
#
#                                               address  \
# 52  {'addresslocality': 'Madrid', 'addresscountry'...
# 53  {'postalcode': '28001', 'addresslocality': 'Ma...
# 56                                               None
# 58                                               None
# 59                                               None
#
#                                              page_url      telephone  \
# 52                https://es.litmind.com/galga_studio            +34
# 53         https://es.litmind.com/salvadormodelagency  +34 914310707
# 56  https://www.litmind.com/eftimasterfotografiamo...  +34 915529999
# 58        https://www.litmind.com/blackandberrymodels  +34 666819078
# 59             https://www.litmind.com/yatepeino/info            +93
#
#    addressregion               streetaddress addresslocality addresscountry  \
# 52        Madrid    calle Lorenzo Gonzalez 4          Madrid             ES
# 53        Madrid  General Pardiñas, 34. 1º7ª          Madrid             ES
# 56          None                        None            None           None
# 58          None                        None            None           None
# 59          None                        None            None           None
#
#            longitude         latitude
# 52        -3.6495914       40.4315119
# 53  -3.6835849285126  40.423894105042
# 56              None             None
# 58              None             None
# 59              None             None

# %%
# Now derive all rows where parsing failed
succesful_rows = list(df_clean_phone_parse["index"])
df_residual = df_clean_phone.drop(succesful_rows)

# %%
print(len(df_residual))
print(len(df_clean_phone_parse))
# Out:
# 3898027
# 1007810

# %%
print(len(df_clean_phone))
# Out:
# 4905837

# %%
# Define function for cleaning telephone numbers
def remove_non_digits(string):
    cleaned = re.sub('[^0-9]', '', string)
    return cleaned
df_residual['telephone_'] = df_residual['telephone'].astype('str').apply(remove_non_digits)

# %%
df_residual.head()
# Out:
#     row_id                                           origin  \
# 52       1  LocalBusiness_litmind.com_September2020.json.gz
# 59       8  LocalBusiness_litmind.com_September2020.json.gz
# 66      15  LocalBusiness_litmind.com_September2020.json.gz
# 70      19  LocalBusiness_litmind.com_September2020.json.gz
# 76      25  LocalBusiness_litmind.com_September2020.json.gz
#
#                         name  \
# 52              Galga Studio
# 59                 Yatepeino
# 66  Alessia Model Management
# 70           Cidermill Films
# 76     Neukla web &amp; film
#
#                                               address  \
# 52  {'addresslocality': 'Madrid', 'addresscountry'...
# 59                                               None
# 66                                               None
# 70                                               None
# 76                                               None
#
#                                             page_url           telephone  \
# 52               https://es.litmind.com/galga_studio                 +34
# 59            https://www.litmind.com/yatepeino/info                 +93
# 66  https://cat.litmind.com/alessiamodels/models/men    +1809 8295859639
# 70            https://cat.litmind.com/cidermillfilms                 +93
# 76                 https://es.litmind.com/capt.tousu  +34 00491708332529
#
#    addressregion             streetaddress addresslocality addresscountry  \
# 52        Madrid  calle Lorenzo Gonzalez 4          Madrid             ES
# 59          None                      None            None           None
# 66          None                      None            None           None
# 70          None                      None            None           None
# 76          None                      None            None           None
#
#      longitude    latitude        telephone_
# 52  -3.6495914  40.4315119                34
# 59        None        None                93
# 66        None        None    18098295859639
# 70        None        None                93
# 76        None        None  3400491708332529

# %%
# Preprocessing for 2nd parsing
# now get the rows where we can use additional coutry code for parsing
#  
df_clean = df_residual[df_residual["addresscountry"].notna()]

# %%
# Normalize country codes for telephone package
countries = {}
for country in pycountry.countries:
    countries[country.name] = country.alpha_2


# fuction to modify the country dictionary in uppercase
def modify_dic(d):
    for key in list(d.keys()):
        new_key = key.upper()
        d[new_key] = d[key]
    return d


countries_upper = modify_dic(countries)

# %%
# uppercase the df_column
df_clean["addresscountry"] = df_clean["addresscountry"].str.upper()

# Replace known countries with ISO-2 format country code
for key, value in countries_upper.items():
    df_clean["addresscountry"] = df_clean["addresscountry"].str.replace(key, value)
# Out:
# /tmp/ipykernel_148074/892414598.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["addresscountry"] = df_clean["addresscountry"].str.upper()
# /tmp/ipykernel_148074/892414598.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["addresscountry"] = df_clean["addresscountry"].str.replace(key, value)
# /tmp/ipykernel_148074/892414598.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_clean["addresscountry"] = df_clean["addresscountry"].str.replace(key, value)

# %%
# Manual country code replacement
country_dictionary = {
    "UNITED STATES": "US",
    "USA": "US",
    "UNITED KINGDOM": "GB",
    "UK": "GB",
    "CANADA": "CA",
    "AUSTRALIA": "AU",
    "UNITED ARAB EMIRATES": "AE",
    "UAE": "AE",
    "INDIA": "IN",
    "NEW ZEALAND": "NZ",
    "SVERIGE": "SE",
    "DEUTSCHLAND": "DE",
    "DEU": "DE",
    "RUSSIA": "RU",
    "ITALIA": "IT",
    "IRAN": "IR",
    ", IN": "IN",
    "ENGLAND": "GB",
    "FRA": "FR"
}
for key, value in country_dictionary.items():
    df_clean["addresscountry"] = df_clean["addresscountry"].str.replace(key, value)
# Out:
# /tmp/ipykernel_148074/1587104272.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["addresscountry"] = df_clean["addresscountry"].str.replace(key, value)

# %%
print("phone_number normalizer")
def normalizer(entity):
    number = entity["telephone_"]
    address_country = entity["addresscountry"]
    phone_number = phonenumbers.parse(number, address_country)
    return phone_number
# Out:
# phone_number normalizer

# %%
df_clean.reset_index(inplace=True)
phone_objects = []
for row_index in df_clean.index:
    try:
        phone_object = normalizer(df_clean.iloc[row_index])
        phone_objects.append(phone_object)
    except:
        phone_objects.append("unknown")

# %%
print("normalizer successful")
# Out:
# normalizer successful

# %%
# append to df_clean
df_clean["phone_object"] = pd.Series(phone_objects)

# save unkown rows where parser failed
unknown_rows = df_clean[df_clean["phone_object"] == "unknown"]
df_clean = df_clean.drop(unknown_rows.index)
# Out:
# /tmp/ipykernel_148074/1044015657.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["phone_object"] = pd.Series(phone_objects)

# %%
# use phone package to isolate valid phone numbers
df_clean = df_clean[df_clean["phone_object"].apply(phonenumbers.is_valid_number)]
df_clean["E.164 format"] = df_clean["phone_object"].apply(
    lambda objects: phonenumbers.format_number(objects, phonenumbers.PhoneNumberFormat.E164))

# %%
# Have a look at parsed numbers
df_clean['telephoneNorm'] = df_clean['E.164 format'].str.replace('+', '').astype(np.int64)
df_clean["E.164 format"].value_counts().sort_values().tail(20)
# Out:
# /tmp/ipykernel_148074/2507955437.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_clean['telephoneNorm'] = df_clean['E.164 format'].str.replace('+', '').astype(np.int64)
# +18775784138       1347
# +18886385044       1365
# +34902901532       1444
# +48507717950       1528
# +525541641401      1671
# +443458121007      1701
# +917676202033      1799
# +17136954939       2053
# +491796910164      2059
# +17156937123       2134
# +18664773715       2179
# +611300032861      2209
# +611300695278      2970
# +498912085467      3189
# +917861004444      4051
# +351936408200      5136
# +9118601234569     5487
# +18555161090       6955
# +18884082399       7587
# +33972196746      29080
# Name: E.164 format, dtype: int64

# %%
# Now derive all rows where parsing failed
succesful_rows_2 = list(df_clean["index"])
df_residual_final = df_residual.drop(succesful_rows_2)

# %%
# LOGIC: df_residual_final + df_clean + df_clean_phone_parse must be equal to whole df_clena_phone

# %%
print("Creating Concatenated Dataframes")
# Out:
# Creating Concatenated Dataframes

# %%
### Concatenate dataframes
# First, the subsets which could be parsed with telephone package

df_parsed = pd.concat([df_clean_phone_parse, df_clean], axis=0)

# %%
# append a new column for later grouping

df_residual_final["telephoneNorm"] = df_residual_final["telephone_"]

# %%
# TESTING

first = len(df_residual_final)
second = len(df_clean_phone_parse)
third = len(df_clean)

total = first + second + third
print(total)
print(len(df_clean_phone))
# Out:
# 4905837
# 4905837

# %%
### Final Concatenation

df_total = pd.concat([df_parsed, df_residual_final], axis=0)
df_total["telephoneNorm"].value_counts().sort_values().tail(20)
# Out:
# 0948235300        4299
# 18883836917       4371
# 0                 4416
# 00                4543
# 33972722345       4865
# 18885385188       4916
# 14072333331       4918
# 0977773614        5142
# 8882057322        5237
# 351936408200      5259
# 9118601234569     5487
# 919313931393      6937
# 18555161090       6955
# 331730790630      9870
# 918076909847     13811
# 13126466365      14010
# 18884082399      14950
# 78007750219      23168
# 33972196746      29080
#                  87937
# Name: telephoneNorm, dtype: int64

# %%
### Some cleaning

df_total_clean = df_total[df_total["telephoneNorm"] != ""]
df_total_clean = df_total_clean[df_total_clean["telephoneNorm"] != "0"]
df_total_clean = df_total_clean[df_total_clean["telephoneNorm"] != "00"]

# %%
df_total_clean["telephoneNorm"].value_counts().sort_values().tail(20)
# Out:
# 917861004444      4051
# 02037884841       4107
# 02145682000       4218
# 0948235300        4299
# 18883836917       4371
# 33972722345       4865
# 18885385188       4916
# 14072333331       4918
# 0977773614        5142
# 8882057322        5237
# 351936408200      5259
# 9118601234569     5487
# 919313931393      6937
# 18555161090       6955
# 331730790630      9870
# 918076909847     13811
# 13126466365      14010
# 18884082399      14950
# 78007750219      23168
# 33972196746      29080
# Name: telephoneNorm, dtype: int64

# %%
df_total_clean.head()
# Out:
#    index  row_id                                           origin  \
# 1   53.0       2  LocalBusiness_litmind.com_September2020.json.gz
# 2   56.0       5  LocalBusiness_litmind.com_September2020.json.gz
# 3   58.0       7  LocalBusiness_litmind.com_September2020.json.gz
# 5   60.0       9  LocalBusiness_litmind.com_September2020.json.gz
# 6   61.0      10  LocalBusiness_litmind.com_September2020.json.gz
#
#                                                name  \
# 1                             Salvador Model Agency
# 2  EFTI - Centro Internacional de Fotografía y Cine
# 3                            Black&amp;berry Models
# 5                                       Nomade MNGT
# 6                                 UNIC AZAFATAS S.L
#
#                                              address  \
# 1  {'postalcode': '28001', 'addresslocality': 'Ma...
# 2                                               None
# 3                                               None
# 5                                               None
# 6  {'postalcode': '28250', 'addresscountry': 'ES'...
#
#                                             page_url       telephone  \
# 1         https://es.litmind.com/salvadormodelagency   +34 914310707
# 2  https://www.litmind.com/eftimasterfotografiamo...   +34 915529999
# 3        https://www.litmind.com/blackandberrymodels   +34 666819078
# 5                 https://es.litmind.com/nomade.mngt  +54 1143611490
# 6                      https://es.litmind.com/456459   +34 918599376
#
#   addressregion               streetaddress addresslocality addresscountry  \
# 1        Madrid  General Pardiñas, 34. 1º7ª          Madrid             ES
# 2          None                        None            None           None
# 3          None                        None            None           None
# 5          None                        None            None           None
# 6        Madrid            C/ TORRENCINA 18    TORRELODONES             ES
#
#           longitude         latitude  \
# 1  -3.6835849285126  40.423894105042
# 2              None             None
# 3              None             None
# 5              None             None
# 6        -3.8939949       40.5808292
#
#                                    phone_object   E.164 format telephoneNorm  \
# 1   Country Code: 34 National Number: 914310707   +34914310707   34914310707
# 2   Country Code: 34 National Number: 915529999   +34915529999   34915529999
# 3   Country Code: 34 National Number: 666819078   +34666819078   34666819078
# 5  Country Code: 54 National Number: 1143611490  +541143611490  541143611490
# 6   Country Code: 34 National Number: 918599376   +34918599376   34918599376
#
#   telephone_
# 1        NaN
# 2        NaN
# 3        NaN
# 5        NaN
# 6        NaN

# %%
df_total_clean["origin"].nunique()
# Out:
# 35728

# %%
df_total_clean.to_json("19-12-21_MatchingFile", compression="gzip", orient='records', lines=True)
print("success")
# Out:
# success
