# %% [markdown]
# # This notebook will give a first baseline estimation for the matching of entities via a random forest algorithm as multi-class classification

# %%
import os
import pandas as pd
import gzip
import json
import numpy as np
import nltk
from nltk.corpus import stopwords
import string
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
Path = r'../../Results/New_Concatenated_MatchingFile.gz'
LBData = []

with gzip.open(Path, 'r') as dataFile:
    for line in dataFile:
        lineData = json.loads(line.decode('utf-8'))
        LBData.append(lineData)
data = pd.DataFrame(LBData)

# %%
# get information about train and test table split
product_path = '../../../../src/data/product'
train_test_output_path = os.path.join(product_path, 'train_test_split/output_unfiltered_tables')
zip_files_train = [file for file in os.listdir(os.path.join(train_test_output_path, 'large/train')) if file.endswith('.json.gz')]
zip_files_val = [file for file in os.listdir(os.path.join(train_test_output_path, 'large/val')) if file.endswith('.json.gz')]
zip_files_test = [file for file in os.listdir(os.path.join(train_test_output_path, 'large/test')) if file.endswith('.json.gz')]

# %%
data_test = data[data['origin'].isin(zip_files_test)].reset_index()

# %%
data
# Out:
#          row_id                                           origin  \
# 0             2  LocalBusiness_litmind.com_September2020.json.gz
# 1            10  LocalBusiness_litmind.com_September2020.json.gz
# 2            16  LocalBusiness_litmind.com_September2020.json.gz
# 3            18  LocalBusiness_litmind.com_September2020.json.gz
# 4            20  LocalBusiness_litmind.com_September2020.json.gz
# ...         ...                                              ...
# 1495583    9968              Hotel_ihg.com_September2020.json.gz
# 1495584    9975              Hotel_ihg.com_September2020.json.gz
# 1495585    9977              Hotel_ihg.com_September2020.json.gz
# 1495586    9999              Hotel_ihg.com_September2020.json.gz
# 1495587   10004              Hotel_ihg.com_September2020.json.gz
#
#                                      name  \
# 0                   Salvador Model Agency
# 1                       UNIC AZAFATAS S.L
# 2                                 Coconut
# 3        SDA MODEL'S INTERNATIONAL AGENCY
# 4                       RAMONSERRANOPHOTO
# ...                                   ...
# 1495583                              None
# 1495584                              None
# 1495585                              None
# 1495586                              None
# 1495587                              None
#
#                                                    address  \
# 0        {'postalcode': '28001', 'addresslocality': 'Ma...
# 1        {'postalcode': '28250', 'addresscountry': 'ES'...
# 2        {'streetaddress': 'Calle Zabaleta, 10', 'addre...
# 3        {'postalcode': '28001', 'addresscountry': 'ES'...
# 4        {'addressregion': 'Badajoz', 'addresslocality'...
# ...                                                    ...
# 1495583  {'postalcode': '32608', 'addresslocality': 'Ga...
# 1495584  {'postalcode': '30150-370', 'addresslocality':...
# 1495585  {'postalcode': 'A-9500', 'streetaddress': 'Eur...
# 1495586  {'streetaddress': '12217 4th Street', 'address...
# 1495587  {'postalcode': '76544', 'addresscountry': 'US'...
#
#                                                   page_url       telephone  \
# 0               https://es.litmind.com/salvadormodelagency   +34 914310707
# 1                            https://es.litmind.com/456459   +34 918599376
# 2                https://es.litmind.com/coconutmadrid/info   +34 913776214
# 3                https://es.litmind.com/sdamodelsintagency   +34 640847492
# 4         https://es.litmind.com/ramonserranophoto-estudio   +34 636540326
# ...                                                    ...             ...
# 1495583  https://www.ihg.com/destinations/de/de/united-...   1-352-3781300
# 1495584  https://www.ihg.com/holidayinn/destinations/us...  55-31-30646555
# 1495585  https://www.ihg.com/voco/hotels/fr/fr/villach/...   43-4242-22522
# 1495586  https://www.ihg.com/holidayinnexpress/destinat...   1-250-7827700
# 1495587  https://www.ihg.com/armyhotels/hotels/us/en/fo...   1-254-5328233
#
#                 addressregion                  streetaddress  \
# 0                      Madrid     General Pardiñas, 34. 1º7ª
# 1                      Madrid               C/ TORRENCINA 18
# 2                      Madrid             Calle Zabaleta, 10
# 3                      Madrid          ayala madrid n7 bajos
# 4                     Badajoz           Avd. Constitucion, 2
# ...                       ...                            ...
# 1495583               FLORIDA          3370 S.W. 42nd Street
# 1495584                  None      Rua Professor Moraes, 600
# 1495585                  None              Europaplatz 1 - 2
# 1495586  COLOMBIE BRITANNIQUE               12217 4th Street
# 1495587                 Texas  Bldg 144 761st Tank Battalion
#
#                    addresslocality addresscountry             longitude  \
# 0                           Madrid             ES      -3.6835849285126
# 1                     TORRELODONES             ES            -3.8939949
# 2                           Madrid             ES            -3.6744062
# 3                        barcelona             ES      -3.6825650000001
# 4        Villafranca de los Barros             ES            -6.3428955
# ...                            ...            ...                   ...
# 1495583                Gainesville             US  -8.238674639999999E1
# 1495584        Belo Horizonte - MG             BR          -4.3931513E1
# 1495585                    Villach             AT            1.384929E1
# 1495586               Dawson Creek             CA         -1.20216293E2
# 1495587                   Ft. Hood             US            -97.760556
#
#                     latitude    telephone_  \
# 0            40.423894105042   34914310707
# 1                 40.5808292   34918599376
# 2                 40.4413414   34913776214
# 3                  40.427645   34640847492
# 4                 38.5616549   34636540326
# ...                      ...           ...
# 1495583  2.962221619999999E1   13523781300
# 1495584         -1.9938399E1  553130646555
# 1495585           4.661559E1   43424222522
# 1495586          5.5737782E1   12507827700
# 1495587            31.137222   12545328233
#
#                                               phone_object   E.164 format  \
# 0        {'country_code': 34, 'extension': None, 'natio...   +34914310707
# 1        {'country_code': 34, 'extension': None, 'natio...   +34918599376
# 2        {'country_code': 34, 'extension': None, 'natio...   +34913776214
# 3        {'country_code': 34, 'extension': None, 'natio...   +34640847492
# 4        {'country_code': 34, 'extension': None, 'natio...   +34636540326
# ...                                                    ...            ...
# 1495583  {'country_code': 1, 'extension': None, 'nation...   +13523781300
# 1495584  {'country_code': 55, 'extension': None, 'natio...  +553130646555
# 1495585  {'country_code': 43, 'extension': None, 'natio...   +43424222522
# 1495586  {'country_code': 1, 'extension': None, 'nation...   +12507827700
# 1495587  {'country_code': 1, 'extension': None, 'nation...   +12545328233
#
#          telephoneNorm
# 0          34914310707
# 1          34918599376
# 2          34913776214
# 3          34640847492
# 4          34636540326
# ...                ...
# 1495583    13523781300
# 1495584   553130646555
# 1495585    43424222522
# 1495586    12507827700
# 1495587    12545328233
#
# [1495588 rows x 16 columns]

# %%
def remove_stopwords(token_vector, stopwords_list):
    return token_vector.apply(lambda token_list: [word for word in token_list if word not in stopwords_list])

# %%
def remove_punctuation(token_vector):
    return token_vector.apply(lambda token_list: [word for word in token_list if word not in string.punctuation])

# %%
clusters = data.groupby(['telephoneNorm']).size().reset_index(name='counts').sort_values('counts', ascending=False)
clusters = clusters.loc[clusters['counts'] > 1]
clusteredData = data[data['telephoneNorm'].isin(clusters['telephoneNorm'])]
clusteredData['ClusterID'] = clusteredData.groupby('telephoneNorm').ngroup()
columns = ['name', 'addressregion', 'streetaddress', 'addresslocality', 'addresscountry', 'longitude', 'latitude']
clusteredData['concat'] = clusteredData[columns].astype(str).agg(' '.join, axis=1)
# Out:
# /tmp/ipykernel_630813/917375409.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clusteredData['ClusterID'] = clusteredData.groupby('telephoneNorm').ngroup()
# /tmp/ipykernel_630813/917375409.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clusteredData['concat'] = clusteredData[columns].astype(str).agg(' '.join, axis=1)

# %%
clusteredData.head(1000)
# Out:
#       row_id                                             origin  \
# 29        18  LocalBusiness_sushipointer.com_September2020.j...
# 43        36  LocalBusiness_sushipointer.com_September2020.j...
# 47        40  LocalBusiness_sushipointer.com_September2020.j...
# 52        46  LocalBusiness_sushipointer.com_September2020.j...
# 61        62  LocalBusiness_sushipointer.com_September2020.j...
# ...      ...                                                ...
# 3949     239  LocalBusiness_visitlakegeneva.com_September202...
# 3950     240  LocalBusiness_visitlakegeneva.com_September202...
# 3952     242  LocalBusiness_visitlakegeneva.com_September202...
# 3953     243  LocalBusiness_visitlakegeneva.com_September202...
# 3954     244  LocalBusiness_visitlakegeneva.com_September202...
#
#                                                    name  \
# 29                     L'wzaar Sea Food Restaurant Doha
# 43    Shiki Japanese Fine Dining | Brasserie | Bar V...
# 47                              Restaurant Toshi Munich
# 52                               OKKU Fine Dining Dubai
# 61                              Restaurant EMIKO Munich
# ...                                                 ...
# 3949                                      Rushwood Park
# 3950                           Gordy's Lakefront Marine
# 3952                      Grand Geneva Resort The Brute
# 3953                          Lake Geneva Nails and Spa
# 3954                          East Troy Railroad Museum
#
#                                                 address  \
# 29    {'addresscountry': 'Qatar', 'addressregion': '...
# 43    {'postalcode': '1010', 'addressregion': 'Vienn...
# 47    {'addresslocality': 'Munich', 'postalcode': '8...
# 52    {'addressregion': 'Dubai', 'streetaddress': 'D...
# 61    {'addresslocality': 'Munich', 'postalcode': '8...
# ...                                                 ...
# 3949  {'addresslocality': 'Lake Geneva', 'postalcode...
# 3950  {'postalcode': '53125', 'streetaddress': '320 ...
# 3952  {'addresslocality': 'Lake Geneva', 'streetaddr...
# 3953  {'postalcode': '53147', 'addresscountry': 'UNI...
# 3954  {'streetaddress': '2002 Church Street', 'addre...
#
#                                                page_url          telephone  \
# 29    https://sushipointer.com/places/qatar/doha/doh...     +974 4408 0710
# 43    https://sushipointer.com/places/austria/vienna...      +43 1 5127397
# 47    https://sushipointer.com/places/germany/bavari...    +49 89 25546942
# 52    https://sushipointer.com/places/united-arab-em...    +971 4 501 8777
# 61    https://sushipointer.com/places/germany/bavari...  +49 89 4111908111
# ...                                                 ...                ...
# 3949  https://www.visitlakegeneva.com/listing/rushwo...       262-248-3673
# 3950  https://www.visitlakegeneva.com/listing/gordys...       262-275-2163
# 3952  https://www.visitlakegeneva.com/listing/grand-...     (262) 248-2556
# 3953  https://www.visitlakegeneva.com/listing/lake-g...       262-812-4081
# 3954  https://www.visitlakegeneva.com/listing/east-t...     (262) 642-3263
#
#      addressregion                               streetaddress  \
# 29            Doha  L'wzaar Sea Food Restaurant, Katara Street
# 43          Vienna                              Krugerstraße 3
# 47         Bavaria                             Wurzerstraße 18
# 52           Dubai                                       Dubai
# 61         Bavaria                           Viktualienmarkt 6
# ...            ...                                         ...
# 3949            WI                               Timothy Drive
# 3950            WI                                320 Lake St.
# 3952            WI                       7036 Grand Geneva Way
# 3953            WI                         820 N. Edward Blvd.
# 3954            WI                          2002 Church Street
#
#      addresslocality addresscountry          longitude            latitude  \
# 29              Doha             QA  51.52650117874146  25.358588885959527
# 43            Vienna             AT          16.371088          48.2041137
# 47            Munich             DE         11.5824846          48.1391124
# 52             Dubai             AE  55.28715133666992  25.229711782091815
# 61            Munich             DE         11.5758719          48.1358655
# ...              ...            ...                ...                 ...
# 3949     Lake Geneva             US      -8.84289221E1        4.25801521E1
# 3950         Fontana             US       -8.8572882E1         4.2550004E1
# 3952     Lake Geneva             US      -8.84051177E1        4.26097253E1
# 3953     lake Geneva             US      -8.84147432E1        4.26001691E1
# 3954       East Troy             US      -8.84045682E1        4.27886516E1
#
#           telephone_                                       phone_object  \
# 29       97444080710  {'country_code': 974, 'extension': None, 'nati...
# 43        4315127397  {'country_code': 43, 'extension': None, 'natio...
# 47      498925546942  {'country_code': 49, 'extension': None, 'natio...
# 52       97145018777  {'country_code': 971, 'extension': None, 'nati...
# 61    49894111908111  {'country_code': 49, 'extension': None, 'natio...
# ...              ...                                                ...
# 3949      2622483673  {'country_code': 1, 'extension': None, 'nation...
# 3950      2622752163  {'country_code': 1, 'extension': None, 'nation...
# 3952      2622482556  {'country_code': 1, 'extension': None, 'nation...
# 3953      2628124081  {'country_code': 1, 'extension': None, 'nation...
# 3954      2626423263  {'country_code': 1, 'extension': None, 'nation...
#
#          E.164 format   telephoneNorm  ClusterID  \
# 29       +97444080710     97444080710      90672
# 43        +4315127397      4315127397       1289
# 47      +498925546942    498925546942     106412
# 52       +97145018777     97145018777      90121
# 61    +49894111908111  49894111908111     117822
# ...               ...             ...        ...
# 3949     +12622483673     12622483673      14224
# 3950     +12622752163     12622752163      14263
# 3952     +12622482556     12622482556      14222
# 3953     +12628124081     12628124081      14408
# 3954     +12626423263     12626423263      14339
#
#                                                  concat
# 29    L'wzaar Sea Food Restaurant Doha Doha L'wzaar ...
# 43    Shiki Japanese Fine Dining | Brasserie | Bar V...
# 47    Restaurant Toshi Munich Bavaria Wurzerstraße 1...
# 52    OKKU Fine Dining Dubai Dubai Dubai Dubai AE 55...
# 61    Restaurant EMIKO Munich Bavaria Viktualienmark...
# ...                                                 ...
# 3949  Rushwood Park WI Timothy Drive Lake Geneva US ...
# 3950  Gordy's Lakefront Marine WI 320 Lake St. Fonta...
# 3952  Grand Geneva Resort The Brute WI 7036 Grand Ge...
# 3953  Lake Geneva Nails and Spa WI 820 N. Edward Blv...
# 3954  East Troy Railroad Museum WI 2002 Church Stree...
#
# [1000 rows x 18 columns]

# %%
clusteredData = clusteredData.head(1000)

# %% [markdown]
# ### Combine tf-idf and tf vector based features

# %%
#clean concated description column to use tf-idf 
clusteredData['concat'] = clusteredData['concat'].apply(lambda row: row.lower())
clusteredData['tokens'] = clusteredData['concat'].apply(lambda row: word_tokenize(row))
clusteredData['tokens'] = remove_stopwords(clusteredData['tokens'],stopwords.words())
clusteredData['tokens'] = remove_punctuation (clusteredData['tokens'])
clusteredData.drop(columns=['concat'],inplace=True)
clusteredData = clusteredData[['tokens','ClusterID']]

# %%
clusteredData
# Out:
#                                                  tokens  ClusterID
# 29    [l'wzaar, food, restaurant, doha, doha, l'wzaa...      90672
# 43    [shiki, japanese, fine, dining, brasserie, bar...       1289
# 47    [restaurant, toshi, munich, bavaria, wurzerstr...     106412
# 52    [okku, fine, dining, dubai, dubai, dubai, duba...      90121
# 61    [restaurant, emiko, munich, bavaria, viktualie...     117822
# ...                                                 ...        ...
# 3949  [rushwood, park, wi, timothy, drive, lake, gen...      14224
# 3950  [gordy, 's, lakefront, marine, wi, 320, lake, ...      14263
# 3952  [grand, geneva, resort, brute, wi, 7036, grand...      14222
# 3953  [lake, geneva, nails, spa, wi, 820, n., edward...      14408
# 3954  [east, troy, railroad, museum, wi, 2002, churc...      14339
#
# [1000 rows x 2 columns]

# %%
#define vectorizer to match preprocessed tokes for term frequency
def dummy(doc):
    return doc

vectorizer  = CountVectorizer(
        tokenizer=dummy,
        preprocessor=dummy,
        max_features=15000)  
tf_value = vectorizer.fit_transform(clusteredData['tokens'])

# %%
#define vectorizer to match preprocessed tokes
def dummy_fun(doc):
    return doc

tfidf = TfidfVectorizer(
    analyzer='word',
    tokenizer=dummy_fun,
    preprocessor=dummy_fun,
    token_pattern=None,
    max_features=15000)  
tfidf_value = tfidf.fit_transform(clusteredData['tokens'])

# %%
df_tf = pd.DataFrame(tf_value.toarray(), columns=vectorizer.get_feature_names())
df_tfidf = pd.DataFrame(tfidf_value.toarray(), columns=tfidf.get_feature_names())
df_prepared = pd.concat([clusteredData.reset_index(), df_tfidf, df_tf], axis=1)

# %%
y = df_prepared['ClusterID']
df_prepared.drop(columns=['tokens','ClusterID'], inplace=True)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df_prepared, y, test_size = 0.2)

# %%
# Baseline random forest
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
prediction = rf.predict(x_test) 
f1_mic = f1_score(y_test,prediction,average='micro')
f1_mac = f1_score(y_test,prediction,average='macro')
accuracy = accuracy_score(y_test,prediction) 
precision = precision_score(y_test,prediction,average='micro') 
recall = recall_score(y_test,prediction,average='micro') 
precision_mac = precision_score(y_test,prediction,average='macro') 
recall_mac = recall_score(y_test,prediction,average='macro') 
print("The F1-Score micro on test set: {:.4f}".format(f1_mic))
print("The F1-Score macro on test set: {:.4f}".format(f1_mac))
print("The Precision on test set: {:.4f}".format(precision))
print("The Recall on test set: {:.4f}".format(recall))
print("The Precision macro on test set: {:.4f}".format(precision_mac))
print("The Recall macro on test set: {:.4f}".format(recall_mac))
print("The Accuracy-Score on test set: {:.4f}".format(accuracy))
# Out:
# The F1-Score micro on test set: 0.5250
# The F1-Score macro on test set: 0.1354
# The Precision on test set: 0.5250
# The Recall on test set: 0.5250
# The Precision macro on test set: 0.1314
# The Recall macro on test set: 0.1429
# The Accuracy-Score on test set: 0.5250
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/bizer-tp2021/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
