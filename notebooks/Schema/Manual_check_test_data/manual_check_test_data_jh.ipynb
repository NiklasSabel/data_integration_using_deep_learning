# %%
# import libraries
import os
import pandas as pd
import json
import gzip
import fasttext 
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
path = '../../src/data/schemafiltereddata/TrainTestTables/Large/Test'
l = [file for file in os.listdir(path) if file.startswith('Product')]
len(l)
# Out:
# 4239

# %%
l2 = l[3800:4000]
l2
# Out:
# ['Product_westsidevw.com_September2020.json.gz',
#  'Product_guygunterhome.com_September2020.json.gz',
#  'Product_royrobinsonrv.com_September2020.json.gz',
#  'Product_goairforcefalcons.com_September2020.json.gz',
#  'Product_illusivecomics.com_September2020.json.gz',
#  'Product_sterlingmccalllexusclearlake.com_September2020.json.gz',
#  'Product_johnhyattclothing.com_September2020.json.gz',
#  'Product_ruvalcabafantasias.com_September2020.json.gz',
#  'Product_kidoozietoys.com_September2020.json.gz',
#  'Product_hartensteincares.com_September2020.json.gz',
#  'Product_canfloor.com_September2020.json.gz',
#  'Product_luluskinstore.com_September2020.json.gz',
#  'Product_essepursemuseum.com_September2020.json.gz',
#  'Product_illfitment.com_September2020.json.gz',
#  'Product_meimiamibeachcondosforsale.com_September2020.json.gz',
#  'Product_shopontime.co.uk_September2020.json.gz',
#  'Product_dieteticabarcelona.com_September2020.json.gz',
#  'Product_thoitrangnuhoang.com_September2020.json.gz',
#  'Product_voitektv.com_September2020.json.gz',
#  'Product_wadesrv.com_September2020.json.gz',
#  'Product_lightingshop.org_September2020.json.gz',
#  'Product_nimnichtbuickgmc.com_September2020.json.gz',
#  'Product_annabelleswigs.co.uk_September2020.json.gz',
#  'Product_lanellodiresalomone.com_September2020.json.gz',
#  'Product_poleoptical.com_September2020.json.gz',
#  'Product_fragrancenet.com_September2020.json.gz',
#  'Product_shayandblue.com_September2020.json.gz',
#  'Product_artock.com.au_September2020.json.gz',
#  'Product_dermalogica.com_September2020.json.gz',
#  'Product_esmobility.co.uk_September2020.json.gz',
#  'Product_arloskye.com_September2020.json.gz',
#  'Product_cynth.com_September2020.json.gz',
#  'Product_charlestonfabric.com_September2020.json.gz',
#  'Product_tungstencarbide-tools.com_September2020.json.gz',
#  'Product_shopfakenotes.com_September2020.json.gz',
#  'Product_artfinder.com_September2020.json.gz',
#  'Product_lcking.com_September2020.json.gz',
#  'Product_ebelts.com_September2020.json.gz',
#  'Product_caroclic.com_September2020.json.gz',
#  'Product_john-anthony.com_September2020.json.gz',
#  'Product_skifix.com_September2020.json.gz',
#  'Product_pserviceweb.com_September2020.json.gz',
#  'Product_dabpress.com_September2020.json.gz',
#  'Product_chowdaheadz.com_September2020.json.gz',
#  'Product_howig.co.uk_September2020.json.gz',
#  'Product_mexicanblankets.com_September2020.json.gz',
#  'Product_shop-boots.com_September2020.json.gz',
#  'Product_carasutra.com_September2020.json.gz',
#  'Product_strokedoctor.com_September2020.json.gz',
#  'Product_plantgem.com_September2020.json.gz',
#  'Product_landerscdjrnorman.com_September2020.json.gz',
#  'Product_godbyhomefurnishings.com_September2020.json.gz',
#  'Product_climbers-shop.com_September2020.json.gz',
#  'Product_cosmofemina.com_September2020.json.gz',
#  'Product_bommeow.com_September2020.json.gz',
#  'Product_kostazul.com_September2020.json.gz',
#  'Product_nj.com_September2020.json.gz',
#  'Product_halilit.co.uk_September2020.json.gz',
#  'Product_marinestereo.com_September2020.json.gz',
#  'Product_prosonic-studios.com_September2020.json.gz',
#  'Product_bolgerfuneral.com_September2020.json.gz',
#  'Product_ilcaffeitaliano.com_September2020.json.gz',
#  'Product_cicekdiyari.com_September2020.json.gz',
#  'Product_acclaimautoparts.com_September2020.json.gz',
#  'Product_acewashersupplies.com_September2020.json.gz',
#  'Product_iq-uv.com_September2020.json.gz',
#  'Product_jennycraig.com.au_September2020.json.gz',
#  'Product_escapade.co.uk_September2020.json.gz',
#  'Product_chemicalplanet.net_September2020.json.gz',
#  'Product_cashforcars.net_September2020.json.gz',
#  'Product_allenhonda.com_September2020.json.gz',
#  'Product_viasweat.com_September2020.json.gz',
#  'Product_homemakersvilla.net_September2020.json.gz',
#  'Product_amersonstravel.com_September2020.json.gz',
#  'Product_brilliantoutdoors.com_September2020.json.gz',
#  'Product_postfallschryslerjeepdodgeram.com_September2020.json.gz',
#  'Product_freemyersbestbrands.com_September2020.json.gz',
#  'Product_inksupply.com_September2020.json.gz',
#  'Product_speed-cat-shoes.org_September2020.json.gz',
#  'Product_rhedo.com_September2020.json.gz',
#  'Product_codesevenhack.net_September2020.json.gz',
#  'Product_artsper.com_September2020.json.gz',
#  'Product_gardenma.com_September2020.json.gz',
#  'Product_shop2luv.com_September2020.json.gz',
#  'Product_mbdiscountparts.com_September2020.json.gz',
#  'Product_stanno.com_September2020.json.gz',
#  'Product_nallforgovernor.com_September2020.json.gz',
#  'Product_flowers4munich.com_September2020.json.gz',
#  'Product_artstar.com_September2020.json.gz',
#  'Product_bandarqq99.org_September2020.json.gz',
#  'Product_sb-components.co.uk_September2020.json.gz',
#  'Product_alpinewines.co.uk_September2020.json.gz',
#  'Product_giltee.com_September2020.json.gz',
#  'Product_dmso-supplier.com_September2020.json.gz',
#  'Product_autonationtoyotasouthaustin.com_September2020.json.gz',
#  'Product_aslangolf.co.uk_September2020.json.gz',
#  'Product_lionelmessijersey.org_September2020.json.gz',
#  'Product_us41cars.com_September2020.json.gz',
#  'Product_ankethread.com_September2020.json.gz',
#  'Product_gilecheese.com_September2020.json.gz',
#  'Product_monkeymotorsmn.com_September2020.json.gz',
#  'Product_alokitabevi.com_September2020.json.gz',
#  'Product_customboxeshub.com_September2020.json.gz',
#  'Product_shophouseofnomad.com_September2020.json.gz',
#  'Product_deesign.com_September2020.json.gz',
#  'Product_chupetesgraciosos.com_September2020.json.gz',
#  'Product_reinerplay.com_September2020.json.gz',
#  'Product_labfreezers.net_September2020.json.gz',
#  'Product_jaxgarage.com.au_September2020.json.gz',
#  'Product_hl-grosshandel.com_September2020.json.gz',
#  'Product_labuanshoppy.com_September2020.json.gz',
#  'Product_lashtavern.com_September2020.json.gz',
#  'Product_creoven.co.uk_September2020.json.gz',
#  'Product_butikjamtangan.com_September2020.json.gz',
#  'Product_tresorbleu.com_September2020.json.gz',
#  'Product_kablosepeti.com_September2020.json.gz',
#  'Product_4pmti.com_September2020.json.gz',
#  'Product_wholesaleleathersupplier.com_September2020.json.gz',
#  'Product_prontocharger.com_September2020.json.gz',
#  'Product_artimagepublications.com_September2020.json.gz',
#  'Product_aplevel.com_September2020.json.gz',
#  'Product_childtherapytoys.com_September2020.json.gz',
#  'Product_highclassmobile.com_September2020.json.gz',
#  'Product_qualite-pieces-auto.com_September2020.json.gz',
#  'Product_selwood.com_September2020.json.gz',
#  'Product_boutonjaune.com_September2020.json.gz',
#  'Product_jeparawoodenfurniture.com_September2020.json.gz',
#  'Product_lendingexpert.co.uk_September2020.json.gz',
#  'Product_absolutedoor.net_September2020.json.gz',
#  'Product_windyhillfarmtoys.com_September2020.json.gz',
#  'Product_philipjonesjewellery.com_September2020.json.gz',
#  'Product_infinitimv.com_September2020.json.gz',
#  'Product_erikapena.com_September2020.json.gz',
#  'Product_flowers4armenia.com_September2020.json.gz',
#  'Product_icelectdata1.com_September2020.json.gz',
#  'Product_elementactivewear.com_September2020.json.gz',
#  'Product_usfarmer.com_September2020.json.gz',
#  'Product_silksisters.com.au_September2020.json.gz',
#  'Product_dchkayhonda.com_September2020.json.gz',
#  'Product_nova-megastore.com_September2020.json.gz',
#  'Product_nametagwizard.com_September2020.json.gz',
#  'Product_mycozycups.com_September2020.json.gz',
#  'Product_allbestcbdoil.com_September2020.json.gz',
#  'Product_masonlindhart.com_September2020.json.gz',
#  'Product_winreal.com.ng_September2020.json.gz',
#  'Product_croydon-tyrescentre.co.uk_September2020.json.gz',
#  'Product_delivape.com_September2020.json.gz',
#  'Product_yachtbooker.com_September2020.json.gz',
#  'Product_factorychryslerparts.com_September2020.json.gz',
#  'Product_thomasfuneralhomecalhoun.com_September2020.json.gz',
#  'Product_jordancamper.com_September2020.json.gz',
#  'Product_slamoof.com_September2020.json.gz',
#  'Product_iludec.com_September2020.json.gz',
#  'Product_bambuskomfort.com_September2020.json.gz',
#  'Product_flowers4quarteira.com_September2020.json.gz',
#  'Product_gmcarsbynelson.com_September2020.json.gz',
#  'Product_aw-lab.com_September2020.json.gz',
#  'Product_team-fishing.com_September2020.json.gz',
#  'Product_cdhomeproducts.com_September2020.json.gz',
#  'Product_bidderlo.com_September2020.json.gz',
#  'Product_dienlanhnguyenphat.com_September2020.json.gz',
#  'Product_buy-motorcycle.com_September2020.json.gz',
#  'Product_bellesmart.com_September2020.json.gz',
#  'Product_powerwalker.com_September2020.json.gz',
#  'Product_royalepharma.com_September2020.json.gz',
#  'Product_stantonsace.com_September2020.json.gz',
#  'Product_towelsandbedsheets.co.uk_September2020.json.gz',
#  'Product_onestopflooring.co.uk_September2020.json.gz',
#  'Product_lucyandcoboutique.com_September2020.json.gz',
#  'Product_qcautoplex.com_September2020.json.gz',
#  'Product_musicscotland.com_September2020.json.gz',
#  'Product_etrailer.com_September2020.json.gz',
#  'Product_lepro.com_September2020.json.gz',
#  'Product_flagsrus.org_September2020.json.gz',
#  'Product_supplyhog.com_September2020.json.gz',
#  'Product_ruffandtumbledogcoats.com_September2020.json.gz',
#  'Product_childrens-ministry-deals.com_September2020.json.gz',
#  'Product_callofdutyleague.com_September2020.json.gz',
#  'Product_lucasignition.com_September2020.json.gz',
#  'Product_yves-salomon.com_September2020.json.gz',
#  'Product_yanbzx.com_September2020.json.gz',
#  'Product_netwalkerstore.com_September2020.json.gz',
#  'Product_parrottfuneralhome.com_September2020.json.gz',
#  'Product_kbctools.com_September2020.json.gz',
#  'Product_hubertvestertoyota.com_September2020.json.gz',
#  'Product_millerwardfuneralhome.com_September2020.json.gz',
#  'Product_3bscientific.co.uk_September2020.json.gz',
#  'Product_evybenita.com_September2020.json.gz',
#  'Product_lovebirdsb.com_September2020.json.gz',
#  'Product_catersuppliesdirect.com_September2020.json.gz',
#  'Product_citydrawers.com_September2020.json.gz',
#  'Product_artsy.net_September2020.json.gz',
#  'Product_topoutdoorsupplies.com_September2020.json.gz',
#  'Product_ppssurf.com_September2020.json.gz',
#  'Product_wildyakexpeditions.com_September2020.json.gz',
#  'Product_goelectrical.com.au_September2020.json.gz',
#  'Product_lovelypetzone.com_September2020.json.gz',
#  'Product_festapratica.com_September2020.json.gz',
#  'Product_perapasha.com_September2020.json.gz',
#  'Product_dutchflies.com_September2020.json.gz']

# %%
listcolt = pd.read_csv('../../src/data/data/CSV_files/stats_filtered_and_cleaned_tables.csv')
listcolt = listcolt.set_index('filename')
listcolt = listcolt[listcolt.index=='Product']
listcolt
# Out:
#                                               listofcolumns  numtables
# filename
# Product   ['name', 'offers', 'brand', 'aggregaterating',...      33203

# %%
path = '/work-ceph/bizer-tp2021/data_integration_using_deep_learning/src/data/data/CSV_files'
stats = pd.read_csv(path + '/all_files_stats.csv')
files = pd.read_csv(path + '/all_files_cleaned.csv')
files = files.drop(columns={'Unnamed: 0'})
listcol= files.groupby('filename')['column_name'].apply(list).reset_index(name='listofcolumns')
listcol.filename = listcol.filename.str.split('_', expand=True)[0]
listcol.index = listcol['filename']
listcol = listcol[listcol['filename']=='Product']
listcol
# Out:
#          filename                                      listofcolumns
# filename
# Product   Product  [name, offers, brand, aggregaterating, mpn, ca...

# %%
path='../../src/data/schemafiltereddata/TrainTestTables/Large/Test'
files = [file for file in os.listdir(path) if file.endswith('.json.gz')]
for index in listcol.filename:
    setcol = listcol.loc[index]['listofcolumns']
    for file in l2:
    # read file
        df = pd.read_json(os.path.join(path, '{}'.format(file)), compression='gzip', lines=True)
        display(file)
        display(df[df.columns.intersection(setcol)].head())
# Out:
# 'Product_westsidevw.com_September2020.json.gz'
#                                                 name  \
# 0                                            Ski Sac
# 1                         Hatch Top Spoiler - Primer
# 2                       Base Bar End Cap Set - Black
# 3                         Base Carrier Bars - Silver
# 4  Hatch Top Spoiler - Primer This Fits Your 2015...
#
#                                               offers       brand  \
# 0                                               None  Volkswagen
# 1  {'itemcondition': 'http://schema.org/NewCondit...  Volkswagen
# 2  {'url': 'parts.westsidevw.com/p/volkswagen__pa...  Volkswagen
# 3  {'itemcondition': 'http://schema.org/NewCondit...  Volkswagen
# 4  {'url': 'parts.westsidevw.com/p/volkswagen_201...  Volkswagen
#
#             mpn                 identifier
# 0     00V061202     {'value': '00V061202'}
# 1  5G0071644GRU  {'value': '5G0071644GRU'}
# 2     3B0071738     {'value': '3B0071738'}
# 3    3C0071126A    {'value': '3C0071126A'}
# 4  5G0071644GRU  {'value': '5G0071644GRU'}
# 'Product_guygunterhome.com_September2020.json.gz'
#                                                 name  \
# 0  GE&reg; 27&quot; Smart Built-In Convection Sin...
# 1  GE&reg; 27&quot; Built-In Combination Microwav...
# 2  GE Profile&trade; Series ENERGY STAR&reg; 27.7...
# 3  1.8 cu. ft. Over-the-Range Microwave Oven with...
# 4  7.4 cu. ft. Ultra Large Capacity Smart wi-fi E...
#
#                                               offers  \
# 0  {'pricecurrency': 'USD', 'availability': 'http...
# 1  {'pricecurrency': 'USD', 'availability': 'http...
# 2  {'pricecurrency': 'USD', 'availability': 'http...
# 3  {'pricecurrency': 'USD', 'availability': 'http...
# 4  {'price': '1199.0', 'availability': 'http://sc...
#
#                        brand  \
# 0  {'name': 'GE Appliances'}
# 1  {'name': 'GE Appliances'}
# 2  {'name': 'GE Appliances'}
# 3             {'name': 'LG'}
# 4             {'name': 'LG'}
#
#                                      aggregaterating          mpn
# 0  {'ratingvalue': '4.1', 'reviewcount': '8', 'it...  JKS5000DNWW
# 1  {'itemreviewed': 'GE&reg; 27&quot; Built-In Co...   JK3800DHWW
# 2  {'reviewcount': '133', 'ratingvalue': '4.3', '...   PFE28KMKES
# 3  {'itemreviewed': '1.8 cu. ft. Over-the-Range M...    LMV1831BD
# 4  {'ratingvalue': '4.6', 'reviewcount': '94', 'i...    DLGX3701V
# 'Product_royrobinsonrv.com_September2020.json.gz'
#                                      name         brand      model  \
# 0  2002 NATIONAL SEABREEZE CLASS A DIESEL      NATIONAL  SEABREEZE
# 1         2019 Winnebago VISTA LX CLASS A     Winnebago   VISTA LX
# 2   2018 FOREST RIVER VIBE TRAVEL TRAILER  FOREST RIVER       VIBE
# 3               2005 THOR CITATION CAMPER          THOR   CITATION
# 4          2020 Winnebago SUNSTAR CLASS A     Winnebago    SUNSTAR
#
#    manufacturer  releasedate     color
# 0      NATIONAL         2002     White
# 1     Winnebago         2019  DEEP SEA
# 2  FOREST RIVER         2018     White
# 3          THOR         2005     White
# 4     Winnebago         2020   SCARLET
# 'Product_goairforcefalcons.com_September2020.json.gz'
#                                                 name  \
# 0  Men's Cutter & Buck Gray Air Force Falcons Vau...
# 1  Air Force Falcons Nike Logo Performance Polo -...
# 2  Men's Fanatics Branded Royal Air Force Falcons...
# 3  Men's Cutter & Buck Black Air Force Falcons Bi...
# 4  Men's Cutter & Buck White Air Force Falcons Bi...
#
#                                               offers             brand  \
# 0  {'serialnumber': '3144514', 'availability': 'h...              None
# 1  {'availability': 'http://schema.org/InStock', ...              Nike
# 2  {'serialnumber': '2888454', 'availability': 'h...  Fanatics Branded
# 3  {'availability': 'http://schema.org/InStock', ...     Cutter & Buck
# 4  {'serialnumber': '2712384', 'category': 'Shirt...     Cutter & Buck
#
#                     category                   itemcondition
# 0                       None  http://schema.org/NewCondition
# 1    Polos &gt; Short Sleeve  http://schema.org/NewCondition
# 2  T-Shirts &gt; Long Sleeve  http://schema.org/NewCondition
# 3    Polos &gt; Short Sleeve  http://schema.org/NewCondition
# 4          Shirts & Sweaters  http://schema.org/NewCondition
# 'Product_illusivecomics.com_September2020.json.gz'
#                                                 name  \
# 0  Z-MAN GAMES INC INFINITY GAUNTLET: A LOVE LETT...
# 1  FUNKO POP DISNEY: MICKEY'S 90TH - PLANE CRAZY ...
# 2                                   FORBIDDEN ISLAND
# 3  FUNKO POP DISNEY: MICKEY'S 90TH - BAND CONCERT...
# 4     MARVEL COMICS MARVEL-VERSE GN TP BLACK PANTHER
#
#                                               offers            brand  \
# 0  {'price': '14.99', 'availability': 'https://sc...  Z-MAN GAMES INC
# 1  {'availability': 'https://schema.org/InStock',...            FUNKO
# 2  {'pricevaliduntil': '2020-12-21', 'availabilit...             None
# 3  {'availability': 'https://schema.org/InStock',...            FUNKO
# 4  {'inventorylevel': '2', 'availability': 'https...    MARVEL COMICS
#
#                      itemcondition        gtin13
# 0  https://schema.org/NewCondition  8.413331e+11
# 1  https://schema.org/NewCondition  8.896983e+11
# 2  https://schema.org/NewCondition  7.597510e+11
# 3  https://schema.org/NewCondition  8.896983e+11
# 4  https://schema.org/NewCondition           NaN
# 'Product_sterlingmccalllexusclearlake.com_September2020.json.gz'
#                                name  \
# 0  New 2020 Lexus IS 300 - In-Stock
# 1  New 2020 Lexus IS 300 - In-Stock
# 2  New 2020 Lexus RC 300 - In-Stock
# 3  New 2020 Lexus NX 300 - In-Stock
# 4  New 2020 Lexus IS 300 - In-Stock
#
#                                               offers  brand     mpn   model  \
# 0  {'itemcondition': 'http://schema.org/NewCondit...  Lexus  9502.0  IS 300
# 1  {'itemcondition': 'http://schema.org/NewCondit...  Lexus  9502.0  IS 300
# 2  {'itemcondition': 'http://schema.org/NewCondit...  Lexus  9202.0  RC 300
# 3  {'itemcondition': 'http://schema.org/NewCondit...  Lexus  9830.0  NX 300
# 4  {'itemcondition': 'http://schema.org/NewCondit...  Lexus  9502.0  IS 300
#
#         manufacturer                color
# 0  {'name': 'Lexus'}             Obsidian
# 1  {'name': 'Lexus'}             Obsidian
# 2  {'name': 'Lexus'}        Atomic Silver
# 3  {'name': 'Lexus'}     Matador Red Mica
# 4  {'name': 'Lexus'}  Eminent White Pearl
# 'Product_johnhyattclothing.com_September2020.json.gz'
#                                                 name  \
# 0            Johnnie-O Pant Marin Prep-formance Pant
# 1               Peter Millar Salem Performance Short
# 2  Crown Soft Merino-Silk Quarter-Zip — Peter Millar
# 3        Kribi Beach Aqua Cotton Polo – Peter Millar
# 4  Crown Comfort Interlock Quarter-Zip — Peter Mi...
#
#                                               offers  \
# 0  [{'itemcondition': 'http://schema.org/NewCondi...
# 1  [{'itemcondition': 'http://schema.org/NewCondi...
# 2  [{'pricevaliduntil': '2021-09-29', 'itemcondit...
# 3  [{'itemcondition': 'http://schema.org/NewCondi...
# 4  [{'pricevaliduntil': '2021-09-29', 'itemcondit...
#
#                       brand          additionalproperty        gtin12
# 0     {'name': 'Johnnie-O'}   {'value': '402507431967'}  8.415982e+11
# 1  {'name': 'Peter Millar'}     {'value': '9043831940'}  1.906786e+11
# 2  {'name': 'Peter Millar'}  {'value': '3945307078774'}  1.946241e+11
# 3  {'name': 'Peter Millar'}  {'value': '4428491325558'}  1.937133e+11
# 4  {'name': 'Peter Millar'}  {'value': '4424690040950'}  1.906786e+11
# 'Product_ruvalcabafantasias.com_September2020.json.gz'
#                                                name  \
# 0          R732001 LETRERO ANUNCIO C/LUZ 30 X 22 CM
# 1  R304202 VIDRIO BASE PARA PASTEL CHICO 21 X 11 CM
# 2         R116008 NAV.RENO FINO DECORADO 63 * 28 CM
# 3           R115001-A NAV. MONO NIEVE COLGANTE 42CM
# 4                R709008 BAJO PLATO 4 GRECAS 35 CMS
#
#                                               offers             brand  \
# 0  {'price': '1.89E2', 'availability': 'https://s...  {'name': 'R732'}
# 1  {'price': '2.09E2', 'availability': 'https://s...  {'name': 'R304'}
# 2  {'pricevaliduntil': '2020-10-08', 'availabilit...  {'name': 'R116'}
# 3  {'sku': 'R115001-A', 'availability': 'https://...  {'name': 'R115'}
# 4  [{'name': 'Plata', 'price': '5.4E1', 'pricecur...  {'name': 'R709'}
#
#               category          gtin14
# 0     Letreros con luz  c7777732001003
# 1        Cupcake Stand  c7777304202005
# 2         Animales Nav  c7777116008000
# 3  Figuras de Trovicel  c7777115001019
# 4           Bajoplatos  c7777709008011
# 'Product_kidoozietoys.com_September2020.json.gz'
#                                                 name  \
# 0  Kidoozie Princess Hideaway Playhouse with Fron...
# 1               Kidoozie Build-A-Road Expansion Pack
# 2                           Kidoozie Funtime Tractor
# 3  Kidoozie Stack 'n Sort Toy - 12 Colorful Piece...
# 4                               Kidoozie Pogo Jumper
#
#                                               offers  \
# 0  {'pricecurrency': 'USD', 'pricevaliduntil': '2...
# 1  {'pricecurrency': 'USD', 'price': '9.95', 'ava...
# 2  {'pricecurrency': 'USD', 'pricevaliduntil': '2...
# 3  {'pricecurrency': 'USD', 'price': '21.99', 'pr...
# 4  {'pricecurrency': 'USD', 'availability': 'http...
#
#                                   brand  \
# 0  {'name': 'International Playthings'}
# 1  {'name': 'International Playthings'}
# 2                  {'name': 'Kidoozie'}
# 3                     {'name': 'iPlay'}
# 4                  {'name': 'Kidoozie'}
#
#                              aggregaterating  mpn
# 0  {'reviewcount': '89', 'ratingvalue': '5'}  768
# 1  {'reviewcount': '89', 'ratingvalue': '5'}  762
# 2  {'reviewcount': '89', 'ratingvalue': '5'}  766
# 3  {'reviewcount': '89', 'ratingvalue': '5'}  750
# 4  {'reviewcount': '89', 'ratingvalue': '5'}  743
# 'Product_hartensteincares.com_September2020.json.gz'
#                                             name  \
# 0                 Cherished Memories - All White
# 1         Peace, Prayers, & Blessings- All White
# 2                White Sympathy Standing Baskets
# 3     Multicolor Pastel Sympathy Standing Basket
# 4  Peace, Prayers, & Blessings- Yellow and White
#
#                                               offers  \
# 0  {'pricecurrency': 'USD', 'highprice': '99.99',...
# 1  {'pricecurrency': 'USD', 'lowprice': '59.99', ...
# 2  {'pricecurrency': 'USD', 'lowprice': '99.99', ...
# 3  {'pricecurrency': 'USD', 'lowprice': '99.99', ...
# 4  {'pricecurrency': 'USD', 'lowprice': '59.99', ...
#
#                                aggregaterating  \
# 0                                         None
# 1  {'reviewcount': '2', 'ratingvalue': '5.00'}
# 2  {'ratingvalue': '5.00', 'reviewcount': '6'}
# 3                                         None
# 4  {'ratingvalue': '4.60', 'reviewcount': '5'}
#
#                                               review itemcondition  \
# 0                                               None  NewCondition
# 1  [{'datepublished': '1/22/2020', 'name': 'Peace...  NewCondition
# 2  [{'author': 'from -', 'description': 'Beautifu...  NewCondition
# 3                                               None  NewCondition
# 4  [{'author': 'from -', 'name': 'Peace, Prayers,...  NewCondition
#
#                                                model
# 0  [{'image': 'https://res.cloudinary.com/picasso...
# 1  [{'sku': '95383S', 'name': 'Peace, Prayers, & ...
# 2  [{'name': 'White Sympathy Standing Baskets (St...
# 3  [{'url': 'https://www.hartensteincares.com/sto...
# 4  [{'image': 'https://res.cloudinary.com/picasso...
# 'Product_canfloor.com_September2020.json.gz'
#                                                 name  \
# 0  Luxury Vinyl Flooring LifeStepp, Cosmopolitan ...
# 1  Engineered Oak Flooring, Fuzion Beaux Arts, Si...
# 2  Luxury Vinyl Flooring Canfloor NLV, Rigid Core...
# 3  Engineered Beech Panache, Hand-Scraped 6.5\" x...
# 4  Engineered White Oak Panache, 7.5\" x 3/4\" Co...
#
#                                        offers                category  \
# 0   {'price': '3.49', 'pricecurrency': 'CAD'}          Vinyl Flooring
# 1  {'price': '11.99', 'pricecurrency': 'CAD'}  Engineered Prefinished
# 2   {'price': '2.29', 'pricecurrency': 'CAD'}          Vinyl Flooring
# 3   {'price': '3.99', 'pricecurrency': 'CAD'}  Engineered Prefinished
# 4   {'price': '6.99', 'pricecurrency': 'CAD'}  Engineered Prefinished
#
#        color        material
# 0      Grace            None
# 1      Monet       White Oak
# 2  NLV-28005            None
# 3       Pier  European Beech
# 4       Mink       White Oak
# 'Product_luluskinstore.com_September2020.json.gz'
#                                                 name  \
# 0                   Timeless Coenzyme Q10 Serum 30ml
# 1  ZENOLOGY Спрей для ароматизации воздуха помеще...
# 2                           Babor Perfect Glow 7 amp
# 3  GIGI Acnon Pore Purifying mask Маска противово...
# 4              Odacite Crystal Contour Gua Sha Green
#
#                                               offers     brand  \
# 0  {'price': '10000', 'pricecurrency': 'KZT', 'av...  Timeless
# 1  {'pricecurrency': 'KZT', 'price': '16300', 'av...  Zenology
# 2  {'pricecurrency': 'KZT', 'availability': 'http...     Babor
# 3  {'availability': 'https://schema.org/InStock',...      GIGI
# 4  {'price': '20000', 'pricecurrency': 'KZT', 'av...   Odacite
#
#                               aggregaterating                 category  \
# 0  {'reviewcount': '2', 'ratingvalue': '4.5'}            Активный уход
# 1  {'reviewcount': '2', 'ratingvalue': '4.5'}                     None
# 2  {'reviewcount': '2', 'ratingvalue': '4.5'}             SOS-средства
# 3  {'reviewcount': '2', 'ratingvalue': '4.5'}            Активный уход
# 4  {'reviewcount': '2', 'ratingvalue': '4.5'}  Антивозрастные средства
#
#   manufacturer
# 0     Timeless
# 1     Zenology
# 2        Babor
# 3         GIGI
# 4      Odacite
# 'Product_essepursemuseum.com_September2020.json.gz'
#                                name  \
# 0        Fair Anita Earrings: Adela
# 1  Fair Anita Earrings: Double Moon
# 2     Fibres of Life Bag: Felt Tote
# 3         Vintage Hat, beige floral
# 4            Gabs G3: Matte Leather
#
#                                               offers  \
# 0  {'gtin8': '97216100', 'itemcondition': 'http:/...
# 1  [{'itemcondition': 'http://schema.org/NewCondi...
# 2  [{'itemcondition': 'http://schema.org/NewCondi...
# 3  {'price': '30', 'itemcondition': 'http://schem...
# 4  [{'itemcondition': 'http://schema.org/NewCondi...
#
#                                        brand weight       gtin8
# 0                     {'name': 'Fair Anita'}  0.0lb  97216100.0
# 1                     {'name': 'Fair Anita'}  0.0lb  27329892.0
# 2                 {'name': 'Fibres of Life'}  1.5lb  36252208.0
# 3  {'name': 'ESSE Purse Museum &amp; Store'}  0.0lb  16241200.0
# 4                           {'name': 'Gabs'}  2.0lb  23790128.0
# 'Product_illfitment.com_September2020.json.gz'
#                    name                                             offers  \
# 0   NICHE - INTAKE M159  NICHE - INTAKE M159 $230.00 18x8 / 5x112 / 42 ...
# 1  NICHE - MILAN - M135  NICHE - MILAN - M135 $295.00 17X8 / 5X114.3 / ...
# 2    NICHE - TARGA M129  NICHE - TARGA M129 $295.00 17x8 / 5x100 / 40 -...
# 3    NICHE - SURGE M114  NICHE - SURGE M114 $295.00 19x8.5 / 5x112 / 42...
# 4   NICHE - MISANO M117  NICHE - MISANO M117 $295.00 17X8 / 5X100 / 40 ...
#
#      price shop-currency
# 0  $230.00           USD
# 1  $295.00           USD
# 2  $295.00           USD
# 3  $295.00           USD
# 4  $295.00           USD
# 'Product_meimiamibeachcondosforsale.com_September2020.json.gz'
#                                                 name  \
# 0  Mei Miami Unit 1 - 4 bedroom condo for rent 30...
# 1  Mei Miami Unit 1108 - 3 bedroom condo for sale...
# 2  Mei Miami Unit 1607 - 2 bedroom condo for sale...
# 3  Mei Miami Unit 504 - 1 bedroom condo for sale ...
# 4  Mei Miami Unit PH6 - 2 bedroom condo for sale ...
#
#                                               offers                  brand  \
# 0  {'itemcondition': 'http://schema.org/UsedCondi...  {'name': 'apartment'}
# 1  {'itemcondition': 'http://schema.org/UsedCondi...  {'name': 'apartment'}
# 2  {'itemcondition': 'http://schema.org/UsedCondi...  {'name': 'apartment'}
# 3  {'itemcondition': 'http://schema.org/UsedCondi...  {'name': 'apartment'}
# 4  {'itemcondition': 'http://schema.org/UsedCondi...  {'name': 'apartment'}
#
#                             aggregaterating        mpn
# 0  {'reviewcount': '1', 'ratingvalue': '5'}  A10848861
# 1  {'reviewcount': '1', 'ratingvalue': '5'}  A10800506
# 2  {'reviewcount': '1', 'ratingvalue': '5'}  A10883714
# 3  {'reviewcount': '1', 'ratingvalue': '5'}  A10874806
# 4  {'reviewcount': '1', 'ratingvalue': '5'}  A10521967
# 'Product_shopontime.co.uk_September2020.json.gz'
#                                                 name  \
# 0  Croft&Barrow 31CB22X019 Men's Brown Leather Sl...
# 1           Emporio Armani AR11085 Men's Dress Watch
# 2  Versus by Versace SOH020015 Men's Chronograph ...
# 3                 FCUK Sport FCS040 Men's Sunglasses
# 4  Michael Kors MK5613 Ladies Mini Blair Rose Gol...
#
#                                               offers           brand  \
# 0  {'name': 'Brown', 'itemcondition': 'http://sch...    Croft&Barrow
# 1  {'name': 'Silver', 'itemcondition': 'http://sc...  Emporio Armani
# 2  {'sku': 'B00VNGL74I', 'itemcondition': 'http:/...          Versus
# 3  {'itemcondition': 'http://schema.org/NewCondit...            FCUK
# 4  {'itemcondition': 'http://schema.org/NewCondit...    Michael Kors
#
#            category                           additionalproperty
# 0     Men's Wallets         {'value': 'Brown', 'name': 'Colour'}
# 1     Men's Watches        {'name': 'Colour', 'value': 'Silver'}
# 2     Men's Watches  {'name': 'Title', 'value': 'Default Title'}
# 3  Men's Sunglasses  {'name': 'Title', 'value': 'Default Title'}
# 4    Ladies Watches     {'value': 'Rose Gold', 'name': 'Colour'}
# 'Product_dieteticabarcelona.com_September2020.json.gz'
#                                                 name  \
# 0            SOLGAR FORMULA VM 75 Uno Al Dia 30 Comp
# 1  DR.HAUSCHKA TRIO DE SOMBRAS DE OJOS 03 ametrin...
# 2           SOLGAR FORMULA VM 75 Uno Al Dia 180 Comp
# 3              SOLGAR FACTORES LIPOTROPICOS 100 Comp
# 4  SOLGAR WHEY TO GO Proteina En Polvo CHOCOLATE ...
#
#                                               offers  \
# 0  {'pricevaliduntil': '2021-12-31}', 'price': '1...
# 1  {'pricevaliduntil': '2021-12-31}', 'url': 'htt...
# 2  {'url': 'https://www.dieteticabarcelona.com/so...
# 3  {'pricevaliduntil': '2021-12-31}', 'price': '2...
# 4  {'pricevaliduntil': '2021-12-31}', 'price': '3...
#
#                                     brand  \
# 0            [SOLGAR, {'name': 'SOLGAR'}]
# 1  [DR.HAUSCHKA, {'name': 'DR.HAUSCHKA'}]
# 2            [SOLGAR, {'name': 'SOLGAR'}]
# 3            [SOLGAR, {'name': 'SOLGAR'}]
# 4            [SOLGAR, {'name': 'SOLGAR'}]
#
#                             aggregaterating       mpn  \
# 0  {'ratingcount': '9', 'ratingvalue': '5'}  SOL-0065
# 1  {'ratingcount': '9', 'ratingvalue': '5'}  1023-103
# 2  {'ratingcount': '9', 'ratingvalue': '5'}  SOL-0064
# 3  {'ratingcount': '9', 'ratingvalue': '5'}  SOL-0054
# 4  {'ratingcount': '9', 'ratingvalue': '5'}  SOL-0319
#
#                                               review        gtin13
# 0  {'author': 'Dietética Online Barcelona', 'date...  3.398401e+10
# 1  {'author': 'Dietética Online Barcelona', 'date...  4.020829e+12
# 2  {'datepublished': '2020-09-20', 'author': 'Die...  3.398401e+10
# 3  {'datepublished': '2020-09-20', 'author': 'Die...  3.398402e+10
# 4  {'author': 'Dietética Online Barcelona', 'date...  3.398404e+10
# 'Product_thoitrangnuhoang.com_September2020.json.gz'
#                                              name  \
# 0        ĐẦM QUÝ BÀ KÈM LƯỚI THÊU LÔNG CÔNG-HN692
# 1            ĐẦM IN HỌA TIẾT CARO CAO CẤP -HN 703
# 2                  SET BỘ HÀNG NHẬP CAO CẤP-HN673
# 3  ĐẦM CÔNG CHÚA SÁT NÁCH PHỐI LƯỚI ĐÍNH HOA -D15
# 4                ĐẦM LỤA CỔ VEST PHỐI CHỮ - HN651
#
#                                               offers  \
# 0  {'pricevaliduntil': '2022-11-05', 'pricecurren...
# 1  {'pricevaliduntil': '2022-11-05', 'price': '56...
# 2  {'pricevaliduntil': '2022-11-05', 'price': '58...
# 3  {'pricevaliduntil': '2022-11-05', 'availabilit...
# 4  {'pricevaliduntil': '2022-11-05', 'pricecurren...
#
#                              brand  \
# 0  {'name': 'Thời Trang Nữ Hoàng'}
# 1  {'name': 'Thời Trang Nữ Hoàng'}
# 2  {'name': 'Thời Trang Nữ Hoàng'}
# 3  {'name': 'Thời Trang Nữ Hoàng'}
# 4  {'name': 'Thời Trang Nữ Hoàng'}
#
#                               aggregaterating    mpn
# 0  {'ratingvalue': '5', 'ratingcount': '326'}  HN692
# 1  {'ratingvalue': '5', 'ratingcount': '326'}  HN703
# 2  {'ratingvalue': '5', 'ratingcount': '326'}  HN673
# 3  {'ratingvalue': '5', 'ratingcount': '326'}    D15
# 4  {'ratingvalue': '5', 'ratingcount': '326'}  HN651
# 'Product_voitektv.com_September2020.json.gz'
#                                                 name  \
# 0  GE&reg; ENERGY STAR&reg; 16.6 Cu. Ft. Recessed...
# 1             GE&reg; Dishwasher with Front Controls
# 2  GE&reg; Front Control with Plastic Interior Di...
# 3  GE&reg; ENERGY STAR&reg; 21.9 Cu. Ft. Top-Free...
# 4  GE&reg; 30&quot; Slide-In Front-Control Convec...
#
#                                               offers  \
# 0  {'pricecurrency': 'USD', 'availability': 'http...
# 1  {'pricecurrency': 'USD', 'price': '413.95', 'a...
# 2  {'pricecurrency': 'USD', 'availability': 'http...
# 3  {'pricecurrency': 'USD', 'availability': 'http...
# 4  {'pricecurrency': 'USD', 'price': '1998.95', '...
#
#                        brand  \
# 0  {'name': 'GE Appliances'}
# 1  {'name': 'GE Appliances'}
# 2  {'name': 'GE Appliances'}
# 3  {'name': 'GE Appliances'}
# 4  {'name': 'GE Appliances'}
#
#                                      aggregaterating          mpn
# 0  {'ratingvalue': '4.6', 'reviewcount': '24', 'i...  GPE17CTNRWW
# 1  {'itemreviewed': 'GE&reg; Dishwasher with Fron...  GDF510PGMWW
# 2  {'ratingvalue': '4.2', 'itemreviewed': 'GE&reg...  GDF530PGMCC
# 3  {'reviewcount': '7', 'itemreviewed': 'GE&reg; ...  GTE22JMNRES
# 4                                               None   JGS760SPSS
# 'Product_wadesrv.com_September2020.json.gz'
#                                                 name  \
# 0                  2021 Dutchmen Aspen Trail 3120BHS
# 1                     2020 Thor Siesta Sprinter 24MB
# 2                  2016 Freightliner Sportchassis M2
# 3                           2021 Newmar Ventana 4037
# 4  2016 Freightliner SPORTS CHASSIS BUSINESS CLAS...
#
#                                               offers  \
# 0  {'price': '27995.00', 'url': 'https://www.wade...
# 1  {'pricevaliduntil': '2020-09-29', 'url': 'http...
# 2  {'price': '134995.00', 'pricevaliduntil': '202...
# 3                                               None
# 4  {'price': '134995.00', 'pricevaliduntil': '202...
#
#                           brand        category                mpn  \
# 0          {'name': 'Dutchmen'}  Travel Trailer            3120BHS
# 1  {'name': 'Thor Motor Coach'}         Class C               24MB
# 2      {'name': 'Freightliner'}   Truck Chassis                 M2
# 3            {'name': 'Newmar'}         Class A               4037
# 4      {'name': 'Freightliner'}   Truck Chassis  BUSINESS CLASS M2
#
#   itemcondition  width   height    depth
# 0  NewCondition     8'   11' 3\   35' 1\
# 1  NewCondition  7' 6\  10' 10\  25' 10\
# 2  NewCondition   None     None     None
# 3  NewCondition  8' 6\  12' 11\  40' 10\
# 4  NewCondition   None     None     None
# 'Product_lightingshop.org_September2020.json.gz'
#                                                 name  \
# 0  Newpow S14 Led Light Bulbs, 24 Pack Dimmable E...
# 1  Cal Lighting BO-213-WH Floor Lamp with Frosted...
# 2  Jazava Modern Mini 1-Light Pendant, 2Pack Indu...
# 3                    SHINE HAI Recessed Lighting Kit
# 4    Good Earth Lighting 24-Inch New Castle Bath Bar
#
#                                               offers  \
# 0  {'pricecurrency': 'USD', 'price': '24.99', 'av...
# 1  {'pricecurrency': 'USD', 'pricevaliduntil': '2...
# 2  {'pricecurrency': 'USD', 'pricevaliduntil': '2...
# 3  {'pricecurrency': 'USD', 'price': '0.00', 'pri...
# 4  {'pricecurrency': 'USD', 'price': '0.00', 'ava...
#
#                                      brand  \
# 0                       {'name': 'NEWPOW'}
# 1                 {'name': 'Cal Lighting'}
# 2                       {'name': 'JAZAVA'}
# 3  {'name': 'Shine Glory Lighting Limted'}
# 4          {'name': 'Good Earth Lighting'}
#
#                              aggregaterating    mpn
# 0  {'reviewcount': '89', 'ratingvalue': '5'}  79529
# 1  {'reviewcount': '89', 'ratingvalue': '5'}   3266
# 2  {'reviewcount': '89', 'ratingvalue': '5'}  81493
# 3  {'reviewcount': '89', 'ratingvalue': '5'}   3207
# 4  {'reviewcount': '89', 'ratingvalue': '5'}   3512
# 'Product_nimnichtbuickgmc.com_September2020.json.gz'
#                                                 name  \
# 0           Pre-Owned 2019 Chevrolet Suburban LT 4WD
# 1      Pre-Owned 2006 Honda Civic Cpe EX FWD 2dr Car
# 2  Certified Pre-Owned 2017 GMC Sierra 1500 Denal...
# 3       Pre-Owned 2010 Acura TL Tech With Navigation
# 4     Pre-Owned 2009 Jeep Liberty Rocky Mountain 4WD
#
#                                               offers      brand       mpn  \
# 0  {'price': '45000', 'itemcondition': 'http://sc...  Chevrolet   CK15906
# 1  {'itemcondition': 'http://schema.org/UsedCondi...      Honda  FG1286JW
# 2  {'itemcondition': 'http://schema.org/UsedCondi...        GMC   TK15543
# 3  {'price': '7735', 'itemcondition': 'http://sch...      Acura  UA8F5AKW
# 4  {'itemcondition': 'http://schema.org/UsedCondi...       Jeep    KKJL74
#
#          model           manufacturer                    color
# 0     Suburban  {'name': 'Chevrolet'}     Shadow Gray Metallic
# 1    Civic Cpe      {'name': 'Honda'}    Nighthawk Black Pearl
# 2  Sierra 1500        {'name': 'GMC'}      Dark Slate Metallic
# 3           TL      {'name': 'Acura'}                     None
# 4      Liberty       {'name': 'Jeep'}  Brilliant Black Crystal
# 'Product_annabelleswigs.co.uk_September2020.json.gz'
#                                                 name  \
# 0                   Long, wavy dark brown wig: Mandy
# 1  Dusty Pink Long Bob Wig (LOB) with textured wa...
# 2  Dark brown wig, long, layered, tip flip style:...
# 3  Auburn 3/4 hairpiece (half wig), long straight...
# 4        Peluca negro, flequillo recto corto: Maxine
#
#                                               offers             brand  \
# 0  {'itemoffered': 'Long, wavy dark brown wig: Ma...  Annabelle's Wigs
# 1  {'itemcondition': 'http://schema.org/NewCondit...  Annabelle's Wigs
# 2  {'itemcondition': 'http://schema.org/NewCondit...  Annabelle's Wigs
# 3  {'itemcondition': 'http://schema.org/NewCondit...  Annabelle's Wigs
# 4  {'itemcondition': 'http://schema.org/NewCondit...  Annabelle's Wigs
#
#                               aggregaterating                             mpn  \
# 0  {'reviewcount': '2', 'ratingvalue': '4.5'}  FW 176 EXTRA LONG DARK BROWN 8
# 1    {'reviewcount': '2', 'ratingvalue': '5'}         AB-147 Dusty Pink T2312
# 2    {'ratingvalue': '5', 'reviewcount': '6'}              FW 171 DARKBROWN 4
# 3    {'reviewcount': '1', 'ratingvalue': '3'}      Three Quarter AB26 Brown30
# 4                                        None   FW 212A-Black-1B Short Fringe
#
#                                               review
# 0  [{'datepublished': '2015-08-04', 'reviewbody':...
# 1  [{'datepublished': '2019-11-17', 'reviewbody':...
# 2  [{'datepublished': '2019-07-10', 'reviewbody':...
# 3  {'datepublished': '2015-02-04', 'reviewbody': ...
# 4                                               None
# 'Product_lanellodiresalomone.com_September2020.json.gz'
#                                name  \
# 0  adidas predator 19.2 firm ground
# 1                   adidas 600 fill
# 2            adidas 11 pro 3 review
# 3            adidas 2010 collection
# 4   adidas alexander wang australia
#
#                                               offers  \
# 0  {'pricevaliduntil': '2020-11-05', 'url': '/img...
# 1  {'pricevaliduntil': '2020-11-05', 'url': '/img...
# 2  {'pricevaliduntil': '2020-11-05', 'url': '/img...
# 3  {'pricevaliduntil': '2020-11-05', 'url': '/img...
# 4  {'pricevaliduntil': '2020-11-05', 'url': '/img...
#
#                               brand  \
# 0  adidas predator 19.2 firm ground
# 1                   adidas 600 fill
# 2            adidas 11 pro 3 review
# 3            adidas 2010 collection
# 4   adidas alexander wang australia
#
#                                aggregaterating    mpn
# 0  {'reviewcount': '56', 'ratingvalue': '4.7'}  75852
# 1  {'ratingvalue': '4.6', 'reviewcount': '63'}  75866
# 2  {'ratingvalue': '4.6', 'reviewcount': '47'}  75869
# 3  {'reviewcount': '66', 'ratingvalue': '4.5'}  75878
# 4  {'ratingvalue': '4.8', 'reviewcount': '65'}  75858
# 'Product_poleoptical.com_September2020.json.gz'
#                        name  \
# 0         AM14 - C4 - 48/19
# 1      Simbo - HVWH - 52/18
# 2  OV5349S - 162571 - 50/24
# 3       Adda - HVBX - 56/17
# 4     Carini - 9038 - 51/16
#
#                                               offers           category  \
# 0  {'availability': 'https://schema.org/InStock',...     Lunette de vue
# 1  {'price': '171', 'itemcondition': 'NewConditio...  Lunette de soleil
# 2  {'price': '289', 'itemcondition': 'NewConditio...  Lunette de soleil
# 3  {'price': '171', 'itemcondition': 'NewConditio...  Lunette de soleil
# 4  {'price': '255', 'itemcondition': 'NewConditio...     Lunette de vue
#
#                  releasedate  \
# 0  2019-11-30T13:46:07+01:00
# 1  2019-10-07T16:09:48+02:00
# 2  2019-10-11T17:06:24+02:00
# 3  2019-10-07T16:28:42+02:00
# 4  2019-10-04T11:07:48+02:00
#
#                                   additionalproperty
# 0  [{'name': 'pa_marque', 'value': 'Lou'}, {'name...
# 1  [{'name': 'pa_gamme', 'value': 'Femme'}, {'val...
# 2  [{'value': 'Prestige', 'name': 'pa_style'}, {'...
# 3  [{'name': 'pa_gamme', 'value': 'Femme'}, {'val...
# 4  [{'value': 'Créateur', 'name': 'pa_style'}, {'...
# 'Product_fragrancenet.com_September2020.json.gz'
#                                                 name offers  \
# 0     Elie Saab Le Parfum L'Eau Couture by Elie Saab   None
# 1        Parfums De Marly Habdan by Parfums De Marly   None
# 2            Halloween Man Rock On by Jesus Del Pozo   None
# 3  Merchant Of Venice Flower Fusion by Merchant O...   None
# 4                      Giorgio Pink by Giorgio Group   None
#
#                                            brand  \
# 0  {'name': 'Elie Saab Le Parfum L'Eau Couture'}
# 1            {'name': 'Parfums De Marly Habdan'}
# 2              {'name': 'Halloween Man Rock On'}
# 3   {'name': 'Merchant Of Venice Flower Fusion'}
# 4                       {'name': 'Giorgio Pink'}
#
#                                      aggregaterating  \
# 0  {'bestrating': '5', 'ratingcount': '0', 'ratin...
# 1                                               None
# 2  {'bestrating': '5', 'ratingcount': '0', 'ratin...
# 3  {'bestrating': '5', 'ratingcount': '0', 'ratin...
# 4                                               None
#
#                      manufacturer
# 0           {'name': 'Elie Saab'}
# 1    {'name': 'Parfums De Marly'}
# 2      {'name': 'Jesus Del Pozo'}
# 3  {'name': 'Merchant Of Venice'}
# 4       {'name': 'Giorgio Group'}
# 'Product_shayandblue.com_September2020.json.gz'
#                                                 name  \
# 0                        Watermelons Fragrance 100ml
# 1  English Cherry Blossom Rich Almond Hand Creme ...
# 2           Discovery Box (Excluded from Promotions)
# 3             English Cherry Blossom Fragrance 100ml
# 4         Amber Oud Ahad Fragrance Concentrate 100ml
#
#                                               offers                    brand  \
# 0  {'availability': 'http://schema.org/InStock', ...  {'name': 'Shay & Blue'}
# 1  {'price': '14', 'availability': 'http://schema...  {'name': 'Shay & Blue'}
# 2  {'availability': 'http://schema.org/InStock', ...  {'name': 'Shay & Blue'}
# 3  {'availability': 'http://schema.org/InStock', ...  {'name': 'Shay & Blue'}
# 4  {'availability': 'http://schema.org/InStock', ...  {'name': 'Shay & Blue'}
#
#          mpn                                             review  \
# 0    0110058  [{'author': 'Kristina M,', 'reviewbody': 'I tr...
# 1    2307560  [{'reviewbody': 'This handcream is the perfect...
# 2  7070601-B  [{'name': 'Shay and blue box', 'author': 'Mitt...
# 3    0110060  [{'reviewbody': 'Beautifully light, floral fra...
# 4    0210083  [{'datepublished': '2018-01-12 09:40:17', 'rev...
#
#                   manufacturer
# 0  {'name': 'Shay &amp; Blue'}
# 1  {'name': 'Shay &amp; Blue'}
# 2                         None
# 3  {'name': 'Shay &amp; Blue'}
# 4  {'name': 'Shay &amp; Blue'}
# 'Product_artock.com.au_September2020.json.gz'
#                                                name  \
# 0  Bunny Small - Speedy Me Bright - French Lavender
# 1                        Children’s Room – Neo 4pcs
# 2                           Smartrod® Set 64 Pieces
# 3        wink classic muslin 1.7 TOG sleeping bag S
# 4                               Washing Machine Set
#
#                                               offers               brand  \
# 0  {'price': '34.99', 'availability': 'InStock', ...           La Millou
# 1  {'price': '39.44', 'availability': 'OutOfStock...            PlanToys
# 2  {'availability': 'OutOfStock', 'pricecurrency'...          Neoformers
# 3  {'availability': 'OutOfStock', 'price': '43.16...      Aden and Anais
# 4  {'availability': 'OutOfStock', 'price': '15.51...  Sylvanian Families
#
#                mpn                                   mainentityofpage
# 0  V31907235201108  {'copyrightyear': '2020', 'name': 'La Millou |...
# 1  V30315672961108  {'copyrightyear': '2020', 'name': 'PlanToys | ...
# 2  V13782106931284  {'name': 'Neoformers - Smartrod® Set 64 Pieces...
# 3  V21111598874708  {'name': 'Aden and Anais - wink classic muslin...
# 4  V30308160176212  {'name': 'Sylvanian Families | Washing Machine...
# 'Product_dermalogica.com_September2020.json.gz'
#                         name  \
# 0        renewal lip complex
# 1         clearing skin wash
# 2               flashfoliant
# 3       active clay cleanser
# 4  daily microfoliant refill
#
#                                               offers        brand  \
# 0  [{'pricecurrency': 'USD', 'price': '27.0', 'av...  Dermalogica
# 1  [{'offercount': '2', 'lowprice': '39.0', 'high...  Dermalogica
# 2  [{'pricecurrency': 'USD', 'url': 'https://www....  Dermalogica
# 3  [{'pricecurrency': 'USD', 'price': '39.0', 'av...  Dermalogica
# 4  [{'pricecurrency': 'USD', 'price': '52.0', 'av...  Dermalogica
#
#                                      aggregaterating          gtin8
# 0  {'bestrating': '5', 'ratingvalue': '4.4', 'wor...   666151061293
# 1  {'bestrating': '5', 'ratingvalue': '4.4', 'wor...   666151011304
# 2  {'bestrating': '5', 'ratingvalue': '4.4', 'wor...   666151111783
# 3  {'bestrating': '5', 'ratingvalue': '4.6', 'wor...   666151011366
# 4  {'bestrating': '5', 'ratingcount': '1648', 'wo...  0666151111929
# 'Product_esmobility.co.uk_September2020.json.gz'
#                         name                                         offers  \
# 0         Rascal Vision 75AH  {'price': '2,695.00', 'pricecurrency': 'GBP'}
# 1        Rascal Vision 100AH  {'price': '2,850.00', 'pricecurrency': 'GBP'}
# 2            Rascal Frontier  {'pricecurrency': 'GBP', 'price': '1,545.00'}
# 3  Kymco HP Feature Midi XLS  {'price': '1,845.00', 'pricecurrency': 'GBP'}
# 4                  Apex Lite  {'price': '1,339.00', 'pricecurrency': 'GBP'}
#
#              brand       aggregaterating mpn
# 0  Rascal Mobility  {'reviewcount': '0'}  CE
# 1  Rascal Mobility  {'reviewcount': '0'}  CE
# 2  Rascal Mobility  {'reviewcount': '0'}  CE
# 3            Kymco  {'reviewcount': '0'}  CE
# 4             Apex  {'reviewcount': '0'}  AL
# 'Product_arloskye.com_September2020.json.gz'
#                                         name  \
# 0  The Zipper Carry-On Max with Front Pocket
# 1                         The Frame Carry-On
# 2                        The Zipper Check-In
# 3                          Online Gift Cards
# 4                            The Luggage Tag
#
#                                               offers                  brand  \
# 0  {'pricecurrency': 'USD', 'price': '375.00', 'a...  {'name': 'Arlo Skye'}
# 1  {'pricecurrency': 'USD', 'price': '450.00', 'a...  {'name': 'Arlo Skye'}
# 2  {'pricecurrency': 'USD', 'price': '395.00', 'a...  {'name': 'Arlo Skye'}
# 3  {'pricecurrency': 'USD', 'availability': 'http...  {'name': 'Arlo Skye'}
# 4  {'pricecurrency': 'USD', 'availability': 'http...  {'name': 'Arlo Skye'}
#
#                                      aggregaterating      mpn
# 0  {'bestrating': '5', 'ratingvalue': '4.89E0', '...  H3SGP23
# 1  {'bestrating': '5', 'reviewcount': '96', 'wors...  H2B0022
# 2  {'bestrating': '5', 'reviewcount': '55', 'wors...  H3YL027
# 3  {'bestrating': '5', 'reviewcount': '1', 'ratin...     None
# 4                                               None  S3BL001
# 'Product_cynth.com_September2020.json.gz'
#                                                 name  \
# 0           Nine West Women's Yesterday Suede Sandal
# 1  TOMS Women's Classic Slip-On (6 B(M) US/36-37 ...
# 2              Ultraclub 8990 UC Ladies Oxford Shirt
# 3  EleQueen Women's Full Cubic Zirconia Long Ball...
# 4  Fashion Ladies Women's Retro Vintage Leather B...
#
#                                               offers  \
# 0  {'pricecurrency': 'USD', 'pricevaliduntil': '2...
# 1  {'pricecurrency': 'USD', 'pricevaliduntil': '2...
# 2  {'pricecurrency': 'USD', 'pricevaliduntil': '2...
# 3  {'pricecurrency': 'USD', 'pricevaliduntil': '2...
# 4  {'pricecurrency': 'USD', 'price': '6.89', 'pri...
#
#                       brand                            aggregaterating  \
# 0     {'name': 'Nine West'}  {'reviewcount': '89', 'ratingvalue': '5'}
# 1                      None  {'reviewcount': '89', 'ratingvalue': '5'}
# 2     {'name': 'UltraClub'}  {'reviewcount': '89', 'ratingvalue': '5'}
# 3      {'name': 'EleQueen'}  {'reviewcount': '89', 'ratingvalue': '5'}
# 4  {'name': 'Broadfashion'}  {'reviewcount': '89', 'ratingvalue': '5'}
#
#        mpn
# 0   940219
# 1   977520
# 2  1620543
# 3  1446616
# 4  1196669
# 'Product_charlestonfabric.com_September2020.json.gz'
#                                        name  \
# 0       Duralee Fabric - Pattern #21048-194
# 1       Duralee Fabric - Pattern #36292-625
# 2     Duralee Fabric - Pattern #DU15917-434
# 3  Tessuto Lino | Steel Robert Allen Design
# 4       Highbury | Pool Robert Allen Design
#
#                                               offers  \
# 0  {'sku': '21048-194', 'gtin12': '706927131629',...
# 1  {'mpn': '706927131563', 'availability': 'https...
# 2  {'availability': 'https://schema.org/InStock',...
# 3  {'pricevaliduntil': '2020-10-27', 'availabilit...
# 4  {'pricevaliduntil': '2020-10-27', 'availabilit...
#
#                                brand           mpn  \
# 0            {'name': 'duralee.com'}  706927131629
# 1            {'name': 'duralee.com'}  706927131563
# 2            {'name': 'duralee.com'}  706927131406
# 3  {'name': 'robertallendesign.com'}  706927132457
# 4  {'name': 'robertallendesign.com'}  706927132258
#
#                      itemcondition
# 0  https://schema.org/NewCondition
# 1  https://schema.org/NewCondition
# 2  https://schema.org/NewCondition
# 3  https://schema.org/NewCondition
# 4  https://schema.org/NewCondition
# 'Product_tungstencarbide-tools.com_September2020.json.gz'
#                                                 name  \
# 0  YT5 / P30 Model E Brazed Carbide Tools Tungste...
# 1                     Sintered tungsten alloy plates
# 2                   Cemented Tungsten Carbide Plates
# 3  YG10XB Tungsten Carbide Inserts For Cutting Gl...
# 4  Polished Tungsten Carbide Strips , square Tung...
#
#                                               offers  brand  \
# 0  [{'pricecurrency': 'USD', 'offercount': '10', ...  RiXin
# 1  [{'pricecurrency': 'USD'}, {'pricecurrency': '...   none
# 2  [{'highprice': '69', 'lowprice': '49', 'pricec...  RiXin
# 3  [{'pricecurrency': 'USD', 'highprice': '45.59'...  rixin
# 4                                               None   none
#
#                     model                                       manufacturer
# 0  Welding Blades Model E  {'legalname': 'Zhuzhou Mingri Cemented Carbide...
# 1                    many  {'legalname': 'Zhuzhou Mingri Cemented Carbide...
# 2  Tungsten carbide strip  {'legalname': 'Zhuzhou Mingri Cemented Carbide...
# 3         carbide inserts  {'legalname': 'Zhuzhou Mingri Cemented Carbide...
# 4                    many  {'legalname': 'Zhuzhou Mingri Cemented Carbide...
# 'Product_shopfakenotes.com_September2020.json.gz'
#                              name  \
# 0  Buy Luxembourg Passport Online
# 1     Buy Austria Passport Online
# 2   Buy Brazilian Passport online
# 3      Buy Italian Identity cards
# 4        Buy Swedish Krona online
#
#                                               offers                    brand  \
# 0  {'offercount': '2', 'highprice': '3500', 'avai...  myresearchemicalshop.co
# 1  {'offercount': '2', 'highprice': '3500', 'avai...  myresearchemicalshop.co
# 2  {'offercount': '2', 'highprice': '3500', 'avai...  myresearchemicalshop.co
# 3  {'offercount': '2', 'lowprice': '215', 'pricec...  myresearchemicalshop.co
# 4  {'highprice': '40000', 'offercount': '48', 'av...  myresearchemicalshop.co
#
#                               aggregaterating  mpn              review
# 0  {'reviewcount': '100', 'ratingvalue': '5'}  N/A  {'author': 'user'}
# 1  {'reviewcount': '100', 'ratingvalue': '5'}  N/A  {'author': 'user'}
# 2  {'reviewcount': '100', 'ratingvalue': '5'}  N/A  {'author': 'user'}
# 3  {'reviewcount': '100', 'ratingvalue': '5'}  N/A  {'author': 'user'}
# 4  {'reviewcount': '100', 'ratingvalue': '5'}  N/A  {'author': 'user'}
# 'Product_artfinder.com_September2020.json.gz'
#                                                 name  \
# 0           Red Cross in Guangzhou - Captain America
# 1                          Shimmering skies of texas
# 2                                       Nude girl #2
# 3            Alien Transistor. a pair of sculptures.
# 4  Poppy Dreams 1 - Floral art by Kathy Morton St...
#
#                                               offers                 brand  \
# 0  {'price': '709.00', 'itemcondition': 'https://...             Dake Wong
# 1  {'price': '495.00', 'itemcondition': 'https://...         Vandana Mehta
# 2  {'price': '25.50', 'itemcondition': 'https://s...         Pavel Kuragin
# 3  {'itemcondition': 'https://schema.org/NewCondi...                 ZheKa
# 4  {'availability': 'OutOfStock', 'itemcondition'...  Kathy Morton Stanion
#
#                                 aggregaterating  \
# 0    {'ratingvalue': '5.0', 'ratingcount': '3'}
# 1                                          None
# 2  {'ratingvalue': '5.0', 'ratingcount': '383'}
# 3   {'ratingvalue': '5.0', 'ratingcount': '10'}
# 4  {'ratingcount': '204', 'ratingvalue': '4.9'}
#
#                                               review  \
# 0  {'reviewbody': 'Shipped per timeline on listin...
# 1                                               None
# 2  {'datepublished': '2020-09-22', 'reviewbody': ...
# 3  {'datepublished': '2020-09-18', 'reviewbody': ...
# 4  {'datepublished': '2020-09-17', 'reviewbody': ...
#
#                        manufacturer
# 0             {'name': 'Dake Wong'}
# 1         {'name': 'Vandana Mehta'}
# 2         {'name': 'Pavel Kuragin'}
# 3                 {'name': 'ZheKa'}
# 4  {'name': 'Kathy Morton Stanion'}
# 'Product_lcking.com_September2020.json.gz'
#                               name  \
# 0     Corduroy Rover Shirt - Stone
# 1      Olive Canvas Utility Jacket
# 2  Indigo Blue Ridge Western Shirt
# 3      Washed Denim Western Jacket
# 4            Brown Duck Chore Coat
#
#                                         offers    brand         gtin8  \
# 0  {'pricecurrency': 'USD', 'price': '125.00'}  LC King  2.283201e+10
# 1  {'pricecurrency': 'USD', 'price': '155.00'}  LC King  2.283201e+10
# 2  {'pricecurrency': 'USD', 'price': '145.00'}  LC King  2.283201e+10
# 3  {'pricecurrency': 'USD', 'price': '165.00'}  LC King           NaN
# 4  {'pricecurrency': 'USD', 'price': '165.00'}  LC King  2.283200e+10
#
#          gtin12
# 0  2.283201e+10
# 1  2.283201e+10
# 2  2.283201e+10
# 3           NaN
# 4  2.283200e+10
# 'Product_ebelts.com_September2020.json.gz'
#                                                 name  \
# 0               Formal Automatic Buckle Leather Belt
# 1                 Black / Brown Genuine Leather Belt
# 2                   High Quality Luxury Leather Belt
# 3                                Unisex Canvas Belts
# 4  100% Genuine Leather Automatic Buckle Belt For...
#
#                                               offers                   brand  \
# 0  {'availability': 'https://schema.org/InStock',...  {'name': 'ebelts.com'}
# 1  {'availability': 'https://schema.org/InStock',...  {'name': 'ebelts.com'}
# 2  {'pricevaliduntil': '2020-10-22', 'availabilit...  {'name': 'ebelts.com'}
# 3  {'availability': 'https://schema.org/InStock',...  {'name': 'ebelts.com'}
# 4  {'availability': 'https://schema.org/InStock',...  {'name': 'ebelts.com'}
#
#                               aggregaterating                      category  \
# 0   {'ratingvalue': '5', 'reviewcount': '12'}  Men's Automatic Buckle Belts
# 1   {'ratingvalue': '5', 'reviewcount': '78'}               Custom category
# 2  {'ratingvalue': '5', 'reviewcount': '229'}           Men's Leather Belts
# 3   {'reviewcount': '92', 'ratingvalue': '5'}            Men's Canvas Belts
# 4                                        None  Men's Automatic Buckle Belts
#
#      mpn                                             review
# 0  53671  [{'reviewbody': 'Very fast delivery in 2 weeks...
# 1   2182  [{'reviewbody': 'Normal belt. I can't say anyt...
# 2   1273  [{'reviewbody': 'Strap quality'}, {'reviewbody...
# 3  38819  [{'reviewbody': 'Quickly sent. Not yet dressed...
# 4    109                                               None
# 'Product_caroclic.com_September2020.json.gz'
#                                     name  \
# 0                             FACE AVANT
# 1  GRILLE DE CALANDRE / SAUF S-LINE / S6
# 2                PARE-CHOCS ARRIERE NOIR
# 3  PHARE ANTI-BROUILLARD DROIT OU GAUCHE
# 4              TRAVERSE AVANT SUPERIEURE
#
#                                               offers     brand  \
# 0  {'availability': 'http://schema.org/InStock', ...  Caroclic
# 1  {'availability': 'http://schema.org/InStock', ...  Caroclic
# 2  {'price': '1.6284E2', 'availability': 'http://...  Caroclic
# 3  {'availability': 'http://schema.org/InStock', ...  Caroclic
# 4  {'availability': 'http://schema.org/InStock', ...  Caroclic
#
#                     category itemcondition manufacturer
# 0                 Face avant  NewCondition   ALFA ROMEO
# 1                   Calandre  NewCondition         AUDI
# 2         Pare-chocs arrière  NewCondition   ALFA ROMEO
# 3         Feu antibrouillard  NewCondition   ALFA ROMEO
# 4  Traverse avant supérieure  NewCondition         AUDI
# 'Product_john-anthony.com_September2020.json.gz'
#                               name  \
# 0         Skidoo Tribe Nylon Parka
# ...
# 3  Acupuncture needles MOXOM TCM 1000 pcs. (silic...
# 4                                    Injection Belly
#
#                                         offers          brand        mpn  \
# 0  {'price': '157.92', 'pricecurrency': 'GBP'}  3B Scientific    VP750/1
# 1  {'pricecurrency': 'GBP', 'price': '103.79'}  3B Scientific      A81/1
# 2    {'price': '3.96', 'pricecurrency': 'GBP'}          Moxom    CW-3030
# 3   {'price': '34.68', 'pricecurrency': 'GBP'}          Moxom  CC10-3030
# 4  {'price': '136.80', 'pricecurrency': 'GBP'}           None   WA28395U
#
#                                   weight
# 0   {'value': '1.21', 'unitcode': 'KGM'}
# 1   {'unitcode': 'KGM', 'value': '0.74'}
# 2  {'unitcode': 'KGM', 'value': '0.063'}
# 3  {'value': '0.281', 'unitcode': 'KGM'}
# 4   {'unitcode': 'KGM', 'value': '0.91'}
# 'Product_evybenita.com_September2020.json.gz'
#                                                 name  \
# 0                         Clouded Leopard Enamel Pin
# 1  SECONDS: Whale Shark (RAINBOW) - Galactic Reef...
# 2  SECONDS: Full Set: Galactic Reef Collection (G...
# 3          Arctic Fox (Gold)- Arctic Nova Collection
# 4  SECONDS: Whale Shark (RAINBOW) - Galactic Reef...
#
#                                               offers       brand  \
# 0  {'price': '12.90', 'availability': 'http://sch...  Evy Benita
# 1  {'pricecurrency': 'AUD', 'availability': 'http...  Evy Benita
# 2  {'pricecurrency': 'GBP', 'pricevaliduntil': '2...  Evy Benita
# 3  {'price': '10.00', 'availability': 'http://sch...  Evy Benita
# 4  {'availability': 'http://schema.org/InStock', ...  Evy Benita
#
#                                                  mpn  \
# 0                         clouded-leopard-enamel-pin
# 1  seconds-whale-shark-rainbow-galactic-reef-coll...
# 2   seconds-full-set-galactic-reef-collection-gold-2
# 3   seconds-arctic-fox-gold-arctic-nova-collection-2
# 4  seconds-whale-shark-rainbow-galactic-reef-coll...
#
#                      itemcondition                 color
# 0  https://schema.org/NewCondition                  None
# 1  https://schema.org/NewCondition          Blue / Lilac
# 2  https://schema.org/NewCondition  Lilac / Pink / White
# 3  https://schema.org/NewCondition                 White
# 4  https://schema.org/NewCondition          Blue / Lilac
# 'Product_lovebirdsb.com_September2020.json.gz'
#                             name  \
# 0       Rag Poets Fulton Sweater
# 1         ElizabethW Body Lotion
# 2                     Metro Tote
# 3  Inizio Linen Magic Capri Pant
# 4     Driftwood Saydi Jean Skirt
#
#                                               offers       brand       mpn  \
# 0  {'validfrom': '2020-09-28', 'pricevaliduntil':...   Rag Poets  RW203323
# 1  {'availability': 'https://schema.org/InStock',...  ElizabethW      None
# 2  {'validfrom': '2020-09-28', 'url': 'https://ww...        None      None
# 3  {'availability': 'https://schema.org/InStock',...      Inizio      3443
# 4  {'price': '88.00', 'pricecurrency': 'USD', 'va...   Driftwood   K40266A
#
#                      itemcondition
# 0  https://schema.org/NewCondition
# 1  https://schema.org/NewCondition
# 2  https://schema.org/NewCondition
# 3  https://schema.org/NewCondition
# 4  https://schema.org/NewCondition
# 'Product_catersuppliesdirect.com_September2020.json.gz'
#                                                 name  \
# 0                 Bolsius Dinner Candle Glass Holder
# 1                          Mixology Spritz 57cl 20oz
# 2                  Martini Cocktail Black Light 21cl
# 3  5L Maxima Bactericidal Food Safe Cleaner/Sanit...
# 4                                 Peacock Flute 20cl
#
#                                               offers                  brand  \
# 0  {'price': '1.20', 'availability': 'http://sche...                bolsius
# 1  {'pricecurrency': 'GBP', 'availability': 'http...  Cater Supplies Direct
# 2  {'price': '6.43', 'pricevaliduntil': '2021-12-...  Cater Supplies Direct
# 3  {'pricevaliduntil': '2021-12-31', 'price': '12...  Cater Supplies Direct
# 4  {'price': '10.00', 'availability': 'http://sch...  Cater Supplies Direct
#
#             mpn itemcondition
# 0  103684140300           new
# 1     15-42-137           new
# 2         H2389           new
# 3       C128MAX           new
# 4      ART51184           new
# 'Product_citydrawers.com_September2020.json.gz'
#                                                 name  \
# 0                    Boody - Boody BK Classic Bikini
# 1  Natori - Natori 7462111 Statement pieced cup u...
# 2                        Boody - Boody BR Shaper Bra
# 3       Evelyn+Bobbie - EVEBOB 17102 Midrise Hipster
# 4             Boody - Boody RBB Active Racerback Bra
#
#                                               offers          brand  \
# 0         {'pricecurrency': 'USD', 'price': '11.95'}          Boody
# 1         {'pricecurrency': 'USD', 'price': '68.00'}         Natori
# 2  {'pricecurrency': 'USD', 'price': '16.95', 'av...          Boody
# 3  {'pricecurrency': 'USD', 'price': '22.00', 'av...  Evelyn+Bobbie
# 4  {'pricecurrency': 'USD', 'price': '39.95', 'av...          Boody
#
#                  mpn                   itemcondition  reviewcount  \
# 0   BOODY BK-XS-Nude  http://schema.org/NewCondition            0
# 1               None  http://schema.org/NewCondition            0
# 2  BOODY BR-M/L-Nude  http://schema.org/NewCondition            0
# 3               None  http://schema.org/NewCondition            0
# 4               None  http://schema.org/NewCondition            0
#
#    ratingvalue  bestrating  worstrating
# 0            0           5            1
# 1            0           5            1
# 2            0           5            1
# 3            0           5            1
# 4            0           5            1
# 'Product_artsy.net_September2020.json.gz'
#                                                 name  \
# 0  David Hockney | David Hockney A Bigger Book Ha...
# 1  Kumikaho Oshima | legs2 (2009) | Available for...
# 2  Newcomb College, Small Two-handled Vase with S...
# 3  Attributed to Syrie Maugham | Desk, England (1...
# 4  Awol Erizku | Girl with a Bamboo Earring (2009...
#
#                                               offers  \
# 0                                               None
# 1  {'pricecurrency': 'EUR', 'availability': 'http...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                      brand               category       width  \
# 0                {'name': 'David Hockney'}   Books and Portfolios   27 3/5 in
# 1              {'name': 'Kumikaho Oshima'}               Painting  55 1/10 in
# 2                                     None  Design/Decorative Art        4 in
# 3  {'name': 'Attributed to Syrie Maugham'}  Design/Decorative Art   31 1/2 in
# 4                  {'name': 'Awol Erizku'}            Photography       64 in
#
#        height
# 0  19 7/10 in
# 1  42 1/10 in
# 2        5 in
# 3       64 in
# 4       49 in
# 'Product_topoutdoorsupplies.com_September2020.json.gz'
#                                                 name  \
# 0  24&#8243;-29&#8243; Bicycle Bike Kick Stand MT...
# 1  original supacaz tape road bike bar tape carbo...
# 2  Adjustable Unisex Bike Cycling Helmet Baseball...
# 3  MTB Road Bike Stand Parking Adjustable Aluminu...
# 4  WEST BIKING Bicycle Water Bottle Portable Leak...
#
#                                               offers  \
# 0  {'pricevaliduntil': '2020-10-17', 'availabilit...
# 1  [{'price': '42.97', 'pricevaliduntil': '2020-1...
# 2  {'price': '26.73', 'name': 'Adjustable Unisex ...
# 3  {'name': 'MTB Road Bike Stand Parking Adjustab...
# 4  {'pricevaliduntil': '2020-10-16', 'availabilit...
#
#                                 brand              category    mpn
# 0  {'name': 'topoutdoorsupplies.com'}             Kickstand  10071
# 1  {'name': 'topoutdoorsupplies.com'}        Handlebar Tape   8766
# 2  {'name': 'topoutdoorsupplies.com'}        Bicycle Helmet   8149
# 3  {'name': 'topoutdoorsupplies.com'}             Kickstand  10045
# 4  {'name': 'topoutdoorsupplies.com'}  Bicycle Water Bottle   8602
# 'Product_ppssurf.com_September2020.json.gz'
#                     name                                             offers  \
# 0              FACE MASK  FACE MASK VISSLA $10.00 Quantity: Subtotal: $1...
# 1              FK PSYCHO  FK PSYCHO FK $40.00 Quantity: Subtotal: $40.00...
# 2     4020 GROMS STINGER  4020 GROMS STINGER CARVE GROMS STINGER $29.99 ...
# 3    RIFLES MIDSIZE TIDE  RIFLES MIDSIZE TIDE RIP CURL Surf Watches $199...
# 4  THE JAM H2O FLOATABLE  THE JAM H2O FLOATABLE DRAGON Product Informati...
#
#      price shop-currency
# 0   $10.00           AUD
# 1   $40.00           AUD
# 2   $29.99           AUD
# 3  $199.99           AUD
# 4  $230.00           AUD
# 'Product_wildyakexpeditions.com_September2020.json.gz'
#                name                             brand  \
# 0        AMA DABLAM  {'name': 'Wildyak Expeditions.'}
# 1  TSUM VALLEY Trek  {'name': 'Wildyak Expeditions.'}
# 2        TIBET Tour  {'name': 'Wildyak Expeditions.'}
# 3       ISLAND Peak  {'name': 'Wildyak Expeditions.'}
# 4      LOBUCHE Peak  {'name': 'Wildyak Expeditions.'}
#
#                             aggregaterating  \
# 0  {'reviewcount': '7', 'ratingvalue': '5'}
# 1  {'reviewcount': '7', 'ratingvalue': '5'}
# 2  {'reviewcount': '7', 'ratingvalue': '5'}
# 3  {'reviewcount': '7', 'ratingvalue': '5'}
# 4  {'reviewcount': '7', 'ratingvalue': '5'}
#
#                                               review     gtin8
# 0  {'description': '<p>The Ama Dablam, 6856 meter...   WYES810
# 1  {'name': 'TSUM VALLEY Trek', 'author': 'Wild Y...   WYES236
# 2  {'description': '<p>WILD YAK EXPEDITIONS bring...  WYES4045
# 3  {'description': '<p>WILD YAK EXPEDITIONS welco...   WYES678
# 4  {'author': 'Wild Yack Expeditions', 'descripti...   WYES646
# 'Product_goelectrical.com.au_September2020.json.gz'
#                                                 name                 mpn  \
# 0        Building Wire 1 Core 1.5mm PVC Blue 0.6/1kV          ADVBW1.5BL
# 1     Building Wire 1 Core 2.5mm PVC Grn/Ylw 0.6/1kV        APEIVM205E-1
# 2  Building Wire 1 Core 1.5mm V90HT PVC Grey 450/...       ELCSR1015-GRY
# 3       Building Wire 1 Core 4.0mm PVC White 0.6/1kV       OLX7/085BWWA5
# 4            SDI 1 Core 10mm Cu PVC/PVC Red Core Wht  TYCBDM17135-WH-500
#
#                                                model  color  \
# 0        Building Wire 1 Core 1.5mm PVC Blue 0.6/1kV  Black
# 1     Building Wire 1 Core 2.5mm PVC Grn/Ylw 0.6/1kV  Black
# 2  Building Wire 1 Core 1.5mm V90HT PVC Grey 450/...  Black
# 3       Building Wire 1 Core 4.0mm PVC White 0.6/1kV  Black
# 4            SDI 1 Core 10mm Cu PVC/PVC Red Core Wht  Black
#
#                 gtin8
# 0          ADVBW1.5BL
# 1        APEIVM205E-1
# 2       ELCSR1015-GRY
# 3       OLX7/085BWWA5
# 4  TYCBDM17135-WH-500
# 'Product_lovelypetzone.com_September2020.json.gz'
#                                         name  \
# 0       Dog’s Warm Coral Fleece Bed Blankets
# 1      Absorbent Soft Dog’s Adjustable Towel
# 2        Large Space Themed Blanket for Pets
# 3  Pet Paw and Heart Shaped Pendant Necklace
# 4  Portable Dog Water Bottle for Outdoor Use
#
#                                               offers              brand  \
# 0  {'availability': 'https://schema.org/InStock',...  lovelypetzone.com
# 1  {'price': '19.96', 'availability': 'https://sc...  lovelypetzone.com
# 2  {'availability': 'https://schema.org/InStock',...  lovelypetzone.com
# 3  {'availability': 'https://schema.org/InStock',...  lovelypetzone.com
# 4  {'price': '15.98', 'availability': 'https://sc...  lovelypetzone.com
#
#                                 aggregaterating category   mpn review
# 0  {'reviewcount': '14', 'ratingvalue': '4.40'}     None  1566   None
# 1  {'ratingvalue': '4.30', 'reviewcount': '12'}     None  1525   None
# 2  {'ratingvalue': '4.60', 'reviewcount': '18'}     None  1568   None
# 3  {'ratingvalue': '4.60', 'reviewcount': '14'}     None  2050   None
# 4  {'ratingvalue': '4.50', 'reviewcount': '14'}     None  1626   None
# 'Product_festapratica.com_September2020.json.gz'
#                                           name  \
# 0  Balão Metalizado Letra Gigante Dourada 95cm
# 1                 Vela Estrela Azul - Curifest
# 2  Balão Metalizado Letra Gigante Dourada 95cm
# 3   Balão Metalizado Número Gigante Preto 95cm
# 4    Balão Metalizado Número Gigante Rosa 95cm
#
#                                               offers  \
# 0  [{'pricecurrency': 'BRL', 'itemcondition': 'ht...
# 1  [{'pricecurrency': 'BRL', 'itemcondition': 'ht...
# 2  [{'pricecurrency': 'BRL', 'itemcondition': 'ht...
# 3  [{'pricecurrency': 'BRL', 'sku': '999000015276...
# 4  [{'pricecurrency': 'BRL', 'itemcondition': 'ht...
#
#                        brand        gtin13 weight
# 0  {'name': 'Festa Prática'}  9.990000e+12    10g
# 1  {'name': 'Festa Prática'}  7.896902e+12    20g
# 2  {'name': 'Festa Prática'}  9.990000e+12    10g
# 3  {'name': 'Festa Prática'}  9.990000e+12    10g
# 4  {'name': 'Festa Prática'}  9.990000e+12    10g
# 'Product_perapasha.com_September2020.json.gz'
#                                                 name         brand  \
# 0           Scheepjes Maxi Sugar Rush 50 g Tangerine  Scheepjeswol
# 1    Lang Yarns Merino 120 Degrade Gerbera (37.0008)    Lang Yarns
# 2  DMC Mouline Color Variations Embroidery Thread...           DMC
# 3                        Opti Zipper 20 cm 4801-0542          Opti
# 4                           Durable Cosy Denim (290)       Durable
#
#                                             category  \
# 0    Home » Scheepjes Maxi Sugar Rush 50 g Tangerine
# 1  Home » Lang Yarns Merino 120 Degrade Gerbera (...
# 2  Home » DMC Mouline Color Variations Embroidery...
# 3                 Home » Opti Zipper 20 cm 4801-0542
# 4                    Home » Durable Cosy Denim (290)
#
#                           review             model  \
# 0  {'count': '0', 'rating': '0'}        SSURUSH281
# 1  {'count': '0', 'rating': '0'}         LY37.0008
# 2  {'count': '0', 'rating': '0'}          DMCC4200
# 3  {'count': '0', 'rating': '0'}  OP4801-0020-0542
# 4  {'count': '0', 'rating': '0'}           DUCO290
#
#                                           breadcrumb  \
# 0    Home » Scheepjes Maxi Sugar Rush 50 g Tangerine
# 1  Home » Lang Yarns Merino 120 Degrade Gerbera (...
# 2  Home » DMC Mouline Color Variations Embroidery...
# 3                 Home » Opti Zipper 20 cm 4801-0542
# 4                    Home » Durable Cosy Denim (290)
#
#                                         offerdetails
# 0  {'currency': 'EUR', 'seller': 'perapasha', 'pr...
# 1  {'currency': 'EUR', 'seller': 'perapasha', 'pr...
# 2  {'price': '1.750023', 'currency': 'EUR', 'sell...
# 3  {'currency': 'EUR', 'seller': 'perapasha', 'pr...
# 4  {'price': '3.599992', 'currency': 'EUR', 'sell...
# 'Product_dutchflies.com_September2020.json.gz'
#                                 name  \
# 0           Quick release indicators
# 1                       Whipfinisher
# 2                          Worm body
# 3  RIO Mainstream 12ft Sink Tip Line
# 4                       Hard Varnish
#
#                                               offers                 brand  \
# 0  {'price': '6.25', 'availability': 'https://sch...  {'name': 'Glomavis'}
# 1  {'price': '3.95', 'availability': 'https://sch...  {'name': 'Glomavis'}
# 2  {'price': '2.25', 'availability': 'https://sch...                  None
# 3  {'price': '49.90', 'availability': 'https://sc...       {'name': 'Rio'}
# 4  {'price': '2.75', 'availability': 'https://sch...  {'name': 'Glomavis'}
#
#               mpn          gtin13
# 0  Phill-quick-in  Phill-quick-in
# 1    Whipfinisher    Whipfinisher
# 2       Worm body       Worm body
# 3      RM12ftSink      RM12ftSink
# 4    Hard Varnish    Hard Varnish
