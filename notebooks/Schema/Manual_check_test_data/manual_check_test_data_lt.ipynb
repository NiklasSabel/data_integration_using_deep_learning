# %%
# import libraries
import os
import pandas as pd
import json
import gzip
import fasttext 
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
path = '../../src/data/schemafiltereddata/TrainTestTables/Large/Test'
l = [file for file in os.listdir(path) if file.startswith('Product_')]
len(l)
# Out:
# 4239

# %%
l2 = l[100:200]
l2
# Out:
# ['Product_mastermachineryllc.com_September2020.json.gz',
#  'Product_tipsycandlecompany.com_September2020.json.gz',
#  'Product_gmemployeepartsdiscount.com_September2020.json.gz',
#  'Product_nuori.com_September2020.json.gz',
#  'Product_vwoaklawn.com_September2020.json.gz',
#  'Product_amycoz.com_September2020.json.gz',
#  'Product_kity-rouen.com_September2020.json.gz',
#  'Product_24chemicalresearch.com_September2020.json.gz',
#  'Product_muglerusa.com_September2020.json.gz',
#  'Product_myla.com_September2020.json.gz',
#  'Product_houseandhold.com_September2020.json.gz',
#  'Product_continentalcommercialproducts.com_September2020.json.gz',
#  'Product_maternityideas.com_September2020.json.gz',
#  'Product_cityxplora.com_September2020.json.gz',
#  'Product_bitek.com.tw_September2020.json.gz',
#  'Product_touchlcdhouse.com_September2020.json.gz',
#  'Product_gallifurniture.com_September2020.json.gz',
#  'Product_officialmemorabilia.com.au_September2020.json.gz',
#  'Product_solovela.net_September2020.json.gz',
#  'Product_steampunkweb.com_September2020.json.gz',
#  'Product_hlmotorcars.com_September2020.json.gz',
#  'Product_progressyourhealth.com_September2020.json.gz',
#  'Product_mosaicnatural.com_September2020.json.gz',
#  'Product_emarinepx.com_September2020.json.gz',
#  'Product_emckay.com_September2020.json.gz',
#  'Product_jewelry-shevchenko.com.ua_September2020.json.gz',
#  'Product_babaautostx.com_September2020.json.gz',
#  'Product_luluschocolate.com_September2020.json.gz',
#  'Product_oxfordmillsoutlet.com_September2020.json.gz',
#  'Product_propertyinbaner.com_September2020.json.gz',
#  'Product_xposed.com.au_September2020.json.gz',
#  'Product_fiberoptic-device.com_September2020.json.gz',
#  'Product_karaca-home.com_September2020.json.gz',
#  'Product_prolocktoolstorage.com_September2020.json.gz',
#  'Product_janalam.com_September2020.json.gz',
#  'Product_innovetpet.com_September2020.json.gz',
#  'Product_pterodactyl-addons.com_September2020.json.gz',
#  'Product_theurbanmen.com_September2020.json.gz',
#  'Product_eastcoastmoparts.com_September2020.json.gz',
#  'Product_nissanofvictoria.com_September2020.json.gz',
#  'Product_femigod.com_September2020.json.gz',
#  'Product_tennis.com.co_September2020.json.gz',
#  'Product_hillwebcreations.com_September2020.json.gz',
#  'Product_chubbiesshorts.com_September2020.json.gz',
#  'Product_basenotes.net_September2020.json.gz',
#  'Product_lightenupelectricalservices.com_September2020.json.gz',
#  'Product_de-atramentis.com_September2020.json.gz',
#  'Product_canvastsupplyco.com_September2020.json.gz',
#  'Product_primeclassicdesign.com_September2020.json.gz',
#  'Product_margaretlukasik.com_September2020.json.gz',
#  'Product_treekeeperbag.com_September2020.json.gz',
#  'Product_ritualgems.com_September2020.json.gz',
#  'Product_21jumpsuits.com_September2020.json.gz',
#  'Product_milkncookiez.com_September2020.json.gz',
#  'Product_dulcesenda.com_September2020.json.gz',
#  'Product_flowers4milan.com_September2020.json.gz',
#  'Product_holderwellsfuneralhome.com_September2020.json.gz',
#  'Product_vw.com_September2020.json.gz',
#  'Product_lightsdaddy.com_September2020.json.gz',
#  'Product_tickets.co.uk_September2020.json.gz',
#  'Product_kammb-karz.com_September2020.json.gz',
#  'Product_augustaloja.com_September2020.json.gz',
#  'Product_ashaybythebay.com_September2020.json.gz',
#  'Product_shopbellemode.com_September2020.json.gz',
#  'Product_zebraz.com_September2020.json.gz',
#  'Product_dyerchevyftpierce.com_September2020.json.gz',
#  'Product_twinset.com_September2020.json.gz',
#  'Product_americanmobilityspecialists.com_September2020.json.gz',
#  'Product_everythingtrackandfield.com_September2020.json.gz',
#  'Product_findlaytruckrvsales.com_September2020.json.gz',
#  'Product_hometreatsuk.com_September2020.json.gz',
#  'Product_dxproz.com_September2020.json.gz',
#  'Product_tyrepoint.com.au_September2020.json.gz',
#  'Product_adnams.co.uk_September2020.json.gz',
#  'Product_compendiumstore.com_September2020.json.gz',
#  'Product_northstarfox.com_September2020.json.gz',
#  'Product_charlieobaugh.com_September2020.json.gz',
#  'Product_bulktoystore.com_September2020.json.gz',
#  'Product_triskafuneralhome.com_September2020.json.gz',
#  'Product_gsmzone.co.uk_September2020.json.gz',
#  'Product_perfumesonline.com.mx_September2020.json.gz',
#  'Product_ar15discounts.com_September2020.json.gz',
#  'Product_nonstophype.com_September2020.json.gz',
#  'Product_sweettez.com_September2020.json.gz',
#  'Product_miccys.com_September2020.json.gz',
#  'Product_gousfbulls.com_September2020.json.gz',
#  'Product_scrapbooking-warehouse.com_September2020.json.gz',
#  'Product_brambletonimports.com_September2020.json.gz',
#  'Product_nesemannsdiamondcenter.com_September2020.json.gz',
#  'Product_kuyhaacrack.com_September2020.json.gz',
#  'Product_acemartmall.com_September2020.json.gz',
#  'Product_famouschairs.com_September2020.json.gz',
#  'Product_archibalds.net_September2020.json.gz',
#  'Product_gypsyrockco.com_September2020.json.gz',
#  'Product_awoodidea.co.uk_September2020.json.gz',
#  'Product_dogdigest.com_September2020.json.gz',
#  'Product_laurelfuneralhome.net_September2020.json.gz',
#  'Product_jugais.com_September2020.json.gz',
#  'Product_sieuthihangmy.com.vn_September2020.json.gz',
#  'Product_bobcatarmament.com_September2020.json.gz']

# %%
path = '/work-ceph/bizer-tp2021/data_integration_using_deep_learning/src/data/data/CSV_files'
stats = pd.read_csv(path + '/all_files_stats.csv')
files = pd.read_csv(path + '/all_files_cleaned.csv')
files = files.drop(columns={'Unnamed: 0'})
listcol= files.groupby('filename')['column_name'].apply(list).reset_index(name='listofcolumns')
listcol.filename = listcol.filename.str.split('_', expand=True)[0]
listcol.index = listcol['filename']
listcol = listcol[listcol['filename']=='Product']

# %%
l2 = l[1900:2000]

# %%
path='../../src/data/schemafiltereddata/TrainTestTables/Large/Test'
#files = [file for file in os.listdir(path) if file.endswith('.json.gz')]
for index in listcol.filename:
    setcol = listcol.loc[index]['listofcolumns']
    for file in l2:
    # read file
        df = pd.read_json(os.path.join(path, '{}'.format(file)), compression='gzip', lines=True)
        display(file)
        display(df[df.columns.intersection(setcol)].head())
    #column_count_Music.extend(list_col)
# Out:
# 'Product_thechristmascottagestore.co.uk_September2020.json.gz'
#                                                 name  \
# 0                  Sony PlayStation 4 500 GB Bundles
# 1  6ft Garland with Velvet Poinsettia Flowers wit...
# 2  Baylis & Harding Fuzzy Duck Men's Ginger and L...
# 3  Decorative Christmas LED Light Up Flame Lanter...
# 4  6 x Rolls Traditional Curling Ribbon Red Gold ...
#
#                                               offers  \
# 0  {'availability': 'https://schema.org/InStock',...
# 1  {'availability': 'https://schema.org/InStock',...
# 2  {'price': '21.99', 'availability': 'https://sc...
# 3  {'price': '0.00', 'availability': 'https://sch...
# 4  {'price': '3.49', 'availability': 'https://sch...
#
#                                  brand  \
# 0                                 None
# 1                                 None
# 2         {'name': 'Baylis & Harding'}
# 3                  {'name': 'Y56(TM)'}
# 4  {'name': 'The Home Fusion Company'}
#
#                              aggregaterating   mpn
# 0  {'reviewcount': '89', 'ratingvalue': '5'}  5637
# 1  {'reviewcount': '89', 'ratingvalue': '5'}  1107
# 2  {'reviewcount': '89', 'ratingvalue': '5'}  6871
# 3  {'reviewcount': '89', 'ratingvalue': '5'}  7951
# 4  {'reviewcount': '89', 'ratingvalue': '5'}  1376
# 'Product_takahala.com_September2020.json.gz'
#                    name                                             offers  \
# 0             ➯ 维修/更换实例  {'url': 'http://www.takahala.com/product_13102...
# 1             ➯ 维修/更换实例  {'pricecurrency': 'NT$', 'price': '0', 'url': ...
# 2           ➯ 订制曳引机后副铁轮  {'pricecurrency': 'NT$', 'pricevaliduntil': '2...
# 3         R-2678-IN（全铁）  {'pricecurrency': 'NT$', 'pricevaliduntil': '2...
# 4  ∅ ８２０（风轮）＋∅ １３４０（胶轮）  {'pricecurrency': 'NT$', 'pricevaliduntil': '2...
#
#               brand                           aggregaterating      mpn  \
# 0          维修/改装/加装  {'reviewcount': '1', 'ratingvalue': '5'}  1310215
# 1          维修/改装/加装  {'reviewcount': '1', 'ratingvalue': '5'}  1310340
# 2           副铁轮/副胶轮  {'reviewcount': '1', 'ratingvalue': '5'}  1310551
# 3            全铁（IN）  {'reviewcount': '1', 'ratingvalue': '5'}  1309847
# 4  多需求（EX：前风轮＋后橡胶轮）  {'reviewcount': '1', 'ratingvalue': '5'}  1310557
#
#                                               review
# 0  {'author': 'takahala.com', 'datepublished': '2...
# 1  {'author': 'takahala.com', 'datepublished': '2...
# 2  {'author': 'takahala.com', 'datepublished': '2...
# 3  {'author': 'takahala.com', 'datepublished': '2...
# 4  {'author': 'takahala.com', 'datepublished': '2...
# 'Product_skatexs.com_September2020.json.gz'
#                                                 name  \
# 0  SkateXS Purple Panda Advanced Complete Skatebo...
# 1  SkateXS Unicorn Advanced Complete Skateboard f...
# 2  SkateXS Purple Panda Beginner Complete Skatebo...
# 3  SkateXS Starboard Advanced Complete Skateboard...
# 4    SkateXS Pirate Pro Complete Skateboard for Kids
#
#                                               offers                brand  \
# 0  {'pricecurrency': 'USD', 'itemcondition': 'New...                 None
# 1  {'pricecurrency': 'USD', 'itemcondition': 'New...                 None
# 2  {'pricecurrency': 'USD', 'price': '123.95', 's...                 None
# 3  {'pricecurrency': 'USD', 'itemcondition': 'New...                 None
# 4  [{'mpn': 'SXC72PGS1', 'availability': 'https:/...  {'name': 'SkateXS'}
#
#                              aggregaterating        mpn
# 0                                       None       None
# 1                                       None       None
# 2                                       None       None
# 3                                       None       None
# 4  {'ratingcount': '20', 'ratingvalue': '5'}  SXC70PBS1
# 'Product_swanbullion.com_September2020.json.gz'
#                                                 name  \
# 0  2017 South Korean Chiwoo Cheonwang 1/2oz .999 ...
# 1  The ANZAC Spirit – To Our Last Man 2014 1/4oz ...
# 2  2011 American Eagle 1oz .999 Silver Bullion Co...
# 3  2016 Year of the Monkey - 3 Coin (1/10 oz, 1/4...
# 4  Southern Cross Bullion 1oz .999 Silver Cast Bu...
#
#                                               offers  \
# 0  {'pricecurrency': 'AUD', 'itemcondition': 'New...
# 1  {'pricecurrency': 'AUD', 'itemcondition': 'New...
# 2  {'pricecurrency': 'AUD', 'itemcondition': 'New...
# 3  {'pricecurrency': 'AUD', 'itemcondition': 'New...
# 4  {'pricecurrency': 'AUD', 'price': '29.48', 'it...
#
#                                 brand  \
# 0                                None
# 1          {'name': 'The Perth Mint'}
# 2                 {'name': 'US Mint'}
# 3          {'name': 'The Perth Mint'}
# 4  {'name': 'Southern Cross Bullion'}
#
#                                       category  \
# 0  Silver Coins > Silver > 1/2 OZ Silver Coins
# 1                                         None
# 2    Silver Coins > Silver > 1 OZ Silver Coins
# 3                                         None
# 4      Silver Bars > Silver > 1 OZ Silver Bars
#
#                                  weight                releasedate  \
# 0   {'value': '.06', 'unitcode': 'KGM'}  2019-02-05T15:05:56+08:00
# 1   {'value': '0.5', 'unitcode': 'KGM'}  2018-02-13T07:48:50+08:00
# 2  {'value': '0.06', 'unitcode': 'KGM'}  2018-07-12T16:14:52+08:00
# 3   {'value': '0.5', 'unitcode': 'KGM'}  2018-02-12T09:28:45+08:00
# 4   {'value': '.05', 'unitcode': 'KGM'}  2018-07-28T14:25:28+08:00
#
#                                width                             height  \
# 0  {'value': '5', 'unitcode': 'CMT'}  {'value': '5', 'unitcode': 'CMT'}
# 1                               None                               None
# 2  {'value': '5', 'unitcode': 'CMT'}  {'value': '5', 'unitcode': 'CMT'}
# 3                               None                               None
# 4  {'value': '5', 'unitcode': 'CMT'}  {'value': '5', 'unitcode': 'CMT'}
#
#                                depth
# 0  {'value': '5', 'unitcode': 'CMT'}
# 1                               None
# 2  {'value': '5', 'unitcode': 'CMT'}
# 3                               None
# 4  {'value': '5', 'unitcode': 'CMT'}
# 'Product_barossafinefoods.com.au_September2020.json.gz'
#                                           name  \
# 0  [Product Information, TexMex Burger - 440g]
# 1     [Product Information, Rump Steak - 400g]
# 2                     American Pork Ribs - 1kg
# 3                             Diced Beef - 1kg
# 4  [Product Information, Smoked Kabana - 220g]
#
#                                        offers               brand  \
# 0   {'price': '8.99', 'pricecurrency': 'AUD'}                None
# 1  {'pricecurrency': 'AUD', 'price': '11.99'}  Barossa Fine Foods
# 2  {'pricecurrency': 'AUD', 'price': '18.99'}  Barossa Fine Foods
# 3  {'pricecurrency': 'AUD', 'price': '25.99'}  Barossa Fine Foods
# 4   {'pricecurrency': 'AUD', 'price': '5.99'}  Barossa Fine Foods
#
#                                   additionalproperty availability
# 0  {'name': 'Serving Suggestion', 'value': 'Grill...     In Stock
# 1  {'value': ['BBQ, stir fry, pan fry & kebabs', ...     In Stock
# 2  {'value': 'BBQ & roast', 'name': 'Cooking Meth...     In Stock
# 3  {'value': 'Roast, pan fry', 'name': 'Cooking M...     In Stock
# 4  {'value': 'Traditionally served with cubed che...     In Stock
# 'Product_calahanfuneralhome.com_September2020.json.gz'
#                            name  \
# 0                Widow to Widow
# 1     Angel Wind Chime - Silver
# 2  Peaceful White Lilies Basket
# 3     Amazing Grace 44\" Sonnet
# 4     Cross Wind Chime - Bronze
#
#                                               offers  \
# 0  {'pricecurrency': 'USD', 'highprice': '39.95',...
# 1  {'pricecurrency': 'USD', 'lowprice': '69.95', ...
# 2  {'pricecurrency': 'USD', 'highprice': '89.95',...
# 3  {'pricecurrency': 'USD', 'highprice': '84.95',...
# 4  {'pricecurrency': 'USD', 'lowprice': '69.95', ...
#
#                                  aggregaterating  \
# 0                                           None
# 1                                           None
# 2  {'reviewcount': '250', 'ratingvalue': '4.93'}
# 3    {'reviewcount': '1', 'ratingvalue': '5.00'}
# 4                                           None
#
#                                               review itemcondition  \
# 0                                               None  NewCondition
# 1                                               None  NewCondition
# 2  [{'datepublished': '6/10/2020', 'description':...  NewCondition
# 3  {'author': 'from -', 'datepublished': '5/3/201...  NewCondition
# 4                                               None  NewCondition
#
#                                                model
# 0  {'image': 'https://res.cloudinary.com/picasso/...
# 1  [{'url': 'https://www.calahanfuneralhome.com/s...
# 2  {'url': 'https://www.calahanfuneralhome.com/st...
# 3  {'sku': '60239', 'image': 'https://res.cloudin...
# 4  [{'name': 'Cross Wind Chime - Bronze (Cross Gr...
# 'Product_ozfilterwarehouse.com.au_September2020.json.gz'
#   name                                             offers  \
# 0   10  {'pricecurrency': 'AUD', 'description': 'This ...
# 1   20  {'price': '18.000', 'url': 'https://www.ozfilt...
# 2   10  {'url': 'https://www.ozfilterwarehouse.com.au/...
# 3   10  {'url': 'https://www.ozfilterwarehouse.com.au/...
# 4    5  {'url': 'https://www.ozfilterwarehouse.com.au/...
#
#                  brand                                           category  \
# 0  Oz Filter Warehouse  10\" x 2-&#189;\" Standard Size Pleated Filter...
# 1  Oz Filter Warehouse  20 inch Standard Water Filter Cartridges|20\" ...
# 2  Oz Filter Warehouse  10 inch Standard Water Filter Cartridges|10\" ...
# 3  Oz Filter Warehouse  10 inch Standard Water Filter Cartridges|10\" ...
# 4  Oz Filter Warehouse  5\" x 2-&#189;\" Standard Size for Chlorinated...
#
#              mpn
# 0    10 STD PL50
# 1    20 PS GD 20
# 2  10 STD SILVER
# 3    10 STD PL01
# 4      5 STD PB1
# 'Product_booksjugaad.com_September2020.json.gz'
#                                                 name  \
# 0  Master Assam Year Book 2020 (Assamese) by Sant...
# 1  Assam Inspector of Excise & Excise Constable B...
# 2  Neurology and Neurosurgery Illustrated By Kenn...
# 3  Colonialism Language and Politics: Origins of ...
# 4                Geography of India By Majid Hussain
#
#                                               offers                category  \
# 0                                               None                Exam Hub
# 1  {'price': '315.00', 'itemcondition': 'NewCondi...  Exam Hub > Assam Based
# 2  {'price': '1458.00', 'itemcondition': 'NewCond...                 Medical
# 3  {'price': '765.00', 'itemcondition': 'NewCondi...           Uncategorized
# 4  {'price': '633.00', 'itemcondition': 'NewCondi...         Exam Hub > APSC
#
#                                  weight                releasedate  \
# 0     {'unitcode': 'KGM', 'value': '1'}  2020-08-13T17:23:10+00:00
# 1   {'value': '0.5', 'unitcode': 'KGM'}  2020-08-23T20:30:44+00:00
# 2     {'unitcode': 'KGM', 'value': '1'}  2020-09-12T18:49:30+00:00
# 3   {'value': '0.5', 'unitcode': 'KGM'}  2020-08-18T20:16:43+00:00
# 4  {'value': '.500', 'unitcode': 'KGM'}  2020-09-12T19:24:39+00:00
#
#                                  width                                height  \
# 0   {'value': '18', 'unitcode': 'CMT'}     {'value': '4', 'unitcode': 'CMT'}
# 1   {'value': '18', 'unitcode': 'CMT'}     {'value': '2', 'unitcode': 'CMT'}
# 2  {'unitcode': 'CMT', 'value': '2.1'}  {'value': '19.2', 'unitcode': 'CMT'}
# 3   {'value': '16', 'unitcode': 'CMT'}     {'value': '2', 'unitcode': 'CMT'}
# 4   {'unitcode': 'CMT', 'value': '14'}     {'value': '4', 'unitcode': 'CMT'}
#
#                                   depth
# 0    {'value': '22', 'unitcode': 'CMT'}
# 1    {'value': '22', 'unitcode': 'CMT'}
# 2  {'value': '21.7', 'unitcode': 'CMT'}
# 3    {'value': '22', 'unitcode': 'CMT'}
# 4    {'value': '20', 'unitcode': 'CMT'}
# 'Product_flowers4madagascar.com_September2020.json.gz'
#                                     name  \
# 0              Impressive Holiday Basket
# 1                   Hvisker af kærlighed
# 2                   Holidays in the Dark
# 3          Taste the Holiday Gift Basket
# 4  Dows 10 Porto and Goodies Gift Basket
#
#                                               offers  \
# 0  {'pricevaliduntil': '30-10-2020', 'price': '50...
# 1  {'url': 'antsirabe/da/hvisker-af-kaerlighed-hv...
# 2  {'url': 'love-in-the-dark-flower-delivery.html...
# 3  {'pricevaliduntil': '30-10-2020', 'pricecurren...
# 4  {'pricevaliduntil': '30-10-2020', 'url': 'dows...
#
#                                   brand  \
# 0  {'name': 'Paradise Promotions LTD.'}
# 1  {'name': 'Paradise Promotions LTD.'}
# 2  {'name': 'Paradise Promotions LTD.'}
# 3  {'name': 'Paradise Promotions LTD.'}
# 4  {'name': 'Paradise Promotions LTD.'}
#
#                                 aggregaterating    mpn  \
# 0  {'reviewcount': '911', 'ratingvalue': '4.5'}  10292
# 1  {'reviewcount': '911', 'ratingvalue': '4.5'}  10097
# 2  {'reviewcount': '911', 'ratingvalue': '4.5'}  10893
# 3  {'reviewcount': '911', 'ratingvalue': '4.5'}  10889
# 4  {'reviewcount': '911', 'ratingvalue': '4.5'}  12078
#
#                                    model                          manufacturer
# 0              Impressive Holiday Basket  {'name': 'Paradise Promotions LTD.'}
# 1                   Hvisker af kærlighed  {'name': 'Paradise Promotions LTD.'}
# 2                   Holidays in the Dark  {'name': 'Paradise Promotions LTD.'}
# 3          Taste the Holiday Gift Basket  {'name': 'Paradise Promotions LTD.'}
# 4  Dows 10 Porto and Goodies Gift Basket  {'name': 'Paradise Promotions LTD.'}
# 'Product_toolmart.com.au_September2020.json.gz'
#                name                                             offers  \
# 0  SP Tools SP23314  {'price': '31.5', 'pricecurrency': 'AUD', 'ite...
# 1  SP Tools SP61021  {'pricecurrency': 'AUD', 'price': '19', 'itemc...
# 2  SP Tools SP32403  {'pricecurrency': 'AUD', 'price': '40.5', 'ite...
# 3  SP Tools SP32282  {'pricecurrency': 'AUD', 'price': '50.95', 'it...
# 4  SP Tools SP63038  {'pricecurrency': 'AUD', 'price': '99.5', 'ite...
#
#       brand      mpn    model
# 0  SP Tools  SP23314  SP23314
# 1  SP Tools  SP61021  SP61021
# 2  SP Tools  SP32403  SP32403
# 3  SP Tools  SP32282  SP32282
# 4  SP Tools  SP63038  SP63038
# 'Product_gamingnerds.co.uk_September2020.json.gz'
#                                          name  \
# 0       Driving Test Success Theory Test (PC)
# 1     Street Fighter IV Ultra (PlayStation 3)
# 2  Mega Man Limited Edition Set of Two Prints
# 3        Meta Merch Marvel Spider-Man Arm Mug
# 4                        PlayStation 4 Wallet
#
#                                               offers             brand  \
# 0  {'price': '7.99', 'url': 'https://www.gamingne...       Focus Media
# 1  {'url': 'https://www.gamingnerds.co.uk/video-g...            Capcom
# 2  {'url': 'https://www.gamingnerds.co.uk/collect...          Fanattik
# 3  {'price': '7.99', 'url': 'https://www.gamingne...  Exquisite Gaming
# 4  {'price': '26.99', 'pricecurrency': 'GBP', 'ur...          Numskull
#
#                     itemcondition        gtin13
# 0  http://schema.org/NewCondition  9.781843e+12
# 1  http://schema.org/NewCondition  5.055061e+12
# 2  http://schema.org/NewCondition  5.060243e+12
# 3  http://schema.org/NewCondition  5.060526e+12
# 4  http://schema.org/NewCondition  5.060577e+12
# 'Product_medicalmarijuanainc.com_September2020.json.gz'
#                                                 name  \
# 0  Green Label CBD Hemp Oil Tincture (500mg CBD) 2oz
# 1  Green Label CBD Hemp Oil Liquid (1000mg CBD) 4 oz
# 2  Gold Label Hemp Oil CBD Capsules (25mg CBD) 30...
# 3                                 ECHO: $20 Donation
# 4                 The Ultimate CBD Kit ($2225 Value)
#
#                                               offers  \
# 0  {'url': 'https://www.medicalmarijuanainc.com/s...
# 1  {'pricecurrency': 'USD', 'url': 'https://www.m...
# 2  {'pricecurrency': 'USD', 'price': '119', 'url'...
# 3  {'url': 'https://www.medicalmarijuanainc.com/s...
# 4                                               None
#
#                        brand                              aggregaterating  \
# 0  Real Scientific Hemp Oil®                                         None
# 1  Real Scientific Hemp Oil®  {'reviewcount': '58', 'ratingvalue': '4.7'}
# 2  Real Scientific Hemp Oil®  {'ratingvalue': '4.8', 'reviewcount': '37'}
# 3                       None                                         None
# 4     Medical Marijuana Inc.                                         None
#
#          gtin12
# 0  7.482528e+11
# 1  7.482528e+11
# 2  7.482528e+11
# 3           NaN
# 4           NaN
# 'Product_themotorvenue.com_September2020.json.gz'
#                                                 name  \
# 0             2013 Tesla Model S 4dr Sdn Performance
# 1                    1987 Pontiac Fiero 2dr GT Coupe
# 2                       1962 Chrysler Imperial Crown
# 3  2010 Mercedes-Benz C-Class 4dr Sdn C 300 Sport...
# 4                        2008 Pontiac G6 2dr Conv GT
#
#                                               offers  \
# 0  {'availability': 'https://schema.org/InStock',...
# 1  {'availability': 'https://schema.org/InStock',...
# 2  {'availability': 'https://schema.org/InStock',...
# 3  {'availability': 'https://schema.org/InStock',...
# 4  {'availability': 'https://schema.org/InStock',...
#
#                        brand                              aggregaterating  \
# 0          {'name': 'Tesla'}  {'ratingvalue': '4.4', 'reviewcount': '89'}
# 1        {'name': 'Pontiac'}  {'ratingvalue': '4.4', 'reviewcount': '89'}
# 2       {'name': 'Chrysler'}  {'ratingvalue': '4.4', 'reviewcount': '89'}
# 3  {'name': 'Mercedes-Benz'}  {'ratingvalue': '4.4', 'reviewcount': '89'}
# 4        {'name': 'Pontiac'}  {'ratingvalue': '4.4', 'reviewcount': '89'}
#
#                  mpn
# 0  5YJSA1DP7DFP25332
# 1  1G2PG1197HP214679
# 2      BH23F8B392504
# 3  WDDGF5EB4AF426668
# 4  1G2ZH361184294051
# 'Product_utmeofficial.com.ng_September2020.json.gz'
#                                                 name  \
# 0  [Download] IJMB Economics Past Questions For 2...
# 1  Upgrade 2020 JUPEB Points /Increase JUPEB 2020...
# 2  Possibly JAMB Runz on Physics /Possibly JAMB P...
# 3  Schools’ reopening: JAMB considers new commenc...
# 4  JAMB 2020 March 29 Questions and Answer /March...
#
#                                               offers  \
# 0  {'availability': 'https://schema.org/InStock',...
# 1  {'availability': 'https://schema.org/InStock',...
# 2  {'availability': 'https://schema.org/InStock',...
# 3  {'pricevaliduntil': '2020-11-10', 'pricecurren...
# 4  {'pricecurrency': 'NGN', 'availability': 'http...
#
#                       brand                                 aggregaterating  \
# 0  {'name': 'UTMEOFFICIAL'}  {'ratingvalue': '4.18', 'reviewcount': '1812'}
# 1  {'name': 'UTMEOFFICIAL'}    {'reviewcount': '708', 'ratingvalue': '4.7'}
# 2  {'name': 'UTMEOFFICIAL'}  {'ratingvalue': '4.18', 'reviewcount': '1812'}
# 3  {'name': 'UTMEOFFICIAL'}  {'ratingvalue': '4.10', 'reviewcount': '1008'}
# 4  {'name': 'UTMEOFFICIAL'}  {'ratingvalue': '4.14', 'reviewcount': '1401'}
#
#     mpn
# 0  1912
# 1  1908
# 2  1912
# 3  2008
# 4  2001
# 'Product_andrewscottmusic.com_September2020.json.gz'
#                                                 name  \
# 0           Masterpiece Silver Plated Alto Saxophone
# 1  15 Children's Songs for Keyboard - Additional ...
# 2       Masterpiece White and Gold - Tenor Saxophone
# 3      Masterpiece Purple and Gold - Tenor Saxophone
# 4  Art Of Saxophone - Option C: Gold Digital and ...
#
#                                               offers            category  \
# 0  {'pricecurrency': 'AUD', 'price': '617.00', 'i...       Uncategorized
# 1  {'pricecurrency': 'AUD', 'itemcondition': 'New...       Uncategorized
# 2  {'pricecurrency': 'AUD', 'price': '775.00', 'i...  Saxophones - Tenor
# 3  {'pricecurrency': 'AUD', 'price': '775.00', 'i...       Uncategorized
# 4  {'pricecurrency': 'AUD', 'itemcondition': 'New...       Uncategorized
#
#                                   weight                releasedate  \
# 0  {'unitcode': 'KGM', 'value': '5.150'}  2020-05-06T06:51:37+09:30
# 1  {'unitcode': 'KGM', 'value': '0.000'}  2020-05-06T06:51:37+09:30
# 2  {'value': '7.200', 'unitcode': 'KGM'}  2020-05-06T06:51:08+09:30
# 3  {'value': '7.200', 'unitcode': 'KGM'}  2020-05-06T06:51:08+09:30
# 4  {'unitcode': 'KGM', 'value': '0.000'}  2020-05-06T06:51:25+09:30
#
#                                    width  \
# 0  {'unitcode': 'CMT', 'value': '31.00'}
# 1   {'unitcode': 'CMT', 'value': '0.00'}
# 2  {'value': '36.00', 'unitcode': 'CMT'}
# 3  {'value': '36.00', 'unitcode': 'CMT'}
# 4   {'unitcode': 'CMT', 'value': '0.00'}
#
#                                   height  \
# 0  {'value': '16.00', 'unitcode': 'CMT'}
# 1   {'unitcode': 'CMT', 'value': '0.00'}
# 2  {'value': '20.00', 'unitcode': 'CMT'}
# 3  {'value': '20.00', 'unitcode': 'CMT'}
# 4   {'unitcode': 'CMT', 'value': '0.00'}
#
#                                    depth
# 0  {'value': '65.00', 'unitcode': 'CMT'}
# 1   {'unitcode': 'CMT', 'value': '0.00'}
# 2  {'value': '84.00', 'unitcode': 'CMT'}
# 3  {'value': '84.00', 'unitcode': 'CMT'}
# 4   {'unitcode': 'CMT', 'value': '0.00'}
# 'Product_cookingcollectibles.com_September2020.json.gz'
#                                         name  \
# 0       Stainless Steel Wine Glass 2 pcs Set
# 1       Round Crystal Wine Glasses 4 pcs Set
# 2  Round White Silicone Wine Glass 2 pcs Set
# 3           Round Stainless Steel Wine Glass
# 4       Kitchen Stainless Steel Towel Holder
#
#                                               offers                    brand  \
# 0  {'url': 'https://cookingcollectibles.com/stain...  cookingcollectibles.com
# 1  {'availability': 'https://schema.org/InStock',...  cookingcollectibles.com
# 2  {'availability': 'https://schema.org/InStock',...  cookingcollectibles.com
# 3  {'availability': 'https://schema.org/InStock',...  cookingcollectibles.com
# 4  {'availability': 'https://schema.org/InStock',...  cookingcollectibles.com
#
#                                 aggregaterating category   mpn review
# 0  {'ratingvalue': '4.80', 'reviewcount': '14'}     None  1055   None
# 1   {'ratingvalue': '4.70', 'reviewcount': '7'}     None  1059   None
# 2   {'reviewcount': '4', 'ratingvalue': '5.00'}     None  1064   None
# 3  {'ratingvalue': '5.00', 'reviewcount': '12'}     None  1062   None
# 4  {'ratingvalue': '4.80', 'reviewcount': '14'}     None   752   None
# 'Product_theoutdoorstores.com_September2020.json.gz'
#                                                 name  \
# 0  BronzeDog Buttstock Cheek Rest Ammo Holder Lea...
# 1                Brooklyn Kayak Company BKC UH-FK184
# 2  Outdoor Edge RazorLite EDC, Replaceable Blade ...
# 3  TOURIT Insulated Cooler Backpack Lightweight B...
# 4              Berkley Big Game Spinning Fishing Rod
#
#                                               offers  \
# 0  {'pricevaliduntil': '2020-09-24 15:23:47', 'pr...
# 1  {'pricecurrency': 'USD', 'pricevaliduntil': '2...
# 2  {'pricecurrency': 'USD', 'price': '0.00', 'pri...
# 3  {'pricecurrency': 'USD', 'pricevaliduntil': '2...
# 4  {'pricecurrency': 'USD', 'price': '0.00', 'ava...
#
#                                 brand  \
# 0               {'name': 'BronzeDog'}
# 1  {'name': 'Brooklyn Kayak Company'}
# 2            {'name': 'OUTDOOR EDGE'}
# 3                  {'name': 'TOURIT'}
# 4                                None
#
#                              aggregaterating   mpn
# 0  {'reviewcount': '89', 'ratingvalue': '5'}  2795
# 1  {'reviewcount': '89', 'ratingvalue': '5'}  2879
# 2  {'reviewcount': '89', 'ratingvalue': '5'}  2181
# 3  {'reviewcount': '89', 'ratingvalue': '5'}  2101
# 4  {'reviewcount': '89', 'ratingvalue': '5'}  2040
# 'Product_eickenhorstfuneral.com_September2020.json.gz'
#                             name  \
# 0          America the Beautiful
# 1   Peaceful White Lilies Basket
# 2  Dreams From the Heart Bouquet
# 3             Medium Dish Garden
# 4                Arrive in Style
#
#                                               offers  \
# 0  {'pricecurrency': 'USD', 'highprice': '72.95',...
# 1  {'pricecurrency': 'USD', 'highprice': '89.95',...
# 2  {'pricecurrency': 'USD', 'lowprice': '92.95', ...
# 3  {'pricecurrency': 'USD', 'lowprice': '59.95', ...
# 4  {'pricecurrency': 'USD', 'highprice': '69.95',...
#
#                                  aggregaterating  \
# 0   {'ratingvalue': '4.89', 'reviewcount': '18'}
# 1  {'reviewcount': '250', 'ratingvalue': '4.93'}
# 2   {'reviewcount': '17', 'ratingvalue': '4.94'}
# 3   {'ratingvalue': '4.90', 'reviewcount': '40'}
# 4  {'reviewcount': '132', 'ratingvalue': '4.91'}
#
#                                               review itemcondition  \
# 0  [{'datepublished': '4/9/2020', 'author': 'from...  NewCondition
# 1  [{'datepublished': '6/10/2020', 'description':...  NewCondition
# 2  [{'author': 'from -', 'datepublished': '4/26/2...  NewCondition
# 3  [{'author': 'from -', 'datepublished': '6/7/20...  NewCondition
# 4  [{'datepublished': '6/1/2020', 'description': ...  NewCondition
#
#                                                model
# 0  {'url': 'https://www.eickenhorstfuneral.com/st...
# 1  {'url': 'https://www.eickenhorstfuneral.com/st...
# 2  [{'name': 'Dreams From the Heart Bouquet (Delu...
# 3  {'image': 'https://res.cloudinary.com/picasso/...
# 4  [{'name': 'Arrive in Style (Standard)', 'sku':...
# 'Product_drdanacarson.com_September2020.json.gz'
#                                 name  \
# 0             Kingdom Preacher's Set
# 1             HC 2018 Workshops (CD)
# 2                    Being a Witness
# 3         Relevant Pulpits Session 6
# 4  Kingdom Gifted Kingdom Devotional
#
#                                               offers  \
# 0  {'sku': 'king_preacher_set', 'availability': '...
# 1  [{'name': 'Kingdom Esteem', 'availability': 'h...
# 2  [{'availability': 'https://schema.org/InStock'...
# 3  {'availability': 'https://schema.org/InStock',...
# 4  [{'price': '1.999E1', 'sku': '07071510505', 'a...
#
#                             brand            category           mpn
# 0  {'name': 'Kingdom Superstore'}             Bundles           NaN
# 1  {'name': 'Kingdom Superstore'}         Audio/Video           NaN
# 2  {'name': 'Kingdom Superstore'}         Audio/Video  8.191810e+09
# 3  {'name': 'Kingdom Superstore'}         Audio/Video           NaN
# 4  {'name': 'Kingdom Superstore'}  Kingdom Devotional           NaN
# 'Product_nativecos.com_September2020.json.gz'
#                             name  \
# 0          Rosemary & Lemon Zest
# 1  (Manual) Seasonal Summer Pack
# 2              Aloe & Eucalyptus
# 3          Pear & Linden Blossom
# 4          Pear & Linden Blossom
#
#                                               offers               brand  \
# 0  {'pricecurrency': 'USD', 'availability': 'http...  {'name': 'Native'}
# 1  {'pricecurrency': 'USD', 'availability': 'http...  {'name': 'Native'}
# 2  {'pricecurrency': 'USD', 'sku': 'BARSOAP-OM1-5...  {'name': 'Native'}
# 3  {'pricecurrency': 'USD', 'availability': 'http...  {'name': 'Native'}
# 4  {'price': '10.00', 'sku': 'DEO-BM1-265-1-Pear&...  {'name': 'Native'}
#
#                        category  \
# 0             BYP Body Wash BYP
# 1  Manual Order Packs Deodorant
# 2          Women's Bar Soap PBP
# 3         Women's Body Wash PBP
# 4         Women's Deodorant PBP
#
#                                   additionalproperty
# 0  {'value': 'Body Wash BYP', 'name': 'Product Ty...
# 1     {'name': 'Product Type', 'value': 'Deodorant'}
# 2  {'name': 'Product Type', 'value': 'Bar Soap PBP'}
# 3  {'name': 'Product Type', 'value': 'Body Wash P...
# 4  {'name': 'Product Type', 'value': 'Deodorant P...
# 'Product_powerofbowser.com_September2020.json.gz'
#                                                 name  \
# 0   New 2020 Hyundai Kona Ultimate AWD Sport Utility
# 1  New 2020 Buick Envision Essence AWD 4D Sport U...
# 2      New 2020 Nissan Rogue SV AWD 4D Sport Utility
# 3           New 2020 Hyundai Sonata SEL FWD 4D Sedan
# 4  New 2020 Buick Envision Premium I AWD 4D Sport...
#
#                                               offers    brand       mpn  \
# 0  {'price': '30855', 'itemcondition': 'http://sc...  Hyundai  Q0472AT5
# 1  {'itemcondition': 'http://schema.org/NewCondit...    Buick     4XZ26
# 2  {'itemcondition': 'http://schema.org/NewCondit...   Nissan     22210
# 3  {'price': '28229', 'itemcondition': 'http://sc...  Hyundai  29422F4S
# 4  {'itemcondition': 'http://schema.org/NewCondit...    Buick     4XT26
#
#       model         manufacturer      color
# 0      Kona  {'name': 'Hyundai'}  Pulse Red
# 1  Envision    {'name': 'Buick'}      Black
# 2     Rogue   {'name': 'Nissan'}       Gray
# 3    Sonata  {'name': 'Hyundai'}       Blue
# 4  Envision    {'name': 'Buick'}      White
# 'Product_maraboujewelry.com_September2020.json.gz'
#                    name                                             offers  \
# 0           Sunny Hoops  {'availability': 'https://schema.org/InStock',...
# 1  Nirvana @Marabou Set  {'availability': 'https://schema.org/InStock',...
# 2       Jungle Earrings  {'availability': 'https://schema.org/InStock',...
# 3   Gypsy Queen Handbag  {'availability': 'https://schema.org/InStock',...
# 4      Sparkle Earrings  [{'gtin12': '746175778503', 'availability': 'h...
#
#                            brand           mpn  \
# 0  {'name': 'Marabou Jewellery'}  7.461757e+11
# 1  {'name': 'Marabou Jewellery'}  7.461758e+11
# 2  {'name': 'Marabou Jewellery'}  7.461758e+11
# 3    {'name': 'Marabou Jewelry'}           NaN
# 4  {'name': 'Marabou Jewellery'}  7.461758e+11
#
#                      itemcondition
# 0  https://schema.org/NewCondition
# 1  https://schema.org/NewCondition
# 2  https://schema.org/NewCondition
# 3  https://schema.org/NewCondition
# 4  https://schema.org/NewCondition
# 'Product_rhino-racks.co.uk_September2020.json.gz'
#                                                 name  \
# 0             Fiat Scudo Single Front Van Seat Cover
# 1  Peugeot Boxer Rhino Van Roof Bar Roller Pre Oc...
# 2  Vauxhall Vivaro Pre Oct 2014 Swb Low Roof Twin...
# 3  Rhino Delta 2 Bar System &#45; Mercedes Citan ...
# 4  Mercedes Vito Rhino Roof Bar Roller System Lwb...
#
#                                               offers                   brand  \
# 0  {'price': '2.934E1', 'availability': 'https://...  Heavy Duty Seat Covers
# 1  {'price': '4.5E1', 'availability': 'https://sc...                   Rhino
# 2  {'availability': 'https://schema.org/InStock',...                   Rhino
# 3  {'price': '8.55E1', 'availability': 'https://s...                   Rhino
# 4  {'price': '4.5E1', 'availability': 'https://sc...                   Rhino
#
#           mpn itemcondition
# 0      SSCUDO           New
# 1  1000-S225P           New
# 2        A501           New
# 3     P2D-B22           New
# 4  1000-S300P           New
# 'Product_subarusouthblvd.com_September2020.json.gz'
#                             name  \
# 0            Cargo Tray - Hybrid
# 1               Air Deflector Ay
# 2               Bolt and Nut Kit
# 3  STI Door Handle Cup Protector
# 4                    Cargo Cover
#
#                                               offers   brand           mpn  \
# 0  {'itemcondition': 'http://schema.org/NewCondit...  Subaru    J501SFL320
# 1  {'itemcondition': 'http://schema.org/NewCondit...  Subaru    E3610AS280
# 2  {'itemcondition': 'http://schema.org/NewCondit...  Subaru    L1010SG550
# 3  {'itemcondition': 'http://schema.org/NewCondit...  Subaru    J1210FL500
# 4  {'itemcondition': 'http://schema.org/NewCondit...  Subaru  65550FL00BVH
#
#                   identifier
# 0    {'value': 'J501SFL320'}
# 1    {'value': 'E3610AS280'}
# 2    {'value': 'L1010SG550'}
# 3    {'value': 'J1210FL500'}
# 4  {'value': '65550FL00BVH'}
# 'Product_caesar-shisha.com_September2020.json.gz'
#                                   name  \
# 0  Hookain Tobacco 200g - Bubblenciaga
# 1                Mammut Adapter - Blue
# 2  7 Days Platin 200 g - Bluber Eyes T
# 3                      E-Shisha - Akku
# 4        Wookah - Nox - White - Olives
#
#                                               offers    brand    weight  \
# 0  {'sku': 'SW10217', 'url': ['https://www.caesar...  Default  0.416 kg
# 1  {'url': ['https://www.caesar-shisha.com/de/shi...  Default   0.03 kg
# 2  {'url': ['https://www.caesar-shisha.com/de/shi...  Default  0.416 kg
# 3  {'url': ['https://www.caesar-shisha.com/de/e-s...  Default    0.2 kg
# 4  {'pricecurrency': 'EUR', 'sku': '20077', 'pric...  Default     30 kg
#
#   releasedate
# 0  0999-12-21
# 1  0999-12-30
# 2        None
# 3  2020-08-13
# 4  0999-12-31
# 'Product_adventurecbd.com_September2020.json.gz'
#                                      name  \
# 0        CBD Pet Tincture - Peanut Butter
# 1  CBD Oil Tincture – Original Unflavored
# 2                CBD Body Scrub - Vanilla
# 3      Full-Spectrum CBD Tincture – Lemon
# 4     Athletica CBD – Electrolyte Gummies
#
#                                               offers  \
# 0  {'availability': 'instock', 'price': '24.99', ...
# 1  {'lowprice': '2.999E1', 'availability': 'insto...
# 2  {'availability': 'instock', 'price': '19.99', ...
# 3  {'offercount': '2', 'availability': 'instock',...
# 4  {'pricecurrency': 'USD', 'pricevaliduntil': '2...
#
#                        brand                              aggregaterating  \
# 0  {'name': 'Adventure CBD'}     {'reviewcount': '1', 'ratingvalue': '5'}
# 1  {'name': 'Adventure CBD'}  {'reviewcount': '2', 'ratingvalue': '5.00'}
# 2  {'name': 'Adventure CBD'}  {'reviewcount': '1', 'ratingvalue': '5.00'}
# 3  {'name': 'Adventure CBD'}  {'ratingvalue': '4.00', 'reviewcount': '1'}
# 4  {'name': 'Adventure CBD'}     {'reviewcount': '1', 'ratingvalue': '5'}
#
#     mpn                                             review         gtin8
# 0   879  {'author': 'adventurecbd', 'description': 'Buy...  8.500055e+11
# 1  1400  [{'author': 'Kate', 'datepublished': '2020-09-...           NaN
# 2   654  {'datepublished': '2020-03-24 13:05:18', 'desc...  8.500055e+11
# 3  3819  {'datepublished': '2020-02-16 11:51:15', 'auth...           NaN
# 4  3174  {'description': 'Buy Athletica CBD Electrolyte...  8.500055e+11
# 'Product_partsdiscounters.com_September2020.json.gz'
#                      name                                             offers  \
# 0  Cargo Tray, Reversible  {'pricecurrency': 'USD', 'price': '8.85E1', 'i...
# 1               Cargo Mat  {'pricecurrency': 'USD', 'availability': 'http...
# 2               Floor Mat  {'pricecurrency': 'USD', 'price': '6.782E1', '...
# 3          Control Module  {'pricecurrency': 'USD', 'itemcondition': 'htt...
# 4                Dust Cap  {'pricecurrency': 'USD', 'availability': 'http...
#
#                        brand           mpn               manufacturer
# 0        {'name': 'Hyundai'}    b1012adu00        {'name': 'Hyundai'}
# 1          {'name': 'Mopar'}    5se95dx9aa          {'name': 'Mopar'}
# 2          {'name': 'Mopar'}    68184087aa          {'name': 'Mopar'}
# 3  {'name': 'Mercedes-Benz'}  204900591280  {'name': 'Mercedes-Benz'}
# 4        {'name': 'Hyundai'}    9214034550        {'name': 'Hyundai'}
# 'Product_elmhursttoyota.com_September2020.json.gz'
#                                                 name  \
# 0                                    Roof Rack Cover
# 1                                    Roof Rack Cover
# 2                                    Roof Rack Cover
# 3  Genuine Toyota (14-20 4Runner) (09-14 FJ Cruis...
# 4                                    Roof Rack Cover
#
#                                               offers               brand  \
# 0  {'pricecurrency': 'USD', 'price': '5.21E1', 'i...  {'name': 'Toyota'}
# 1  {'pricecurrency': 'USD', 'price': '6.44E0', 'i...  {'name': 'Toyota'}
# 2  {'pricecurrency': 'USD', 'price': '5.265E1', '...  {'name': 'Toyota'}
# 3  {'pricecurrency': 'USD', 'availability': 'http...  {'name': 'Toyota'}
# 4  {'pricecurrency': 'USD', 'price': '7.09E0', 'i...  {'name': 'Toyota'}
#
#             mpn        manufacturer
# 0    6349148020  {'name': 'Toyota'}
# 1    6349648020  {'name': 'Toyota'}
# 2  6349242011b1  {'name': 'Toyota'}
# 3    ptr6089190  {'name': 'Toyota'}
# 4    6349548040  {'name': 'Toyota'}
# 'Product_giftpens.com_September2020.json.gz'
#                                          name  \
# 0                  Arizona Fountain Pen - Red
# 1         Cross Calais Rollerball Pen - Black
# 2  Parker Style Ballpoint Ink Refills 2 Packs
# 3          Cross Calais Ballpoint Pen - Black
# 4   Cross Tech3+ Pen - Lustrous Chrome Finish
#
#                                               offers  \
# 0  {'pricecurrency': 'USD', 'availability': 'http...
# 1  {'pricecurrency': 'USD', 'price': '31.99', 'av...
# 2  {'pricecurrency': 'USD', 'price': '4.99', 'ava...
# 3  {'pricecurrency': 'USD', 'availability': 'http...
# 4  {'pricecurrency': 'USD', 'price': '54.99', 'av...
#
#                           brand  \
# 0           {'name': 'Generic'}
# 1  {'name': 'AT Cross Pens DS'}
# 2    {'name': 'Dayspring Pens'}
# 3     {'name': 'AT Cross Pens'}
# 4         {'name': 'No Refill'}
#
#                                      aggregaterating                  mpn
# 0  {'bestrating': '5', 'ratingvalue': '4.82E0', '...              GP-1134
# 1  {'bestrating': '5', 'ratingvalue': '5', 'revie...  GP-1237 | AT0115-14
# 2                                               None           GP-1289-01
# 3  {'bestrating': '5', 'reviewcount': '11', 'rati...  GP-1218 | AT0112-14
# 4  {'bestrating': '5', 'reviewcount': '7', 'worst...    GP-106 | AT0090-1
# 'Product_reneesgarden.com_September2020.json.gz'
#                        name  \
# 0  Redwing Long Keeping Red
# 1            Violetta Lunga
# 2             Wedding Bells
# 3     Black-Eyed Susan Vine
# 4               Angel Wings
#
#                                               offers  \
# 0  {'itemcondition': 'http://schema.org/NewCondit...
# 1  {'sku': '3081', 'itemcondition': 'http://schem...
# 2  {'price': '2.79', 'itemcondition': 'http://sch...
# 3  {'price': '2.79', 'itemcondition': 'http://sch...
# 4  {'itemcondition': 'http://schema.org/NewCondit...
#
#                        brand         mpn                   itemcondition
# 0  {'name': 'renees-garden'}  6443861569  http://schema.org/NewCondition
# 1  {'name': 'renees-garden'}  2419235329  http://schema.org/NewCondition
# 2  {'name': 'renees-garden'}  2419088193  http://schema.org/NewCondition
# 3  {'name': 'renees-garden'}  2419106561  http://schema.org/NewCondition
# 4  {'name': 'renees-garden'}  2419092737  http://schema.org/NewCondition
# 'Product_mgsports.com.br_September2020.json.gz'
#                                      name  \
# 0                  Coxal Realtex Elastico
# 1            Short Adidas Sp3 - Masculino
# 2      Tênis New Balance ML373 - Feminino
# 3  Tênis Under Armour Skyline - Masculino
# 4            Bola Penalty Mirim - Unissex
#
#                                               offers                    brand  \
# 0  {'pricecurrency': 'BRL', 'availability': 'http...      {'name': 'Realtex'}
# 1  {'pricecurrency': 'BRL', 'availability': 'http...       {'name': 'Adidas'}
# 2  {'pricecurrency': 'BRL', 'price': '299.90', 'a...  {'name': 'New Balance'}
# 3  {'pricecurrency': 'BRL', 'availability': 'http...                     None
# 4  {'pricecurrency': 'BRL', 'availability': 'http...      {'name': 'Penalty'}
#
#                      itemcondition        gtin13 weight    width   height  \
# 0  https://schema.org/NewCondition  7.897471e+12  900 g  35.0 cm  12.0 cm
# 1  https://schema.org/NewCondition  4.060515e+12  400 g  22.0 cm  12.0 cm
# 2  https://schema.org/NewCondition  7.908260e+12  900 g  35.0 cm  12.0 cm
# 3  https://schema.org/NewCondition           NaN  900 g  35.0 cm  12.0 cm
# 4  https://schema.org/NewCondition  7.909342e+12    0 g   0.0 cm   0.0 cm
#
#      depth
# 0  22.0 cm
# 1  22.0 cm
# 2  22.0 cm
# 3  22.0 cm
# 4   0.0 cm
# 'Product_porschegoldcoast.com_September2020.json.gz'
#                                        name  \
# 0                    New 2020 Porsche Macan
# 1             New 2020 Porsche Taycan Turbo
# 2  Certified Pre-Owned 2017 Porsche Cayenne
# 3                New 2020 Porsche Taycan 4S
# 4            New 2020 Porsche Cayenne Turbo
#
#                                               offers    brand     mpn  \
# 0  {'itemcondition': 'http://schema.org/NewCondit...  Porsche  95BAG1
# 1  {'price': '161520', 'itemcondition': 'http://s...  Porsche  Y1AFC1
# 2  {'price': '47900', 'itemcondition': 'http://sc...  Porsche  92AAA1
# 3  {'itemcondition': 'http://schema.org/NewCondit...  Porsche  Y1ADB1
# 4  {'itemcondition': 'http://schema.org/NewCondit...  Porsche  9YACF1
#
#      model         manufacturer                  color
# 0    Macan  {'name': 'Porsche'}                  White
# 1   Taycan  {'name': 'Porsche'}  Gentian Blue Metallic
# 2  Cayenne  {'name': 'Porsche'}                  White
# 3   Taycan  {'name': 'Porsche'}   Frozen Blue Metallic
# 4  Cayenne  {'name': 'Porsche'}                  Black
# 'Product_aliceandblair.co.uk_September2020.json.gz'
#                                        name  \
# 0           Venus Velvet Croissant Headband
# 1              Imogen Knotted Silk Headband
# 2                            The Peggy Knit
# 3                   The Peggy Knit - Purple
# 4  Swarovski Crystal Cushion Cut Hair Slide
#
#                                               offers  \
# 0  [{'pricecurrency': 'GBP', 'availability': 'htt...
# 1  {'pricevaliduntil': '2020-10-27', 'gtin13': '5...
# 2  [{'pricecurrency': 'GBP', 'itemcondition': 'ht...
# 3  [{'pricecurrency': 'GBP', 'itemcondition': 'ht...
# 4  [{'availability': 'https://schema.org/InStock'...
#
#                        brand            mpn                    itemcondition
# 0  {'name': 'Alice & Blair'}           None  https://schema.org/NewCondition
# 1  {'name': 'Alice & Blair'}  5060720550532  https://schema.org/NewCondition
# 2  {'name': 'Alice & Blair'}           None  https://schema.org/NewCondition
# 3  {'name': 'Alice & Blair'}           None  https://schema.org/NewCondition
# 4  {'name': 'Alice & Blair'}  5060720550396  https://schema.org/NewCondition
# 'Product_thinkshoes.com_September2020.json.gz'
#                             name  \
# 0  Kapsl Lace up - Grunge Estate
# 1             Obajo boot - Black
# 2           Think! belt - cognac
# 3    Think! Leather case - Black
# 4        Civita Lace up - cognac
#
#                                               offers   brand         gtin13  \
# 0  {'url': 'https://www.thinkshoes.com/en/kapsl-l...  Think!  9010463244829
# 1  {'price': '119.9', 'url': 'https://www.thinksh...  Think!  9010463023585
# 2  {'url': 'https://www.thinkshoes.com/en/think-b...  Think!  9010463343669
# 3  {'url': 'https://www.thinkshoes.com/en/think-l...  Think!  9010463271245
# 4  {'sku': '9010463246199', 'price': '189.90', 'u...  Think!  9010463246199
#
#   releasedate
# 0  2020-06-01
# 1  2019-06-01
# 2  2020-06-01
# 3  2020-06-01
# 4  2020-06-01
# 'Product_cellphoneoutletsale.com_September2020.json.gz'
#                                                 name  \
# 0  Global Unlimited SIM by Mobal. Unlimited Roami...
# 1  Octopus GlueÂ® -UV LOCA Glue 3 ml Graduated Sy...
# 2  ONLY 24h SALE! Apple iPhone 6 6S 4.7\" inch Fr...
# 3  Mudder Back Rear Camera Lens Cover Ring Replac...
# 4  Ultra Mobile Triple Cut SIM Card w/ $29 Month ...
#
#                                               offers                brand  \
# 0  {'pricecurrency': 'USD', 'itemcondition': 'New...                Mobal
# 1  {'pricecurrency': 'USD', 'price': '9.95', 'ite...         Octopus Glue
# 2  {'pricecurrency': 'USD', 'price': '29.99', 'it...  ESSENTIAL SALES4YOU
# 3  {'pricecurrency': 'USD', 'price': '6.59', 'ite...               Mudder
# 4  {'pricecurrency': 'USD', 'price': '29.99', 'it...          HJ Wireless
#
#                                      aggregaterating                      mpn  \
# 0  {'ratingcount': '95', 'ratingvalue': '3.8', 'b...                     None
# 1  {'ratingcount': '527', 'ratingvalue': '4.2', '...              OGLOCA3RBMF
# 2  {'ratingvalue': '3.7', 'ratingcount': '177', '...                  5491027
# 3  {'ratingvalue': '4.0', 'ratingcount': '67', 'b...  MUDDER-ACCESSORY-KITS-1
# 4  {'ratingvalue': '3.7', 'ratingcount': '10', 'b...                     None
#
#                      model         manufacturer  \
# 0                     None                Mobal
# 1              OGLOCA3RBMF         Octopus Glue
# 2                    E-G-B  ESSENTIAL SALES4YOU
# 3  MUDDER-ACCESSORY-KITS-1               Mudder
# 4                     None         Ultra Mobile
#
#                                                color
# 0                                          Micro SIM
# 1                                        3 ml Single
# 2  IPHONE 6 6S BLACK Outer Glass + TOOLS + 3M TAPE +
# 3                                             Silver
# 4                                   $29 Monthly Plan
# 'Product_flowers4moscow.com_September2020.json.gz'
#                        name  \
# 0   11 Pink Oriental Lilies
# 1        Standard glas Vase
# 2  Anthurium in a small pot
# 3          Iridescent Roses
# 4           11 Orange Roses
#
#                                               offers  \
# 0  {'url': 'da/fragrance-10-pink-orientalske-lilj...
# 1  {'pricecurrency': 'USD', 'price': '15.00', 'av...
# 2  {'price': '44.00', 'pricevaliduntil': '28-10-2...
# 3  {'price': '54.00', 'pricevaliduntil': '28-10-2...
# 4  {'price': '44.00', 'url': 'golden-delight-12-o...
#
#                                   brand  \
# 0  {'name': 'Paradise Promotions LTD.'}
# 1  {'name': 'Paradise Promotions LTD.'}
# 2  {'name': 'Paradise Promotions LTD.'}
# 3  {'name': 'Paradise Promotions LTD.'}
# 4  {'name': 'Paradise Promotions LTD.'}
#
#                                 aggregaterating      mpn  \
# 0  {'reviewcount': '911', 'ratingvalue': '4.5'}   BQP105
# 1  {'reviewcount': '911', 'ratingvalue': '4.5'}  Vase101
# 2  {'reviewcount': '911', 'ratingvalue': '4.5'}   POT102
# 3  {'reviewcount': '911', 'ratingvalue': '4.5'}   IRI101
# 4  {'reviewcount': '911', 'ratingvalue': '4.5'}   BQO106
#
#                       model                          manufacturer
# 0   11 Pink Oriental Lilies  {'name': 'Paradise Promotions LTD.'}
# 1        Standard glas Vase  {'name': 'Paradise Promotions LTD.'}
# 2  Anthurium in a small pot  {'name': 'Paradise Promotions LTD.'}
# 3          Iridescent Roses  {'name': 'Paradise Promotions LTD.'}
# 4           11 Orange Roses  {'name': 'Paradise Promotions LTD.'}
# 'Product_lastlooksfx.com_September2020.json.gz'
#                                     name  \
# 0  Monda Magnetic Palette - 6 Small Pans
# 1      SUPER Stick It! Double Sided Tape
# 2                          PPI Dry Spray
# 3                  Ben Nye Gel Wound Kit
# 4         Bdellium SFX 136 Filbert Brush
#
#                                               offers  \
# 0  {'pricecurrency': 'USD', 'itemcondition': 'New...
# 1  {'pricecurrency': 'USD', 'availability': 'http...
# 2  {'pricecurrency': 'USD', 'price': '21.99', 'it...
# 3  {'pricecurrency': 'USD', 'itemcondition': 'New...
# 4  {'pricecurrency': 'USD', 'price': '15.00', 'it...
#
#                                    category  \
# 0  Tools &amp; Accessories > Empty Palettes
# 1              Wardrobe > Double Sided Tape
# 2                                    Makeup
# 3                                Special FX
# 4  Tools &amp; Accessories > Makeup Brushes
#
#                                  weight                releasedate  \
# ...
# 4  [{'author': 'N***h', 'reviewbody': 'Good!'}, {...
# 'Product_skatepro.uk_September2020.json.gz'
#                                                 name  \
# 0               Powerslide One Allround Skate Helmet
# 1  Atomic Redster Carbon Classic Cold S Cross Cou...
# 2       Hyper Concrete +G Inline Skate Wheels 4-pack
# 3                          Crisp Stunt Scooter Brake
# 4            Hella Grip Broadway Stunt Scooter Grips
#
#                                         offers                          brand  \
# 0   {'price': '23.95', 'pricecurrency': 'GBP'}  {'name': 'Powerslide Skates'}
# 1  {'price': '339.95', 'pricecurrency': 'GBP'}        {'name': 'Atomic Skis'}
# 2   {'price': '30.95', 'pricecurrency': 'GBP'}       {'name': 'Hyper Wheels'}
# 3   {'price': '17.95', 'pricecurrency': 'GBP'}     {'name': 'Crisp scooters'}
# 4   {'pricecurrency': 'GBP', 'price': '18.95'}         {'name': 'Hella Grip'}
#
#                                      aggregaterating         gtin13
# 0  {'bestrating': '5', 'reviewcount': '48', 'wors...  4040333492208
# 1                                               None  0884397248111
# 2  {'bestrating': '5', 'reviewcount': '45', 'wors...  0790782043196
# 3  {'bestrating': '5', 'worstrating': '1', 'revie...           None
# 4  {'bestrating': '5', 'reviewcount': '7', 'worst...           None
# 'Product_classiccarsales.net_September2020.json.gz'
#                                                 name  \
# 0               1999 Lexus RX 300 Luxury SUV 4dr SUV
# 1        2012 Land Rover Range Rover 4WD 4dr HSE LUX
# 2  2013 Volkswagen Tiguan 4WD 4dr Auto SE *Ltd Av...
# 3      2008 Audi TT 2dr Roadster Auto 2.0T FrontTrak
# 4       2013 Jeep Wrangler Unlimited 4WD 4dr Rubicon
#
#                                               offers                   brand  \
# 0  {'availability': 'https://schema.org/InStock',...       {'name': 'Lexus'}
# 1  {'price': '16995', 'availability': 'https://sc...  {'name': 'Land Rover'}
# 2  {'availability': 'https://schema.org/InStock',...  {'name': 'Volkswagen'}
# 3  {'availability': 'https://schema.org/InStock',...        {'name': 'Audi'}
# 4  {'availability': 'https://schema.org/InStock',...        {'name': 'Jeep'}
#
#                                aggregaterating                mpn
# 0  {'ratingvalue': '4.4', 'reviewcount': '89'}  JT6GF10U8X0017782
# 1  {'ratingvalue': '4.4', 'reviewcount': '89'}  SALMF1D44CA391227
# 2  {'ratingvalue': '4.4', 'reviewcount': '89'}  WVGBV7AX6DW549019
# 3  {'ratingvalue': '4.4', 'reviewcount': '89'}  TRUMF38J581002613
# 4  {'ratingvalue': '4.4', 'reviewcount': '89'}  1C4HJWFG7DL595392
# 'Product_destinationbabykids.com_September2020.json.gz'
#                                                 name  \
# 0           Baby Appleseed Davenport 3 Piece Package
# 1            NUNA Pipa Lite Infant Car Seat in Aspen
# 2            Pali Napoli Flat Top Crib in Mocacchino
# 3  Natart Cortina 3 Piece Nursery Set in Grey Chalet
# 4  Liz and Roo Buck Woodland 3 Piece Crib Bedding...
#
#                                               offers           brand  \
# 0  {'itemcondition': 'http://schema.org/NewCondit...  Baby Appleseed
# 1  {'price': '382.32', 'itemcondition': 'http://s...            Nuna
# 2  {'category': 'Napoli', 'itemcondition': 'http:...            Pali
# 3  {'itemcondition': 'http://schema.org/NewCondit...          Natart
# 4  {'itemoffered': 'Liz and Roo Buck Woodland 3 P...       Liz & Roo
#
#                            mpn        gtin13
# 0  babyappleseed_davenport-3pc           NaN
# 1                   CF08500ASP  8.719744e+12
# 2                       8150-M           NaN
# 3        natart-cortina-3pc-ch           NaN
# 4                     29444BB3  7.583994e+11
# 'Product_wire-brush.co.uk_September2020.json.gz'
#                                                 name  \
# 0     <!-- 055 -->Cylinder Wire Brush 15mm with Loop
# 1  <!-- 052 -->Steel Wire Brush 5 Row with Plasti...
# 2        <!-- 015 -->15mm Cotton Mop Brush with Loop
# 3  <!-- 050 -->Stainless Steel Cylinder Wire Brus...
# 4    <!-- 010 -->15mm Hole Cleaning Brass Wire Brush
#
#                                               offers       brand      mpn  \
# 0  {'availability': 'http://schema.org/InStock', ...    Lessmann   542307
# 1  {'availability': 'http://schema.org/InStock', ...  Silverline   456957
# 2  {'availability': 'http://schema.org/InStock', ...       Anvil  P100015
# 3  {'price': '10.55', 'availability': 'http://sch...    Lessmann   500519
# 4  {'availability': 'http://schema.org/InStock', ...    Lessmann   560715
#
#                weight
# 0  {'value': '0.000'}
# 1  {'value': '0.000'}
# 2  {'value': '0.000'}
# 3  {'value': '0.000'}
# 4  {'value': '0.000'}
# 'Product_katespade.com_September2020.json.gz'
#                                  name  \
# 0  Make It Mine Chain Crossbody Strap
# 1          Lagoon Spade Chain Sandals
# 2                   Shadow Large Tote
# 3            Spencer Slim Flap Wallet
# 4                Margaux Mini Satchel
#
#                                               offers  \
# 0  {'pricevaliduntil': '9999-12-31', 'price': '48...
# 1  {'price': '190.0', 'availability': 'http://sch...
# 2  {'price': '350.0', 'availability': 'http://sch...
# 3  {'price': '145.0', 'availability': 'http://sch...
# 4  {'pricevaliduntil': '9999-12-31', 'price': '24...
#
#                              brand  \
# 0  {'name': 'Kate Spade New York'}
# 1  {'name': 'Kate Spade New York'}
# 2  {'name': 'Kate Spade New York'}
# 3  {'name': 'Kate Spade New York'}
# 4  {'name': 'Kate Spade New York'}
#
#                                      aggregaterating             color
# 0  {'reviewcount': 'null', 'worstrating': '1', 'b...         rose gold
# 1                                               None         LIGHT TAN
# 2                                               None       OPTIC WHITE
# 3                                               None             BLACK
# 4  {'reviewcount': 'null', 'worstrating': '1', 'b...  black/warm taupe
# 'Product_slightgift.com_September2020.json.gz'
#                                                 name  \
# 0  Dinosaur series 3D night light led remote cont...
# 1  3D night light Eiffel Tower bedside table lamp...
# 2  Musical instrument series 3d night light Color...
# 3  Christmas series 3D night light LED remote con...
# 4  Football series night light 3d remote control ...
#
#                                               offers                   brand  \
# 0  {'sku': '56489', 'availability': 'https://sche...  {'name': 'Slightgift'}
# 1  {'gtin': '0006W', 'availability': 'https://sch...  {'name': 'Slightgift'}
# 2  {'availability': 'https://schema.org/InStock',...  {'name': 'Slightgift'}
# 3  {'pricevaliduntil': '2020-05-13', 'gtin': '001...  {'name': 'Slightgift'}
# 4  {'pricevaliduntil': '2020-05-13', 'gtin': '001...  {'name': 'Slightgift'}
#
#      mpn   gtin
# 0  0001B  0001B
# 1  0006W  0006W
# 2  0019B  0019B
# 3  0012B  0012B
# 4  0014B  0014B
# 'Product_whatstove.co.uk_September2020.json.gz'
#                                  name  \
# 0  La Nordica Crystal 50 Insert stove
# 1                       Chilli Billie
# 2                     Dovre 700 stove
# 3                    Charnwood LA 45B
# 4          Barbas Cuatro Tunnel stove
#
#                                      aggregaterating  \
# 0                                               None
# 1                                               None
# 2  {'bestrating': '5', 'name': 'Overall Rating', ...
# 3  {'bestrating': '5', 'name': 'Overall Rating', ...
# 4  {'bestrating': '5', 'ratingvalue': '3.5', 'nam...
#
#                                               review  width  height  depth
# 0                                               None  500.0   800.0  500.0
# 1                                               None  220.0   500.0  210.0
# 2  [{'author': 'Paul Mortimer-lee', 'name': 'Exce...    NaN     NaN    NaN
# 3  [{'author': 'John Redfern', 'name': 'Charnwood...  554.0   619.0  480.0
# 4  [{'name': 'Stylish and effective...', 'author'...    NaN     NaN    NaN
# 'Product_bohoshelf.com_September2020.json.gz'
#                                          name  \
# 0           European Vintage Tucker Jean Coat
# 1    Long Tassel Buddhist Glass Bead Necklace
# 2             Black Lace Floral Tassel Kimono
# 3  Handmade Bow Wool Hat For Women - Boho Hat
# 4          Sexy Lace Bikini Cover Up Cardigan
#
#                                               offers  \
# 0  {'pricecurrency': 'USD', 'price': '74.99', 'av...
# 1  {'pricecurrency': 'USD', 'availability': 'http...
# 2  {'pricecurrency': 'USD', 'availability': 'http...
# 3  {'pricecurrency': 'USD', 'availability': 'http...
# 4  {'price': '32.99', 'availability': 'http://sch...
#
#                                      aggregaterating  \
# 0  {'bestrating': '5', 'ratingcount': '10', 'rati...
# 1  {'bestrating': '5', 'reviewcount': '1', 'ratin...
# 2                                               None
# 3  {'bestrating': '5', 'ratingcount': '13', 'rati...
# 4                                               None
#
#                                          category  \
# 0  Denim Clothing > Boho Clothing > Denim Jackets
# 1                             jewelry > Necklaces
# 2                Boho Clothing > Kimonos-Cardigan
# 3             Beauty &amp; Fashion > Women's Hats
# 4                Boho Clothing > Kimonos-Cardigan
#
#                                  weight                releasedate  \
# 0                                  None  2019-07-27T13:23:44+00:00
# 1  {'value': '0.05', 'unitcode': 'KGM'}  2018-11-04T06:23:46+00:00
# 2                                  None  2019-06-09T08:57:35+00:00
# 3  {'value': '0.25', 'unitcode': 'KGM'}  2018-11-28T06:17:22+00:00
# 4                                  None  2019-06-09T08:57:16+00:00
#
#                                   additionalproperty  \
# 0  [{'value': 'Jackets', 'name': 'outerwear-type'...
# 1  [{'value': 'Men necklace', 'name': 'vintage-ne...
# 2  [{'value': 'Casual', 'name': 'style'}, {'value...
# 3  [{'value': 'chapeau vintage femme', 'name': 'i...
# 4  [{'value': 'Casual', 'name': 'style'}, {'value...
#
#                                          color  \
# 0                                   Light Blue
# 1                                         None
# 2                                        Black
# 3  Black, Light Khaki, purple, Red, royal blue
# 4                                        White
#
#                                 width                              height  \
# 0                                None                                None
# 1   {'value': '5', 'unitcode': 'CMT'}   {'value': '5', 'unitcode': 'CMT'}
# 2                                None                                None
# 3  {'value': '30', 'unitcode': 'CMT'}  {'value': '30', 'unitcode': 'CMT'}
# 4                                None                                None
#
#                                 depth
# 0                                None
# 1  {'value': '10', 'unitcode': 'CMT'}
# 2                                None
# 3  {'value': '30', 'unitcode': 'CMT'}
# 4                                None
# 'Product_nissanpartsnh.com_September2020.json.gz'
#          name                                             offers   brand  \
# 0  Fog Lights  {'url': 'www.nissanpartsnh.com/p/nissan_2021_/...  Nissan
# 1  Fog Lights  {'itemcondition': 'http://schema.org/NewCondit...  Nissan
# 2  Fog Lights  {'itemcondition': 'http://schema.org/NewCondit...  Nissan
# 3  Fog Lights  {'pricevaliduntil': '10/24/2020 3:57:21 PM', '...  Nissan
# 4  Fog Lights  {'itemcondition': 'http://schema.org/NewCondit...  Nissan
#
#                                      aggregaterating          mpn  \
# 0  {'reviewcount': '12', 'itemreviewed': 'Dealer'...  999F1-UZ000
# 1  {'reviewcount': '12', 'itemreviewed': 'Dealer'...  999F1-UZ000
# 2  {'reviewcount': '12', 'itemreviewed': 'Dealer'...  999F1-UZ000
# 3  {'reviewcount': '12', 'itemreviewed': 'Dealer'...  999F1-UZ000
# 4  {'reviewcount': '12', 'itemreviewed': 'Dealer'...  999F1-UZ000
#
#                  identifier
# 0  {'value': '999F1-UZ000'}
# 1  {'value': '999F1-UZ000'}
# 2  {'value': '999F1-UZ000'}
# 3  {'value': '999F1-UZ000'}
# 4  {'value': '999F1-UZ000'}
# 'Product_surfskateoutlet.com_September2020.json.gz'
#                                             name  \
# 0  Sweatshirt c/Capuz e Zip Skullcandy Shattered
# 1                Sweatshirt básica Enjoi Tie Dye
# 2            Sweatshirt c/Capuz e Zip DC Slauson
# 3                 Boné Homem Dragon Icon Trucker
# 4          Long Sleeve 3/4 Independent Head Line
#
#                                               offers                    brand  \
# 0  {'offercount': '3', 'price': '39.9900016784668...   {'name': 'Skullcandy'}
# 1  {'offercount': '1', 'highprice': '29.9', 'pric...        {'name': 'Enjoi'}
# 2  {'price': '37.5', 'offercount': '1', 'pricecur...           {'name': 'DC'}
# 3  {'offercount': '1', 'highprice': '14.99', 'pri...       {'name': 'Dragon'}
# 4  {'offercount': '1', 'highprice': '14.99', 'pri...  {'name': 'INDEPENDENT'}
#
#   category                   itemcondition
# 0     MENS  http://schema.org/NewCondition
# 1     MENS  http://schema.org/NewCondition
# 2     MENS  http://schema.org/NewCondition
# 3     MENS  http://schema.org/NewCondition
# 4     MENS  http://schema.org/NewCondition
# 'Product_specscart.co.uk_September2020.json.gz'
#           name                                             offers  \
# 0    JONES ST3  {'availability': 'https://schema.org/SoldOut',...
# 1  WOODFORD-S2  {'pricevaliduntil': '2020-12-22', 'price': '69...
# 2     WARREN 1  {'availability': 'https://schema.org/InStock',...
# 3     SF2837 3  {'pricevaliduntil': '2020-12-22', 'availabilit...
# 4   OLIVER SA1  {'availability': 'https://schema.org/InStock',...
#
#                              brand  \
# 0           {'name': 'Tom Archer'}
# 1           {'name': 'Tom Archer'}
# 2           {'name': 'Tom Archer'}
# 3  {'name': 'Salvatore Ferragamo'}
# 4           {'name': 'Tom Archer'}
#
#                                      aggregaterating  \
# 0  {'bestrating': '5', 'reviewcount': '121', 'rat...
# 1  {'bestrating': '5', 'reviewcount': '121', 'rat...
# 2  {'bestrating': '5', 'reviewcount': '121', 'rat...
# 3  {'bestrating': '5', 'reviewcount': '121', 'rat...
# 4  {'bestrating': '5', 'reviewcount': '121', 'rat...
#
#                                               review        gtin13
# 0  [{'datepublished': '2020-01-20', 'description'...  689243262191
# 1  [{'name': 'WOODFORD-S2', 'description': 'Recei...  689243263221
# 2  [{'description': 'It was very difficult find t...  689243263392
# 3  [{'name': 'SF2837 3', 'datepublished': '2020-0...  689243262912
# 4  [{'description': 'It was very difficult find t...  689243261696
# 'Product_ochelari.net_September2020.json.gz'
#                                    name  \
# 0              Polaroid Black P4139 KIH
# 1   Ray-Ban Aviator Mirror RB3025 W3277
# 2  Calvin Klein Pale Yellow CK4185S 250
# 3          Diesel Camouflage DL0135 95C
# 4         Guess Gold & Green GG1121 32F
#
#                                          offers  \
# 0  {'price': '199 lei', 'pricecurrency': 'lei'}
# 1  {'price': '618 lei', 'pricecurrency': 'lei'}
# 2  {'pricecurrency': 'lei', 'price': '249 lei'}
# 3  {'price': '279 lei', 'pricecurrency': 'lei'}
# 4  {'pricecurrency': 'lei', 'price': '249 lei'}
#
#                                      aggregaterating         model  \
# 0  {'bestrating': '5', 'ratingvalue': '0', 'revie...     P4139 KIH
# 1  {'bestrating': '5', 'reviewcount': '2', 'ratin...  RB3025 W3277
# 2  {'bestrating': '5', 'ratingvalue': '0', 'revie...   CK4185S 250
# 3  {'bestrating': '5', 'ratingvalue': '0', 'revie...    DL0135 95C
# 4  {'bestrating': '5', 'ratingvalue': '0', 'revie...    GG1121 32F
#
#    manufacturer
# 0      Polaroid
# 1       Ray-Ban
# 2  Calvin Klein
# 3        Diesel
# 4         Guess
