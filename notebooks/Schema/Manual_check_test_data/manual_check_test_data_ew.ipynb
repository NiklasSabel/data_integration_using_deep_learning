# %%
# import libraries
import os
import pandas as pd
import json
import gzip
import fasttext 
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
# Music Recording
path = '../../src/data/schemafiltereddata/TrainTestTables/Large/Test'
l = [file for file in os.listdir(path) if file.endswith('.json.gz')]

# %%
mr = [i for i in l if i.startswith('MusicRecording')]

# %%
event = [i for i in l if i.startswith('Event')]

# %%
creativework = [i for i in l if i.startswith('CreativeWork')]

# %%
len(mr)
# Out:
# 1103

# %%
len(event)
# Out:
# 1000

# %%
len(creativework)
# Out:
# 876

# %%
CreativeWork = ['headline',
 'author',
 'datepublished',
 'datemodified',
 'name',
 'publisher',
 'mainentityofpage',
 'interactionstatistic',
 'datecreated',
 'alternativeheadline',
 'keywords',
 'articlebody',
 'aggregaterating',
 'interactioncount',
 'inlanguage',
 'commentcount',
 'interactiontype',
 'creator',
 'genre',
 'version',
 'offers',
 'copyrightholder',
 'copyrightyear']

# %%
MusicRecording = ['name',
 'duration',
 'byartist',
 'inalbum',
 'datepublished',
 'genre',
 'datecreated']

# %%
files = mr
for file in files:
    # read file
    df = pd.read_json(os.path.join(path, '{}'.format(file)), compression='gzip', lines=True)
    print('name:', file)
    print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2228612/1094988407.py in <module>
# ----> 1 files = mr
#       2 for file in files:
#       3     # read file
#       4     df = pd.read_json(os.path.join(path, '{}'.format(file)), compression='gzip', lines=True)
#       5     print('name:', file)
#
# NameError: name 'mr' is not defined

# %%
Event = ['name',
 'enddate',
 'location',
 'performer',
 'organizer',
 'eventstatus',
 'eventattendancemode',
 'duration',
 'doortime',
 'typicalagerange',
 'performers']

# %%
files = creativework
for file in files:
    # read file
    df = pd.read_json(os.path.join(path, '{}'.format(file)), compression='gzip', lines=True)
    print('name:', file)
    print(df.head())
# Out:
# name: CreativeWork_tel-group.com_September2020.json.gz
#    row_id         headline             author        datepublished  \
# 0       0  201908-image013  {'name': 'jenny'}  2019-10-28 10:01:26
# 1       1  201910-image001  {'name': 'jenny'}  2019-10-29 09:52:11
# 2       2             hg03  {'name': 'jenny'}  2019-04-18 14:44:34
# 3       3     casestudy4.1  {'name': 'jenny'}  2016-06-21 16:51:47
# 4       4  191025-image016  {'name': 'jenny'}  2019-10-28 10:25:05
#
#           datemodified             name          publisher  \
# 0  2019-10-28 10:01:26  201908-image013  {'name': 'jenny'}
# 1  2019-10-29 09:52:11  201910-image001  {'name': 'jenny'}
# 2  2019-04-18 14:44:34             hg03  {'name': 'jenny'}
# 3  2016-09-08 14:11:21     casestudy4.1  {'name': 'jenny'}
# 4  2019-10-28 10:25:05  191025-image016  {'name': 'jenny'}
#
#                                                image mainentityofpage  \
# 0  {'height': '0', 'width': '0', 'url': 'http://w...  201908-image013
# ...

# %%
Event_tet-asw.org_September2020
