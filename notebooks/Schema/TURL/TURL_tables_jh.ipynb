# %%
import pandas as pd
import json 
import gzip
import os
import re as regex
import pickle
import progressbar

# %%
#pip install progressbar2

# %%
path = '../../../src/data/schemafiltereddata/TrainTestTables/'
#small_files_train = os.listdir(path+'Small/Train/')
#small_files_train = [file for file in os.listdir(path+'Small/Train/') if file.endswith('.json.gz')]
#medium_files_train = [file for file in os.listdir(path+'Medium/Train/') if file.endswith('.json.gz')]
large_files_train = [file for file in os.listdir(path+'Large/Train/') if file.endswith('.json.gz')]  
test_files = [file for file in os.listdir(path+'Test/') if file.endswith('.json.gz')]  
#turl_input_path = os.path.join(product_path, 'TURL/input')

# %%
#small_files_train
large_files_train
# Out:
# ['Product_mytechstyle.com_September2020.json.gz',
#  'Product_huskyboost.com_September2020.json.gz',
#  'Product_abouttimetoo.com_September2020.json.gz',
#  'Recipe_prevention.com_September2020.json.gz',
#  'CreativeWork_greatrooms24.com_September2020.json.gz',
#  'Product_kingmemorialpark.com_September2020.json.gz',
#  'CreativeWork_upownersclub.co.uk_September2020.json.gz',
#  'Product_bayerautogroup.com_September2020.json.gz',
#  'Product_uzurii.com_September2020.json.gz',
#  'Product_high-supplies.com_September2020.json.gz',
#  'MusicRecording_bencrosbymusic.com_September2020.json.gz',
#  'Product_mycraftystencils.com_September2020.json.gz',
#  'LocalBusiness_agfg.com.au_September2020.json.gz',
#  'Product_elrincondelasmermeladas.com_September2020.json.gz',
#  'CreativeWork_fujifloraldesign.com_September2020.json.gz',
#  'Recipe_teaforturmeric.com_September2020.json.gz',
#  'LocalBusiness_innatturkeyhill.com_September2020.json.gz',
#  'Product_4newstyle.com_September2020.json.gz',
#  'Product_metesenbeauty.com_September2020.json.gz',
#  'Book_virago.co.uk_September2020.json.gz',
#  'Product_dtcommercialphoto.com_September2020.json.gz',
#  'Hotel_bthetravelbrand.com_September2020.json.gz',
#  'Hotel_khaosanroad.com_September2020.json.gz',
#  'MusicRecording_travisdaggettmusic.com_September2020.json.gz',
#  'Event_stockholmpride.org_September2020.json.gz',
#  'LocalBusiness_ssdntech.com_September2020.json.gz',
#  'MusicRecording_cavazosmusic.com_September2020.json.gz',
#  'Event_ewingnj.org_September2020.json.gz',
#  'Product_dipyourcar.com_September2020.json.gz',
#  'Recipe_tasteoftequila.com_September2020.json.gz',
#  'Product_discountcontactlenses.com_September2020.json.gz',
#  'MusicRecording_robertaumannband.com_September2020.json.gz',
#  'Hotel_kauai-vacations-ahh.com_September2020.json.gz',
#  'Person_jaybsmith.com_September2020.json.gz',
#  'Product_mac-case.com_September2020.json.gz',
#  'Event_eastmont.org_September2020.json.gz',
#  'MusicRecording_dashriprock.net_September2020.json.gz',
#  'Product_stringerfuneral.com_September2020.json.gz',
#  'Product_pinkmoteltlv.com_September2020.json.gz',
#  'Person_abnamro.com_September2020.json.gz',
#  'LocalBusiness_zellamsee-kaprun.com_September2020.json.gz',
#  'Event_fairplaysport.org_September2020.json.gz',
#  'Event_jonathan-balcombe.com_September2020.json.gz',
#  'MusicRecording_foggyhogtownboys.com_September2020.json.gz',
#  'Event_suepellanddesigns.com_September2020.json.gz',
#  'Product_itibeyou.com_September2020.json.gz',
#  'Product_onkruidbrander.com_September2020.json.gz',
#  'Product_jgmaker3dofficial.com_September2020.json.gz',
#  'Recipe_connectingkitchen.com_September2020.json.gz',
#  'Product_zales.com_September2020.json.gz',
#  'Event_freewheelinbikes.org_September2020.json.gz',
#  'CreativeWork_cafecampesino.com_September2020.json.gz',
#  'Recipe_goodlifeeats.com_September2020.json.gz',
#  'Recipe_kidfriendlythingstodo.com_September2020.json.gz',
#  'Product_littmanbros.com_September2020.json.gz',
#  'Place_charlottetilbury.com_September2020.json.gz',
#  'Product_shackelfordfuneraldirectors.com_September2020.json.gz',
#  'Product_shadeaustralia.com.au_September2020.json.gz',
#  'Product_utmeofficial.net_September2020.json.gz',
#  'Product_miamijewellers.com_September2020.json.gz',
#  'Product_islandbeverages.com_September2020.json.gz',
#  'Product_hobmodel.com_September2020.json.gz',
#  'LocalBusiness_eldercare.com_September2020.json.gz',
#  'MusicRecording_hoodfacez.com_September2020.json.gz',
#  'CreativeWork_zenithdigitalmarketing.com.au_September2020.json.gz',
#  'Product_avinstalls.co.uk_September2020.json.gz',
#  'Product_tubaexchange.com_September2020.json.gz',
#  'Product_allwinelovers.com_September2020.json.gz',
#  'CreativeWork_pzmethodist.org.uk_September2020.json.gz',
#  'LocalBusiness_hollyspringschamber.org_September2020.json.gz',
#  'Person_elcuadernodeclover.com_September2020.json.gz',
#  'Person_ts4rent.com.mx_September2020.json.gz',
#  'Hotel_edlets.com_September2020.json.gz',
#  'Product_carlingfordmusic.com.au_September2020.json.gz',
#  'MusicRecording_thesoutherngothicmusic.com_September2020.json.gz',
#  'Product_mbofbend.com_September2020.json.gz',
#  'MusicRecording_shriekback.com_September2020.json.gz',
#  'Event_gardenontario.org_September2020.json.gz',
#  'LocalBusiness_visitthy.com_September2020.json.gz',
#  'Person_showcamsgirls.com_September2020.json.gz',
#  'Product_mommesilk.com_September2020.json.gz',
#  'MusicRecording_composerhigbee.com_September2020.json.gz',
#  'Product_februn.com_September2020.json.gz',
#  'Product_edmancenter.com_September2020.json.gz',
#  'LocalBusiness_goldbuyersharma.com.au_September2020.json.gz',
#  'Event_thetvolution.com_September2020.json.gz',
#  'Product_fabfunky.co.uk_September2020.json.gz',
#  'Place_beaumont.org_September2020.json.gz',
#  'CreativeWork_westmontjoyfulvoices.org_September2020.json.gz',
#  'Product_solaremobility.com_September2020.json.gz',
#  'Event_bacps.net_September2020.json.gz',
#  'Product_adh.com.vn_September2020.json.gz',
#  'MusicRecording_richardpearsonthomas.com_September2020.json.gz',
#  'Product_conicellinissan.com_September2020.json.gz',
#  'Hotel_bookingsuedtirol.com_September2020.json.gz',
#  'Event_austinrowing.org_September2020.json.gz',
#  'Product_telegraphnl.com_September2020.json.gz',
#  'Product_kientrucdesign.com_September2020.json.gz',
#  'Product_alohahawaiianflowers.com_September2020.json.gz',
#  'CreativeWork_holycityhogs.com_September2020.json.gz',
#  'LocalBusiness_waterproofingnearme.com.au_September2020.json.gz',
#  'MusicRecording_bellaciaobandaitaliana.com_September2020.json.gz',
#  'Recipe_whiteapronblog.com_September2020.json.gz',
#  'Product_theapplianceadvantage.com_September2020.json.gz',
#  'Product_jamrockgrocery.com_September2020.json.gz',
#  'Event_cccmaine.org_September2020.json.gz',
#  'Hotel_rotana.com_September2020.json.gz',
#  'CreativeWork_radiumthemes.com_September2020.json.gz',
#  'Product_lushusa.com_September2020.json.gz',
#  'Recipe_shewearsmanyhats.com_September2020.json.gz',
#  'Person_irglobal.com_September2020.json.gz',
#  'MusicRecording_brandonwalkermusic.com_September2020.json.gz',
#  'Product_absolute360.co.uk_September2020.json.gz',
#  'Event_grpride.org_September2020.json.gz',
#  'CreativeWork_archiscene.net_September2020.json.gz',
#  'Product_novmak.com_September2020.json.gz',
#  'Product_aphotostore.com_September2020.json.gz',
#  'Product_barnesfuneralhome.org_September2020.json.gz',
#  'Product_kidzholic.com_September2020.json.gz',
#  'Product_nasbilisim.com_September2020.json.gz',
#  'CreativeWork_qriconsulting.com_September2020.json.gz',
#  'Product_shop4sg.com_September2020.json.gz',
#  'LocalBusiness_innatmonticello.com_September2020.json.gz',
#  'Event_thecookinglabpw.com_September2020.json.gz',
#  'CreativeWork_srtforums.com_September2020.json.gz',
#  'Product_camtecphoto.com_September2020.json.gz',
#  'Product_spaceworkx.com_September2020.json.gz',
#  'Recipe_lindtexcellence.com_September2020.json.gz',
#  'Product_zenzahome.com_September2020.json.gz',
#  'Product_reality-doll.com_September2020.json.gz',
#  'Product_vilingerie.com.br_September2020.json.gz',
#  'Product_siluleddisplay.com_September2020.json.gz',
#  'Event_atlasobscura.com_September2020.json.gz',
#  'Product_engelcoolers.com_September2020.json.gz',
#  'Product_super-cyber-mall.com_September2020.json.gz',
#  'Product_jsflyfishing.com_September2020.json.gz',
#  'Event_ifmbe.org_September2020.json.gz',
#  'Product_giftshirtstoday.com_September2020.json.gz',
#  'Event_chevychasebaptist.org_September2020.json.gz',
#  'LocalBusiness_plasterersnearme.com.au_September2020.json.gz',
#  'Product_babausanhdieu.com_September2020.json.gz',
#  'LocalBusiness_gmsvcc.org_September2020.json.gz',
#  'Product_ocautoguys.com_September2020.json.gz',
#  'Person_financial-planning.com_September2020.json.gz',
#  'MusicRecording_mattangell.com_September2020.json.gz',
#  'Recipe_lisaloufitness.com_September2020.json.gz',
#  'Recipe_kunzler.com_September2020.json.gz',
#  'Product_protechprojection.com_September2020.json.gz',
#  'Product_flowers4stlucia.com_September2020.json.gz',
#  'Person_ze.com_September2020.json.gz',
#  'Event_balldrop.com_September2020.json.gz',
#  'Product_cyclingceramic.com_September2020.json.gz',
#  'Product_512boutique.com_September2020.json.gz',
#  'Recipe_stonyfield.com_September2020.json.gz',
#  'MusicRecording_dwdasher.com_September2020.json.gz',
#  'Product_racewaykia.com_September2020.json.gz',
#  'Product_profumeriadelcorso.net_September2020.json.gz',
#  'Product_redhamper.co.uk_September2020.json.gz',
#  'Product_prindo.co.uk_September2020.json.gz',
#  'Event_chicagotabernacle.org_September2020.json.gz',
#  'Product_tozzibologna.com_September2020.json.gz',
#  'Product_perfumesideal.com_September2020.json.gz',
#  'Hotel_kayak.co.uk_September2020.json.gz',
#  'Recipe_dawnastone.com_September2020.json.gz',
#  'LocalBusiness_creditconsolidation-usa.com_September2020.json.gz',
#  'Product_supercowtoys.com_September2020.json.gz',
#  'Recipe_chelseasmessyapron.com_September2020.json.gz',
#  'LocalBusiness_terraboost.com_September2020.json.gz',
#  'Event_moorecountychamber.com_September2020.json.gz',
#  'MusicAlbum_linga.org_September2020.json.gz',
#  'LocalBusiness_utbchamber.com_September2020.json.gz',
#  'Place_sanford365.com_September2020.json.gz',
#  'LocalBusiness_montanagems.net_September2020.json.gz',
#  'Product_dragonflywhispers.net_September2020.json.gz',
#  'Product_comboink.com_September2020.json.gz',
#  'Hotel_go-connecticut.com_September2020.json.gz',
#  'Restaurant_cookingchanneltv.com_September2020.json.gz',
#  'Hotel_carnarvonaccommodation.com_September2020.json.gz',
#  'Product_stores.net.co_September2020.json.gz',
#  'MusicRecording_thewhiskeyfarm.com_September2020.json.gz',
#  'Product_bestbuyautoinc.com_September2020.json.gz',
#  'Recipe_parveenskitchen.com_September2020.json.gz',
#  'Recipe_vspotz.com_September2020.json.gz',
#  'Product_shiro-shiro.uk_September2020.json.gz',
#  'Product_linkproved.com_September2020.json.gz',
#  'Product_oasisgardening.co.uk_September2020.json.gz',
#  'Event_realtorscentralma.org_September2020.json.gz',
#  'Event_massmep.org_September2020.json.gz',
#  'Product_macmotorscars.com_September2020.json.gz',
#  'Product_blair.com_September2020.json.gz',
#  'CreativeWork_albacomedy.com_September2020.json.gz',
#  'Product_nailperfect.com_September2020.json.gz',
#  'Product_rudolphhonda.com_September2020.json.gz',
#  'CreativeWork_opspectraining.com_September2020.json.gz',
#  'Product_giglio.com_September2020.json.gz',
#  'Product_theterribletwos.org_September2020.json.gz',
#  'Product_sportsmanspecialtyproducts.com_September2020.json.gz',
#  'Product_rallyandracing.com_September2020.json.gz',
#  'Product_simpleautosaleslasvegas.com_September2020.json.gz',
#  'Event_igcministries.com_September2020.json.gz',
#  'Event_beerrepublicbangkok.com_September2020.json.gz',
#  'Product_honeymotorsllc.com_September2020.json.gz',
#  'CreativeWork_cx3forum.com_September2020.json.gz',
#  'Product_kaylule.com.tr_September2020.json.gz',
#  'Event_rivermistband.com_September2020.json.gz',
#  'Person_poorclaresc.com_September2020.json.gz',
#  'CreativeWork_4drclanforum.com_September2020.json.gz',
#  'CreativeWork_outdoorhappens.com_September2020.json.gz',
#  'LocalBusiness_inaxvn.com_September2020.json.gz',
#  'Place_gosanangelo.com_September2020.json.gz',
#  'Event_padmr.net_September2020.json.gz',
#  'Person_frettens.co.uk_September2020.json.gz',
#  'Recipe_vanskitchen.com_September2020.json.gz',
#  'Person_runnersworldonline.com.au_September2020.json.gz',
#  'Product_fawkes-cycles.co.uk_September2020.json.gz',
#  'CreativeWork_holidayrambler.com_September2020.json.gz',
#  'Person_amazingeducationalresourcescalendar.com_September2020.json.gz',
#  'Person_treatmenttraveller.com_September2020.json.gz',
#  'Product_fergushomeandhardware.com_September2020.json.gz',
#  'Product_briggssupercenter.com_September2020.json.gz',
#  'Product_winediscounter.com_September2020.json.gz',
#  'Product_gimmesimulators.com_September2020.json.gz',
#  'Place_edmonton55.com_September2020.json.gz',
#  'Person_partybilder24.com_September2020.json.gz',
#  'CreativeWork_siemreaptuktuk.net_September2020.json.gz',
#  'Product_tribesportgroup.com_September2020.json.gz',
#  'Product_bpcshobbies.com_September2020.json.gz',
#  'CreativeWork_galvestonislandbeachpatrol.com_September2020.json.gz',
#  'Product_personalisedbanners.co.uk_September2020.json.gz',
#  'Event_ruthmanning.com_September2020.json.gz',
#  'Product_rat-coffeeshop.com_September2020.json.gz',
#  'MusicRecording_sastargang.com_September2020.json.gz',
#  'Product_factoryhdsw.com_September2020.json.gz',
#  'Recipe_nordicviolet.com_September2020.json.gz',
#  'Product_mdvresort.com_September2020.json.gz',
#  'Product_besamecosmetics.com_September2020.json.gz',
#  'Person_yorkcity.org_September2020.json.gz',
#  'Product_unitywatersports.co.uk_September2020.json.gz',
#  'Recipe_delmonte.com_September2020.json.gz',
#  'Product_softcarecosmetics.com_September2020.json.gz',
#  'Product_gillette.co.uk_September2020.json.gz',
#  'LocalBusiness_inplain.net_September2020.json.gz',
#  'Person_visitmuskegon.org_September2020.json.gz',
#  'Recipe_aredspatula.com_September2020.json.gz',
#  'MusicRecording_lynneamalley.com_September2020.json.gz',
#  'Recipe_thebigmansworld.com_September2020.json.gz',
#  'Product_taylorsclematis.co.uk_September2020.json.gz',
#  'Product_nativatours.com_September2020.json.gz',
#  'LocalBusiness_extreme-directory.net_September2020.json.gz',
#  'Recipe_nowyourecookingrecipes.com_September2020.json.gz',
#  'LocalBusiness_kidsbaqueira.com_September2020.json.gz',
#  'CreativeWork_thedieselstop.com_September2020.json.gz',
#  'Product_konsantreparfum.com_September2020.json.gz',
#  'Product_green-house-store.com_September2020.json.gz',
#  'Product_tonkinfiat.com_September2020.json.gz',
#  'Recipe_freshforkmarket.com_September2020.json.gz',
#  'Recipe_shadesofcinnamon.com_September2020.json.gz',
#  'Product_genesisfiat.com_September2020.json.gz',
#  'Event_adaptivedesign.org_September2020.json.gz',
#  'Product_lalamira.com_September2020.json.gz',
#  'Hotel_sercotelhotels.co.uk_September2020.json.gz',
#  'Product_missmafia.com_September2020.json.gz',
#  'Book_marasworld.com_September2020.json.gz',
#  'Recipe_cuisineravecmicheline.com_September2020.json.gz',
#  'Product_shoppingcartusa.com_September2020.json.gz',
#  'Event_doorcountypulse.com_September2020.json.gz',
#  'Product_onegreatcoffee.com_September2020.json.gz',
#  'MusicRecording_nicobe.com_September2020.json.gz',
#  'Product_mearsfamilyfunerals.co.uk_September2020.json.gz',
#  'LocalBusiness_serviciotecnicos.com.es_September2020.json.gz',
#  'Product_joesautostoledo.com_September2020.json.gz',
#  'Person_ins-zone.com_September2020.json.gz',
#  'Product_wearlively.com_September2020.json.gz',
#  'Product_thewinedepository.com.au_September2020.json.gz',
#  'Product_adventistdeva.org_September2020.json.gz',
#  'Person_avonandsomerset.police.uk_September2020.json.gz',
#  'Event_stpetersrockland.org_September2020.json.gz',
#  'Hotel_lemoutonblanc-lemontsaintmichel.com_September2020.json.gz',
#  'Book_kylebooks.co.uk_September2020.json.gz',
#  'Event_aomci.org_September2020.json.gz',
#  'Product_weltpixel.com_September2020.json.gz',
#  'Product_equikro.com_September2020.json.gz',
#  'Product_conlins.com_September2020.json.gz',
#  'MusicRecording_sutildiscos.com_September2020.json.gz',
#  'Recipe_granorfarm.com_September2020.json.gz',
#  'Product_cyclesolutions.co.uk_September2020.json.gz',
#  'CreativeWork_nomadwomen.com_September2020.json.gz',
#  'Person_advantaira.com_September2020.json.gz',
#  'Restaurant_menupix.com_September2020.json.gz',
#  'Event_allseats.com_September2020.json.gz',
#  'CreativeWork_hartvillehealthandwellness.com_September2020.json.gz',
#  'Event_catchyourbreath.org_September2020.json.gz',
#  'Product_continentalacura.com_September2020.json.gz',
#  'Person_robertsandsonsfuneralhome.com_September2020.json.gz',
#  'Product_vitrinapro.com_September2020.json.gz',
#  'Product_tarienterprises.com_September2020.json.gz',
#  'Person_tributecenteronline.com_September2020.json.gz',
#  'MusicRecording_virgilgibson.com_September2020.json.gz',
#  'Product_charlestoncremationcenter.com_September2020.json.gz',
#  'Recipe_grapearborbandb.com_September2020.json.gz',
#  'MusicRecording_cookiecrotchnuts.com_September2020.json.gz',
#  'MusicRecording_4daru.com_September2020.json.gz',
#  'Product_dermalogica.com.au_September2020.json.gz',
#  'LocalBusiness_winetastingbliss.com_September2020.json.gz',
#  'CreativeWork_agronovae.com_September2020.json.gz',
#  'MusicRecording_deanrichard.com_September2020.json.gz',
#  'Place_reveresriders.org_September2020.json.gz',
#  'Product_420science.com_September2020.json.gz',
#  'Product_btowstore.com_September2020.json.gz',
#  'MusicRecording_dedwardmusic.com_September2020.json.gz',
#  'Place_nyaoh.com_September2020.json.gz',
#  'MusicRecording_billycardine.com_September2020.json.gz',
#  'Product_soshomesales.com_September2020.json.gz',
#  'Product_greenvalleynation.com_September2020.json.gz',
#  'Person_vancethompsonvision.com_September2020.json.gz',
#  'Person_marlattfuneralhome.com_September2020.json.gz',
#  'TVEpisode_123moviesreal.com_September2020.json.gz',
#  'Product_joneschevy.com_September2020.json.gz',
#  'Product_babyandco.com_September2020.json.gz',
#  'Product_head-for-the-hills.co.uk_September2020.json.gz',
#  'Event_worldsmarathons.com_September2020.json.gz',
#  'Event_foreseeablefuture.org_September2020.json.gz',
#  'MusicRecording_brunosteelemusic.com_September2020.json.gz',
#  'Product_thefoxholeshop.com_September2020.json.gz',
#  'Person_cournoyerfh.com_September2020.json.gz',
#  'LocalBusiness_broussardchamber.net_September2020.json.gz',
#  'CreativeWork_allpeoplescc.org_September2020.json.gz',
#  'CreativeWork_themarqueehirecompany.com_September2020.json.gz',
#  'MusicRecording_wallylawder.com_September2020.json.gz',
#  'Product_hustledude.com_September2020.json.gz',
#  'Product_yiddishbookcenter.org_September2020.json.gz',
#  'Product_boucherhyundaijanesville.com_September2020.json.gz',
#  'Event_prstatistics.com_September2020.json.gz',
#  'CreativeWork_vibrant-coaching.com_September2020.json.gz',
#  'Product_dollwives.com_September2020.json.gz',
#  'MusicRecording_vctmsofficial.com_September2020.json.gz',
#  'Product_omegaticket.com_September2020.json.gz',
#  'Recipe_nourishingplot.com_September2020.json.gz',
#  'LocalBusiness_clovisnm.org_September2020.json.gz',
#  'Person_lexisnexis.com.hk_September2020.json.gz',
#  'MusicRecording_holyhopemusic.com_September2020.json.gz',
#  'Recipe_comfortablefood.com_September2020.json.gz',
#  'Product_mcqueenlabs.com_September2020.json.gz',
#  'Person_audiologyonline.com_September2020.json.gz',
#  'MusicRecording_talytali.com_September2020.json.gz',
#  'Recipe_truroots.com_September2020.json.gz',
#  'MusicRecording_johnfordblues.com_September2020.json.gz',
#  'Book_2d-market.com_September2020.json.gz',
#  'Product_pocolocoswims.com_September2020.json.gz',
#  'Place_losranchos.org_September2020.json.gz',
#  'Recipe_northcoasteats.com_September2020.json.gz',
#  'MusicRecording_thelebeaus.com_September2020.json.gz',
#  'Product_eend.co.uk_September2020.json.gz',
#  'Product_luckyscent.com_September2020.json.gz',
#  'Person_urbanleasing.com_September2020.json.gz',
#  'Product_calcoastautosales.com_September2020.json.gz',
#  'Product_tafisagames2016.com_September2020.json.gz',
#  'LocalBusiness_eaglerider.com_September2020.json.gz',
#  'Book_acappellabooks.com_September2020.json.gz',
#  'LocalBusiness_rochesternh.org_September2020.json.gz',
#  'Product_irealbio.com_September2020.json.gz',
#  'Product_orbasics.com_September2020.json.gz',
#  'Product_fillersupplies.com_September2020.json.gz',
#  'Product_pixilink.com_September2020.json.gz',
#  'Product_solarsportinggoods.com_September2020.json.gz',
#  'Product_villa-phuket.com_September2020.json.gz',
#  'Recipe_feastingathome.com_September2020.json.gz',
#  'Person_ineternalmemory.com_September2020.json.gz',
#  'Event_penguinpointproductions.com_September2020.json.gz',
#  'Product_jacuzziontario.com_September2020.json.gz',
#  'Event_theshepherdshouseinternational.org_September2020.json.gz',
#  'CreativeWork_vintage-instruments.com_September2020.json.gz',
#  'CreativeWork_crossbownation.com_September2020.json.gz',
#  'Product_flitsenflash.com_September2020.json.gz',
#  'Recipe_tasteofartisan.com_September2020.json.gz',
#  'Product_edgystar.com_September2020.json.gz',
#  'Product_gearbrain.com_September2020.json.gz',
#  'Person_stokesprockandmundt.com_September2020.json.gz',
#  'Recipe_veganuary.com_September2020.json.gz',
#  'MusicRecording_jeffcampbellmusic.com_September2020.json.gz',
#  'MusicRecording_thelovejunkies.co.uk_September2020.json.gz',
#  'Person_bushcenter.org_September2020.json.gz',
#  'Product_vipercleaning.co.uk_September2020.json.gz',
#  'Product_scentsplit.com_September2020.json.gz',
#  'CreativeWork_edebiyatdefteri.com_September2020.json.gz',
#  'Product_firebirdtours.com_September2020.json.gz',
#  'Product_flowers4thailand.com_September2020.json.gz',
#  'Product_billjacobsmini.com_September2020.json.gz',
#  'MusicRecording_calmandchaos.com_September2020.json.gz',
#  'CreativeWork_metropolitanbushey.co.uk_September2020.json.gz',
#  'Product_sieuthimang.com.vn_September2020.json.gz',
#  'Product_hollyhood.com.tr_September2020.json.gz',
#  'CreativeWork_chainmaillers.com_September2020.json.gz',
#  'Recipe_kimspireddiy.com_September2020.json.gz',
#  'LocalBusiness_lufranbrasil.com.br_September2020.json.gz',
#  'Product_flowers4istanbul.com_September2020.json.gz',
#  'Product_flowers4angola.com_September2020.json.gz',
#  'Product_abeautifulmess.com_September2020.json.gz',
#  'Product_alpinstore.com_September2020.json.gz',
#  'Product_donjacobstoyota.com_September2020.json.gz',
#  'Recipe_wildatlantictaste.com_September2020.json.gz',
#  'MusicRecording_nenadbachband.com_September2020.json.gz',
#  'MusicAlbum_raprnb.com_September2020.json.gz',
#  'Event_californiaunpublished.com_September2020.json.gz',
#  'Product_turuya7.com_September2020.json.gz',
#  'MusicRecording_invincibleczars.com_September2020.json.gz',
#  'LocalBusiness_saltedvines.com_September2020.json.gz',
#  'MusicRecording_freerocknroll.com_September2020.json.gz',
#  'Event_macquarieanglican.org_September2020.json.gz',
#  'Product_thestemstore.com_September2020.json.gz',
#  'Product_crichardsleather.com_September2020.json.gz',
#  'Product_extraspace.com_September2020.json.gz',
#  'Product_gozags.com_September2020.json.gz',
#  'Person_idtechex.com_September2020.json.gz',
#  'LocalBusiness_fhaloanfortworthtx.com_September2020.json.gz',
#  'MusicRecording_nathansheppard.net_September2020.json.gz',
#  'Recipe_needarecipe.com_September2020.json.gz',
#  'Event_siepk.org_September2020.json.gz',
#  'Product_oooleee.com_September2020.json.gz',
#  'Product_ecoescape.com.br_September2020.json.gz',
#  'Product_kidsmallshop.com_September2020.json.gz',
#  'CreativeWork_minitorque.com_September2020.json.gz',
#  'Product_keptforhersextoys.com_September2020.json.gz',
#  'Product_remax.com_September2020.json.gz',
#  'Product_weaponupgrade.com_September2020.json.gz',
#  'Product_prospermagic.com_September2020.json.gz',
#  'Product_lascoautoparts.com_September2020.json.gz',
#  'Event_gpblackhistorymuseum.org_September2020.json.gz',
#  'Product_idefix.com_September2020.json.gz',
#  'MusicRecording_chasetheriver.com_September2020.json.gz',
#  'Product_sheelys.com_September2020.json.gz',
#  'LocalBusiness_dumpster-rentals.com_September2020.json.gz',
#  'Product_giorgioarmanibeauty.com.au_September2020.json.gz',
#  'MusicRecording_ryandishen.com_September2020.json.gz',
#  'Place_yoast.com_September2020.json.gz',
#  'Event_discoverbuellton.com_September2020.json.gz',
#  'CreativeWork_befemalegroup.com_September2020.json.gz',
#  'Person_valcon.com_September2020.json.gz',
#  'Product_mastroautosales.com_September2020.json.gz',
#  'Product_vceebeauty.com_September2020.json.gz',
#  'Product_worcesterpencompany.co.uk_September2020.json.gz',
#  'MusicRecording_atlysmusic.com_September2020.json.gz',
#  'Product_toalebrothers.com_September2020.json.gz',
#  'Place_re-read.com_September2020.json.gz',
#  'CreativeWork_iptv-host.com_September2020.json.gz',
#  'Product_cewe-photoworld.com_September2020.json.gz',
#  'Product_broadwayautomotive.com_September2020.json.gz',
#  'Product_trilogyrestoration.com_September2020.json.gz',
#  'Product_salaostore.com.br_September2020.json.gz',
#  'Product_gear4teens.com_September2020.json.gz',
#  'Person_hocw.com.au_September2020.json.gz',
#  'Product_dailydongtam.com_September2020.json.gz',
#  'Person_sullivansfuneralandcremation.com_September2020.json.gz',
#  'Product_wizardcoinsupply.com_September2020.json.gz',
#  'Event_rockfordcommunitychurch.org_September2020.json.gz',
#  'Product_orientbell.com_September2020.json.gz',
#  'Person_beeradvocaten.com_September2020.json.gz',
#  'Product_bestkitchenandappliances.com_September2020.json.gz',
#  'Product_yaladesigns.com_September2020.json.gz',
#  'Person_freshfields.com_September2020.json.gz',
#  'LocalBusiness_mostrecommendedhomecare.co.uk_September2020.json.gz',
#  'Place_thelastgreenvalley.org_September2020.json.gz',
#  'Product_woofshack.com_September2020.json.gz',
#  'Place_visitfloridafarms.com_September2020.json.gz',
#  'Product_redpartyshop.com_September2020.json.gz',
#  'Recipe_health-advices.net_September2020.json.gz',
#  'Product_customdrinkwarestore.com_September2020.json.gz',
#  'Recipe_spicepaw.com_September2020.json.gz',
#  'Product_bobbaileys.com_September2020.json.gz',
#  'Person_woodcountyhospital.org_September2020.json.gz',
#  'LocalBusiness_cliniqueavenir.com_September2020.json.gz',
#  'MusicRecording_rogerbainmusic.com_September2020.json.gz',
#  'Product_theswagsisters.com_September2020.json.gz',
#  'MusicRecording_kathyreidnaiman.com_September2020.json.gz',
#  'Person_donnabaldwin.com_September2020.json.gz',
#  'Product_waxvinylrecords.co.uk_September2020.json.gz',
#  'Product_kenkohrelief.com_September2020.json.gz',
#  'Product_istanbulairporttransfer724.com_September2020.json.gz',
#  'Product_spitalfieldssports.com_September2020.json.gz',
#  'Book_mulhollandbooks.com_September2020.json.gz',
#  'Person_seattlechristiancounseling.com_September2020.json.gz',
#  'Product_oilfilterseparator.com_September2020.json.gz',
#  'Recipe_platein28.com_September2020.json.gz',
#  'Product_bicicletesrestoreit.com_September2020.json.gz',
#  'Person_charlestondiocese.org_September2020.json.gz',
#  'Recipe_aseeminspiration.com_September2020.json.gz',
#  'Product_everythinglegwear.com_September2020.json.gz',
#  'LocalBusiness_blackmagictocontrolsomeone.com_September2020.json.gz',
#  'Product_socialitelife.com_September2020.json.gz',
#  'Event_shorewoodchamber.com_September2020.json.gz',
#  'MusicRecording_hurwitzmusic.com_September2020.json.gz',
#  'Recipe_momswhothink.com_September2020.json.gz',
#  'Recipe_zuranazrecipe.com_September2020.json.gz',
#  'Person_anandaportland.org_September2020.json.gz',
#  'Event_stcharlesgreece.org_September2020.json.gz',
#  'Person_viewlascruceshomes.com_September2020.json.gz',
#  'Event_thefirebirds.com_September2020.json.gz',
#  'Hotel_australiansky.co.uk_September2020.json.gz',
#  'Product_hrkgame.com_September2020.json.gz',
#  'Hotel_i4calgary.com_September2020.json.gz',
#  'Recipe_pangananku.com_September2020.json.gz',
#  'Product_scentbars.com_September2020.json.gz',
#  'Product_teakclassicfurniture.com_September2020.json.gz',
#  'CreativeWork_ridgelineownersclub.com_September2020.json.gz',
#  'Product_quirkchryslerjeep.com_September2020.json.gz',
#  'Product_thesportshuddle.com_September2020.json.gz',
#  'Event_cityofdarlington.com_September2020.json.gz',
#  'Product_netbilbilisim.com_September2020.json.gz',
#  'Product_boltonhay.com_September2020.json.gz',
#  'Product_fitbas.com_September2020.json.gz',
#  'Event_trfchamber.com_September2020.json.gz',
#  'Product_avecbd.com_September2020.json.gz',
#  'LocalBusiness_easternwashingtonyellowpages.com_September2020.json.gz',
#  'Event_billywestpodcast.com_September2020.json.gz',
#  'Event_turkishcafeandlounge.com_September2020.json.gz',
#  'Product_nesstone.com_September2020.json.gz',
#  'Product_bonggon.com.vn_September2020.json.gz',
#  'Product_velofuze.com_September2020.json.gz',
#  'Product_grandoptical.com_September2020.json.gz',
#  'MusicRecording_timherroncorporation.com_September2020.json.gz',
#  'CreativeWork_metro-metals.com_September2020.json.gz',
#  'Event_thedalleschamber.com_September2020.json.gz',
#  'Recipe_westernstarbutter.com.au_September2020.json.gz',
#  'Product_hsdfuneralhome.com_September2020.json.gz',
#  'Product_white-birch-farm.com_September2020.json.gz',
#  'CreativeWork_guardioesdasaude.org_September2020.json.gz',
#  'MusicRecording_pattispadaro.com_September2020.json.gz',
#  'Recipe_acadianatable.com_September2020.json.gz',
#  'MusicRecording_albanothemadman.com_September2020.json.gz',
#  'MusicRecording_daveharrismusic.uk_September2020.json.gz',
#  'Place_scoutcambridge.com_September2020.json.gz',
#  'CreativeWork_paykolmus.com_September2020.json.gz',
#  'Person_primas2.com_September2020.json.gz',
#  'Event_towncalendar.org_September2020.json.gz',
#  'Product_fruitridgetools.com_September2020.json.gz',
#  'CreativeWork_solverglobal.com_September2020.json.gz',
#  'LocalBusiness_dublinchamber.org_September2020.json.gz',
#  'Product_prolaptops.com_September2020.json.gz',
#  'Product_airportautosales.org_September2020.json.gz',
#  'Product_paperandtea.com_September2020.json.gz',
#  'CreativeWork_ankiros.com_September2020.json.gz',
#  'MusicRecording_dadboddmusic.com_September2020.json.gz',
#  'Product_walkieon.com_September2020.json.gz',
#  'MusicRecording_whitenoisemusic.co.uk_September2020.json.gz',
#  'Product_ottena.co.uk_September2020.json.gz',
#  'Person_videochatex.net_September2020.json.gz',
#  'Product_wkbwholesale.com_September2020.json.gz',
#  'MusicRecording_yoursongmysong.com_September2020.json.gz',
#  'MusicRecording_the-snow-owl.com_September2020.json.gz',
#  'Event_raginrandyentertainment.com_September2020.json.gz',
#  'MusicRecording_cindysleemusic.com_September2020.json.gz',
#  'Product_belleandbee.co.uk_September2020.json.gz',
#  'Product_houseofwatches.co.uk_September2020.json.gz',
#  'MusicRecording_joelstrauss.com_September2020.json.gz',
#  'Recipe_moinkbox.com_September2020.json.gz',
#  'Person_branchburgfuneralhome.com_September2020.json.gz',
#  'Product_hampromos.com_September2020.json.gz',
#  'Product_herb-oil.com_September2020.json.gz',
#  'Product_saatchiart.com_September2020.json.gz',
#  'Product_bluenty.com_September2020.json.gz',
#  'Event_silvereaglegroup.com_September2020.json.gz',
#  'Product_mikemillerkia.com_September2020.json.gz',
#  'Person_na-mcta.com_September2020.json.gz',
#  'Event_hope-foundation.org.uk_September2020.json.gz',
#  'LocalBusiness_rate.com_September2020.json.gz',
#  'Product_taktaibrand.com_September2020.json.gz',
#  'Person_wallerfuneralhome.com_September2020.json.gz',
#  'Book_buyprobolan50.co.uk_September2020.json.gz',
#  'Product_omhealthcart.com_September2020.json.gz',
#  'Product_clemsontigers.com_September2020.json.gz',
#  'Product_wirmax.net_September2020.json.gz',
#  'CreativeWork_djneilarmstrong.com_September2020.json.gz',
#  'MusicRecording_wiltonsaid.com_September2020.json.gz',
#  'Product_colesauto.net_September2020.json.gz',
#  'Product_booko.com.au_September2020.json.gz',
#  'Product_backpacksusa.com_September2020.json.gz',
#  'Product_usab.com_September2020.json.gz',
#  'Event_anandayogaretreatsibiza.com_September2020.json.gz',
#  'Product_almaherbal.com_September2020.json.gz',
#  'Product_eyeofhoruscosmetics.com_September2020.json.gz',
#  'Place_makemytrip.com_September2020.json.gz',
#  'MusicRecording_talltimbermedicineshow.com_September2020.json.gz',
#  'Recipe_avenuemarkets.com_September2020.json.gz',
#  'Person_bristolbearsrugby.com_September2020.json.gz',
#  'Person_caringcremations.com_September2020.json.gz',
#  'Product_thecatball.com_September2020.json.gz',
#  'Product_bigprostore.com_September2020.json.gz',
#  'Product_kanbancrafts.com_September2020.json.gz',
#  'Book_stephensdrivingschool.co.uk_September2020.json.gz',
#  'Product_lyxcsfx.com_September2020.json.gz',
#  'Product_cpap.com_September2020.json.gz',
#  'Product_shenyunshop.com_September2020.json.gz',
#  'MusicRecording_audiojoadproductions.com_September2020.json.gz',
#  'Product_rqcsupply.com_September2020.json.gz',
#  'Product_ottostackleworld.com.au_September2020.json.gz',
#  'LocalBusiness_partyrentalsbeverlyhills.com_September2020.json.gz',
#  'Product_iso-chauffe.com_September2020.json.gz',
#  'MusicRecording_mp3jaja.com_September2020.json.gz',
#  'MusicRecording_phoenixstreetnews.com_September2020.json.gz',
#  'Product_lex-hesse.com_September2020.json.gz',
#  'MusicRecording_wildaster.com_September2020.json.gz',
#  'CreativeWork_wuileng.org.my_September2020.json.gz',
#  'Product_kettlefreaks.com_September2020.json.gz',
#  'Product_premierppesupply.com_September2020.json.gz',
#  'Recipe_badtothebowl.com_September2020.json.gz',
#  'Recipe_therawchef.com_September2020.json.gz',
#  'Event_racethread.com_September2020.json.gz',
#  'Person_teenswallow.org_September2020.json.gz',
#  'Product_eminent.com_September2020.json.gz',
#  'Product_mackley.com_September2020.json.gz',
#  'Product_anayachannellecosmetics.com_September2020.json.gz',
#  'Product_le-tre.com_September2020.json.gz',
#  'Product_filmartgallery.com_September2020.json.gz',
#  'Place_fearlesspresentations.com_September2020.json.gz',
#  'LocalBusiness_dicksoncountychamber.com_September2020.json.gz',
#  'Recipe_truebites.co.uk_September2020.json.gz',
#  'Person_mlb.com_September2020.json.gz',
#  'Product_shopwaa.com_September2020.json.gz',
#  'Person_impactcomics.com.au_September2020.json.gz',
#  'Product_itplanet.com_September2020.json.gz',
#  'Person_nationalmortgagenews.com_September2020.json.gz',
#  'Recipe_balancedgrub.com_September2020.json.gz',
#  'Product_daxxholding.com_September2020.json.gz',
#  'Product_lexusofmemphis.com_September2020.json.gz',
#  'Book_livres-medicaux.com_September2020.json.gz',
#  'CreativeWork_mecanicasgr.com_September2020.json.gz',
#  'Product_cadenshae.co.uk_September2020.json.gz',
#  'Person_ign.com.cn_September2020.json.gz',
#  'MusicRecording_themispent.com_September2020.json.gz',
#  'Product_essenceofthailand.com_September2020.json.gz',
#  'Product_drumsonsale.com_September2020.json.gz',
#  'MusicRecording_hearjohnny.com_September2020.json.gz',
#  'Product_prostitutki-love.com_September2020.json.gz',
#  'Product_bulkapparel.com_September2020.json.gz',
#  'Product_piecesmoto.net_September2020.json.gz',
#  'LocalBusiness_superprof.co.uk_September2020.json.gz',
#  'Person_arnoldskeys.com_September2020.json.gz',
#  'MusicRecording_jefftynan.com_September2020.json.gz',
#  'CreativeWork_velocitymusicacademy.com_September2020.json.gz',
#  'Product_myanmarkt.com_September2020.json.gz',
#  'Product_mamajewels.co.uk_September2020.json.gz',
#  'MusicRecording_chrisjentsch.com_September2020.json.gz',
#  'Product_ricambicarburatori.com_September2020.json.gz',
#  'Recipe_greenhealthycooking.com_September2020.json.gz',
#  'Event_pawlingfreelibrary.org_September2020.json.gz',
#  'Product_lovepopcards.com_September2020.json.gz',
#  'Product_hollowbonerecords.com_September2020.json.gz',
#  'Product_lafranceenaction.com_September2020.json.gz',
#  'Recipe_thecardswedrew.com_September2020.json.gz',
#  'Product_miyacosmetics.com_September2020.json.gz',
#  'MusicRecording_alicehowe.com_September2020.json.gz',
#  'Product_gotosmokeshop.com_September2020.json.gz',
#  'Product_akinsford.com_September2020.json.gz',
#  'LocalBusiness_tctmagazine.com_September2020.json.gz',
#  'MusicRecording_leslietommusic.com_September2020.json.gz',
#  'Product_syrite.com_September2020.json.gz',
#  'Product_newmotorssubaru.com_September2020.json.gz',
#  'CreativeWork_greensquarecenter.com_September2020.json.gz',
#  'Product_tonimalloni-shop.com_September2020.json.gz',
#  'Person_ecocanterbury.org.nz_September2020.json.gz',
#  'Event_codercollege.com.au_September2020.json.gz',
#  'Product_grizzlyriversports.com_September2020.json.gz',
#  'LocalBusiness_gorynych-plast.com_September2020.json.gz',
#  'Product_force4.co.uk_September2020.json.gz',
#  'Product_arcenciel-maison-jardin.com_September2020.json.gz',
#  'Product_emirkozmetik.net_September2020.json.gz',
#  'Product_pricewhack.com_September2020.json.gz',
#  'Person_derby.ac.uk_September2020.json.gz',
#  'MusicRecording_kristinchambers.com_September2020.json.gz',
#  'Product_deanimeydemanga.com_September2020.json.gz',
#  'Product_getastra.com_September2020.json.gz',
#  'Product_armadillomusic.com_September2020.json.gz',
#  'Product_universodabola.com.br_September2020.json.gz',
#  'LocalBusiness_uplinemoving.com_September2020.json.gz',
#  'Recipe_bevcooks.com_September2020.json.gz',
#  'LocalBusiness_naijastolencars.com_September2020.json.gz',
#  'MusicRecording_mandrrush.com_September2020.json.gz',
#  'Person_networthlist.org_September2020.json.gz',
#  'Product_inegolmobilyadukkani.com_September2020.json.gz',
#  'Recipe_feedthemwisely.com_September2020.json.gz',
#  'Recipe_livingsweetmoments.com_September2020.json.gz',
#  'Event_avaa.com.au_September2020.json.gz',
#  'CreativeWork_hitsa.com.au_September2020.json.gz',
#  'Product_urban-street-shop.com_September2020.json.gz',
#  'MusicRecording_luminaaband.com_September2020.json.gz',
#  'LocalBusiness_aussiebusinesssales.com.au_September2020.json.gz',
#  'Event_wotfa.org_September2020.json.gz',
#  'Person_gigisplayhouse.org_September2020.json.gz',
#  'Recipe_andiswines.com_September2020.json.gz',
#  'Event_gugcstudentguild.com.au_September2020.json.gz',
#  'MusicRecording_steveandruth.com_September2020.json.gz',
#  'Event_downtownlosaltos.org_September2020.json.gz',
#  'Event_calvaryev.org_September2020.json.gz',
#  'Person_thetimesrussia.com_September2020.json.gz',
#  'Product_toolex.com_September2020.json.gz',
#  'Product_tante-ines.com_September2020.json.gz',
#  'Person_yatco.com_September2020.json.gz',
#  'MusicRecording_katiefrassinelli.com_September2020.json.gz',
#  'MusicRecording_zitapetrak.com_September2020.json.gz',
#  'Product_techboxs.org_September2020.json.gz',
#  'Product_idealmotors112.com_September2020.json.gz',
#  'Product_tyres-online.com.ng_September2020.json.gz',
#  'CreativeWork_arhiv-beograda.org_September2020.json.gz',
#  'Event_klsonline.org_September2020.json.gz',
#  'LocalBusiness_uppervalleybusinessalliance.com_September2020.json.gz',
#  'Product_stiiizy.org_September2020.json.gz',
#  'CreativeWork_moblesfarres.com_September2020.json.gz',
#  'MusicRecording_morellamusic.com_September2020.json.gz',
#  'Product_smarthomeshop.org_September2020.json.gz',
#  'Event_thegamingstadium.com_September2020.json.gz',
#  'Recipe_diydougherty.com_September2020.json.gz',
#  'Recipe_hot-thai-kitchen.com_September2020.json.gz',
#  'CreativeWork_poehcenter.org_September2020.json.gz',
#  'CreativeWork_forteforums.com_September2020.json.gz',
#  'CreativeWork_experimentsinopera.com_September2020.json.gz',
#  'Product_njtoysandcollectibles.com_September2020.json.gz',
#  'Person_crimejusticejournal.com_September2020.json.gz',
#  'Event_visitkearney.org_September2020.json.gz',
#  'LocalBusiness_kebenaran.com_September2020.json.gz',
#  'Product_licht365.com_September2020.json.gz',
#  'CreativeWork_oxmansafety.com_September2020.json.gz',
#  'MusicRecording_davidtolk.com_September2020.json.gz',
#  'Product_cyclestore.co.uk_September2020.json.gz',
#  'MusicRecording_roliepolieguacamole.com_September2020.json.gz',
#  'Product_cartwrightfitness.co.uk_September2020.json.gz',
#  'Event_foltzpottery.com_September2020.json.gz',
#  'Product_isaelite.com.au_September2020.json.gz',
#  'Event_hollywoodnow.org_September2020.json.gz',
#  'Event_pranicbeauty.com_September2020.json.gz',
#  'MusicRecording_4thandmainmusic.com_September2020.json.gz',
#  'Product_oec-fl.com_September2020.json.gz',
#  'Product_nowlighting.com_September2020.json.gz',
#  'MusicRecording_serumn.com_September2020.json.gz',
#  'CreativeWork_epicureansb.com_September2020.json.gz',
#  'Product_your-cuckoo-clock.com_September2020.json.gz',
#  'LocalBusiness_halfords.com_September2020.json.gz',
#  'MusicRecording_intheglowingtwilight.com_September2020.json.gz',
#  'Product_biancapopp.com_September2020.json.gz',
#  'MusicRecording_aoifescott.com_September2020.json.gz',
#  'CreativeWork_postscapes.com_September2020.json.gz',
#  'CreativeWork_homeportpress.com_September2020.json.gz',
#  'Recipe_culturedtable.com_September2020.json.gz',
#  'LocalBusiness_cylex.net.za_September2020.json.gz',
#  'Product_bluemercury.com_September2020.json.gz',
#  'Product_qualitysubaru.com_September2020.json.gz',
#  'Event_nvbia.com_September2020.json.gz',
#  'MusicRecording_lundenreign.com_September2020.json.gz',
#  'Recipe_juliaschild.com_September2020.json.gz',
#  'Product_urbanprofile.com_September2020.json.gz',
#  'Person_checkphonecaller.com_September2020.json.gz',
#  'Recipe_slimmingtoday.co.uk_September2020.json.gz',
#  'MusicRecording_rioconbrio.net_September2020.json.gz',
#  'LocalBusiness_columbiachamber.com_September2020.json.gz',
#  'MusicRecording_grandshoresmusic.com_September2020.json.gz',
#  'Product_workweardiscounts.com.au_September2020.json.gz',
#  'Hotel_seaclub.com_September2020.json.gz',
#  'LocalBusiness_smkazoo.com_September2020.json.gz',
#  'Person_bikermatch.co.uk_September2020.json.gz',
#  'Product_machineryassociates.com_September2020.json.gz',
#  'Product_brandscovery.com_September2020.json.gz',
#  'Product_mindwellrescue.com_September2020.json.gz',
#  'Product_fullsendfpv.com_September2020.json.gz',
#  'Event_burlingtoncountrydancers.org_September2020.json.gz',
#  'Recipe_thecarefreekitchen.com_September2020.json.gz',
#  'Product_motoreasy.com_September2020.json.gz',
#  'Event_wearetheobserver.com_September2020.json.gz',
#  'Person_jckirbyandson.com_September2020.json.gz',
#  'Product_ledlightstore.org_September2020.json.gz',
#  'Product_bahraingreetings.com_September2020.json.gz',
#  'Product_remelectriconline.com_September2020.json.gz',
#  'Product_atlas-scientific.com_September2020.json.gz',
#  'Hotel_eveniahotels.com_September2020.json.gz',
#  'Product_zoccas.com_September2020.json.gz',
#  'Person_rcherz.com_September2020.json.gz',
#  'Recipe_nodietsallowed.com_September2020.json.gz',
#  'Recipe_ricette.com_September2020.json.gz',
#  'Person_reminger.com_September2020.json.gz',
#  'Product_thebloomfieldfarms.com_September2020.json.gz',
#  'Product_diversitechdowndraft.com_September2020.json.gz',
#  'MusicRecording_yvonneperea.com_September2020.json.gz',
#  'MusicRecording_evanmurdock.com_September2020.json.gz',
#  'Restaurant_greeka.com_September2020.json.gz',
#  'Product_southchapelhill.com_September2020.json.gz',
#  'Product_pikibuy.com_September2020.json.gz',
#  'Product_iyisarap.net_September2020.json.gz',
#  'Event_hyannis.com_September2020.json.gz',
#  'Product_plattsburghcreativesigns.com_September2020.json.gz',
#  'LocalBusiness_dogobedienceandtraining.com_September2020.json.gz',
#  'Product_ledlightingnet.com_September2020.json.gz',
#  'Product_joomlaux.com_September2020.json.gz',
#  'Product_soapavenuecompany.com_September2020.json.gz',
#  'MusicRecording_jimhudak.com_September2020.json.gz',
#  'MusicRecording_davidgillis.com_September2020.json.gz',
#  'Event_kmc.org.uk_September2020.json.gz',
#  'Person_cascadehealth.org_September2020.json.gz',
#  'MusicRecording_edonothegaijin.com_September2020.json.gz',
#  'Product_alionlinestore.com_September2020.json.gz',
#  'LocalBusiness_artphotostudio.com.br_September2020.json.gz',
#  'Person_moriclaudio.com_September2020.json.gz',
#  'Event_kayakbassfishing.com_September2020.json.gz',
#  'MusicRecording_konstantinemargaritis.com_September2020.json.gz',
#  'Event_counteveryonein.org.uk_September2020.json.gz',
#  'MusicRecording_robredeemed.net_September2020.json.gz',
#  'Book_pandora-ring.org.uk_September2020.json.gz',
#  'Product_astrograph.net_September2020.json.gz',
#  'CreativeWork_le-serpent-retrogamer.org_September2020.json.gz',
#  'Product_wrooom.net_September2020.json.gz',
#  'Recipe_flairprojectsb.com_September2020.json.gz',
#  'Product_wickedmetal.com_September2020.json.gz',
#  'Product_flowers4santo-domingo.com_September2020.json.gz',
#  'Person_clubcorp.com_September2020.json.gz',
#  'Event_europeanproducersclub.org_September2020.json.gz',
#  'Product_popiblack.com_September2020.json.gz',
#  'Event_palmbeachchamber.com_September2020.json.gz',
#  'MusicRecording_willpreyer.com_September2020.json.gz',
#  'Product_industrialairpower.com_September2020.json.gz',
#  'Person_maggardfuneralhomes.com_September2020.json.gz',
#  'Person_muirbrotherslapeer.com_September2020.json.gz',
#  'Person_carlislebranson.com_September2020.json.gz',
#  'Product_alfredetcompagnie.com_September2020.json.gz',
#  'MusicRecording_barrymusic.com_September2020.json.gz',
#  'MusicRecording_abbypayne.com_September2020.json.gz',
#  'LocalBusiness_hewittchamber.com_September2020.json.gz',
#  'MusicRecording_grewsum.com_September2020.json.gz',
#  'Recipe_oaklandjobs.co.uk_September2020.json.gz',
#  'Product_jeaken.com_September2020.json.gz',
#  'Product_realrecyclers.com_September2020.json.gz',
#  'Product_bullionbypost.co.uk_September2020.json.gz',
#  'Hotel_visitmode.com_September2020.json.gz',
#  'MusicRecording_jamesdoreworld.com_September2020.json.gz',
#  'Person_hustlerslesbians.com_September2020.json.gz',
#  'MusicRecording_patrickjoseph.com_September2020.json.gz',
#  'Product_tempattidurjepara.com_September2020.json.gz',
#  'Product_tressagifts.com_September2020.json.gz',
#  'MusicRecording_belzarbeats.com_September2020.json.gz',
#  'TVEpisode_sonicretro.org_September2020.json.gz',
#  'MusicRecording_gregharpermusic.com_September2020.json.gz',
#  'MusicRecording_shyspeaks.com_September2020.json.gz',
#  'CreativeWork_0en-hp.com_September2020.json.gz',
#  'Product_lojakallucci.com.br_September2020.json.gz',
#  'Product_joimachine.com_September2020.json.gz',
#  'Product_cottontraders.com_September2020.json.gz',
#  'Event_jamiebgall.co.uk_September2020.json.gz',
#  'Product_funftesrad.com_September2020.json.gz',
#  'Product_wantdo.com_September2020.json.gz',
#  'Product_greengoldstore.com_September2020.json.gz',
#  'Product_babygloo.com_September2020.json.gz',
#  'Product_morley-tyres.co.uk_September2020.json.gz',
#  'MusicRecording_scottkinseymusic.com_September2020.json.gz',
#  'Event_npleadershipfv.org_September2020.json.gz',
#  'Recipe_homejobsbymom.com_September2020.json.gz',
#  'Place_kyivmaps.com_September2020.json.gz',
#  'Event_dccj.org_September2020.json.gz',
#  'MusicRecording_sherylclapton.com_September2020.json.gz',
#  'CreativeWork_mushroomdiary.co.uk_September2020.json.gz',
#  'Person_pinkney-smithfuneralhome.com_September2020.json.gz',
#  'CreativeWork_csnlg.com_September2020.json.gz',
#  'Product_griffinmall.com_September2020.json.gz',
#  'Recipe_nestlebabyandme.com.mx_September2020.json.gz',
#  'Event_angasplainswines.com.au_September2020.json.gz',
#  'Product_woovina.com_September2020.json.gz',
#  'MusicRecording_ricopabon.com_September2020.json.gz',
#  'Product_mitchellstores.com_September2020.json.gz',
#  'Event_dovernh.org_September2020.json.gz',
#  'LocalBusiness_laroofing-services.com_September2020.json.gz',
#  'Product_themancompany.com_September2020.json.gz',
#  'Person_gabelliconnect.com_September2020.json.gz',
#  'Product_bullarduniformsonline.com_September2020.json.gz',
#  'Product_kirksvilletoyota.com_September2020.json.gz',
#  'Recipe_eatingevolved.com_September2020.json.gz',
#  'MusicRecording_rinkbeats.com_September2020.json.gz',
#  'Recipe_recipecommunity.co.uk_September2020.json.gz',
#  'Event_centerforhealthandhealingnj.com_September2020.json.gz',
#  'CreativeWork_tmpprinting.com_September2020.json.gz',
#  'Product_kempfuneralhome.com_September2020.json.gz',
#  'Product_cardermotors.com_September2020.json.gz',
#  'Recipe_realcajunrecipes.com_September2020.json.gz',
#  'MusicRecording_owenhowell.com_September2020.json.gz',
#  'Recipe_myloveofbaking.com_September2020.json.gz',
#  'Person_denvertherapymatch.com_September2020.json.gz',
#  'Product_510sales.com_September2020.json.gz',
#  'Product_ashantijewels.com_September2020.json.gz',
#  'Product_pallkris.com_September2020.json.gz',
#  'LocalBusiness_trueeye.com_September2020.json.gz',
#  'Person_graveslibrary.org_September2020.json.gz',
#  'MusicRecording_alisonreynoldsmusic.com_September2020.json.gz',
#  'Recipe_vegpapa.com_September2020.json.gz',
#  'Product_cassette.com.tr_September2020.json.gz',
#  'MusicRecording_bunkyhunt.net_September2020.json.gz',
#  'Product_nissanofyorktownheights.com_September2020.json.gz',
#  'Product_vermeulenfh.com_September2020.json.gz',
#  'MusicRecording_thisisqueen.com_September2020.json.gz',
#  'Product_mynamebadges.com_September2020.json.gz',
#  'Product_anciranissansa.com_September2020.json.gz',
#  'Product_aidasuniforms.com_September2020.json.gz',
#  'CreativeWork_inmunotek.com_September2020.json.gz',
#  'Product_crestock.com_September2020.json.gz',
#  'Product_hobbyperline.com_September2020.json.gz',
#  'Product_woodyknows.com_September2020.json.gz',
#  'Product_centuryfp.com_September2020.json.gz',
#  'Product_lambiek.net_September2020.json.gz',
#  'Product_clearh2otackle.com_September2020.json.gz',
#  'Event_nistraining.com_September2020.json.gz',
#  'Product_smartusedphones.com_September2020.json.gz',
#  'Person_mql5.com_September2020.json.gz',
#  'Person_neighborschools.com_September2020.json.gz',
#  'Product_topstringlacrosse.com_September2020.json.gz',
#  'Product_knitting-yarns.co.uk_September2020.json.gz',
#  'CreativeWork_tapetafootings.com_September2020.json.gz',
#  'CreativeWork_eviat.com_September2020.json.gz',
#  'Product_hopkinslawver.com_September2020.json.gz',
#  'Product_outwithaudrey.com.au_September2020.json.gz',
#  'Event_optimusinfo.com_September2020.json.gz',
#  'MusicRecording_bryanandersonmusic.com_September2020.json.gz',
#  'MusicRecording_dalvarezprod.com_September2020.json.gz',
#  'Product_dbs-impressions.com_September2020.json.gz',
#  'Event_trustbluereview.com_September2020.json.gz',
#  'Product_thewatchbox.com_September2020.json.gz',
#  'CreativeWork_emersonflowsolutions.com_September2020.json.gz',
#  'Product_pulpoproducts.com_September2020.json.gz',
#  'Product_chantangda.net_September2020.json.gz',
#  'Recipe_letstacoboutitblog.com_September2020.json.gz',
#  'MusicRecording_ritahosking.com_September2020.json.gz',
#  'Product_toucheairbrush.com_September2020.json.gz',
#  'Hotel_fredericksburgtexas-online.com_September2020.json.gz',
#  'Person_frsa.org.au_September2020.json.gz',
#  'CreativeWork_rudr1ven.com_September2020.json.gz',
#  'Book_passarellaweb.com_September2020.json.gz',
#  'Product_oralsurgeonokc.com_September2020.json.gz',
#  'MusicRecording_jeffness711.com_September2020.json.gz',
#  'Product_waukeganfunerals.com_September2020.json.gz',
#  'Product_likigram.com_September2020.json.gz',
#  'Product_michaels.com_September2020.json.gz',
#  'Person_artebooking.com_September2020.json.gz',
#  'Product_swedencar.com_September2020.json.gz',
#  'Recipe_injennieskitchen.com_September2020.json.gz',
#  'Person_ecs.org_September2020.json.gz',
#  'Product_replacement-mattress.com_September2020.json.gz',
#  'Product_bohofairy.com_September2020.json.gz',
#  'CreativeWork_heritagebrands.com.au_September2020.json.gz',
#  'Place_twhbea.com_September2020.json.gz',
#  'Event_region9hsa.org_September2020.json.gz',
#  'Product_viascreens.com_September2020.json.gz',
#  'Recipe_onehotoven.com_September2020.json.gz',
#  'Product_eczemahoneyco.com_September2020.json.gz',
#  'Product_chillhoodies.com_September2020.json.gz',
#  'MusicRecording_rudeyna.com_September2020.json.gz',
#  'Product_cheapestfactoryparts.com_September2020.json.gz',
#  'Product_billaud-segeba.com_September2020.json.gz',
#  'CreativeWork_1000rr.net_September2020.json.gz',
#  'Place_friendlyaussiebuds.com_September2020.json.gz',
#  'Product_newfanglednetworks.com_September2020.json.gz',
#  'Product_indianauto.com_September2020.json.gz',
#  'MusicRecording_davidkowal.com_September2020.json.gz',
#  'MusicRecording_jimmycarpenter.net_September2020.json.gz',
#  'Event_samag.org_September2020.json.gz',
#  'LocalBusiness_assured-samedaycouriers.com_September2020.json.gz',
#  'MusicRecording_richkrueger.com_September2020.json.gz',
#  'Product_allyourtools.com_September2020.json.gz',
#  'Event_brooklinebooksmith-shop.com_September2020.json.gz',
#  'LocalBusiness_baltimoreappliancerepair.com_September2020.json.gz',
#  'Product_godoggiestyle.com_September2020.json.gz',
#  'Product_1coinmaster.com_September2020.json.gz',
#  'CreativeWork_calindian.org_September2020.json.gz',
#  'Recipe_pipandebby.com_September2020.json.gz',
#  'Product_adkinsfamilyrv.com_September2020.json.gz',
#  'Event_greytownrailtrail.org.nz_September2020.json.gz',
#  'Event_rodaleinstitute.org_September2020.json.gz',
#  'Person_laubenthalmercado.com_September2020.json.gz',
#  'Product_delraybuickgmc.com_September2020.json.gz',
#  'Product_iontopia.co.uk_September2020.json.gz',
#  'Person_bisnow.com_September2020.json.gz',
#  'Product_lovetheocean.net_September2020.json.gz',
#  'Product_breakingbadshop.com_September2020.json.gz',
#  'Recipe_hatfieldqualitymeats.com_September2020.json.gz',
#  'MusicRecording_yvonnej.com_September2020.json.gz',
#  'CreativeWork_luckslist.com_September2020.json.gz',
#  'Product_discountdealsusa.com_September2020.json.gz',
#  'CreativeWork_supportstfrancishospital.org_September2020.json.gz',
#  'Product_quirkkia.com_September2020.json.gz',
#  'Product_ascentfootwear.com.au_September2020.json.gz',
#  'MusicRecording_fredchandlermusic.com_September2020.json.gz',
#  'MusicRecording_unknowablesoundrecordings.com_September2020.json.gz',
#  'Product_powertoolsonlinecorp.com_September2020.json.gz',
#  'Event_celestiallodge.org_September2020.json.gz',
#  'MusicRecording_ghosttownhangmen.com_September2020.json.gz',
#  'CreativeWork_biggsuccess.com_September2020.json.gz',
#  'Place_nationwidetitle.net_September2020.json.gz',
#  'Product_homestatebbq.com_September2020.json.gz',
#  'Product_thepaperstone.com_September2020.json.gz',
#  'CreativeWork_topweddinggarden.com_September2020.json.gz',
#  'Recipe_immaeatthat.com_September2020.json.gz',
#  'MusicRecording_kathrynjonesmusic.com.au_September2020.json.gz',
#  'Product_jumporange.com_September2020.json.gz',
#  'Product_followalice.com_September2020.json.gz',
#  'MusicRecording_georgiewonders.com_September2020.json.gz',
#  'Product_fredorch.com.cn_September2020.json.gz',
#  'LocalBusiness_translationinbirmingham.co.uk_September2020.json.gz',
#  'Product_coragempratudo.com.br_September2020.json.gz',
#  'Hotel_planetofhotels.com_September2020.json.gz',
#  ...]

# %%
print(len(large_files_train))
# Out:
# 44435

# %%
#table_id = 'Product_kingmemorialpark.com_September2020.json.gz'
df = pd.read_json(os.path.join(path + 'Small/Train/Product_kingmemorialpark.com_September2020.json.gz'), compression='gzip', lines=True)

# %%
file = 'Product_kingmemorialpark.com_September2020.json.gz'
category , file = file.split('_', 1)
print(category)
# Out:
# Product

# %%
df #test for one table
# Out:
#     row_id                          name  \
# 0        0     Heavenly Sentiments Spray
# 1        1  Peaceful White Lilies Basket
# 2        2          Full Of Love Bouquet
# 3        3  Sentiments of Serenity Spray
# 4        4       Strength & Solace Spray
# ..     ...                           ...
# 78      78    Pet Loss and Human Emotion
# 79      79   Reflections of Glory Wreath
# 80      80     Angel Wind Chime - Silver
# 81      81        Grieving Beyond Gender
# 82      82         Country Basket Blooms
#
#                                                offers  \
# 0   {'pricecurrency': 'USD', 'lowprice': '202.95',...
# 1   {'pricecurrency': 'USD', 'price': '89.95', 'av...
# 2   {'pricecurrency': 'USD', 'price': '49.95', 'av...
# 3   {'pricecurrency': 'USD', 'price': '139.95', 'a...
# 4   {'pricecurrency': 'USD', 'price': '119.95', 'a...
# ..                                                ...
# 78  {'pricecurrency': 'USD', 'lowprice': '34.95', ...
# 79  {'pricecurrency': 'USD', 'highprice': '212.95'...
# 80  {'pricecurrency': 'USD', 'lowprice': '69.95', ...
# 81  {'pricecurrency': 'USD', 'highprice': '39.95',...
# 82  {'pricecurrency': 'USD', 'lowprice': '67.95', ...
#
#                                                   url  \
# 0   https://www.kingmemorialpark.com/store/standin...
# 1   https://www.kingmemorialpark.com/store/best-se...
# 2   https://www.kingmemorialpark.com/store/best-se...
# 3   https://www.kingmemorialpark.com/store/best-se...
# 4   https://www.kingmemorialpark.com/store/best-se...
# ..                                                ...
# 78  https://www.kingmemorialpark.com/store/pet-los...
# 79  https://www.kingmemorialpark.com/store/wreaths...
# 80  https://www.kingmemorialpark.com/store/pre-ins...
# 81  https://www.kingmemorialpark.com/store/grief-b...
# 82  https://www.kingmemorialpark.com/store/baskets...
#
#                                                 image  \
# 0   https://res.cloudinary.com/picasso/image/uploa...
# 1   https://res.cloudinary.com/picasso/image/uploa...
# 2   https://res.cloudinary.com/picasso/image/uploa...
# 3   https://res.cloudinary.com/picasso/image/uploa...
# 4   https://res.cloudinary.com/picasso/image/uploa...
# ..                                                ...
# 78  https://res.cloudinary.com/picasso/image/uploa...
# 79  https://res.cloudinary.com/picasso/image/uploa...
# 80  https://res.cloudinary.com/picasso/image/uploa...
# 81  https://res.cloudinary.com/picasso/image/uploa...
# 82  https://res.cloudinary.com/picasso/image/uploa...
#
#                                   aggregaterating  productid  \
# 0     {'reviewcount': '4', 'ratingvalue': '5.00'}       1394
# 1   {'reviewcount': '250', 'ratingvalue': '4.93'}       1442
# 2   {'reviewcount': '122', 'ratingvalue': '4.98'}       4358
# 3   {'ratingvalue': '4.96', 'reviewcount': '181'}       2989
# 4   {'reviewcount': '115', 'ratingvalue': '4.90'}       2988
# ..                                            ...        ...
# 78                                           None        754
# 79    {'reviewcount': '4', 'ratingvalue': '5.00'}       1470
# 80                                           None        950
# 81                                           None        757
# 82  {'reviewcount': '145', 'ratingvalue': '4.97'}       4357
#
#                                                review itemcondition  \
# 0   [{'author': 'from -', 'description': 'Arrangem...  NewCondition
# 1                                                None  NewCondition
# 2                                                None  NewCondition
# 3                                                None  NewCondition
# 4                                                None  NewCondition
# ..                                                ...           ...
# 78                                               None  NewCondition
# 79  [{'description': 'A beautiful wreath as seen o...  NewCondition
# 80                                               None  NewCondition
# 81                                               None  NewCondition
# 82  [{'name': 'Country Basket Blooms', 'descriptio...  NewCondition
#
#                                                 model  \
# 0   {'sku': 'T247-2A', 'name': 'Heavenly Sentiment...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 78  {'sku': '9780415955768', 'image': 'https://res...
# 79  {'url': 'https://www.kingmemorialpark.com/stor...
# 80  [{'image': 'https://res.cloudinary.com/picasso...
# 81  {'name': 'Grieving Beyond Gender (Standard)', ...
# 82  [{'name': 'Country Basket Blooms (Standard)', ...
#
#                                              page_url
# 0   https://www.kingmemorialpark.com/store/deliver...
# 1   https://www.kingmemorialpark.com/store/?icn=ex...
# 2   https://www.kingmemorialpark.com/store/?icn=ex...
# 3   https://www.kingmemorialpark.com/store/?icn=ex...
# 4   https://www.kingmemorialpark.com/store/?icn=ex...
# ..                                                ...
# 78  https://www.kingmemorialpark.com/store/grief-b...
# 79  https://www.kingmemorialpark.com/store/funeral...
# 80  https://www.kingmemorialpark.com/store/garden-...
# 81  https://www.kingmemorialpark.com/store/grief-b...
# 82  https://www.kingmemorialpark.com/store/best-se...
#
# [83 rows x 11 columns]

# %%
list(df.columns)
# Out:
# ['row_id',
#  'name',
#  'offers',
#  'url',
#  'image',
#  'aggregaterating',
#  'productid',
#  'review',
#  'itemcondition',
#  'model',
#  'page_url']

# %%
col_types = [] # create empty list for col types
file = 'Product_kingmemorialpark.com_September2020.json.gz'
category , file = file.split('_', 1) #get category for file
for element in list(df.columns): #iterate over headers in tables
    col_types = [category + '.' + element for element in list(df.columns)] #append category to header for col type annotation
col_types
# Out:
# ['Product.row_id',
#  'Product.name',
#  'Product.offers',
#  'Product.url',
#  'Product.image',
#  'Product.aggregaterating',
#  'Product.productid',
#  'Product.review',
#  'Product.itemcondition',
#  'Product.model',
#  'Product.page_url']

# %%
#df_test = [list(df.columns)]

# %%
#df_test
# Out:
# [['row_id',
#   'name',
#   'offers',
#   'url',
#   'image',
#   'aggregaterating',
#   'productid',
#   'review',
#   'itemcondition',
#   'model',
#   'page_url']]

# %%
# test cell representation for one table
#df_test = df
#cell_representation=[] # cell representation of first row
#i = 0
#for col in df.columns:
    cell_representation.append([[int(i),int(0)],[df_test['row_id'][0],str(df_test[col][0])]])
    i = i+1

# %%
#test cell representations
#cell_representation
# Out:
# [[[0, 0], [0, '0']],
#  [[1, 0], [0, 'Heavenly Sentiments Spray']],
#  [[2, 0],
#   [0,
#    "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#  [[3, 0],
#   [0,
#    'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#  [[4, 0],
#   [0,
#    'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#  [[5, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#  [[6, 0], [0, '1394']],
#  [[7, 0],
#   [0,
#    '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#  [[8, 0], [0, 'NewCondition']],
#  [[9, 0],
#   [0,
#    "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#  [[10, 0],
#   [0,
#    'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]]

# %%
#test entire table representation for one table
#table_representation = [] #empty list for table
#table_representation.append(table_id)#append table id

# %%
#all_rows_representation = []#representation of all rows
#j = 0
#for i in range(len(df_test)):
#    row_representation=[] # cell representation of single row
#    for col in df.columns:
#        row_representation.append([[int(j),int(0)],[df_test['row_id'][0],str(df_test[col][0])]])
#        j = j+1
#    #row_representation.append([[int(0),int(i)],[df_testing['row_id'][i],str(df_testing['name'][i])]])
#    #row_representation.append([[int(1),int(i)],[df_testing['row_id'][i],str(df_testing['description'][i])]])
#    all_rows_representation.append(row_representation) #append single cell representation to representation of all rows
#table_representation.append(all_rows_representation)#append it to representation of whole table

# %%
#table_representation
# Out:
# ['Product_kingmemorialpark.com_September2020.json.gz',
#  [[[[0, 0], [0, '0']],
#    [[1, 0], [0, 'Heavenly Sentiments Spray']],
#    [[2, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[3, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[4, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[5, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[6, 0], [0, '1394']],
#    [[7, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[8, 0], [0, 'NewCondition']],
#    [[9, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[10, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[11, 0], [0, '0']],
#    [[12, 0], [0, 'Heavenly Sentiments Spray']],
#    [[13, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[14, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[15, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[16, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[17, 0], [0, '1394']],
#    [[18, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[19, 0], [0, 'NewCondition']],
#    [[20, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[21, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[22, 0], [0, '0']],
#    [[23, 0], [0, 'Heavenly Sentiments Spray']],
#    [[24, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[25, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[26, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[27, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[28, 0], [0, '1394']],
#    [[29, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[30, 0], [0, 'NewCondition']],
#    [[31, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[32, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[33, 0], [0, '0']],
#    [[34, 0], [0, 'Heavenly Sentiments Spray']],
#    [[35, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[36, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[37, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[38, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[39, 0], [0, '1394']],
#    [[40, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[41, 0], [0, 'NewCondition']],
#    [[42, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[43, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[44, 0], [0, '0']],
#    [[45, 0], [0, 'Heavenly Sentiments Spray']],
#    [[46, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[47, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[48, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[49, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[50, 0], [0, '1394']],
#    [[51, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[52, 0], [0, 'NewCondition']],
#    [[53, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[54, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[55, 0], [0, '0']],
#    [[56, 0], [0, 'Heavenly Sentiments Spray']],
#    [[57, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[58, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[59, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[60, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[61, 0], [0, '1394']],
#    [[62, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[63, 0], [0, 'NewCondition']],
#    [[64, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[65, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[66, 0], [0, '0']],
#    [[67, 0], [0, 'Heavenly Sentiments Spray']],
#    [[68, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[69, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[70, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[71, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[72, 0], [0, '1394']],
#    [[73, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[74, 0], [0, 'NewCondition']],
#    [[75, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[76, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[77, 0], [0, '0']],
#    [[78, 0], [0, 'Heavenly Sentiments Spray']],
#    [[79, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[80, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[81, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[82, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[83, 0], [0, '1394']],
#    [[84, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[85, 0], [0, 'NewCondition']],
#    [[86, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[87, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[88, 0], [0, '0']],
#    [[89, 0], [0, 'Heavenly Sentiments Spray']],
#    [[90, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[91, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[92, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[93, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[94, 0], [0, '1394']],
#    [[95, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[96, 0], [0, 'NewCondition']],
#    [[97, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[98, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[99, 0], [0, '0']],
#    [[100, 0], [0, 'Heavenly Sentiments Spray']],
#    [[101, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[102, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[103, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[104, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[105, 0], [0, '1394']],
#    [[106, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[107, 0], [0, 'NewCondition']],
#    [[108, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[109, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[110, 0], [0, '0']],
#    [[111, 0], [0, 'Heavenly Sentiments Spray']],
#    [[112, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[113, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[114, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[115, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[116, 0], [0, '1394']],
#    [[117, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[118, 0], [0, 'NewCondition']],
#    [[119, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[120, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[121, 0], [0, '0']],
#    [[122, 0], [0, 'Heavenly Sentiments Spray']],
#    [[123, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[124, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[125, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[126, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[127, 0], [0, '1394']],
#    [[128, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[129, 0], [0, 'NewCondition']],
#    [[130, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[131, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[132, 0], [0, '0']],
#    [[133, 0], [0, 'Heavenly Sentiments Spray']],
#    [[134, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[135, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[136, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[137, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[138, 0], [0, '1394']],
#    [[139, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[140, 0], [0, 'NewCondition']],
#    [[141, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[142, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[143, 0], [0, '0']],
#    [[144, 0], [0, 'Heavenly Sentiments Spray']],
#    [[145, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[146, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[147, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[148, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[149, 0], [0, '1394']],
#    [[150, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[151, 0], [0, 'NewCondition']],
#    [[152, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[153, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[154, 0], [0, '0']],
#    [[155, 0], [0, 'Heavenly Sentiments Spray']],
#    [[156, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[157, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[158, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[159, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[160, 0], [0, '1394']],
#    [[161, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[162, 0], [0, 'NewCondition']],
#    [[163, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[164, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[165, 0], [0, '0']],
#    [[166, 0], [0, 'Heavenly Sentiments Spray']],
#    [[167, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[168, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[169, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[170, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[171, 0], [0, '1394']],
#    [[172, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[173, 0], [0, 'NewCondition']],
#    [[174, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[175, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[176, 0], [0, '0']],
#    [[177, 0], [0, 'Heavenly Sentiments Spray']],
#    [[178, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[179, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[180, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[181, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[182, 0], [0, '1394']],
#    [[183, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[184, 0], [0, 'NewCondition']],
#    [[185, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[186, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[187, 0], [0, '0']],
#    [[188, 0], [0, 'Heavenly Sentiments Spray']],
#    [[189, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[190, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[191, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[192, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[193, 0], [0, '1394']],
#    [[194, 0],
#     [0,
# ...
#    [[855, 0], [0, 'NewCondition']],
#    [[856, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[857, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[858, 0], [0, '0']],
#    [[859, 0], [0, 'Heavenly Sentiments Spray']],
#    [[860, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[861, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[862, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[863, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[864, 0], [0, '1394']],
#    [[865, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[866, 0], [0, 'NewCondition']],
#    [[867, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[868, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[869, 0], [0, '0']],
#    [[870, 0], [0, 'Heavenly Sentiments Spray']],
#    [[871, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[872, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[873, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[874, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[875, 0], [0, '1394']],
#    [[876, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[877, 0], [0, 'NewCondition']],
#    [[878, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[879, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[880, 0], [0, '0']],
#    [[881, 0], [0, 'Heavenly Sentiments Spray']],
#    [[882, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[883, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[884, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[885, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[886, 0], [0, '1394']],
#    [[887, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[888, 0], [0, 'NewCondition']],
#    [[889, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[890, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[891, 0], [0, '0']],
#    [[892, 0], [0, 'Heavenly Sentiments Spray']],
#    [[893, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[894, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[895, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[896, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[897, 0], [0, '1394']],
#    [[898, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[899, 0], [0, 'NewCondition']],
#    [[900, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[901, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]],
#   [[[902, 0], [0, '0']],
#    [[903, 0], [0, 'Heavenly Sentiments Spray']],
#    [[904, 0],
#     [0,
#      "{'pricecurrency': 'USD', 'lowprice': '202.95', 'highprice': '202.95'}"]],
#    [[905, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray']],
#    [[906, 0],
#     [0,
#      'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg']],
#    [[907, 0], [0, "{'reviewcount': '4', 'ratingvalue': '5.00'}"]],
#    [[908, 0], [0, '1394']],
#    [[909, 0],
#     [0,
#      '[{\'author\': \'from -\', \'description\': \'Arrangement was made beautifully... I was completely satisfied...I truly recommend this service and the flowers. Very Nice Job! Thank you!\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'6/19/2019\'}, {\'author\': \'from -\', \'datepublished\': \'7/29/2019\', \'name\': \'Heavenly Sentiments Spray\', \'description\': "I ordered the Heavenly Sentiments Spray around 1pm for a same-day delivery. However, I received an email shortly after ordering saying the florist couldn\'t deliver for same-day. I called the customer service team, and together we were able to find a different florist that make a custom spray (they didn\'t have orchids) that was perfect, looked twice as big, and really made a statement for the family. I really appreciate the service team going out of their way to call and find a different florist that understood our needs and found a creative way to meet them."}, {\'datepublished\': \'12/5/2019\', \'description\': \'I purchased a spary for the anut of my boss after re viewing a photo online. The cusotmer service was excellent. I recieved several notifications of the arrangement and went sent. After the family viewing, my boss contacted me and stated it was the largest most beautiful arrangement there. I live in NC and am very happy that I received such wonderful service and a beautiful arrangement from this far away. I wish you had a store closer to me. Thank you\', \'name\': \'Heavenly Sentiments Spray\', \'author\': \'from Carthage - North Carolina\'}, {\'author\': \'from -\', \'description\': \'It looked even prettier in person than in the picture.\', \'name\': \'Heavenly Sentiments Spray\', \'datepublished\': \'1/25/2019\'}]']],
#    [[910, 0], [0, 'NewCondition']],
#    [[911, 0],
#     [0,
#      "{'sku': 'T247-2A', 'name': 'Heavenly Sentiments Spray (Standard)', 'url': 'https://www.kingmemorialpark.com/store/standing-sprays/heavenly-sentiments-spray', 'image': 'https://res.cloudinary.com/picasso/image/upload/c_lpad,f_jpg,fl_progressive,h_300,q_auto,w_300/tr6abs1s5y3oazvpsmfe.jpg'}"]],
#    [[912, 0],
#     [0,
#      'https://www.kingmemorialpark.com/store/delivery-location/heavenly-sentiments-spray']]]]]

# %%
#get all tables in Small/Medium/Large-Train, append into a repective series and get an entire list of all small training representations
#get all test tables, append into a repective series and get an entire list of all small test representations

count = 0
j = 0
#rain_representation=[] #representation of whole training set
test_representation=[] #representation of whole test set
with progressbar.ProgressBar(max_value=len(test_files)) as bar:
    #inputdir = '../../../src/data/schemafiltereddata/TrainTestTables/Small/Train/'
    #inputdir = '../../../src/data/schemafiltereddata/TrainTestTables/Medium/Train/'
    #inputdir = '../../../src/data/schemafiltereddata/TrainTestTables/Large/Train/'
    inputdir = '../../../src/data/schemafiltereddata/TrainTestTables/Test/'
    files = [file for file in os.listdir(inputdir) if file.endswith('.json.gz')]  
    for file in files:
    #for file in small_files_train:
        #print('/{}'.format(file))
        df = pd.read_json(os.path.join(inputdir, '{}'.format(file)), compression='gzip', lines=True)
        #if('description' in df.columns)== False: # check if description column given
        #    df['description'] = ''
        #if ('name' in df.columns)== False: # check if description column given
        #    df['name'] = x = df.page_url.apply(lambda x: x.split("/")[4])
        #df['header']=''#empty string for headers
        table_representation = [] #empty list for table
        table_representation.append(file)#append filename table id
        table_representation.append('')#append page title -> not relevant
        table_representation.append('')#append wikipedia page id -> not given
        category , file = file.split('_', 1) #get category for file
        table_representation.append(category)#append information about entity/section title 
        table_representation.append('')#append table caption -> not given
        table_representation.append(list(df.columns)) #append headers
        cells_representation = []#representation of all rows
        for i in range(len(df)):
            cell_representation=[] # cell representation of single row
            for col in df.columns: #get column content for each column
                cell_representation.append([[int(j),int(i)],[df['row_id'][i],str(df[col][i])]])
                j += 1
            cells_representation.append(cell_representation) #append single cell representation to representation of all rows
        table_representation.append(cells_representation)#append it to representation of whole table
        col_types = [] # create empty list for col types
        category , file = file.split('_', 1) #get category for file
        for element in list(df.columns): #iterate over headers in tables
            col_types = [category + '.' + element for element in list(df.columns)] #append category to header for col type annotation
        table_representation.append(col_types) #append col type annotation 
        #train_representation.append(table_representation)
        test_representation.append(table_representation)
        count += 1
        bar.update(count)
# Out:
# 100% (8912 of 8912) |####################| Elapsed Time: 1:20:08 Time:  1:20:08

# %%
turl_path = path = '../../../src/data/schemafiltereddata/TURL/input/'
with open(os.path.join(turl_path, 'small_train_representation.txt'), 'w') as f:
    for item in train_representation:
        f.write("%s\n" % item)

# %%
turl_path = path = '../../../src/data/schemafiltereddata/TURL/input/'
with open(os.path.join(turl_path, 'test_representation.txt'), 'w') as f:
    for item in test_representation:
        f.write("%s\n" % item)

# %%
#train_representation
#train_file = open("train_representation.txt", "w")
#for element in train_representation:
#    train_file.write(element + "\n")
#train_file.close()
turl_path = path = '../../../src/data/schemafiltereddata/TURL/input_old'

# write small train representation to txt
#with open(os.path.join(turl_path, 'small_train_representation.txt'), "wb") as fp:  #Pickling - write list to txt file
#    pickle.dump(train_representation, fp)

# write medium train representation to txt
#with open(os.path.join(turl_path, 'medium_train_representation.txt'), "wb") as fp:  #Pickling - write list to txt file
#    pickle.dump(train_representation, fp)

# write test representation to txt
with open(os.path.join(turl_path, 'test_representation.txt'), "wb") as fp:  #Pickling - write list to txt file
    pickle.dump(test_representation, fp)

# %%
with open(os.path.join(turl_path, 'medium_train_representation.txt'), "rb") as fp:   # Unpickling
    train_representation = pickle.load(fp)

# %%
path = '/work-ceph/bizer-tp2021/data_integration_using_deep_learning/src/data/data/CSV_files'
tables = pd.read_csv(path + '/all_files_cleaned.csv')
tables = tables.drop(columns={'Unnamed: 0'})
target_columns = tables.groupby('filename')['column_name'].apply(list).reset_index(name='listofcolumns')
target_columns.filename = target_columns.filename.str.split('_', expand = True)
target_columns.index = target_columns['filename']
target_columns
# Out:
#                       filename  \
# filename
# Book                      Book
# CreativeWork      CreativeWork
# Event                    Event
# Hotel                    Hotel
# LocalBusiness    LocalBusiness
# MusicAlbum          MusicAlbum
# MusicRecording  MusicRecording
# Person                  Person
# Place                    Place
# Product                Product
# Recipe                  Recipe
# Restaurant          Restaurant
# TVEpisode            TVEpisode
#
#                                                     listofcolumns
# filename
# Book            [name, author, isbn, publisher, offers, datepu...
# CreativeWork    [headline, author, datepublished, datemodified...
# Event           [name, enddate, location, performer, organizer...
# Hotel           [name, address, telephone, pricerange, geo, ag...
# LocalBusiness   [name, address, telephone, geo, pricerange, ag...
# MusicAlbum                     [name, byartist, track, numtracks]
# MusicRecording  [name, duration, byartist, inalbum, datepublis...
# Person          [mainentityofpage, jobtitle, birthdate, givenn...
# Place           [name, geo, telephone, sameas, openinghoursspe...
# Product         [name, offers, brand, aggregaterating, mpn, ca...
# Recipe          [name, recipeinstructions, author, recipeyield...
# Restaurant      [name, address, telephone, servescuisine, geo,...
# TVEpisode                     [name, partofseries, episodenumber]

# %%
target_columns = target_columns.explode('listofcolumns')
target_columns
# Out:
#               filename  listofcolumns
# filename
# Book              Book           name
# Book              Book         author
# Book              Book           isbn
# Book              Book      publisher
# Book              Book         offers
# ...                ...            ...
# Restaurant  Restaurant   openinghours
# Restaurant  Restaurant           menu
# TVEpisode    TVEpisode           name
# TVEpisode    TVEpisode   partofseries
# TVEpisode    TVEpisode  episodenumber
#
# [207 rows x 2 columns]

# %%
#create list of target columns types for type_vocab.txt file

target_type = [] # create emplyt list for target col types
for row in target_columns.itertuples(): # iterate over each rows in target_columns df
    target_type.append(row.filename + '.' + row.listofcolumns)
target_type
# Out:
# ['Book.name',
#  'Book.author',
#  'Book.isbn',
#  'Book.publisher',
#  'Book.offers',
#  'Book.datepublished',
#  'Book.numberofpages',
#  'Book.bookformat',
#  'Book.inlanguage',
#  'Book.genre',
#  'Book.aggregaterating',
#  'Book.bookedition',
#  'CreativeWork.headline',
#  'CreativeWork.author',
#  'CreativeWork.datepublished',
#  'CreativeWork.datemodified',
#  'CreativeWork.name',
#  'CreativeWork.publisher',
#  'CreativeWork.mainentityofpage',
#  'CreativeWork.interactionstatistic',
#  'CreativeWork.datecreated',
#  'CreativeWork.alternativeheadline',
#  'CreativeWork.keywords',
#  'CreativeWork.articlebody',
#  'CreativeWork.aggregaterating',
#  'CreativeWork.interactioncount',
#  'CreativeWork.inlanguage',
#  'CreativeWork.commentcount',
#  'CreativeWork.interactiontype',
#  'CreativeWork.creator',
#  'CreativeWork.genre',
#  'CreativeWork.version',
#  'CreativeWork.offers',
#  'CreativeWork.copyrightholder',
#  'CreativeWork.copyrightyear',
#  'Event.name',
#  'Event.enddate',
#  'Event.location',
#  'Event.performer',
#  'Event.organizer',
#  'Event.eventstatus',
#  'Event.eventattendancemode',
#  'Event.duration',
#  'Event.doortime',
#  'Event.typicalagerange',
#  'Event.performers',
#  'Hotel.name',
#  'Hotel.address',
#  'Hotel.telephone',
#  'Hotel.pricerange',
#  'Hotel.geo',
#  'Hotel.aggregaterating',
#  'Hotel.starrating',
#  'Hotel.email',
#  'LocalBusiness.name',
#  'LocalBusiness.address',
#  'LocalBusiness.telephone',
#  'LocalBusiness.geo',
#  'LocalBusiness.pricerange',
#  'LocalBusiness.aggregaterating',
#  'LocalBusiness.email',
#  'LocalBusiness.sameas',
#  'LocalBusiness.faxnumber',
#  'LocalBusiness.openinghours',
#  'LocalBusiness.openinghoursspecification',
#  'LocalBusiness.review',
#  'LocalBusiness.contactpoint',
#  'LocalBusiness.legalname',
#  'LocalBusiness.areaserved',
#  'LocalBusiness.location',
#  'LocalBusiness.addresslocality',
#  'LocalBusiness.addressregion',
#  'LocalBusiness.streetaddress',
#  'LocalBusiness.postalcode',
#  'LocalBusiness.paymentaccepted',
#  'LocalBusiness.founder',
#  'LocalBusiness.citystatezip',
#  'LocalBusiness.owns',
#  'LocalBusiness.hasmap',
#  'MusicAlbum.name',
#  'MusicAlbum.byartist',
#  'MusicAlbum.track',
#  'MusicAlbum.numtracks',
#  'MusicRecording.name',
#  'MusicRecording.duration',
#  'MusicRecording.byartist',
#  'MusicRecording.inalbum',
#  'MusicRecording.datepublished',
#  'MusicRecording.genre',
#  'MusicRecording.datecreated',
#  'Person.mainentityofpage',
#  'Person.jobtitle',
#  'Person.birthdate',
#  'Person.givenname',
#  'Person.familyname',
#  'Person.telephone',
#  'Person.email',
#  'Person.deathdate',
#  'Person.additionalname',
#  'Person.gender',
#  'Person.worksfor',
#  'Person.height',
#  'Person.address',
#  'Person.nationality',
#  'Person.weight',
#  'Person.affiliation',
#  'Person.homelocation',
#  'Person.knowslanguage',
#  'Person.makesoffer',
#  'Person.sameas',
#  'Person.birthplace',
#  'Person.memberof',
#  'Person.faxnumber',
#  'Person.worklocation',
#  'Person.contactpoint',
#  'Place.name',
#  'Place.geo',
#  'Place.telephone',
#  'Place.sameas',
#  'Place.openinghoursspecification',
#  'Product.name',
#  'Product.offers',
#  'Product.brand',
#  'Product.aggregaterating',
#  'Product.mpn',
#  'Product.category',
#  'Product.review',
#  'Product.manufacturer',
#  'Product.itemcondition',
#  'Product.model',
#  'Product.weight',
#  'Product.price',
#  'Product.gtin13',
#  'Product.releasedate',
#  'Product.color',
#  'Product.mainentityofpage',
#  'Product.isrelatedto',
#  'Product.gtin12',
#  'Product.pricecurrency',
#  'Product.width',
#  'Product.height',
#  'Product.additionalproperty',
#  'Product.depth',
#  'Product.gtin8',
#  'Product.gtin',
#  'Product.identifier',
#  'Product.availability',
#  'Product.gtin14',
#  'Product.shop-currency',
#  'Product.reviewcount',
#  'Product.ratingvalue',
#  'Product.issimilarto',
#  'Product.itemlistelement',
#  'Product.bestrating',
#  'Product.condition',
#  'Product.worstrating',
#  'Product.alternatename',
#  'Product.audience',
#  'Product.breadcrumb',
#  'Product.material',
#  'Product.disambiguatingdescription',
#  'Product.title',
#  'Product.address',
#  'Product.author',
#  'Product.offerdetails',
#  'Product.reviews',
#  'Product.geo',
#  'Product.datepublished',
#  'Recipe.name',
#  'Recipe.recipeinstructions',
#  'Recipe.author',
#  'Recipe.recipeyield',
#  'Recipe.recipeingredient',
#  'Recipe.preptime',
#  'Recipe.cooktime',
#  'Recipe.datepublished',
#  'Recipe.totaltime',
#  'Recipe.recipecategory',
#  'Recipe.recipecuisine',
#  'Recipe.aggregaterating',
#  'Recipe.keywords',
#  'Recipe.nutrition',
#  'Recipe.mainentityofpage',
#  'Recipe.ispartof',
#  'Recipe.ingredients',
#  'Recipe.performtime',
#  'Recipe.cookingmethod',
#  'Recipe.review',
#  'Recipe.suitablefordiet',
#  'Recipe.datemodified',
#  'Recipe.publisher',
#  'Recipe.headline',
#  'Restaurant.name',
#  'Restaurant.address',
#  'Restaurant.telephone',
#  'Restaurant.servescuisine',
#  'Restaurant.geo',
#  'Restaurant.pricerange',
#  'Restaurant.aggregaterating',
#  'Restaurant.hasmenu',
#  'Restaurant.acceptsreservations',
#  'Restaurant.openinghoursspecification',
#  'Restaurant.openinghours',
#  'Restaurant.menu',
#  'TVEpisode.name',
#  'TVEpisode.partofseries',
#  'TVEpisode.episodenumber']

# %%
#create df with index of target_types
type_df = pd.DataFrame(target_type)
type_df
# Out:
#                            0
# 0                  Book.name
# 1                Book.author
# 2                  Book.isbn
# 3             Book.publisher
# 4                Book.offers
# ..                       ...
# 202  Restaurant.openinghours
# 203          Restaurant.menu
# 204           TVEpisode.name
# 205   TVEpisode.partofseries
# 206  TVEpisode.episodenumber
#
# [207 rows x 1 columns]

# %%
#save target types to type_vocab.txt
turl_path = path = '../../../src/data/schemafiltereddata/TURL/input/'
pd.DataFrame(type_df).to_csv(path_or_buf=os.path.join(turl_path, 'type_vocab.txt'),sep='\t', index=True, header=False)

# %%
# write tagret col types to txt
with open(os.path.join(turl_path, 'type_vocab.txt'), "wb") as fp:  #Pickling - write list to txt file
    pickle.dump(target_type, fp)
